# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.font_manager import FontProperties
import numpy as np

# %%
font_path = os.path.join("..", "kaiu.ttf")
myfont=FontProperties(fname= font_path, size=14)
sns.set(font=myfont.get_name())

plt.rcParams['figure.figsize'] = (10,5)

# %%
csv_path = os.path.join("..", "data","TSR_CMUH", "CASEDRFUR(denormalized).csv")
cdr = pd.read_csv(csv_path)
cdr.head()
# Out:
#    ICASE_ID       IDCASE_ID  FSTATUS_ID_1   RFUR_DT_1  LOCATION_ID_1  \
# 0     11903  024-00011903-1           1.0   2012/6/11            1.0
# 1     74000  022-00074000-1           1.0   2012/11/7            4.0
# 2     73069  022-00073069-1           1.0  2012/10/23            1.0
# 3     13014  025-00013014-1           1.0   2012/6/19            1.0
# 4     74752  022-00074752-1           1.0   2012/11/8            4.0
#
#   TORG_ID_1  FLU_ID_1 FLUORG_ID_1 FLUORG_TX_1 FLURESULT_TX_1  ... VERS_DT_12  \
# 0         O       1.0          24         NaN            NaN  ...   1900/1/1
# 1         O       1.0          22         NaN            NaN  ...        NaN
# 2         O       1.0          22         NaN            NaN  ...        NaN
# 3         O       1.0          25         NaN            NaN  ...   1900/1/1
# 4         O       1.0          22         NaN            NaN  ...        NaN
#
#    VERSORG_ID_12  VEIHD_FL_12 VEIHD_ID_12 VEIHD_DT_12 VEIHDORG_ID_12  \
# 0              O            N         NaN    1900/1/1              O
# 1            NaN          NaN         NaN         NaN            NaN
# 2            NaN          NaN         NaN         NaN            NaN
# 3              O            N         NaN    1900/1/1              O
# 4            NaN          NaN         NaN         NaN            NaN
#
#   MRS_TX_12 TORG_TX_12 VERSORG_TX_12 VEIHDORG_TX_12
# 0         2        NaN           NaN            NaN
# 1       NaN        NaN           NaN            NaN
# 2       NaN        NaN           NaN            NaN
# 3         1        NaN           NaN            NaN
# 4       NaN        NaN           NaN            NaN
#
# [5 rows x 102 columns]

# %%
cdr.describe()
# Out:
#             ICASE_ID  FSTATUS_ID_1  LOCATION_ID_1     FLU_ID_1   DEATH_ID_1  \
# count    7189.000000   6930.000000    6858.000000  5795.000000  4670.000000
# mean    40549.720684      0.997835       2.228055     1.057808     2.994433
# std     32845.014210      0.046477       1.506261     0.386525     0.103334
# min        65.000000      0.000000       1.000000     1.000000     1.000000
# 25%     29880.000000      1.000000       1.000000     1.000000     3.000000
# 50%     31573.000000      1.000000       1.000000     1.000000     3.000000
# 75%     33337.000000      1.000000       4.000000     1.000000     3.000000
# max    138354.000000      1.000000       6.000000     6.000000     3.000000
#
#        DEATHSK_ID_1      MRS_TX_1  FSTATUS_ID_3  LOCATION_ID_3     FLU_ID_3  \
# count     69.000000   6778.000000   5095.000000    4958.000000  4647.000000
# mean       0.260870     69.280171      0.998037       1.566962     1.131052
# std        0.610019   2142.368499      0.044263       1.275874     0.577075
# min        0.000000      0.000000      0.000000       1.000000     1.000000
# 25%        0.000000      1.000000      1.000000       1.000000     1.000000
# 50%        0.000000      3.000000      1.000000       1.000000     1.000000
# 75%        0.000000      4.000000      1.000000       1.000000     1.000000
# max        2.000000  91690.000000      1.000000       6.000000     6.000000
#
#        ...  LOCATION_ID_6     FLU_ID_6   DEATH_ID_6  DEATHSK_ID_6  \
# count  ...    4429.000000  4286.000000  3896.000000     58.000000
# mean   ...       1.333258     1.154690     2.998460      0.068966
# std    ...       1.008558     0.602686     0.050646      0.368118
# min    ...       1.000000     1.000000     1.000000      0.000000
# 25%    ...       1.000000     1.000000     3.000000      0.000000
# 50%    ...       1.000000     1.000000     3.000000      0.000000
# 75%    ...       1.000000     1.000000     3.000000      0.000000
# max    ...       6.000000     6.000000     3.000000      2.000000
#
#        FSTATUS_ID_12  LOCATION_ID_12    FLU_ID_12  DEATH_ID_12  DEATHSK_ID_12  \
# count    3538.000000     3264.000000  3462.000000  2804.000000      27.000000
# mean        0.999435        1.190870     1.261121     2.996790       0.222222
# std         0.023772        0.773862     0.684147     0.077811       0.640513
# min         0.000000        1.000000     1.000000     1.000000       0.000000
# 25%         1.000000        1.000000     1.000000     3.000000       0.000000
# 50%         1.000000        1.000000     1.000000     3.000000       0.000000
# 75%         1.000000        1.000000     1.000000     3.000000       0.000000
# max         1.000000        6.000000     6.000000     3.000000       2.000000
#
#        VEIHDORG_TX_12
# count             4.0
# mean           7438.5
# std           14875.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%            7438.5
# max           29751.0
#
# [8 rows x 23 columns]

# %% [markdown]
# # FSTATUS_ID_1

# %%
fstatus_id_1 = cdr.loc[:,"FSTATUS_ID_1"]
#print(fstatus_id_1)
print(fstatus_id_1.value_counts() / len(fstatus_id_1))
#print(fstatus_id_1.describe())

sns.countplot(fstatus_id_1)
plt.title("FSTATUS_ID_1 - Barplot")
plt.xlabel('FSTATUS_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.961886
# 0.0    0.002087
# Name: FSTATUS_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 日期_1

# %%
rfur_dt_1 = cdr.loc[:,"RFUR_DT_1"]
rfur_dt_1 = pd.to_datetime(rfur_dt_1, errors='coerce')
rfur_dt_1[(rfur_dt_1.dt.year < 2006) | (rfur_dt_1.dt.year > 2021)] = np.nan
#print(rfur_dt_1)
#print(rfur_dt_1.value_counts() / len(rfur_dt_1))
print(rfur_dt_1.describe())

rfur_dt_1.value_counts().plot()
plt.title("RFUR_DT_1 - Lineplot")
plt.xlabel('RFUR_DT_1')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                    6928
# unique                   2352
# top       2007-03-07 00:00:00
# freq                       47
# first     2006-08-26 00:00:00
# last      2019-07-02 00:00:00
# Name: RFUR_DT_1, dtype: object
# <ipython-input-6-a0b615ab65dd>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(rfur_dt_1.describe())

# %% [markdown]
# # 所在地_1

# %%
location_id_1 = cdr.loc[:,"LOCATION_ID_1"]
#print(location_id_1)
print(location_id_1.value_counts() / len(location_id_1))
#print(location_id_1.describe())

location_id_1_labels = ["住家","護理之家","呼吸病房","本院住院中","轉至其他院","失聯"]
sns.countplot(location_id_1).set_xticklabels(location_id_1_labels)
plt.title("LOCATION_ID_1 - Barplot")
plt.xlabel('LOCATION_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.551398
# 4.0    0.286827
# 5.0    0.047155
# 3.0    0.041591
# 2.0    0.023925
# 6.0    0.003060
# Name: LOCATION_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 轉至醫院_1

# %%
torg_id_1 = cdr.loc[:,"TORG_ID_1"]
#print(torg_id_1)
print(torg_id_1.value_counts() / len(torg_id_1))
#print(torg_id_1.describe())

sns.countplot(torg_id_1)
plt.title("TORG_ID_1 - Barplot")
plt.xlabel('TORG_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.890249
# 22    0.009459
# 41    0.002782
# 21    0.002226
# 26    0.001391
# 24    0.001113
# 61    0.000696
# 30    0.000278
# 25    0.000278
# 38    0.000139
# 13    0.000139
# 1     0.000139
# 29    0.000139
# 27    0.000139
# Name: TORG_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 相關醫療紀錄_1

# %%
flu_id_1 = cdr.loc[:,"FLU_ID_1"]
#print(flu_id_1)
print(flu_id_1.value_counts() / len(flu_id_1))
#print(flu_id_1.describe())

#flu_id_1_labels = ["本院或他院門診繼續服藥","拒回診","死亡"]
sns.countplot(flu_id_1)#.set_xticklabels(flu_id_1_labels)
plt.title("FLU_ID_1 - Barplot")
plt.xlabel('FLU_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.784532
# 3.0    0.008763
# 2.0    0.005981
# 4.0    0.005286
# 6.0    0.001113
# 5.0    0.000417
# Name: FLU_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 門診醫院_1

# %%
fluorg_id_1 = cdr.loc[:,"FLUORG_ID_1"]
#print(fluorg_id_1)
print(fluorg_id_1.value_counts() / len(fluorg_id_1))
#print(fluorg_id_1.describe())

sns.countplot(fluorg_id_1)
plt.title("FLUORG_ID_1 - Barplot")
plt.xlabel('FLUORG_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.677007
# 22    0.247183
# 21    0.006260
# 25    0.005703
# 24    0.004590
# 41    0.002921
# 26    0.001808
# 1     0.000974
# 23    0.000835
# 29    0.000835
# 61    0.000835
# 28    0.000696
# 32    0.000417
# 2     0.000417
# 27    0.000417
# 7     0.000417
# 33    0.000278
# 38    0.000278
# 34    0.000278
# 30    0.000278
# 12    0.000139
# 36    0.000139
# 46    0.000139
# 13    0.000139
# 45    0.000139
# 57    0.000139
# 5     0.000139
# 35    0.000139
# 15    0.000139
# 53    0.000139
# Name: FLUORG_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# FLUORG_TX_1

# %% [raw]
# FLURESULT_TX_1

# %% [markdown]
# # 死亡日期_1

# %%
death_dt_1 = cdr.loc[:,'DEATH_DT_1']
death_dt_1 = pd.to_datetime(death_dt_1, errors='coerce')
death_dt_1[(death_dt_1.dt.year < 2006) | (death_dt_1.dt.year > 2021)] = np.nan
#print(death_dt_1)
#print(death_dt_1.value_counts() / len(death_dt_1))
print(death_dt_1.describe())

death_dt_1.value_counts().plot()
plt.title("DEATH_DT_1 - Lineplot")
plt.xlabel('DEATH_DT_1')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                      63
# unique                     60
# top       2019-02-24 00:00:00
# freq                        2
# first     2006-10-02 00:00:00
# last      2019-04-13 00:00:00
# Name: DEATH_DT_1, dtype: object
# <ipython-input-11-4ba0193a174f>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(death_dt_1.describe())

# %% [markdown]
# # 死因_1

# %%
death_id_1 = cdr.loc[:,'DEATH_ID_1']
#print(death_id_1)
print(death_id_1.value_counts() / len(death_id_1))
#print(death_id_1.describe())

death_id_1_labels = ["因中風而死亡","因心臟疾病而死亡","其他"]
sns.countplot(death_id_1).set_xticklabels(death_id_1_labels)
plt.title("DEATH_ID_1 - Barplot")
plt.xlabel('DEATH_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 3.0    0.647656
# 1.0    0.001669
# 2.0    0.000278
# Name: DEATH_ID_1, dtype: float64

# %% [markdown]
# # 因中風而死亡(CI/CH)_1

# %%
deathsk_id_1 = cdr.loc[:,'DEATHSK_ID_1']
#print(deathsk_id_1)
print(deathsk_id_1.value_counts() / len(deathsk_id_1))
#print(deathsk_id_1.describe())

#deathsk_id_1_labels = ["CI", "CH"]
sns.countplot(deathsk_id_1)#.set_xticklabels(deathsk_id_1_labels)
plt.title("DEATHSK_ID_1 - Barplot")
plt.xlabel('DEATHSK_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.007929
# 1.0    0.000835
# 2.0    0.000835
# Name: DEATHSK_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# DEATHO_TX_1

# %% [markdown]
# # 相關醫療紀錄2_1

# %%
ve_id_1 = cdr.loc[:,'VE_ID_1']
#print(ve_id_1)
print(ve_id_1.value_counts() / len(ve_id_1))
#print(ve_id_1.describe())

sns.countplot(ve_id_1)
plt.title("VE_ID_1 - Barplot")
plt.xlabel('VE_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0    0.520796
# N    0.000278
# Name: VE_ID_1, dtype: float64

# %% [markdown]
# # 再中風_1

# %%
vers_fl_1 = cdr.loc[:,'VERS_FL_1']
#print(vers_fl_1)
print(vers_fl_1.value_counts() / len(vers_fl_1))
#print(vers_fl_1.describe())

sns.countplot(vers_fl_1)
plt.title("VERS_FL_1 - Barplot")
plt.xlabel('VERS_FL_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N           0.925720
# Y           0.022117
# 1900/1/1    0.013354
# Name: VERS_FL_1, dtype: float64

# %% [markdown]
# # 再中風 (CI / CH)_1

# %%
verscich_id_1 = cdr.loc[:,'VERSCICH_ID_1']
#print(verscich_id_1)
print(verscich_id_1.value_counts() / len(verscich_id_1))
#print(verscich_id_1.describe())

sns.countplot(verscich_id_1)
plt.title("VERSCICH_ID_1 - Barplot")
plt.xlabel('VERSCICH_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1           0.013493
# O           0.013354
# 2           0.001669
# 1900/1/1    0.000278
# Name: VERSCICH_ID_1, dtype: float64

# %% [markdown]
# # 再中風日期_1

# %%
vers_dt_1 = cdr.loc[:,'VERS_DT_1']
vers_dt_1 = pd.to_datetime(vers_dt_1, errors='coerce')
vers_dt_1[(vers_dt_1.dt.year < 2006) | (vers_dt_1.dt.year > 2021)] = np.nan
#print(vers_dt_1)
#print(vers_dt_1.value_counts() / len(vers_dt_1))
print(vers_dt_1.describe())

vers_dt_1.value_counts().plot()
plt.title("VERS_DT_1 - Lineplot")
plt.xlabel('VERS_DT_1')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                     202
# unique                    192
# top       2007-06-21 00:00:00
# freq                        3
# first     2006-10-27 00:00:00
# last      2019-02-24 00:00:00
# Name: VERS_DT_1, dtype: object
# <ipython-input-17-388a7c881c49>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(vers_dt_1.describe())

# %% [markdown]
# # 再中風醫院_1

# %%
versorg_id_1 = cdr.loc[:,'VERSORG_ID_1']
#print(versorg_id_1)
print(versorg_id_1.value_counts() / len(versorg_id_1))
#print(versorg_id_1.describe())

sns.countplot(versorg_id_1)
plt.title("VERSORG_ID_1 - Barplot")
plt.xlabel('VERSORG_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# O     0.880790
# 22    0.015997
# 2     0.000278
# N     0.000278
# 21    0.000278
# 38    0.000139
# 41    0.000139
# 25    0.000139
# 61    0.000139
# Name: VERSORG_ID_1, dtype: float64

# %% [markdown]
# # Ischemic Heart Disease_1

# %%
veihd_fl_1 = cdr.loc[:,'VEIHD_FL_1']
#print(veihd_fl_1)
print(veihd_fl_1.value_counts() / len(veihd_fl_1))
#print(veihd_fl_1.describe())

sns.countplot(veihd_fl_1)
plt.title("VEIHD_FL_1 - Barplot")
plt.xlabel('VEIHD_FL_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N           0.942273
# 1900/1/1    0.013354
# Y           0.000696
# Name: VEIHD_FL_1, dtype: float64

# %% [markdown]
# # Types of Ischemic Heart Disease_1

# %%
veihd_id_1 = cdr.loc[:,'VEIHD_ID_1']
#print(veihd_id_1)
print(veihd_id_1.value_counts() / len(veihd_id_1))
#print(veihd_id_1.describe())

#veihd_id_1_labels = ["AMI","Angina"]
sns.countplot(veihd_id_1)#.set_xticklabels(veihd_id_1_labels)
plt.title("VEIHD_ID_1 - Barplot")
plt.xlabel('VEIHD_ID_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0           0.010850
# O           0.002504
# 1900/1/1    0.000278
# Name: VEIHD_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease日期_1

# %%
veihd_dt_1 = cdr.loc[:,'VEIHD_DT_1']
veihd_dt_1 = pd.to_datetime(veihd_dt_1, errors='coerce')
veihd_dt_1[(veihd_dt_1.dt.year < 2006) | (veihd_dt_1.dt.year > 2021)] = np.nan
#print(veihd_dt_1)
#print(veihd_dt_1.value_counts() / len(veihd_dt_1))
print(veihd_dt_1.describe())

veihd_dt_1.value_counts().plot()
plt.title("VEIHD_DT_1 - Lineplot")
plt.xlabel('VEIHD_DT_1')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-21-c6b662ffe2d6>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(veihd_dt_1.describe())
# count                       8
# unique                      8
# top       2009-05-16 00:00:00
# freq                        1
# first     2007-05-16 00:00:00
# last      2017-01-03 00:00:00
# Name: VEIHD_DT_1, dtype: object

# %% [markdown]
# # Ischemic Heart Disease醫院_1

# %%
veihdorg_id_1 = cdr.loc[:,'VEIHDORG_ID_1']
#print(veihdorg_id_1)
print(veihdorg_id_1.value_counts() / len(veihdorg_id_1))
#print(veihdorg_id_1.describe())

sns.countplot(veihdorg_id_1)
plt.title("VEIHDORG_ID_1 - Barplot")
plt.xlabel('VEIHDORG_ID_1')
plt.ylabel('Number', rotation=0)
plt.xticks(rotation = 90)
plt.show()
# Out:
# 0                                0.645570
# O                                0.247044
# ?��???                           0.000278
# ?��??�中總醫?�中清�???,","\n18855"    0.000139
# ?��?                             0.000139
# ?�中?�屯??,","\n19001"             0.000139
# 22                               0.000139
# 秀??,","\n12293"                  0.000139
# 竹山秀?�PAC                         0.000139
# ?�屯??,","\n15098"                0.000139
# 3                                0.000139
# 中�??�學??,","\n17958"             0.000139
# ?�屯??,","\n17867"                0.000139
# ?�東?�督?�PAC                      0.000139
# ?�屯?�院                           0.000139
# ?�中?��???,","\n15824"            0.000139
# 中�???,","\n103"                  0.000139
# 衛�??��??�醫??,","\n19587"         0.000139
# Name: VEIHDORG_ID_1, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # MRS_1

# %%
mrs_tx_1 = cdr.loc[:,'MRS_TX_1']
mrs_tx_1[(mrs_tx_1 < 0) | (mrs_tx_1 > 6)] = np.nan
#print(mrs_tx_1)
print(mrs_tx_1.value_counts() / len(mrs_tx_1))
#print(mrs_tx_1.describe())

sns.countplot(mrs_tx_1)
plt.title("MRS_TX_1 - Barplot")
plt.xlabel('MRS_TX_1')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 5.0    0.227013
# 4.0    0.208374
# 1.0    0.176520
# 2.0    0.129782
# 3.0    0.118375
# 0.0    0.077897
# 6.0    0.003617
# Name: MRS_TX_1, dtype: float64
# <ipython-input-23-c0233e220610>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs_tx_1[(mrs_tx_1 < 0) | (mrs_tx_1 > 6)] = np.nan
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# TORG_TX_1

# %% [raw]
# VERSORG_TX_1

# %% [raw]
# VEIHDORG_TX_1

# %% [markdown]
# # FSTATUS_ID_3

# %%
fstatus_id_3 = cdr.loc[:,"FSTATUS_ID_3"]
#print(fstatus_id_3)
print(fstatus_id_3.value_counts() / len(fstatus_id_3))
#print(fstatus_id_3.describe())

sns.countplot(fstatus_id_3)
plt.title("FSTATUS_ID_3 - Barplot")
plt.xlabel('FSTATUS_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.707331
# 0.0    0.001391
# Name: FSTATUS_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 日期_3

# %%
rfur_dt_3 = cdr.loc[:,"RFUR_DT_3"]
rfur_dt_3 = pd.to_datetime(rfur_dt_3, errors='coerce')
rfur_dt_3[(rfur_dt_3.dt.year < 2006) | (rfur_dt_3.dt.year > 2021)] = np.nan
#print(rfur_dt_3)
#print(rfur_dt_3.value_counts() / len(rfur_dt_3))
print(rfur_dt_3.describe())

rfur_dt_3.value_counts().plot()
plt.title("RFUR_DT_3 - Lineplot")
plt.xlabel('RFUR_DT_3')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-25-5404bf98ce59>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(rfur_dt_3.describe())
# count                    5095
# unique                   1459
# top       2007-03-23 00:00:00
# freq                       53
# first     2006-10-13 00:00:00
# last      2019-08-27 00:00:00
# Name: RFUR_DT_3, dtype: object

# %% [markdown]
# # 所在地_3

# %%
location_id_3 = cdr.loc[:,"LOCATION_ID_3"]
#print(location_id_3)
print(location_id_3.value_counts() / len(location_id_3))
#print(location_id_3.describe())

location_id_3_labels = ["住家","護理之家","呼吸病房","本院住院中","轉至其他院","失聯"]
sns.countplot(location_id_3).set_xticklabels(location_id_3_labels)
plt.title("LOCATION_ID_3 - Barplot")
plt.xlabel('LOCATION_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.554597
# 5.0    0.052302
# 4.0    0.035332
# 2.0    0.033245
# 3.0    0.009459
# 6.0    0.004729
# Name: LOCATION_ID_3, dtype: float64

# %% [markdown]
# # 轉至醫院_3

# %%
torg_id_3 = cdr.loc[:,"TORG_ID_3"]
#print(torg_id_3)
print(torg_id_3.value_counts() / len(torg_id_3))
#print(torg_id_3.describe())

sns.countplot(torg_id_3)
plt.title("TORG_ID_3 - Barplot")
plt.xlabel('TORG_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.685214
# 21    0.004173
# 22    0.003478
# 41    0.000696
# 24    0.000556
# 26    0.000556
# 44    0.000139
# Name: TORG_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 相關醫療紀錄_3

# %%
flu_id_3 = cdr.loc[:,"FLU_ID_3"]
#print(flu_id_3)
print(flu_id_3.value_counts() / len(flu_id_3))
#print(flu_id_3.describe())

#flu_id_3_labels = ["本院或他院門診繼續服藥","拒回診","死亡"]
sns.countplot(flu_id_3)#.set_xticklabels(flu_id_3_labels)
plt.title("FLU_ID_3 - Barplot")
plt.xlabel('FLU_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.603978
# 2.0    0.017527
# 3.0    0.015162
# 4.0    0.005564
# 6.0    0.003478
# 5.0    0.000696
# Name: FLU_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 門診醫院_3

# %%
fluorg_id_3 = cdr.loc[:,"FLUORG_ID_3"]
#print(fluorg_id_3)
print(fluorg_id_3.value_counts() / len(fluorg_id_3))
#print(fluorg_id_3.describe())

sns.countplot(fluorg_id_3)
plt.title("FLUORG_ID_3 - Barplot")
plt.xlabel('FLUORG_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.619836
# 22    0.064682
# 21    0.007790
# 25    0.004173
# 24    0.003756
# 41    0.001252
# 28    0.000974
# 26    0.000696
# 1     0.000556
# 29    0.000556
# 32    0.000417
# 27    0.000417
# 23    0.000417
# 33    0.000278
# 34    0.000278
# 7     0.000278
# 45    0.000139
# 12    0.000139
# 38    0.000139
# 30    0.000139
# 36    0.000139
# 2     0.000139
# 44    0.000139
# 61    0.000139
# Name: FLUORG_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# FLUORG_TX_3

# %% [raw]
# FLURESULT_TX_3

# %% [markdown]
# # 死亡日期_3

# %%
death_dt_3 = cdr.loc[:,'DEATH_DT_3']
death_dt_3 = pd.to_datetime(death_dt_3, errors='coerce')
death_dt_3[(death_dt_3.dt.year < 2006) | (death_dt_3.dt.year > 2021)] = np.nan
#print(death_dt_3)
print(death_dt_3.value_counts() / len(death_dt_3))
#print(death_dt_3.describe())

death_dt_3.value_counts().plot()
plt.title("DEATH_DT_3 - Lineplot")
plt.xlabel('DEATH_DT_3')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# 2008-10-18    0.000278
# 2007-11-07    0.000278
# 2013-02-15    0.000278
# 2009-06-06    0.000278
# 2007-03-05    0.000278
#                 ...
# 2018-03-09    0.000139
# 2009-08-22    0.000139
# 2008-09-18    0.000139
# 2009-02-01    0.000139
# 2010-02-12    0.000139
# Name: DEATH_DT_3, Length: 100, dtype: float64

# %% [markdown]
# # 死因_3

# %%
death_id_3 = cdr.loc[:,'DEATH_ID_3']
#print(death_id_3)
print(death_id_3.value_counts() / len(death_id_3))
#print(death_id_3.describe())

death_id_3_labels = ["因中風而死亡","因心臟疾病而死亡","其他"]
sns.countplot(death_id_3).set_xticklabels(death_id_3_labels)
plt.title("DEATH_ID_3 - Barplot")
plt.xlabel('DEATH_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 3.0    0.582278
# 1.0    0.000556
# 2.0    0.000278
# Name: DEATH_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 因中風而死亡(CI/CH)_3

# %%
deathsk_id_3 = cdr.loc[:,'DEATHSK_ID_3']
#print(deathsk_id_3)
print(deathsk_id_3.value_counts() / len(deathsk_id_3))
#print(deathsk_id_3.describe())

#deathsk_id_3_labels = ["CI", "CH"]
sns.countplot(deathsk_id_3)#.set_xticklabels(deathsk_id_3_labels)
plt.title("DEATHSK_ID_3 - Barplot")
plt.xlabel('DEATHSK_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.007511
# 2.0    0.000417
# 1.0    0.000139
# Name: DEATHSK_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# DEATHO_TX_3

# %% [markdown]
# # 相關醫療紀錄2_3

# %%
ve_id_3 = cdr.loc[:,'VE_ID_3']
#print(ve_id_3)
print(ve_id_3.value_counts() / len(ve_id_3))
#print(ve_id_3.describe())

sns.countplot(ve_id_3)
plt.title("VE_ID_3 - Barplot")
plt.xlabel('VE_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0    0.281541
# N    0.002365
# Name: VE_ID_3, dtype: float64

# %% [markdown]
# # 再中風_3

# %%
vers_fl_3 = cdr.loc[:,'VERS_FL_3']
#print(vers_fl_3)
print(vers_fl_3.value_counts() / len(vers_fl_3))
#print(vers_fl_3.describe())

sns.countplot(vers_fl_3)
plt.title("VERS_FL_3 - Barplot")
plt.xlabel('VERS_FL_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N            0.673390
# 1900/1/1     0.020170
# Y            0.012102
# 2007/12/5    0.000139
# Name: VERS_FL_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 再中風 (CI / CH)_3

# %%
verscich_id_3 = cdr.loc[:,'VERSCICH_ID_3']
#print(verscich_id_3)
print(verscich_id_3.value_counts() / len(verscich_id_3))
#print(verscich_id_3.describe())

sns.countplot(verscich_id_3)
plt.title("VERSCICH_ID_3 - Barplot")
plt.xlabel('VERSCICH_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# O           0.020309
# 1           0.005981
# 1900/1/1    0.002087
# Name: VERSCICH_ID_3, dtype: float64

# %% [markdown]
# # 再中風日期_3

# %%
vers_dt_3 = cdr.loc[:,'VERS_DT_3']
vers_dt_3 = pd.to_datetime(vers_dt_3, errors='coerce')
vers_dt_3[(vers_dt_3.dt.year < 2006) | (vers_dt_3.dt.year > 2021)] = np.nan
#print(vers_dt_3)
#print(vers_dt_3.value_counts() / len(vers_dt_3))
print(vers_dt_3.describe())

vers_dt_3.value_counts().plot()
plt.title("VERS_DT_3 - Lineplot")
plt.xlabel('VERS_DT_3')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-36-f33632f462df>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(vers_dt_3.describe())
# count                     133
# unique                    126
# top       2008-05-17 00:00:00
# freq                        3
# first     2006-10-23 00:00:00
# last      2016-08-12 00:00:00
# Name: VERS_DT_3, dtype: object

# %% [markdown]
# # 再中風醫院_3

# %%
versorg_id_3 = cdr.loc[:,'VERSORG_ID_3']
#print(versorg_id_3)
print(versorg_id_3.value_counts() / len(versorg_id_3))
#print(versorg_id_3.describe())

sns.countplot(versorg_id_3)
plt.title("VERSORG_ID_3 - Barplot")
plt.xlabel('VERSORG_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.666991
# 22    0.005981
# N     0.002087
# 1     0.000278
# 27    0.000139
# 25    0.000139
# Name: VERSORG_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease_3

# %%
veihd_fl_3 = cdr.loc[:,'VEIHD_FL_3']
#print(veihd_fl_3)
print(veihd_fl_3.value_counts() / len(veihd_fl_3))
#print(veihd_fl_3.describe())

sns.countplot(veihd_fl_3)
plt.title("VEIHD_FL_3 - Barplot")
plt.xlabel('VEIHD_FL_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N           0.682988
# 1900/1/1    0.020309
# Y           0.000139
# Name: VEIHD_FL_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Types of Ischemic Heart Disease_3

# %%
veihd_id_3 = cdr.loc[:,'VEIHD_ID_3']
#print(veihd_id_3)
print(veihd_id_3.value_counts() / len(veihd_id_3))
#print(veihd_id_3.describe())

#veihd_id_3_labels = ["AMI","Angina"]
sns.countplot(veihd_id_3)#.set_xticklabels(veihd_id_3_labels)
plt.title("VEIHD_ID_3 - Barplot")
plt.xlabel('VEIHD_ID_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0           0.018779
# 1900/1/1    0.002087
# O           0.001530
# Name: VEIHD_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease日期_3

# %%
veihd_dt_3 = cdr.loc[:,'VEIHD_DT_3']
veihd_dt_3 = pd.to_datetime(veihd_dt_3, errors='coerce')
veihd_dt_3[(veihd_dt_3.dt.year < 2006) | (veihd_dt_3.dt.year > 2021)] = np.nan
#print(veihd_dt_3)
print(veihd_dt_3.value_counts() / len(veihd_dt_3))
#print(veihd_dt_3.describe())

veihd_dt_3.value_counts().plot()
plt.title("veihd_dt_3 - Lineplot")
plt.xlabel('veihd_dt_3')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# 2008-06-04    0.000139
# 2007-03-10    0.000139
# 2007-12-17    0.000139
# 2008-10-15    0.000139
# 2007-09-13    0.000139
# Name: VEIHD_DT_3, dtype: float64

# %% [markdown]
# # Ischemic Heart Disease醫院_3

# %%
veihdorg_id_3 = cdr.loc[:,'VEIHDORG_ID_3']
#print(veihdorg_id_3)
print(veihdorg_id_3.value_counts() / len(veihdorg_id_3))
#print(veihdorg_id_3.describe())

sns.countplot(veihdorg_id_3)
plt.title("VEIHDORG_ID_3 - Barplot")
plt.xlabel('VEIHDORG_ID_3')
plt.ylabel('Number', rotation=0)
plt.xticks(rotation = 90)
plt.show()
# Out:
# 0                        0.576714
# O                        0.094450
# 6                        0.000417
# 1                        0.000278
# 3                        0.000278
# 豐�???,","\n41"           0.000139
# ?�中?��???,","\n15922"    0.000139
# ??,","\n17606"           0.000139
# ?�中?��???,","\n15118"    0.000139
# ?��?                     0.000139
# 秀??,","\n12987"          0.000139
# Name: VEIHDORG_ID_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # MRS_3

# %%
mrs_tx_3 = cdr.loc[:,'MRS_TX_3']
mrs_tx_3 = pd.to_numeric(mrs_tx_3, errors = "coerce")
mrs_tx_3[(mrs_tx_3 < 0) | (mrs_tx_3 > 6)] = np.nan
#print(mrs_tx_3)
print(mrs_tx_3.value_counts() / len(mrs_tx_3))
#print(mrs_tx_3.describe())

sns.countplot(mrs_tx_3)
plt.title("MRS_TX_3 - Barplot")
plt.xlabel('MRS_TX_3')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.171929
# 4.0    0.117402
# 2.0    0.098762
# 3.0    0.094867
# 5.0    0.094172
# 0.0    0.089860
# 6.0    0.003199
# Name: MRS_TX_3, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# TORG_TX_3

# %% [raw]
# VERSORG_TX_3

# %% [raw]
# VEIHDORG_TX_3

# %% [markdown]
# # FSTATUS_ID_6

# %%
fstatus_id_6 = cdr.loc[:,"FSTATUS_ID_6"]
#print(fstatus_id_6)
print(fstatus_id_6.value_counts() / len(fstatus_id_6))
#print(fstatus_id_6.describe())

sns.countplot(fstatus_id_6)
plt.title("FSTATUS_ID_6 - Barplot")
plt.xlabel('FSTATUS_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.634581
# 0.0    0.000835
# Name: FSTATUS_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 日期_6

# %%
rfur_dt_6 = cdr.loc[:,"RFUR_DT_6"]
rfur_dt_6 = pd.to_datetime(rfur_dt_6, errors='coerce')
rfur_dt_6[(rfur_dt_6.dt.year < 2006) | (rfur_dt_6.dt.year > 2021)] = np.nan
#print(rfur_dt_6)
#print(rfur_dt_6.value_counts() / len(rfur_dt_6))
print(rfur_dt_6.describe())

rfur_dt_6.value_counts().plot()
plt.title("RFUR_DT_6 - Lineplot")
plt.xlabel('RFUR_DT_6')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-44-20b84b09dd59>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(rfur_dt_6.describe())
# count                    4567
# unique                   1255
# top       2009-09-03 00:00:00
# freq                       53
# first     2006-10-13 00:00:00
# last      2019-11-28 00:00:00
# Name: RFUR_DT_6, dtype: object

# %% [markdown]
# # 所在地_6

# %%
location_id_6 = cdr.loc[:,"LOCATION_ID_6"]
#print(location_id_6)
print(location_id_6.value_counts() / len(location_id_6))
#print(location_id_6.describe())

location_id_6_labels = ["住家","護理之家","呼吸病房","本院住院中","轉至其他院","失聯"]
sns.countplot(location_id_1).set_xticklabels(location_id_6_labels)
plt.title("LOCATION_ID_6 - Barplot")
plt.xlabel('LOCATION_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.536514
# 2.0    0.031159
# 5.0    0.021700
# 4.0    0.013910
# 6.0    0.006677
# 3.0    0.006120
# Name: LOCATION_ID_6, dtype: float64

# %% [markdown]
# # 轉至醫院_6

# %%
torg_id_6 = cdr.loc[:,"TORG_ID_6"]
#print(torg_id_6)
print(torg_id_6.value_counts() / len(torg_id_6))
#print(torg_id_6.describe())

sns.countplot(torg_id_6)
plt.title("TORG_ID_6 - Barplot")
plt.xlabel('TORG_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# O     0.626513
# 21    0.001252
# 22    0.000556
# 44    0.000139
# 34    0.000139
# 26    0.000139
# Name: TORG_ID_6, dtype: float64

# %% [markdown]
# # 相關醫療紀錄_6

# %%
flu_id_6 = cdr.loc[:,"FLU_ID_6"]
#print(flu_id_6)
print(flu_id_6.value_counts() / len(flu_id_6))
#print(flu_id_6.describe())

#flu_id_6_labels = ["本院或他院門診繼續服藥","拒回診","死亡"]
sns.countplot(flu_id_6)#.set_xticklabels(flu_id_6_labels)
plt.title("FLU_ID_6 - Barplot")
plt.xlabel('FLU_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.544999
# 2.0    0.026847
# 3.0    0.015440
# 4.0    0.004869
# 6.0    0.003756
# 5.0    0.000278
# Name: FLU_ID_6, dtype: float64

# %% [markdown]
# # 門診醫院_6

# %%
fluorg_id_6 = cdr.loc[:,"FLUORG_ID_6"]
#print(fluorg_id_6)
print(fluorg_id_6.value_counts() / len(fluorg_id_6))
#print(fluorg_id_6.describe())

sns.countplot(fluorg_id_6)
plt.title("FLUORG_ID_6 - Barplot")
plt.xlabel('FLUORG_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# O     0.577271
# 22    0.041035
# 21    0.004869
# 25    0.003895
# 24    0.002782
# 28    0.000835
# 26    0.000556
# 29    0.000556
# 32    0.000417
# 23    0.000417
# 27    0.000278
# 41    0.000278
# 12    0.000278
# 33    0.000278
# 34    0.000278
# 7     0.000278
# 1     0.000278
# 45    0.000139
# 44    0.000139
# 61    0.000139
# Name: FLUORG_ID_6, dtype: float64

# %% [raw]
# FLUORG_TX_6

# %% [raw]
# FLURESULT_TX_6

# %% [markdown]
# # 死亡日期_6

# %%
death_dt_6 = cdr.loc[:,'DEATH_DT_6']
death_dt_6 = pd.to_datetime(death_dt_6, errors='coerce')
death_dt_6[(death_dt_6.dt.year < 2006) | (death_dt_6.dt.year > 2021)] = np.nan
#print(death_dt_6)
#print(death_dt_6.value_counts() / len(death_dt_6))
print(death_dt_6.describe())

death_dt_6.value_counts().plot()
plt.title("DEATH_DT_6 - Lineplot")
plt.xlabel('DEATH_DT_6')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-49-dd2eec211fa7>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(death_dt_6.describe())
# count                     111
# unique                    105
# top       2007-11-01 00:00:00
# freq                        2
# first     2006-01-17 00:00:00
# last      2019-04-13 00:00:00
# Name: DEATH_DT_6, dtype: object

# %% [markdown]
# # 死因_6

# %%
death_id_6 = cdr.loc[:,'DEATH_ID_6']
#print(death_id_6)
print(death_id_6.value_counts() / len(death_id_6))
#print(death_id_6.describe())

death_id_6_labels = ["因中風而死亡","因心臟疾病而死亡","其他"]
sns.countplot(death_id_6).set_xticklabels(death_id_6_labels)
plt.title("DEATH_ID_6 - Barplot")
plt.xlabel('DEATH_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 3.0    0.541383
# 1.0    0.000278
# 2.0    0.000278
# Name: DEATH_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 因中風而死亡(CI/CH)_6

# %%
deathsk_id_6 = cdr.loc[:,'DEATHSK_ID_6']
#print(deathsk_id_6)
print(deathsk_id_6.value_counts() / len(deathsk_id_6))
#print(deathsk_id_6.describe())

#deathsk_id_6_labels = ["CI", "CH"]
sns.countplot(deathsk_id_6)#.set_xticklabels(deathsk_id_6_labels)
plt.title("DEATHSK_ID_6 - Barplot")
plt.xlabel('DEATHSK_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.007790
# 2.0    0.000278
# Name: DEATHSK_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# DEATHO_TX_6

# %% [markdown]
# # 相關醫療紀錄2_6

# %%
ve_id_6 = cdr.loc[:,'VE_ID_6']
#print(ve_id_6)
print(ve_id_6.value_counts() / len(ve_id_6))
#print(ve_id_6.describe())

sns.countplot(ve_id_6)
plt.title("VE_ID_6 - Barplot")
plt.xlabel('VE_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0    0.217415
# N    0.001947
# Name: VE_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 再中風_6

# %%
vers_fl_6 = cdr.loc[:,'VERS_FL_6']
#print(vers_fl_6)
print(vers_fl_6.value_counts() / len(vers_fl_6))
#print(vers_fl_6.describe())

sns.countplot(vers_fl_6)
plt.title("VERS_FL_6 - Barplot")
plt.xlabel('VERS_FL_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N            0.602448
# 1900/1/1     0.021839
# Y            0.008485
# 2010/2/23    0.000139
# 2009/5/25    0.000139
# 2013/6/6     0.000139
# 2009/12/3    0.000139
# Name: VERS_FL_6, dtype: float64

# %% [markdown]
# # 再中風 (CI / CH)_6

# %%
verscich_id_6 = cdr.loc[:,'VERSCICH_ID_6']
#print(verscich_id_6)
print(verscich_id_6.value_counts() / len(verscich_id_6))
#print(verscich_id_6.describe())

sns.countplot(verscich_id_6)
plt.title("VERSCICH_ID_6 - Barplot")
plt.xlabel('VERSCICH_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# O           0.022256
# 1           0.005008
# 1900/1/1    0.001808
# 22          0.000139
# Name: VERSCICH_ID_6, dtype: float64

# %% [markdown]
# # 再中風日期_6

# %%
vers_dt_6 = cdr.loc[:,'VERS_DT_6']
vers_dt_6 = pd.to_datetime(vers_dt_6, errors='coerce')
vers_dt_6[(vers_dt_6.dt.year < 2006) | (vers_dt_6.dt.year > 2021)] = np.nan
#print(vers_dt_6)
#print(vers_dt_6.value_counts() / len(vers_dt_6))
print(vers_dt_6.describe())

vers_dt_6.value_counts().plot()
plt.title("VERS_DT_6 - Lineplot")
plt.xlabel('VERS_DT_6')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-55-563ce8bc0890>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(vers_dt_6.describe())
# count                     108
# unique                    102
# top       2011-02-16 00:00:00
# freq                        3
# first     2006-12-27 00:00:00
# last      2017-12-23 00:00:00
# Name: VERS_DT_6, dtype: object

# %% [markdown]
# # 再中風醫院_6

# %%
versorg_id_6 = cdr.loc[:,'VERSORG_ID_6']
#print(versorg_id_6)
print(versorg_id_6.value_counts() / len(versorg_id_6))
#print(versorg_id_6.describe())

sns.countplot(versorg_id_6)
plt.title("VERSORG_ID_6 - Barplot")
plt.xlabel('VERSORG_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.601196
# 22    0.004451
# N     0.001808
# 21    0.000278
# 28    0.000139
# 34    0.000139
# 3     0.000139
# 45    0.000139
# 12    0.000139
# Name: VERSORG_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease_6

# %%
veihd_fl_6 = cdr.loc[:,'VEIHD_FL_6']
#print(veihd_fl_6)
print(veihd_fl_6.value_counts() / len(veihd_fl_6))
#print(veihd_fl_6.describe())

sns.countplot(veihd_fl_6)
plt.title("VEIHD_FL_6 - Barplot")
plt.xlabel('VEIHD_FL_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N           0.608569
# 1900/1/1    0.022395
# Y           0.000278
# Name: VEIHD_FL_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Types of Ischemic Heart Disease_6

# %%
veihd_id_6 = cdr.loc[:,'VEIHD_ID_6']
#print(veihd_id_6)
print(veihd_id_6.value_counts() / len(veihd_id_6))
#print(veihd_id_6.describe())

#veihd_id_6_labels = ["AMI","Angina"]
sns.countplot(veihd_id_6)#.set_xticklabels(veihd_id_6_labels)
plt.title("VEIHD_ID_6 - Barplot")
plt.xlabel('VEIHD_ID_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0           0.019613
# O           0.002782
# 1900/1/1    0.001808
# 1           0.000139
# Name: VEIHD_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease日期_6

# %%
veihd_dt_6 = cdr.loc[:,'VEIHD_DT_6']
veihd_dt_6 = pd.to_datetime(veihd_dt_6, errors='coerce')
veihd_dt_6[(veihd_dt_6.dt.year < 2006) | (veihd_dt_6.dt.year > 2021)] = np.nan
#print(veihd_dt_6)
print(veihd_dt_6.value_counts() / len(veihd_dt_6))
#print(veihd_dt_6.describe())

veihd_dt_6.value_counts().plot()
plt.title("VEIHD_DT_6 - Lineplot")
plt.xlabel('VEIHD_DT_6')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# 2009-09-04    0.000139
# 2014-07-14    0.000139
# 2008-02-22    0.000139
# 2008-02-14    0.000139
# Name: VEIHD_DT_6, dtype: float64

# %% [markdown]
# # Ischemic Heart Disease醫院_6

# %%
veihdorg_id_6 = cdr.loc[:,'VEIHDORG_ID_6']
#print(veihdorg_id_6)
print(veihdorg_id_6.value_counts() / len(veihdorg_id_6))
#print(veihdorg_id_6.describe())

sns.countplot(veihdorg_id_6)
plt.title("VEIHDORG_ID_6 - Barplot")
plt.xlabel('VEIHDORG_ID_6')
plt.ylabel('Number', rotation=0)
plt.xticks(rotation = 90)
plt.show()
# Out:
# 0                       0.537766
# O                       0.067047
# 3                       0.000556
# ?�中?��???,CMUH"         0.000139
# 1                       0.000139
# 2                       0.000139
# ?�榮                     0.000139
# 22                      0.000139
# 中�??�學??,","\n17987"    0.000139
# Name: VEIHDORG_ID_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # MRS_6

# %%
mrs_tx_6 = cdr.loc[:,'MRS_TX_6']
mrs_tx_6 = pd.to_numeric(mrs_tx_6, errors='coerce')
mrs_tx_6[(mrs_tx_6 < 0) | (mrs_tx_6 > 6)] = np.nan
#print(mrs_tx_6)
print(mrs_tx_6.value_counts() / len(mrs_tx_6))
#print(mrs_tx_6.describe())

sns.countplot(mrs_tx_6)
plt.title("MRS_TX_6 - Barplot")
plt.xlabel('MRS_TX_6')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.167478
# 0.0    0.098901
# 4.0    0.086521
# 2.0    0.081931
# 3.0    0.081513
# 5.0    0.072055
# 6.0    0.001808
# Name: MRS_TX_6, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# TORG_TX_6

# %% [raw]
# VERSORG_TX_6

# %% [raw]
# VEIHDORG_TX_6

# %% [markdown]
# # FSTATUS_ID_12

# %%
fstatus_id_12 = cdr.loc[:,"FSTATUS_ID_12"]
#print(fstatus_id_12)
print(fstatus_id_12.value_counts() / len(fstatus_id_12))
#print(fstatus_id_12.describe())

sns.countplot(fstatus_id_12)
plt.title("FSTATUS_ID_12 - Barplot")
plt.xlabel('FSTATUS_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.491863
# 0.0    0.000278
# Name: FSTATUS_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 日期_12

# %%
rfur_dt_12 = cdr.loc[:,"RFUR_DT_12"]
rfur_dt_12 = pd.to_datetime(rfur_dt_12, errors='coerce')
rfur_dt_12[(rfur_dt_12.dt.year < 2006) | (rfur_dt_12.dt.year > 2021)] = np.nan
#print(rfur_dt_12)
#print(rfur_dt_12.value_counts() / len(rfur_dt_12))
print(rfur_dt_12.describe())

rfur_dt_12.value_counts().plot()
plt.title("RFUR_DT_12 - Lineplot")
plt.xlabel('RFUR_DT_12')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                    3537
# unique                    649
# top       2009-08-14 00:00:00
# freq                       92
# first     2008-02-19 00:00:00
# last      2020-05-27 00:00:00
# Name: RFUR_DT_12, dtype: object
# <ipython-input-63-1289b7c5a689>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(rfur_dt_12.describe())

# %% [markdown]
# # 所在地_12

# %%
location_id_12 = cdr.loc[:,"LOCATION_ID_12"]
#print(location_id_12)
print(location_id_12.value_counts() / len(location_id_12))
#print(location_id_12.describe())

location_id_12_labels = ["住家","護理之家","呼吸病房","本院住院中","轉至其他院","失聯"]
sns.countplot(location_id_12).set_xticklabels(location_id_12_labels)
plt.title("LOCATION_ID_12 - Barplot")
plt.xlabel('LOCATION_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.415774
# 2.0    0.020448
# 6.0    0.005842
# 4.0    0.004451
# 5.0    0.004312
# 3.0    0.003199
# Name: LOCATION_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 轉至醫院_12

# %%
torg_id_12 = cdr.loc[:,"TORG_ID_12"]
#print(torg_id_12)
print(torg_id_12.value_counts() / len(torg_id_12))
#print(torg_id_12.describe())

sns.countplot(torg_id_12)
plt.title("TORG_ID_12 - Barplot")
plt.xlabel('TORG_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.450689
# 26    0.000278
# 29    0.000139
# 21    0.000139
# 22    0.000139
# Name: TORG_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 相關醫療紀錄_12

# %%
flu_id_12 = cdr.loc[:,"FLU_ID_12"]
#print(flu_id_12)
print(flu_id_12.value_counts() / len(flu_id_12))
#print(flu_id_12.describe())

#flu_id_12_labels = ["本院或他院門診繼續服藥","拒回診","死亡"]
sns.countplot(flu_id_12)#.set_xticklabels(flu_id_12_labels)
plt.title("FLU_ID_12 - Barplot")
plt.xlabel('FLU_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.405759
# 2.0    0.035471
# 3.0    0.035193
# 4.0    0.002921
# 6.0    0.002226
# Name: FLU_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 門診醫院_12

# %%
fluorg_id_12 = cdr.loc[:,"FLUORG_ID_12"]
#print(fluorg_id_12)
print(fluorg_id_12.value_counts() / len(fluorg_id_12))
#print(fluorg_id_12.describe())

sns.countplot(fluorg_id_12)
plt.title("FLUORG_ID_12 - Barplot")
plt.xlabel('FLUORG_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.419530
# 22    0.048129
# 21    0.004590
# 25    0.004034
# 24    0.002365
# 29    0.000974
# 26    0.000835
# 41    0.000696
# 28    0.000556
# 23    0.000417
# 32    0.000278
# 27    0.000278
# 61    0.000278
# 33    0.000278
# 7     0.000278
# 38    0.000139
# 45    0.000139
# 30    0.000139
# 36    0.000139
# 35    0.000139
# 1     0.000139
# 12    0.000139
# Name: FLUORG_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# FLUORG_TX_12

# %% [raw]
# FLURESULT_TX_12

# %% [markdown]
# # 死亡日期_12

# %%
death_dt_12 = cdr.loc[:,'DEATH_DT_12']
death_dt_12 = pd.to_datetime(death_dt_12, errors='coerce')
death_dt_12[(death_dt_12.dt.year < 2006) | (death_dt_12.dt.year > 2021)] = np.nan
#print(death_dt_12)
#print(death_dt_12.value_counts() / len(death_dt_12))
print(death_dt_12.describe())

death_dt_12.value_counts().plot()
plt.title("DEATH_DT_12 - Lineplot")
plt.xlabel('DEATH_DT_12')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                     257
# unique                    201
# top       2008-12-15 00:00:00
# freq                        6
# first     2006-01-17 00:00:00
# last      2019-08-16 00:00:00
# Name: DEATH_DT_12, dtype: object
# <ipython-input-68-64a1d56e1263>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(death_dt_12.describe())

# %% [markdown]
# # 死因_12

# %%
death_id_12 = cdr.loc[:,'DEATH_ID_12']
#print(death_id_12)
print(death_id_12.value_counts() / len(death_id_12))
#print(death_id_12.describe())

death_id_12_labels = ["因中風而死亡","因心臟疾病而死亡","其他"]
sns.countplot(death_id_12).set_xticklabels(death_id_12_labels)
plt.title("DEATH_ID_12 - Barplot")
plt.xlabel('DEATH_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 3.0    0.389345
# 1.0    0.000556
# 2.0    0.000139
# Name: DEATH_ID_12, dtype: float64

# %% [markdown]
# # 因中風而死亡(CI/CH)_12

# %%
deathsk_id_12 = cdr.loc[:,'DEATHSK_ID_12']
#print(deathsk_id_12)
print(deathsk_id_12.value_counts() / len(deathsk_id_12))
#print(deathsk_id_12.describe())

sns.countplot(deathsk_id_12)
plt.title("DEATHSK_ID_12 - Barplot")
plt.xlabel('DEATHSK_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.003338
# 2.0    0.000417
# Name: DEATHSK_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# DEATHO_TX_1

# %% [markdown]
# # 相關醫療紀錄2_12

# %%
ve_id_12 = cdr.loc[:,'VE_ID_12']
#print(ve_id_12)
print(ve_id_12.value_counts() / len(ve_id_12))
#print(ve_id_12.describe())

sns.countplot(ve_id_12)
plt.title("VE_ID_12 - Barplot")
plt.xlabel('VE_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0    0.122548
# N    0.002087
# 1    0.000139
# Name: VE_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 再中風_12

# %%
vers_fl_12 = cdr.loc[:,'VERS_FL_12']
#print(vers_fl_12)
print(vers_fl_12.value_counts() / len(vers_fl_12))
#print(vers_fl_12.describe())

sns.countplot(vers_fl_12)
plt.title("VERS_FL_12 - Barplot")
plt.xlabel('VERS_FL_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N             0.458896
# 1900/1/1      0.019196
# Y             0.004729
# 2007/10/12    0.000139
# 2008/3/26     0.000139
# 2013/11/26    0.000139
# 2009/4/16     0.000139
# 2007/7/4      0.000139
# 2008/11/29    0.000139
# 2009/1/28     0.000139
# 2009/6/5      0.000139
# Name: VERS_FL_12, dtype: float64

# %% [markdown]
# # 再中風 (CI / CH)_12

# %%
verscich_id_12 = cdr.loc[:,'VERSCICH_ID_12']
#print(verscich_id_12)
print(verscich_id_12.value_counts() / len(verscich_id_12))
#print(verscich_id_12.describe())

sns.countplot(verscich_id_12)
plt.title("VERSCICH_ID_12 - Barplot")
plt.xlabel('VERSCICH_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O           0.020170
# 1           0.002782
# 1900/1/1    0.000696
# 2           0.000139
# 22          0.000139
# Name: VERSCICH_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 再中風日期_12

# %%
vers_dt_12 = cdr.loc[:,'VERS_DT_12']
vers_dt_12 = pd.to_datetime(vers_dt_12, errors='coerce')
vers_dt_12[(vers_dt_12.dt.year < 2006) | (vers_dt_12.dt.year > 2021)] = np.nan
#print(vers_dt_12)
#print(vers_dt_12.value_counts() / len(vers_dt_12))
print(vers_dt_12.describe())

vers_dt_12.value_counts().plot()
plt.title("VERS_DT_12 - Lineplot")
plt.xlabel('VERS_DT_12')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                     115
# unique                    110
# top       2011-10-12 00:00:00
# freq                        2
# first     2007-06-09 00:00:00
# last      2016-01-31 00:00:00
# Name: VERS_DT_12, dtype: object
# <ipython-input-74-c3a1ed6d0205>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(vers_dt_12.describe())

# %% [markdown]
# # 再中風醫院_12

# %%
versorg_id_12 = cdr.loc[:,'VERSORG_ID_12']
#print(versorg_id_12)
print(versorg_id_12.value_counts() / len(versorg_id_12))
#print(versorg_id_12.describe())

sns.countplot(versorg_id_12)
plt.title("VERSORG_ID_12 - Barplot")
plt.xlabel('VERSORG_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# O     0.428850
# 22    0.002643
# N     0.000974
# 1     0.000556
# 0     0.000556
# Name: VERSORG_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease_12

# %%
veihd_fl_12 = cdr.loc[:,'VEIHD_FL_12']
#print(veihd_fl_12)
print(veihd_fl_12.value_counts() / len(veihd_fl_12))
#print(veihd_fl_12.describe())

sns.countplot(veihd_fl_12)
plt.title("VEIHD_FL_12 - Barplot")
plt.xlabel('VEIHD_FL_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N           0.462790
# 1900/1/1    0.020309
# Y           0.000417
# Name: VEIHD_FL_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Types of Ischemic Heart Disease_12

# %%
veihd_id_12 = cdr.loc[:,'VEIHD_ID_12']
#print(veihd_id_12)
print(veihd_id_12.value_counts() / len(veihd_id_12))
#print(veihd_id_12.describe())

#veihd_id_12_labels = ["AMI","Angina"]
sns.countplot(veihd_id_12)#.set_xticklabels(veihd_id_12_labels)
plt.title("VEIHD_ID_12 - Barplot")
plt.xlabel('VEIHD_ID_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0           0.018779
# O           0.001530
# 1900/1/1    0.000696
# 1           0.000278
# Name: VEIHD_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Ischemic Heart Disease日期_12

# %%
veihd_dt_12 = cdr.loc[:,'VEIHD_DT_12']
veihd_dt_12 = pd.to_datetime(veihd_dt_12, errors='coerce')
veihd_dt_12[(veihd_dt_12.dt.year < 2006) | (veihd_dt_12.dt.year > 2021)] = np.nan
#print(veihd_dt_12)
#print(veihd_dt_12.value_counts() / len(veihd_dt_12))
print(veihd_dt_12.describe())

veihd_dt_12.value_counts().plot()
plt.title("VEIHD_DT_12 - Lineplot")
plt.xlabel('VEIHD_DT_12')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-78-e2054326b95a>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(veihd_dt_12.describe())
# count                       3
# unique                      3
# top       2011-11-11 00:00:00
# freq                        1
# first     2011-06-25 00:00:00
# last      2012-01-31 00:00:00
# Name: VEIHD_DT_12, dtype: object

# %% [markdown]
# # Ischemic Heart Disease醫院_12

# %%
veihdorg_id_12 = cdr.loc[:,'VEIHDORG_ID_12']
#print(veihdorg_id_12)
print(veihdorg_id_12.value_counts() / len(veihdorg_id_12))
#print(veihdorg_id_12.describe())

sns.countplot(veihdorg_id_12)
plt.title("VEIHDORG_ID_12 - Barplot")
plt.xlabel('VEIHDORG_ID_12')
plt.ylabel('Number', rotation=0)
plt.xticks(rotation = 90)
plt.show()
# Out:
# 0                    0.377939
# O                    0.052163
# 22                   0.000417
# 6                    0.000278
# 1                    0.000139
# 秀??,","\n3861"       0.000139
# 彰�?秀??,","\n5734"    0.000139
# 3                    0.000139
# 秀??,","\n5777"       0.000139
# Name: VEIHDORG_ID_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # MRS_12

# %%
mrs_tx_12 = cdr.loc[:,'MRS_TX_12']
mrs_tx_12 = pd.to_numeric(mrs_tx_12, errors='coerce')
mrs_tx_12[(mrs_tx_12 < 0) | (mrs_tx_12 > 6)] = np.nan
#print(mrs_tx_12)
print(mrs_tx_12.value_counts() / len(mrs_tx_12))
#print(mrs_tx_12.describe())

sns.countplot(mrs_tx_12)
plt.title("MRS_TX_12 - Barplot")
plt.xlabel('MRS_TX_12')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.134372
# 0.0    0.095424
# 2.0    0.057727
# 4.0    0.053137
# 5.0    0.045486
# 3.0    0.045069
# 6.0    0.005425
# Name: MRS_TX_12, dtype: float64
# C:\Users\Jacky C\Anaconda3\envs\tsr_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [raw]
# TORG_TX_12

# %% [raw]
# VERSORG_TX_12

# %% [raw]
# VEIHDORG_TX_12
