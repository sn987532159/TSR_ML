# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.font_manager import FontProperties
myfont=FontProperties(fname=r'C:\Windows\Fonts\kaiu.ttf',size=14)
sns.set(font=myfont.get_name())

#plt.rcParams['font.sans-serif'] = ['kaiu']  
#plt.rcParams['axes.unicode_minus'] = False   
#sns.set(font='kaiu', font_scale=0.8)

# %%
cdc = pd.read_excel("C:/Users/Jacky C/Desktop/TSR-proganosis/Data/TSR_2018_raw/CASEDCASE.xlsx")
cdc.head()
# Out:
#    IPROTOCOL_ID  ICASE_ID       IDCASE_ID  CSTATUS_ID  ORG_ID DCTYPE24_ID  \
# 0           NaN         1  007-00000001-1           0    22.0           1
# 1           NaN         1  022-00000001-1           0    22.0         NaN
# 2           NaN         2  007-00000002-1           1    22.0           1
# 3           NaN         2  022-00000002-1           0    22.0           1
# 4           NaN         3  007-00000003-1           1     7.0          72
#
#   PATIENT_ID  INPUT_NM  AGE_NM  HEIGHT_NM  ...  MCDLI_ID  CREATE_DT  \
# 0    1176949       1.0     NaN      160.0  ...       NaN 2011-06-20
# 1        NaN       NaN     NaN        NaN  ...       NaN 2012-09-20
# 2    1377394       1.0     NaN      170.0  ...       NaN 2011-06-21
# 3    1377394       NaN     NaN      170.0  ...       NaN 2012-09-20
# 4    4086713       1.0     NaN      165.0  ...       NaN 2011-06-21
#
#    CREATESTAFF_ID  SYSUPD_DT  SYSUPDSTAFF_ID MODIFY_NM  \
# ...

# %%
cdc.describe()
# Out:
#        IPROTOCOL_ID       ICASE_ID     CSTATUS_ID         ORG_ID     INPUT_NM  \
# count           0.0  140484.000000  140484.000000  139216.000000  9348.000000
# mean            NaN   62524.518401       0.418681      23.513799     1.043646
# std             NaN   37065.229757       0.493345      14.554859     0.225238
# min             NaN       1.000000       0.000000       1.000000     1.000000
# 25%             NaN   30329.750000       0.000000      11.000000     1.000000
# 50%             NaN   61958.500000       0.000000      24.000000     1.000000
# 75%             NaN   94497.250000       1.000000      35.000000     1.000000
# max             NaN  127958.000000       1.000000      64.000000     4.000000
#
#        AGE_NM      HEIGHT_NM      WEIGHT_NM         EDU_ID         PRO_ID  \
# count     0.0  137458.000000  137585.000000  137118.000000  137580.000000
# mean      NaN     267.208864     145.918184       4.149076       6.422721
# ...

# %%
#IPROTOCOL_ID to AGE_NM are meaningless

# %%
#身高
ht = cdc.iloc[:,9]
#print(ht)
print(ht.value_counts().sort_values(ascending= True), ht.describe())
# Out:
# 69.0         1
# 63.5         1
# 173.6        1
# 147.4        1
# 174.1        1
#          ...
# 150.0     6758
# 170.0     7862
# 165.0     8969
# 160.0    10376
# 999.9    17358
# Name: HEIGHT_NM, Length: 568, dtype: int64 count    137458.000000
# mean        267.208864
# std         279.026415
# min          -1.000000
# 25%         156.000000
# 50%         163.000000
# 75%         170.000000
# max         999.990000
# Name: HEIGHT_NM, dtype: float64

# %%
ht.plot.box(figsize=(5,5))
plt.show()
ht.plot.hist(figsize=(5,5), bins=100)
plt.show()
ht.plot.hist(figsize=(5,5), bins=100, range=[100,200])
plt.show()

# %%
#體重
wt = cdc.iloc[:,10]
#print(wt)
print(wt.value_counts().sort_values(ascending= True), wt.describe())
# Out:
# 108.60        1
# 6.60          1
# 105.40        1
# 111.50        1
# 60.25         1
#           ...
# 55.00      3420
# 70.00      4770
# 65.00      5167
# 60.00      5556
# 999.90    11989
# Name: WEIGHT_NM, Length: 1271, dtype: int64 count    137585.000000
# mean        145.918184
# std         264.770446
# min           0.000000
# 25%          56.000000
# 50%          65.000000
# 75%          75.000000
# max         999.990000
# Name: WEIGHT_NM, dtype: float64

# %%
wt.plot.box(figsize=(5,5))
plt.show()
wt.plot.hist(figsize=(5,5), bins=100)
plt.show()
wt.plot. hist(figsize=(5,5), bins=100, range=[20,120])
plt.show()

# %%
#教育
edu = cdc.iloc[:,11]
#print(edu)
print(edu.value_counts().sort_values(ascending= True), edu.describe())
# Out:
# 6.0      1073
# 7.0      1911
# 98.0     2338
# 5.0     12212
# 3.0     16968
# 4.0     20221
# 1.0     37664
# 2.0     44731
# Name: EDU_ID, dtype: int64 count    137118.000000
# mean          4.149076
# std          12.441390
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max          98.000000
# Name: EDU_ID, dtype: float64

# %%
edu_labels = ["無","國小","國中","高中職","大學","研究所","不詳","98"]
sns.countplot(edu).set_xticklabels(edu_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '無'),
#  Text(1, 0, '國小'),
#  Text(2, 0, '國中'),
#  Text(3, 0, '高中職'),
#  Text(4, 0, '大學'),
#  Text(5, 0, '研究所'),
#  Text(6, 0, '不詳'),
#  Text(7, 0, '98')]

# %%
#職業
pro = cdc.iloc[:,12]
#print(pro)
print(pro.value_counts().sort_values(ascending= True), pro.describe())
# Out:
# 2.0       213
# 9.0       286
# 4.0       670
# 11.0     1284
# 3.0      1303
# 98.0     1761
# 12.0     2032
# 99.0     2718
# 6.0      5796
# 7.0      6190
# 8.0      7168
# 5.0     10100
# 10.0    12208
# 1.0     85851
# Name: PRO_ID, dtype: int64 count    137580.000000
# mean          6.422721
# std          17.242067
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           6.000000
# max          99.000000
# Name: PRO_ID, dtype: float64

# %%
pro_labels = ["無","軍","公","教","工","農","商","服務業","學生","退休","不詳","其他","98","99"]
sns.countplot(pro).set_xticklabels(pro_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '無'),
#  Text(1, 0, '軍'),
#  Text(2, 0, '公'),
#  Text(3, 0, '教'),
#  Text(4, 0, '工'),
#  Text(5, 0, '農'),
#  Text(6, 0, '商'),
#  Text(7, 0, '服務業'),
#  Text(8, 0, '學生'),
#  Text(9, 0, '退休'),
#  Text(10, 0, '不詳'),
#  Text(11, 0, '其他'),
#  Text(12, 0, '98'),
#  Text(13, 0, '99')]

# %%
#ITOWN_ID to FTITLE_TX are meaningless

# %%
#入院方式
opc_id = cdc.iloc[:,21]
#print(opc_id)
print(opc_id.value_counts().sort_values(ascending= True), opc_id.describe())
# Out:
# 1.0      6543
# 2.0     11377
# 3.0    120701
# Name: OPC_ID, dtype: int64 count    138621.000000
# mean          2.823526
# std           0.489626
# min           1.000000
# 25%           3.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000
# Name: OPC_ID, dtype: float64

# %%
opc_id_labels = ["住院","門診","急診"]
sns.countplot(opc_id).set_xticklabels(opc_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '住院'), Text(1, 0, '門診'), Text(2, 0, '急診')]

# %%
#是否住院
ih_fl = cdc.iloc[:,22]
#print(ih_fl)
print(ih_fl.value_counts().sort_values(ascending= True), ih_fl.describe())
# Out:
# Y        77
# N       103
# 1      3334
# 0    128550
# Name: IH_FL, dtype: int64 count     132064
# unique         4
# top            0
# freq      128550
# Name: IH_FL, dtype: int64

# %%
sns.countplot(ih_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IH_FL', ylabel='count'>

# %%
#住院日期 ???
ih_dt = cdc.iloc[:,23]
#print(ih_dt)
print(ih_dt.value_counts().sort_values(ascending= True), ih_dt.describe())
# Out:
# 0101-05-06              1
# 2006-01-12 00:00:00     1
# 2106-04-12 00:00:00     1
# 2005-09-20 00:00:00     1
# 2047-04-24 00:00:00     1
#                        ..
# 2007-02-12 00:00:00    71
# 2008-08-18 00:00:00    71
# 2008-01-21 00:00:00    76
# 2008-02-11 00:00:00    83
# 2008-02-18 00:00:00    86
# Name: IH_DT, Length: 4683, dtype: int64 count                  134627
# unique                   4683
# top       2008-02-18 00:00:00
# freq                       86
# Name: IH_DT, dtype: object

# %%
#離院日期
oh_dt = cdc.iloc[:,24]
#print(oh_dt)
print(oh_dt.value_counts().sort_values(ascending= True), oh_dt.describe())
# Out:
# 2044-04-15 00:00:00      1
# 0107-05-01               1
# 2006-07-09 00:00:00      1
# 2006-09-24 00:00:00      1
# 9999-01-01 00:00:00      1
#                       ...
# 2008-02-02 00:00:00    101
# 2009-01-23 00:00:00    119
# 2008-02-05 00:00:00    121
# 2007-02-15 00:00:00    122
# 2007-02-16 00:00:00    150
# Name: OH_DT, Length: 4678, dtype: int64 count                  137222
# unique                   4678
# top       2007-02-16 00:00:00
# freq                      150
# Name: OH_DT, dtype: object

# %%
#發病日期
onset_dt = cdc.iloc[:,25]
#print(onset_dt)
print(onset_dt.value_counts().sort_values(ascending= True), onset_dt.describe())
# Out:
# 2107-12-01 00:00:00     1
# 1956-10-31 00:00:00     1
# 0102-10-04              1
# 1958-01-25 00:00:00     1
# 1972-08-07 00:00:00     1
#                        ..
# 2008-01-25 00:00:00    69
# 2008-02-16 00:00:00    69
# 2008-03-01 00:00:00    69
# 2008-08-25 00:00:00    73
# 2008-02-11 00:00:00    76
# Name: ONSET_DT, Length: 4736, dtype: int64 count                  140484
# unique                   4736
# top       2008-02-11 00:00:00
# freq                       76
# Name: ONSET_DT, dtype: object

# %%
#發病時間-時
onseth_nm = cdc.iloc[:,26]
#print(onseth_nm)
print(onseth_nm.value_counts().sort_values(ascending= True), onseth_nm.describe())
# Out:
# 99.0       1
# 24.0      36
# 1.0     1238
# 0.0     1385
# 2.0     1513
# 3.0     1561
# 4.0     1613
# 23.0    2112
# 5.0     2290
# 13.0    2870
# 21.0    2998
# 22.0    3001
# 14.0    3308
# 20.0    3458
# 11.0    3541
# 19.0    3575
# 15.0    3595
# 16.0    3731
# 18.0    3777
# 17.0    3807
# 6.0     3818
# 12.0    3906
# 9.0     3992
# 10.0    4370
# 7.0     4846
# 8.0     4889
# Name: ONSETH_NM, dtype: int64 count    75231.000000
# mean        12.412357
# std          6.068454
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         18.000000
# max         99.000000
# Name: ONSETH_NM, dtype: float64

# %%
#發病時間-分
onsetm_nm = cdc.iloc[:,27]
#print(onsetm_nm)
print(onsetm_nm.value_counts().sort_values(ascending= True), onsetm_nm.describe())
# Out:
# 75.0        1
# 90.0        1
# 99.0        1
# 60.0        5
# 54.0        9
#         ...
# 50.0     1229
# 40.0     1324
# 20.0     1343
# 30.0    13528
# 0.0     53749
# Name: ONSETM_NM, Length: 64, dtype: int64 count    75078.00000
# mean         8.48403
# std         14.41902
# min          0.00000
# 25%          0.00000
# 50%          0.00000
# 75%         20.00000
# max         99.00000
# Name: ONSETM_NM, dtype: float64

# %%
#Y = 不確定發病時間
onset_fl = cdc.iloc[:,28]
#print(onset_fl)
print(onset_fl.value_counts().sort_values(ascending= True), onset_fl.describe())
# Out:
# Y    60571
# N    76459
# Name: ONSET_FL, dtype: int64 count     137030
# unique         2
# top            N
# freq       76459
# Name: ONSET_FL, dtype: object

# %%
#門診/急診日期
ot_dt = cdc.iloc[:,29]
#print(ot_dt)
print(ot_dt.value_counts().sort_values(ascending= True), ot_dt.describe())
# Out:
# 0102-05-18              1
# 1822-01-10              1
# 0105-12-14              1
# 0208-12-01              1
# 0210-03-07              1
#                        ..
# 2008-01-28 00:00:00    64
# 2008-04-04 00:00:00    67
# 2007-07-31 00:00:00    68
# 2008-02-18 00:00:00    71
# 2008-02-11 00:00:00    77
# Name: OT_DT, Length: 4683, dtype: int64 count                  126426
# unique                   4683
# top       2008-02-11 00:00:00
# freq                       77
# Name: OT_DT, dtype: object

# %%
#門診/急診時間-時
ottih_nm = cdc.iloc[:,30]
#print(ottih_nm)
print(ottih_nm.value_counts().sort_values(ascending= True), ottih_nm.describe())
# Out:
# 24.0       2
# 3.0     1059
# 4.0     1070
# 2.0     1262
# 5.0     1410
# 1.0     1576
# 0.0     2127
# 6.0     2344
# 23.0    3048
# 7.0     4108
# 22.0    4147
# 21.0    5232
# 17.0    6012
# 18.0    6587
# 16.0    6641
# 8.0     6736
# 15.0    6776
# 20.0    6825
# 19.0    7036
# 14.0    7071
# 13.0    7169
# 12.0    7752
# 11.0    8648
# 9.0     9278
# 10.0    9427
# Name: OTTIH_NM, dtype: int64 count    123343.000000
# mean         13.324939
# std           5.427967
# min           0.000000
# 25%           9.000000
# 50%          13.000000
# 75%          18.000000
# max          24.000000
# Name: OTTIH_NM, dtype: float64

# %%
#門診/急診時間-秒
ottim_nm = cdc.iloc[:,31]
#print(ottim_nm)
print(ottim_nm.value_counts().sort_values(ascending= True), ottim_nm.describe())
# Out:
# 44.0    1850
# 7.0     1861
# 57.0    1863
# 39.0    1863
# 6.0     1877
# 9.0     1879
# 56.0    1880
# 31.0    1884
# 1.0     1895
# 21.0    1898
# 33.0    1904
# 12.0    1905
# 59.0    1909
# 26.0    1914
# 53.0    1919
# 46.0    1930
# 54.0    1934
# 4.0     1939
# 47.0    1941
# 23.0    1944
# 29.0    1947
# 41.0    1949
# 36.0    1950
# 11.0    1955
# 16.0    1957
# 37.0    1960
# 14.0    1961
# 38.0    1965
# 19.0    1966
# 49.0    1968
# 51.0    1971
# 3.0     1980
# 43.0    1982
# 28.0    1985
# 2.0     1990
# 24.0    1995
# 34.0    1999
# 52.0    2004
# 18.0    2006
# 32.0    2018
# 13.0    2021
# 42.0    2026
# 27.0    2026
# 58.0    2026
# 8.0     2056
# 17.0    2060
# 48.0    2074
# 22.0    2105
# 55.0    2193
# 25.0    2278
# 5.0     2286
# 35.0    2312
# 10.0    2347
# 15.0    2362
# 40.0    2378
# 45.0    2385
# 20.0    2448
# 50.0    2485
# 30.0    2645
# 0.0     3326
# Name: OTTIM_NM, dtype: int64 count    123336.000000
# mean         29.173307
# ...

# %%
#Y = 不確定門/急診時間
ot_fl = cdc.iloc[:,32]
#print(ot_fl)
print(ot_fl.value_counts().sort_values(ascending= True), ot_fl.describe())
# Out:
# Y      2826
# N    132415
# Name: OT_FL, dtype: int64 count     135241
# unique         2
# top            N
# freq      132415
# Name: OT_FL, dtype: object

# %%
#第一次醫師檢視日期
flook_dt = cdc.iloc[:,33]
#print(flook_dt)
print(flook_dt.value_counts().sort_values(ascending= True), flook_dt.describe())
# Out:
# 2000-06-18 00:00:00     1
# 0106-01-15              1
# 0106-03-03              1
# 2031-03-04 00:00:00     1
# 2005-09-06 00:00:00     1
#                        ..
# 2007-12-13 00:00:00    65
# 2008-04-04 00:00:00    66
# 2007-07-31 00:00:00    69
# 2008-02-18 00:00:00    72
# 2008-02-11 00:00:00    76
# Name: FLOOK_DT, Length: 4731, dtype: int64 count                  129269
# unique                   4731
# top       2008-02-11 00:00:00
# freq                       76
# Name: FLOOK_DT, dtype: object

# %%
#第一次醫師檢視時間-時
flookh_nm = cdc.iloc[:,34]
#print(flookh_nm)
print(flookh_nm.value_counts().sort_values(ascending= True), flookh_nm.describe())
# Out:
# 29.0       1
# 25.0       1
# 24.0       7
# 4.0     1095
# 3.0     1097
# 2.0     1301
# 5.0     1348
# 1.0     1694
# 6.0     2129
# 0.0     2287
# 23.0    3382
# 7.0     3818
# 22.0    4491
# 21.0    5683
# 8.0     6171
# 17.0    6377
# 18.0    6629
# 16.0    6964
# 20.0    6997
# 19.0    7023
# 15.0    7082
# 14.0    7326
# 13.0    7508
# 12.0    8143
# 9.0     8923
# 11.0    8980
# 10.0    9575
# Name: FLOOKH_NM, dtype: int64 count    126032.000000
# mean         13.450640
# std           5.450906
# min           0.000000
# 25%          10.000000
# 50%          13.000000
# 75%          18.000000
# max          29.000000
# Name: FLOOKH_NM, dtype: float64

# %%
#第一次醫師檢視時間-分
flookm_nm = cdc.iloc[:,35]
#print(flookm_nm)
print(flookm_nm.value_counts().sort_values(ascending= True), flookm_nm.describe())
# Out:
# 60.0       3
# 4.0     1422
# 31.0    1437
# 49.0    1439
# 1.0     1445
#         ...
# 20.0    4630
# 40.0    4634
# 50.0    4798
# 30.0    5548
# 0.0     6344
# Name: FLOOKM_NM, Length: 61, dtype: int64 count    126026.000000
# mean         28.520988
# std          17.451710
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          60.000000
# Name: FLOOKM_NM, dtype: float64

# %%
#Y = 不確定第一次醫師檢視時間
flook_fl = cdc.iloc[:,36]
#print(flook_fl)
print(flook_fl.value_counts().sort_values(ascending= True), flook_fl.describe())
# Out:
# Y      2778
# N    132376
# Name: FLOOK_FL, dtype: int64 count     135154
# unique         2
# top            N
# freq      132376
# Name: FLOOK_FL, dtype: object

# %%
#1st CT 日期
fct_dt = cdc.iloc[:,37]
#print(fct_dt)
print(fct_dt.value_counts().sort_values(ascending= True), fct_dt.describe())
# Out:
# 0102-07-06              1
# 2018-12-29 00:00:00     1
# 2019-08-08 00:00:00     1
# 0107-03-19              1
# 0106-06-29              1
#                        ..
# 2007-07-31 00:00:00    68
# 2008-06-16 00:00:00    70
# 2008-02-18 00:00:00    75
# 2007-04-23 00:00:00    80
# 2008-02-11 00:00:00    87
# Name: FCT_DT, Length: 4750, dtype: int64 count                  130730
# unique                   4750
# top       2008-02-11 00:00:00
# freq                       87
# Name: FCT_DT, dtype: object

# %%
#1st CT 時間-時
fcth_nm = cdc.iloc[:,38]
#print(fcth_nm)
print(fcth_nm.value_counts().sort_values(ascending= True), fcth_nm.describe())
# Out:
# 55.0       1
# 26.0       1
# 63.0       1
# 31.0       1
# 52.0       1
# 33.0       1
# 85.0       1
# 29.0       1
# 90.0       1
# 28.0       2
# 24.0       5
# 99.0       9
# 4.0     1044
# 3.0     1045
# 5.0     1197
# 2.0     1393
# 1.0     1837
# 6.0     1854
# 0.0     2255
# 7.0     3340
# 23.0    3566
# 22.0    4660
# 8.0     5289
# 21.0    6079
# 18.0    6316
# 17.0    6611
# 19.0    6843
# 20.0    6936
# 14.0    7528
# 16.0    7539
# 15.0    7561
# 13.0    7608
# 12.0    7773
# 9.0     7892
# 11.0    9297
# 10.0    9615
# Name: FCTH_NM, dtype: int64 count    125103.000000
# mean         13.623422
# std           5.508904
# min           0.000000
# 25%          10.000000
# 50%          14.000000
# 75%          18.000000
# max          99.000000
# Name: FCTH_NM, dtype: float64

# %%
#1st CT 時間-分
fctm_nm = cdc.iloc[:,39]
#print(fctm_nm)
print(fctm_nm.value_counts().sort_values(ascending= True), fctm_nm.describe())
# Out:
# 72.0       1
# 91.0       1
# 66.0       1
# 63.0       1
# 84.0       1
#         ...
# 20.0    2388
# 50.0    2388
# 40.0    2500
# 30.0    2849
# 0.0     3249
# Name: FCTM_NM, Length: 70, dtype: int64 count    125098.000000
# mean         29.349190
# std          17.383725
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          99.000000
# Name: FCTM_NM, dtype: float64

# %%
#Y = 1st CT 外片
fctoh_fl = cdc.iloc[:,40]
#print(fctoh_fl)
print(fctoh_fl.value_counts().sort_values(ascending= True), fctoh_fl.describe())
# Out:
# Y     5963
# N    69673
# Name: FCTOH_FL, dtype: int64 count     75636
# unique        2
# top           N
# freq      69673
# Name: FCTOH_FL, dtype: object

# %%
sns.countplot(fctoh_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FCTOH_FL', ylabel='count'>

# %%
#IV-tPA
ivtpath_id = cdc.iloc[:,41]
#print(ivtpath_id)
print(ivtpath_id.value_counts().sort_values(ascending= True), ivtpath_id.describe())
# Out:
# 2.0     205
# 1.0    5481
# Name: IVTPATH_ID, dtype: int64 count    5686.000000
# mean        1.036053
# std         0.186440
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: IVTPATH_ID, dtype: float64

# %%
ivtpath_id_labels = ["This hospital","Another hospital"]
sns.countplot(ivtpath_id).set_xticklabels(ivtpath_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'This hospital'), Text(1, 0, 'Another hospital')]

# %%
#IV-tPA 日期
ivtpa_dt = cdc.iloc[:,44]
#print(ivtpa_dt)
print(ivtpa_dt.value_counts().sort_values(ascending= True), ivtpa_dt.describe())
# Out:
# 2010-09-23 00:00:00    1
# 2013-07-11 00:00:00    1
# 0105-11-18             1
# 2008-11-25 00:00:00    1
# 2014-03-05 00:00:00    1
#                       ..
# 2015-06-24 00:00:00    7
# 2014-01-09 00:00:00    7
# 2016-04-19 00:00:00    7
# 2012-06-23 00:00:00    8
# 2014-02-12 00:00:00    9
# Name: IVTPA_DT, Length: 2977, dtype: int64 count                    5697
# unique                   2977
# top       2014-02-12 00:00:00
# freq                        9
# Name: IVTPA_DT, dtype: object

# %%
#IV-tPA 時間-時
ivtpah_nm = cdc.iloc[:,45]
#print(ivtpah_nm)
print(ivtpah_nm.value_counts().sort_values(ascending= True), ivtpah_nm.describe())
# Out:
# 4.0      42
# 5.0      48
# 3.0      60
# 6.0      63
# 7.0      84
# 2.0      95
# 1.0     121
# 0.0     152
# 8.0     193
# 23.0    227
# 18.0    262
# 19.0    272
# 22.0    286
# 17.0    289
# 15.0    304
# 16.0    304
# 21.0    312
# 9.0     314
# 12.0    320
# 13.0    338
# 20.0    369
# 11.0    372
# 10.0    379
# 14.0    385
# Name: IVTPAH_NM, dtype: int64 count    5591.000000
# mean       13.844929
# std         5.883280
# min         0.000000
# 25%        10.000000
# 50%        14.000000
# 75%        19.000000
# max        23.000000
# Name: IVTPAH_NM, dtype: float64

# %%
#IV-tPA 時間-分
ivtpam_nm = cdc.iloc[:,46]
#print(ivtpam_nm)
print(ivtpam_nm.value_counts().sort_values(ascending= True), ivtpam_nm.describe())
# Out:
# 11.0     40
# 21.0     41
# 44.0     43
# 31.0     43
# 9.0      44
# 16.0     44
# 46.0     45
# 6.0      46
# 54.0     47
# 39.0     47
# 14.0     49
# 41.0     49
# 19.0     50
# 53.0     50
# 22.0     52
# 59.0     52
# 47.0     52
# 49.0     54
# 51.0     54
# 29.0     55
# 1.0      55
# 36.0     55
# 4.0      56
# 56.0     57
# 33.0     57
# 27.0     58
# 26.0     58
# 13.0     58
# 34.0     60
# 52.0     60
# 57.0     61
# 28.0     64
# 7.0      65
# 2.0      66
# 32.0     66
# 8.0      66
# 38.0     67
# 58.0     67
# 24.0     68
# 18.0     70
# 48.0     72
# 3.0      72
# 37.0     73
# 17.0     75
# 42.0     75
# 12.0     79
# 43.0     80
# 23.0     86
# 35.0    168
# 5.0     179
# 25.0    188
# 55.0    190
# 10.0    225
# 45.0    226
# 15.0    227
# 20.0    247
# 50.0    250
# 40.0    254
# 30.0    296
# 0.0     337
# Name: IVTPAM_NM, dtype: int64 count    5590.000000
# mean       28.233095
# std        17.434946
# min         0.000000
# 25%        14.000000
# ...

# %%
#Start IV-tPA mg
ivtpamg_nm = cdc.iloc[:,47]
#print(ivtpamg_nm)
print(ivtpamg_nm.value_counts().sort_values(ascending= True), ivtpamg_nm.describe())
# Out:
# 40.2      1
# 39.2      1
# 39.9      1
# 53.8      1
# 5.4       1
#        ...
# 30.0    132
# 60.0    165
# 45.0    223
# 40.0    257
# 50.0    882
# Name: IVTPAMG_NM, Length: 346, dtype: int64 count    4534.000000
# mean       48.940940
# std        21.941571
# min         0.000000
# 25%        40.000000
# 50%        50.000000
# 75%        58.000000
# max      1000.000000
# Name: IVTPAMG_NM, dtype: float64

# %%
ht.plot.box(figsize=(5,5))
plt.show()
ht.plot.hist(figsize=(5,5), bins=100)
plt.show()
ht.plot.hist(figsize=(5,5), bins=100, range=[130,190])
plt.show()

# %%
#未打IV-tPA 原因
nivtpa_id = cdc.iloc[:,48]
#print(nivtpa_id)
print(nivtpa_id.value_counts().sort_values(ascending= True), nivtpa_id.describe())
# Out:
# 3.0     2962
# 2.0     4869
# 1.0    43965
# Name: NIVTPA_ID, dtype: int64 count    51796.000000
# mean         1.208375
# std          0.528519
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: NIVTPA_ID, dtype: float64

# %%
nivtpa_id_labels = ["輸注本藥前，急性缺血性中風發作的時間已超過 3 小時或症狀發作時間不明","缺血性中風發作至到院2 小時內，但不符合下列施打條件", "缺血性中風發作至到院2-3 小時內，但不符合下列施打條件"]
sns.countplot(nivtpa_id).set_xticklabels(nivtpa_id_labels, rotation=5)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '輸注本藥前，急性缺血性中風發作的時間已超過 3 小時或症狀發作時間不明'),
#  Text(1, 0, '缺血性中風發作至到院2 小時內，但不符合下列施打條件'),
#  Text(2, 0, '缺血性中風發作至到院2-3 小時內，但不符合下列施打條件')]

# %%
#輸注本藥前，急性缺血性腦中風的症狀已迅速改善或症狀輕微。（如NIHSS<6分）
nivtpa1_fl = cdc.iloc[:,49]
#print(nivtpa1_fl)
print(nivtpa1_fl.value_counts().sort_values(ascending= True), nivtpa1_fl.describe())
# Out:
# Y      350
# 1     4173
# N     7075
# 0    67387
# Name: NIVTPA1_FL, dtype: int64 count     78985
# unique        4
# top           0
# freq      67387
# Name: NIVTPA1_FL, dtype: int64

# %%
sns.countplot(nivtpa1_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA1_FL', ylabel='count'>

# %%
#臨床或影像判定為嚴重之中風（如NIHSS>25）
nivtpa2_fl = cdc.iloc[:,50]
#print(nivtpa2_fl)
print(nivtpa2_fl.value_counts().sort_values(ascending= True), nivtpa2_fl.describe())
# Out:
# Y       64
# 1      704
# N     7361
# 0    70856
# Name: NIVTPA2_FL, dtype: int64 count     78985
# unique        4
# top           0
# freq      70856
# Name: NIVTPA2_FL, dtype: int64

# %%
sns.countplot(nivtpa2_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA2_FL', ylabel='count'>

# %%
#年齡在18歲以下，或80歲以上
nivtpa3_fl = cdc.iloc[:,51]
#print(nivtpa3_fl)
print(nivtpa3_fl.value_counts().sort_values(ascending= True), nivtpa3_fl.describe())
# Out:
# Y      150
# 1     1680
# N     7275
# 0    69880
# Name: NIVTPA3_FL, dtype: int64 count     78985
# unique        4
# top           0
# freq      69880
# Name: NIVTPA3_FL, dtype: int64

# %%
sns.countplot(nivtpa3_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA3_FL', ylabel='count'>

# %%
#過去曾中風且合併糖尿病
nivtpa4_fl = cdc.iloc[:,52]
#print(nivtpa4_fl)
print(nivtpa4_fl.value_counts().sort_values(ascending= True), nivtpa4_fl.describe())
# Out:
# Y       49
# 1      456
# N     7283
# 0    71104
# Name: NIVTPA4_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71104
# Name: NIVTPA4_FL, dtype: int64

# %%
sns.countplot(nivtpa4_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA4_FL', ylabel='count'>

# %%
#最近3個月內有中風病史或有嚴重性頭部創傷
nivtpa5_fl = cdc.iloc[:,53]
#print(nivtpa5_fl)
print(nivtpa5_fl.value_counts().sort_values(ascending= True), nivtpa5_fl.describe())
# Out:
# Y       28
# 1      209
# N     7304
# 0    71351
# Name: NIVTPA5_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71351
# Name: NIVTPA5_FL, dtype: int64

# %%
sns.countplot(nivtpa5_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA5_FL', ylabel='count'>

# %%
#中風發作時併發癲癇
nivtpa6_fl = cdc.iloc[:,54]
#print(nivtpa6_fl)
print(nivtpa6_fl.value_counts().sort_values(ascending= True), nivtpa6_fl.describe())
# Out:
# Y       16
# 1      139
# N     7316
# 0    71421
# Name: NIVTPA6_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71421
# Name: NIVTPA6_FL, dtype: int64

# %%
sns.countplot(nivtpa6_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA6_FL', ylabel='count'>

# %%
#病人正接受口服抗凝血劑，如warfarin sodium（INR>1.3）
nivtpa7_fl = cdc.iloc[:,55]
#print(nivtpa7_fl)
print(nivtpa7_fl.value_counts().sort_values(ascending= True), nivtpa7_fl.describe())
# Out:
# Y       19
# 1      209
# N     7313
# 0    71351
# Name: NIVTPA7_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71351
# Name: NIVTPA7_FL, dtype: int64

# %%
sns.countplot(nivtpa7_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA7_FL', ylabel='count'>

# %%
#最近3個月內曾患胃腸道潰瘍
nivtpa8_fl = cdc.iloc[:,56]
#print(nivtpa8_fl)
print(nivtpa8_fl.value_counts().sort_values(ascending= True), nivtpa8_fl.describe())
# Out:
# Y        6
# 1      101
# N     7326
# 0    71459
# Name: NIVTPA8_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71459
# Name: NIVTPA8_FL, dtype: int64

# %%
sns.countplot(nivtpa8_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA8_FL', ylabel='count'>

# %%
#家屬拒絕
nivtpa9_fl = cdc.iloc[:,57]
#print(nivtpa9_fl)
print(nivtpa9_fl.value_counts().sort_values(ascending= True), nivtpa9_fl.describe())
# Out:
# Y       12
# 1      195
# N     7320
# 0    71365
# Name: NIVTPA9_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71365
# Name: NIVTPA9_FL, dtype: int64

# %%
sns.countplot(nivtpa9_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA9_FL', ylabel='count'>

# %%
#輸注本藥前，缺血性腦中風發作的時間已超過3小時
nivtpa10_fl = cdc.iloc[:,58]
#print(nivtpa10_fl)
print(nivtpa10_fl.value_counts().sort_values(ascending= True), nivtpa10_fl.describe())
# Out:
# Y      168
# 1     1897
# N     7164
# 0    69663
# Name: NIVTPA10_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      69663
# Name: NIVTPA10_FL, dtype: int64

# %%
sns.countplot(nivtpa10_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA10_FL', ylabel='count'>

# %%
#收縮壓>185mmhg或舒張壓>110mmhg
nivtpa11_fl = cdc.iloc[:,59]
#print(nivtpa11_fl)
print(nivtpa11_fl.value_counts().sort_values(ascending= True), nivtpa11_fl.describe())
# Out:
# Y       18
# 1      493
# N     7314
# 0    71067
# Name: NIVTPA11_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      71067
# Name: NIVTPA11_FL, dtype: int64

# %%
sns.countplot(nivtpa11_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA11_FL', ylabel='count'>

# %%
#不符合施打條件其他(未打IV-tPA 原因)
nivtpa99_fl = cdc.iloc[:,60]
#print(nivtpa99_fl)
print(nivtpa99_fl.value_counts().sort_values(ascending= True), nivtpa99_fl.describe())
# Out:
# Y       80
# 1     1344
# N     7252
# 0    70216
# Name: NIVTPA99_FL, dtype: int64 count     78892
# unique        4
# top           0
# freq      70216
# Name: NIVTPA99_FL, dtype: int64

# %%
sns.countplot(nivtpa99_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NIVTPA99_FL', ylabel='count'>

# %%
#nivtpa99_tx

# %%
#GCS-E eye opening
gscenm = cdc.iloc[:,62]
#print(gscenm)
print(gscenm.value_counts().sort_values(ascending= True), gscenm.describe())
# Out:
# 7.0           1
# 82.0          1
# 14.0          1
# 6.0           1
# 54.0          1
# 0.0           1
# 5.0           2
# 999.9        30
# 2.0        4397
# 1.0        7805
# 3.0        8277
# 4.0      116433
# Name: GCSE_NM, dtype: int64 count    136950.000000
# mean          3.923563
# std          14.765725
# min           0.000000
# 25%           4.000000
# 50%           4.000000
# 75%           4.000000
# max         999.900000
# Name: GCSE_NM, dtype: float64

# %%
sns.countplot(gscenm)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GCSE_NM', ylabel='count'>

# %%
#GCS-V verbal response
gscvnm = cdc.iloc[:,63]
#print(gscvnm)
print(gscvnm.value_counts().sort_values(ascending= True), gscvnm.describe())
# Out:
# T                          1
# Ｔ                          1
# m                          1
# 2021-01-02 00:00:00        1
# 1+E                        1
# 1+t                        1
# V                          1
# ET                         1
# L                          1
# A5                         1
# 1E                         1
# 56                         1
# 36.8                       1
# d                          1
# 1+T                        3
# 0                          5
# 7                          5
# D                         12
# 999.9                     30
# e                         51
# 6                         54
# t                         59
# a                        141
# T                       1134
# E                       1972
# A                       2374
# 3                       3301
# 4                       6935
# 2                       7673
# 1                      13697
# 5                      99496
# ...

# %%
sns.countplot(gscvnm)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GCSV_NM', ylabel='count'>

# %%
#GCS-M motor response
gscmnm = cdc.iloc[:,64]
#print(gscmnm)
print(gscmnm.value_counts().sort_values(ascending= True), gscmnm.describe())
# Out:
# 23.0          1
# 9.0           1
# 177.0         1
# 8.0           2
# 4.5           2
# 999.9        29
# 2.0        1627
# 3.0        2352
# 1.0        3752
# 4.0        7822
# 5.0       12877
# 6.0      108490
# Name: GCSM_NM, dtype: int64 count    136956.000000
# mean          5.767590
# std          14.515051
# min           1.000000
# 25%           6.000000
# 50%           6.000000
# 75%           6.000000
# max         999.900000
# Name: GCSM_NM, dtype: float64

# %%
sns.countplot(gscmnm)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GCSM_NM', ylabel='count'>

# %%
#SBP
sbp_nm = cdc.iloc[:,65]
#print(sbp_nm)
print(sbp_nm.value_counts().sort_values(ascending= True), sbp_nm.describe())
# Out:
# 0.16         1
# 46.00        1
# 20.00        1
# 28.00        1
# 38.00        1
#           ...
# 151.00    1835
# 154.00    1864
# 140.00    2021
# 160.00    2060
# 150.00    2076
# Name: SBP_NM, Length: 296, dtype: int64 count    136910.000000
# mean        161.874082
# std          38.356997
# min           0.000000
# 25%         139.000000
# 50%         159.000000
# 75%         182.000000
# max         999.900000
# Name: SBP_NM, dtype: float64

# %%
sbp_nm.plot.box(figsize=(5,5))
plt.show()
sbp_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
sbp_nm.plot.hist(figsize=(5,5), bins=100, range=[50,300])
plt.show()

# %%
#DBP
dbp_nm = cdc.iloc[:,66]
#print(dbp_nm)
print(dbp_nm.value_counts().sort_values(ascending= True), dbp_nm.describe())
# Out:
# 836.0       1
# 1.8         1
# 474.0       1
# 221.0       1
# 70.6        1
#          ...
# 88.0     2954
# 86.0     2954
# 84.0     3073
# 90.0     3481
# 80.0     3622
# Name: DBP_NM, Length: 225, dtype: int64 count    136909.000000
# mean         90.442104
# std          30.883359
# min           0.000000
# 25%          76.000000
# 50%          88.000000
# 75%         102.000000
# max         999.900000
# Name: DBP_NM, dtype: float64

# %%
dbp_nm.plot.box(figsize=(5,5))
plt.show()
dbp_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
dbp_nm.plot.hist(figsize=(5,5), bins=100, range=[0,200])
plt.show()

# %%
#BT bleesing time?
dt_nm = cdc.iloc[:,67]
#print(dt_nm)
print(dt_nm.value_counts().sort_values(ascending= True), dt_nm.describe())
# Out:
# 69.70        1
# 31.60        1
# 36.36        1
# 16.60        1
# 31.10        1
#          ...
# 36.80     8399
# 36.40     8468
# 36.20    10470
# 36.50    11801
# 36.00    14826
# Name: BT_NM, Length: 204, dtype: int64 count    136870.000000
# mean         37.721094
# std          33.523866
# min           0.000000
# 25%          36.000000
# 50%          36.500000
# 75%          36.800000
# max         999.900000
# Name: BT_NM, dtype: float64

# %%
dt_nm.plot.box(figsize=(5,5))
plt.show()
dt_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
dt_nm.plot.hist(figsize=(5,5), bins=100, range=[34,40])
plt.show()

# %%
#HR
hr_nm = cdc.iloc[:,68]
#print(hr_nm)
print(hr_nm.value_counts().sort_values(ascending= True), hr_nm.describe())
# Out:
# 27.0        1
# 189.0       1
# 58.8        1
# 13.0        1
# 218.0       1
#          ...
# 70.0     3446
# 76.0     3638
# 78.0     3737
# 72.0     3801
# 80.0     4472
# Name: HR_NM, Length: 211, dtype: int64 count    136904.000000
# mean         82.621670
# std          28.288596
# min           0.000000
# 25%          70.000000
# 50%          80.000000
# 75%          92.000000
# max         999.900000
# Name: HR_NM, dtype: float64

# %%
hr_nm.plot.box(figsize=(5,5))
plt.show()
hr_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
hr_nm.plot.hist(figsize=(5,5), bins=100, range=[0,200])
plt.show()

# %%
#RR
rr_nm = cdc.iloc[:,69]
#print(rr_nm)
print(rr_nm.value_counts().sort_values(ascending= True), rr_nm.describe())
# Out:
# 71.0         1
# 119.0        1
# 55.0         1
# 62.0         1
# 74.0         1
#          ...
# 22.0      6128
# 19.0      9187
# 16.0     14317
# 18.0     39644
# 20.0     47983
# Name: RR_NM, Length: 91, dtype: int64 count    136684.000000
# mean         21.193953
# std          48.110909
# min           0.000000
# 25%          18.000000
# 50%          19.000000
# 75%          20.000000
# max         999.900000
# Name: RR_NM, dtype: float64

# %%
rr_nm.plot.box(figsize=(5,5))
plt.show()
rr_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
rr_nm.plot.hist(figsize=(5,5), range=[10,30])
plt.show()

# %%
#Final Stroke diagnosis
icd_id = cdc.iloc[:,70]
#print(icd_id)
print(icd_id.value_counts().sort_values(ascending= True), icd_id.describe())
# Out:
# 99.0       315
# 4.0       3381
# 2.0       9940
# 3.0      19231
# 1.0     102460
# Name: ICD_ID, dtype: int64 count    135327.000000
# mean          1.660733
# std           4.773418
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          99.000000
# Name: ICD_ID, dtype: float64

# %%
icd_id_labels = ["Infarct","TIA", "ICH", "SAH", "Others"]
sns.countplot(icd_id).set_xticklabels(icd_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Infarct'),
#  Text(1, 0, 'TIA'),
#  Text(2, 0, 'ICH'),
#  Text(3, 0, 'SAH'),
#  Text(4, 0, 'Others')]

# %%
#ICD_TX

# %%
#Final Stroke Diagnosis TIA
icdtia_id = cdc.iloc[:,72]
#print(icdtia_id)
print(icdtia_id.value_counts().sort_values(ascending= True), icdtia_id.describe())
# Out:
# 2.0    3117
# 1.0    7264
# Name: ICDTIA_ID, dtype: int64 count    10381.000000
# mean         1.300260
# std          0.458393
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000
# Name: ICDTIA_ID, dtype: float64

# %%
icdtia_id_labels = ["Carotid","VB"]
sns.countplot(icdtia_id).set_xticklabels(icdtia_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Carotid'), Text(1, 0, 'VB')]

# %%
#ICDO_TX

# %%
#Ischemic subtype(TOAST 分類)_缺血性中風
toast_id = cdc.iloc[:,74]
#print(toast_id)
print(toast_id.value_counts().sort_values(ascending= True), toast_id.describe())
# Out:
# 3.0     1664
# 4.0    12373
# 5.0    17714
# 1.0    26573
# 2.0    36819
# Name: TOAST_ID, dtype: int64 count    95143.000000
# mean         2.556836
# std          1.477354
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max          5.000000
# Name: TOAST_ID, dtype: float64

# %%
toast_id_labels = ["Large artery atherosclerosis","Small vessel occlusion","Specific etiology","Cardioembolism","Undetermined etiology"]
sns.countplot(toast_id).set_xticklabels(toast_id_labels, rotation=5)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Large artery atherosclerosis'),
#  Text(1, 0, 'Small vessel occlusion'),
#  Text(2, 0, 'Specific etiology'),
#  Text(3, 0, 'Cardioembolism'),
#  Text(4, 0, 'Undetermined etiology')]

# %%
#Large artery atherosclerosis - extra
toastle_fl = cdc.iloc[:,75]
#print(toastle_fl)
print(toastle_fl.value_counts().sort_values(ascending= True), toastle_fl.describe())
# Out:
# Y       389
# 1      5509
# N      6945
# 0    125612
# Name: TOASTLE_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      125612
# Name: TOASTLE_FL, dtype: int64

# %%
sns.countplot(toastle_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTLE_FL', ylabel='count'>

# %%
#Large artery atherosclerosis - intra
toastli_fl = cdc.iloc[:,76]
#print(toastli_fl)
print(toastli_fl.value_counts().sort_values(ascending= True), toastli_fl.describe())
# Out:
# Y      1140
# N      6194
# 1     20585
# 0    110536
# Name: TOASTLI_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      110536
# Name: TOASTLI_FL, dtype: int64

# %%
sns.countplot(toastli_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTLI_FL', ylabel='count'>

# %%
#Specific etiology - Cerebral venous thrombosis
toastsce_fl = cdc.iloc[:,77]
#print(toastsce_fl)
print(toastsce_fl.value_counts().sort_values(ascending= True), toastsce_fl.describe())
# Out:
# Y        11
# 1       185
# N      7323
# 0    130936
# Name: TOASTSCE_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      130936
# Name: TOASTSCE_FL, dtype: int64

# %%
sns.countplot(toastsce_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSCE_FL', ylabel='count'>

# %%
#Specific etiology - Moyamoya Syndrome
toastsmo_fl = cdc.iloc[:,78]
#print(toastsmo_fl)
print(toastsmo_fl.value_counts().sort_values(ascending= True), toastsmo_fl.describe())
# Out:
# 1      2521
# N      7334
# 0    128600
# Name: TOASTSMO_FL, dtype: int64 count     138455
# unique         3
# top            0
# freq      128600
# Name: TOASTSMO_FL, dtype: int64

# %%
sns.countplot(toastsmo_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSMO_FL', ylabel='count'>

# %%
#Specific etiology - Radiation
toastsra_fl = cdc.iloc[:,79]
#print(toastsra_fl)
print(toastsra_fl.value_counts().sort_values(ascending= True), toastsra_fl.describe())
# Out:
# Y         2
# N      7332
# 1     10014
# 0    121107
# Name: TOASTSRA_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      121107
# Name: TOASTSRA_FL, dtype: int64

# %%
sns.countplot(toastsra_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSRA_FL', ylabel='count'>

# %%
#Specific etiology - Dissection
toastsdi_fl = cdc.iloc[:,80]
#print(toastsdi_fl)
print(toastsdi_fl.value_counts().sort_values(ascending= True), toastsdi_fl.describe())
# Out:
# Y        17
# 1       375
# N      7317
# 0    130746
# Name: TOASTSDI_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      130746
# Name: TOASTSDI_FL, dtype: int64

# %%
sns.countplot(toastsdi_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSDI_FL', ylabel='count'>

# %%
#Specific etiology - Migraine
toastsmi_fl = cdc.iloc[:,81]
#print(toastsmi_fl)
print(toastsmi_fl.value_counts().sort_values(ascending= True), toastsmi_fl.describe())
# Out:
# 1         6
# N      7334
# 0    131115
# Name: TOASTSMI_FL, dtype: int64 count     138455
# unique         3
# top            0
# freq      131115
# Name: TOASTSMI_FL, dtype: int64

# %%
sns.countplot(toastsmi_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSMI_FL', ylabel='count'>

# %%
#Specific etiology - Antiphospholipid Ab Synd
toastsantip_fl = cdc.iloc[:,82]
#print(toastsantip_fl)
print(toastsantip_fl.value_counts().sort_values(ascending= True), toastsantip_fl.describe())
# Out:
# Y         7
# 1        78
# N      7327
# 0    131043
# Name: TOASTSANTIP_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131043
# Name: TOASTSANTIP_FL, dtype: int64

# %%
sns.countplot(toastsantip_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSANTIP_FL', ylabel='count'>

# %%
#Specific etiology - Autoimmune disease
toastsau_fl = cdc.iloc[:,83]
#print(toastsau_fl)
print(toastsau_fl.value_counts().sort_values(ascending= True), toastsau_fl.describe())
# Out:
# Y         9
# 1        59
# N      7325
# 0    131062
# Name: TOASTSAU_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131062
# Name: TOASTSAU_FL, dtype: int64

# %%
sns.countplot(toastsau_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSAU_FL', ylabel='count'>

# %%
#Specific etiology - Hyperfibrinogenemia
toastshy_fl = cdc.iloc[:,84]
#print(toastshy_fl)
print(toastshy_fl.value_counts().sort_values(ascending= True), toastshy_fl.describe())
# Out:
# Y         1
# 1         6
# N      7333
# 0    131115
# Name: TOASTSHY_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131115
# Name: TOASTSHY_FL, dtype: int64

# %%
sns.countplot(toastshy_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSHY_FL', ylabel='count'>

# %%
#Specific etiology - Prot C/Prot S deficiency
toastspr_fl = cdc.iloc[:,85]
#print(toastspr_fl)
print(toastspr_fl.value_counts().sort_values(ascending= True), toastspr_fl.describe())
# Out:
# Y        10
# 1        32
# N      7324
# 0    131089
# Name: TOASTSPR_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131089
# Name: TOASTSPR_FL, dtype: int64

# %%
sns.countplot(toastspr_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSPR_FL', ylabel='count'>

# %%
#Specific etiology - Antithrombin III deficiency
toastsantit_fl = cdc.iloc[:,86]
#print(toastsantit_fl)
print(toastsantit_fl.value_counts().sort_values(ascending= True), toastsantit_fl.describe())
# Out:
# Y         4
# 1        12
# N      7330
# 0    131109
# Name: TOASTSANTIT_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131109
# Name: TOASTSANTIT_FL, dtype: int64

# %%
sns.countplot(toastsantit_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSANTIT_FL', ylabel='count'>

# %%
#Specific etiology - Homocystinuria
toastsho_fl = cdc.iloc[:,87]
#print(toastsho_fl)
print(toastsho_fl.value_counts().sort_values(ascending= True), toastsho_fl.describe())
# Out:
# Y         6
# 1        49
# N      7328
# 0    131072
# Name: TOASTSHO_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131072
# Name: TOASTSHO_FL, dtype: int64

# %%
sns.countplot(toastsho_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSHO_FL', ylabel='count'>

# %%
#Specific etiology - Hypercoagulable state
toastshys_fl = cdc.iloc[:,88]
#print(toastshys_fl)
print(toastshys_fl.value_counts().sort_values(ascending= True), toastshys_fl.describe())
# Out:
# Y         5
# 1        68
# N      7329
# 0    131053
# Name: TOASTSHYS_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      131053
# Name: TOASTSHYS_FL, dtype: int64

# %%
sns.countplot(toastshys_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSHYS_FL', ylabel='count'>

# %%
#Specific etiology - Cancer
toastsca_fl = cdc.iloc[:,89]
#print(toastsca_fl)
print(toastsca_fl.value_counts().sort_values(ascending= True), toastsca_fl.describe())
# Out:
# Y        23
# 1       385
# N      7311
# 0    130736
# Name: TOASTSCA_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      130736
# Name: TOASTSCA_FL, dtype: int64

# %%
sns.countplot(toastsca_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSCA_FL', ylabel='count'>

# %%
#Cancer text

# %%
#Specific etiology - Others
toastso_fl = cdc.iloc[:,91]
#print(toastso_fl)
print(toastso_fl.value_counts().sort_values(ascending= True), toastso_fl.describe())
# Out:
# Y        14
# 1       389
# N      7320
# 0    130732
# Name: TOASTSO_FL, dtype: int64 count     138455
# unique         4
# top            0
# freq      130732
# Name: TOASTSO_FL, dtype: int64

# %%
sns.countplot(toastso_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOASTSO_FL', ylabel='count'>

# %%
#Others text

# %%
#Undetermined etiology
toastu_id = cdc.iloc[:,93]
#print(toastu_id)
print(toastu_id.value_counts().sort_values(ascending= True), toastu_id.describe())
# Out:
# 2.0    4332
# 3.0    6338
# 1.0    7317
# Name: TOASTU_ID, dtype: int64 count    17987.000000
# mean         1.945572
# std          0.869620
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          3.000000
# Name: TOASTU_ID, dtype: float64

# %%
toastu_id_labels = ["Imcomplete study","Conflict data","Complete study"]
sns.countplot(toastu_id).set_xticklabels(toastu_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Imcomplete study'),
#  Text(1, 0, 'Conflict data'),
#  Text(2, 0, 'Complete study')]

# %%
#Cause of ICH 
cich_id = cdc.iloc[:,94]
#print(cich_id)
print(cich_id.value_counts().sort_values(ascending= True), cich_id.describe())
# Out:
# 2.0      3146
# 1.0     15218
# 0.0    113770
# Name: CICH_ID, dtype: int64 count    132134.000000
# mean          0.162789
# std           0.428846
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.000000
# Name: CICH_ID, dtype: float64

# %%
sns.countplot(cich_id)
#2 values but got 3 values
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CICH_ID', ylabel='count'>

# %%
#Cause of SAH (蜘蛛膜下腔出血(Subarachnoid hemorrhage, SAH))
csah_id = cdc.iloc[:,95]
#print(csah_id)
print(csah_id.value_counts().sort_values(ascending= True), csah_id.describe())
# Out:
# 3.0      168
# 99.0     216
# 2.0      306
# 4.0      323
# 1.0     2498
# Name: CSAH_ID, dtype: int64 count    3511.000000
# mean        7.487895
# std        23.452451
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        99.000000
# Name: CSAH_ID, dtype: float64

# %%
csah_id_labels = ["Aneurysm","AVM","Angio negative","Angio undone","Others"]
sns.countplot(csah_id).set_xticklabels(csah_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Aneurysm'),
#  Text(1, 0, 'AVM'),
#  Text(2, 0, 'Angio negative'),
#  Text(3, 0, 'Angio undone'),
#  Text(4, 0, 'Others')]

# %%
#Cause of SAH - Others

# %%
#Type of heart disease - NONE
thd_id = cdc.iloc[:,97]
#print(thd_id)
print(thd_id.value_counts(), len(thd_id) - thd_id.value_counts())
#88927 ppl have heart disease
# Out:
# 0.0    51557
# Name: THD_ID, dtype: int64 0.0    88927
# Name: THD_ID, dtype: int64

# %%
#Heart disease - Atrial fibrillation
thda_fl = cdc.iloc[:,98]
#print(thda_fl)
print(thda_fl.value_counts().sort_values(ascending= True), thda_fl.describe())
# Out:
# Y      1008
# N      5604
# 1     10311
# 0    121044
# Name: THDA_FL, dtype: int64 count     137967
# unique         4
# top            0
# freq      121044
# Name: THDA_FL, dtype: int64

# %%
sns.countplot(thda_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDA_FL', ylabel='count'>

# %%
#Heart disease - Heart failure
thdh_fl = cdc.iloc[:,99]
#print(thdh_fl)
print(thdh_fl.value_counts().sort_values(ascending= True), thdh_fl.describe())
# Out:
# Y       329
# 1      3112
# N      6010
# 0    128243
# Name: THDH_FL, dtype: int64 count     137694
# unique         4
# top            0
# freq      128243
# Name: THDH_FL, dtype: int64

# %%
sns.countplot(thdh_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDH_FL', ylabel='count'>

# %%
#Heart disease - Ischemic heart (CAD, old MI)
thdi_fl = cdc.iloc[:,100]
#print(thdi_fl)
print(thdi_fl.value_counts().sort_values(ascending= True), thdi_fl.describe())
# Out:
# Y       920
# N      5684
# 1     14920
# 0    116435
# Name: THDI_FL, dtype: int64 count     137959
# unique         4
# top            0
# freq      116435
# Name: THDI_FL, dtype: int64

# %%
sns.countplot(thdi_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDI_FL', ylabel='count'>

# %%
#Heart disease - AMI<4W
thdam_fl = cdc.iloc[:,101]
#print(thdam_fl)
print(thdam_fl.value_counts().sort_values(ascending= True), thdam_fl.describe())
# Out:
# Y        19
# 1       383
# N      3693
# 0    130972
# Name: THDAM_FL, dtype: int64 count     135067
# unique         4
# top            0
# freq      130972
# Name: THDAM_FL, dtype: int64

# %%
sns.countplot(thdam_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDAM_FL', ylabel='count'>

# %%
#Heart disease - Valvular replacement
thdv_fl = cdc.iloc[:,103]
#print(thdv_fl)
print(thdv_fl.value_counts().sort_values(ascending= True), thdv_fl.describe())
# Out:
# Y        55
# 1       572
# N      6184
# 0    130783
# Name: THDV_FL, dtype: int64 count     137594
# unique         4
# top            0
# freq      130783
# Name: THDV_FL, dtype: int64

# %%
sns.countplot(thdv_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDV_FL', ylabel='count'>

# %%
#Heart disease - Endocarditis
thde_fl = cdc.iloc[:,104]
#print(thde_fl)
print(thde_fl.value_counts().sort_values(ascending= True), thde_fl.describe())
# Out:
# Y         6
# 1        74
# N      6218
# 0    131281
# Name: THDE_FL, dtype: int64 count     137579
# unique         4
# top            0
# freq      131281
# Name: THDE_FL, dtype: int64

# %%
sns.countplot(thde_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDE_FL', ylabel='count'>

# %%
#Heart disease - Myxoma
thdm_fl = cdc.iloc[:,105]
#print(thdm_fl)
print(thdm_fl.value_counts().sort_values(ascending= True), thdm_fl.describe())
# Out:
# Y         1
# 1        14
# N      6222
# 0    131341
# Name: THDM_FL, dtype: int64 count     137578
# unique         4
# top            0
# freq      131341
# Name: THDM_FL, dtype: int64

# %%
sns.countplot(thdm_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDM_FL', ylabel='count'>

# %%
#Heart disease - RHD
thdr_fl = cdc.iloc[:,106]
#print(thdr_fl)
print(thdr_fl.value_counts().sort_values(ascending= True), thdr_fl.describe())
# Out:
# Y        25
# 1       171
# N      6209
# 0    131184
# Name: THDR_FL, dtype: int64 count     137589
# unique         4
# top            0
# freq      131184
# Name: THDR_FL, dtype: int64

# %%
sns.countplot(thdr_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDR_FL', ylabel='count'>

# %%
#Heart disease - Patent foramen ovale
thdp_fl = cdc.iloc[:,107]
#print(thdp_fl)
print(thdp_fl.value_counts().sort_values(ascending= True), thdp_fl.describe())
# Out:
# Y         9
# 1        47
# N      6218
# 0    131308
# Name: THDP_FL, dtype: int64 count     137582
# unique         4
# top            0
# freq      131308
# Name: THDP_FL, dtype: int64

# %%
sns.countplot(thdp_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDP_FL', ylabel='count'>

# %%
#Heart disease - Others
thdoo_fl = cdc.iloc[:,108]
#print(thdoo_fl)
print(thdoo_fl.value_counts().sort_values(ascending= True), thdoo_fl.describe())
# Out:
# Y       275
# 1      4031
# N      6044
# 0    127324
# Name: THDOO_FL, dtype: int64 count     137674
# unique         4
# top            0
# freq      127324
# Name: THDOO_FL, dtype: int64

# %%
sns.countplot(thdoo_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='THDOO_FL', ylabel='count'>

# %%
#THDOO_TX

# %%
#無住院治療
trm_id = cdc.iloc[:,131]
#print(trm_id)
print(trm_id.value_counts(), len(trm_id) - trm_id.value_counts())
#140175 ppl were admitted and treated
# Out:
# 0.0    309
# Name: TRM_ID, dtype: int64 0.0    140175
# Name: TRM_ID, dtype: int64

# %%
#住院治療 - Antithrombotic drugs start within 48h
trman_fl = cdc.iloc[:,132]
#print(trman_fl)
print(trman_fl.value_counts().sort_values(ascending= True), trman_fl.describe())
# Out:
# Y    55791
# N    81920
# Name: TRMAN_FL, dtype: int64 count     137711
# unique         2
# top            N
# freq       81920
# Name: TRMAN_FL, dtype: object

# %%
sns.countplot(trman_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMAN_FL', ylabel='count'>

# %%
#住院治療 - Aspirin
trmas_fl = cdc.iloc[:,133]
#print(trmas_fl)
print(trmas_fl.value_counts().sort_values(ascending= True), trmas_fl.describe())
# Out:
# Y    52191
# N    85402
# Name: TRMAS_FL, dtype: int64 count     137593
# unique         2
# top            N
# freq       85402
# Name: TRMAS_FL, dtype: object

# %%
sns.countplot(trmas_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMAS_FL', ylabel='count'>

# %%
#住院治療 - Ticlopidine
trmti_fl = cdc.iloc[:,134]
#print(trmti_fl)
print(trmti_fl.value_counts().sort_values(ascending= True), trmti_fl.describe())
# Out:
# Y      8736
# N    126384
# Name: TRMTI_FL, dtype: int64 count     135120
# unique         2
# top            N
# freq      126384
# Name: TRMTI_FL, dtype: object

# %%
sns.countplot(trmti_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMTI_FL', ylabel='count'>

# %%
#住院治療 - Heparin
trmhe_fl = cdc.iloc[:,135]
#print(trmhe_fl)
print(trmhe_fl.value_counts().sort_values(ascending= True), trmhe_fl.describe())
# Out:
# Y      2929
# N    132183
# Name: TRMHE_FL, dtype: int64 count     135112
# unique         2
# top            N
# freq      132183
# Name: TRMHE_FL, dtype: object

# %%
sns.countplot(trmhe_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMHE_FL', ylabel='count'>

# %%
#住院治療 - Warfarin
trmwa_fl = cdc.iloc[:,136]
#print(trmwa_fl)
print(trmwa_fl.value_counts().sort_values(ascending= True), trmwa_fl.describe())
# Out:
# Y      8825
# N    126456
# Name: TRMWA_FL, dtype: int64 count     135281
# unique         2
# top            N
# freq      126456
# Name: TRMWA_FL, dtype: object

# %%
sns.countplot(trmwa_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMWA_FL', ylabel='count'>

# %%
#住院治療 - IA thrombolysis
trmia_fl = cdc.iloc[:,137]
#print(trmia_fl)
print(trmia_fl.value_counts().sort_values(ascending= True), trmia_fl.describe())
# Out:
# Y      1984
# N    133093
# Name: TRMIA_FL, dtype: int64 count     135077
# unique         2
# top            N
# freq      133093
# Name: TRMIA_FL, dtype: object

# %%
sns.countplot(trmia_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMIA_FL', ylabel='count'>

# %%
#住院治療 - Foley
trmfo_fl = cdc.iloc[:,138]
#print(trmfo_fl)
print(trmfo_fl.value_counts().sort_values(ascending= True), trmfo_fl.describe())
# Out:
# Y     34634
# N    101367
# Name: TRMFO_FL, dtype: int64 count     136001
# unique         2
# top            N
# freq      101367
# Name: TRMFO_FL, dtype: object

# %%
sns.countplot(trmfo_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMFO_FL', ylabel='count'>

# %%
#住院治療 - Transarterial-embolization
trmta_fl = cdc.iloc[:,139]
#print(trmta_fl)
print(trmta_fl.value_counts().sort_values(ascending= True), trmta_fl.describe())
# Out:
# Y       206
# N    134883
# Name: TRMTA_FL, dtype: int64 count     135089
# unique         2
# top            N
# freq      134883
# Name: TRMTA_FL, dtype: object

# %%
sns.countplot(trmta_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMTA_FL', ylabel='count'>

# %%
#住院治療 - Sign DNR
trmsd_fl = cdc.iloc[:,140]
#print(trmsd_fl)
print(trmsd_fl.value_counts().sort_values(ascending= True), trmsd_fl.describe())
# Out:
# Y     10292
# N    125124
# Name: TRMSD_FL, dtype: int64 count     135416
# unique         2
# top            N
# freq      125124
# Name: TRMSD_FL, dtype: object

# %%
sns.countplot(trmsd_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMSD_FL', ylabel='count'>

# %%
#住院治療 - Rehab
trmre_fl = cdc.iloc[:,141]
#print(trmre_fl)
print(trmre_fl.value_counts().sort_values(ascending= True), trmre_fl.describe())
# Out:
# N    60511
# Y    76738
# Name: TRMRE_FL, dtype: int64 count     137249
# unique         2
# top            Y
# freq       76738
# Name: TRMRE_FL, dtype: object

# %%
sns.countplot(trmre_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMRE_FL', ylabel='count'>

# %%
#住院治療 - Endovascular treatment
trmen_fl = cdc.iloc[:,142]
#print(trmen_fl)
print(trmen_fl.value_counts().sort_values(ascending= True), trmen_fl.describe())
# Out:
# Y       330
# N    134756
# Name: TRMEN_FL, dtype: int64 count     135086
# unique         2
# top            N
# freq      134756
# Name: TRMEN_FL, dtype: object

# %%
sns.countplot(trmen_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMEN_FL', ylabel='count'>

# %%
#住院治療 - Endovascular treatment options
trmen_id = cdc.iloc[:,143]
#print(trmen_id)
print(trmen_id.value_counts().sort_values(ascending= True), trmen_id.describe())
# Out:
# 2.0     19
# 1.0     60
# 3.0    193
# Name: TRMEN_ID, dtype: int64 count    272.000000
# mean       2.488971
# std        0.832829
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: TRMEN_ID, dtype: float64

# %%
trmen_id_labels = ["Aneurysm","AVM","Stenting"]
sns.countplot(trmen_id).set_xticklabels(trmen_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Aneurysm'), Text(1, 0, 'AVM'), Text(2, 0, 'Stenting')]

# %%
#住院治療 - Aggrenox
trmag_fl = cdc.iloc[:,144]
#print(trmag_fl)
print(trmag_fl.value_counts().sort_values(ascending= True), trmag_fl.describe())
# Out:
# Y      1315
# N    133809
# Name: TRMAG_FL, dtype: int64 count     135124
# unique         2
# top            N
# freq      133809
# Name: TRMAG_FL, dtype: object

# %%
sns.countplot(trmas_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMAS_FL', ylabel='count'>

# %%
#住院治療 - Clopidogrel
trmcl_fl = cdc.iloc[:,145]
#print(trmcl_fl)
print(trmcl_fl.value_counts().sort_values(ascending= True), trmcl_fl.describe())
# Out:
# Y     20788
# N    114737
# Name: TRMCL_FL, dtype: int64 count     135525
# unique         2
# top            N
# freq      114737
# Name: TRMCL_FL, dtype: object

# %%
sns.countplot(trmcl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMCL_FL', ylabel='count'>

# %%
#住院治療 - Pletaal
trmpl_fl = cdc.iloc[:,146]
#print(trmpl_fl)
print(trmpl_fl.value_counts().sort_values(ascending= True), trmpl_fl.describe())
# Out:
# Y      1385
# N    133713
# Name: TRMPL_FL, dtype: int64 count     135098
# unique         2
# top            N
# freq      133713
# Name: TRMPL_FL, dtype: object

# %%
sns.countplot(trmpl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMPL_FL', ylabel='count'>

# %%
#住院治療 - LMW heparin
trmlm_fl = cdc.iloc[:,147]
#print(trmlm_fl)
print(trmlm_fl.value_counts().sort_values(ascending= True), trmlm_fl.describe())
# Out:
# Y      3842
# N    131413
# Name: TRMLM_FL, dtype: int64 count     135255
# unique         2
# top            N
# freq      131413
# Name: TRMLM_FL, dtype: object

# %%
sns.countplot(trmlm_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMLM_FL', ylabel='count'>

# %%
#住院治療 - IV t-PA
trmiv_fl = cdc.iloc[:,148]
#print(trmiv_fl)
print(trmiv_fl.value_counts().sort_values(ascending= True), trmiv_fl.describe())
# Out:
# Y      4404
# N    130848
# Name: TRMIV_FL, dtype: int64 count     135252
# unique         2
# top            N
# freq      130848
# Name: TRMIV_FL, dtype: object

# %%
sns.countplot(trmiv_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMIV_FL', ylabel='count'>

# %%
#住院治療 - Ventilator
trmve_fl = cdc.iloc[:,149]
#print(trmve_fl)
print(trmve_fl.value_counts().sort_values(ascending= True), trmve_fl.describe())
# Out:
# Y     15746
# N    119871
# Name: TRMVE_FL, dtype: int64 count     135617
# unique         2
# top            N
# freq      119871
# Name: TRMVE_FL, dtype: object

# %%
sns.countplot(trmve_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMVE_FL', ylabel='count'>

# %%
#住院治療 - Nasogastric tube
trmng_fl = cdc.iloc[:,150]
#print(trmng_fl)
print(trmng_fl.value_counts().sort_values(ascending= True), trmng_fl.describe())
# Out:
# Y    40484
# N    95682
# Name: TRMNG_FL, dtype: int64 count     136166
# unique         2
# top            N
# freq       95682
# Name: TRMNG_FL, dtype: object

# %%
sns.countplot(trmng_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMNG_FL', ylabel='count'>

# %%
#住院治療 - Dysphagia Screen
trmdy_fl = cdc.iloc[:,151]
#print(trmdy_fl)
print(trmdy_fl.value_counts().sort_values(ascending= True), trmdy_fl.describe())
# Out:
# Y    60673
# N    76895
# Name: TRMDY_FL, dtype: int64 count     137568
# unique         2
# top            N
# freq       76895
# Name: TRMDY_FL, dtype: object

# %%
sns.countplot(trmdy_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMDY_FL', ylabel='count'>

# %%
#住院治療 -  admission to ICU
trmicu_fl = cdc.iloc[:,152]
#print(trmicu_fl)
print(trmicu_fl.value_counts().sort_values(ascending= True), trmicu_fl.describe())
# Out:
# Y     22143
# N    114045
# Name: TRMICU_FL, dtype: int64 count     136188
# unique         2
# top            N
# freq      114045
# Name: TRMICU_FL, dtype: object

# %%
sns.countplot(trmicu_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMICU_FL', ylabel='count'>

# %%
#住院治療 - Smoking cessation counseling
trmsn_fl = cdc.iloc[:,152]
#print(trmsn_fl)
print(trmsn_fl.value_counts().sort_values(ascending= True), trmsn_fl.describe())
# Out:
# Y     22143
# N    114045
# Name: TRMICU_FL, dtype: int64 count     136188
# unique         2
# top            N
# freq      114045
# Name: TRMICU_FL, dtype: object

# %%
sns.countplot(trmsn_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMICU_FL', ylabel='count'>

# %%
#住院治療 - Education about stroke
trmed_fl = cdc.iloc[:,154]
#print(trmed_fl)
print(trmed_fl.value_counts().sort_values(ascending= True), trmed_fl.describe())
# Out:
# Y    65511
# N    72714
# Name: TRMED_FL, dtype: int64 count     138225
# unique         2
# top            N
# freq       72714
# Name: TRMED_FL, dtype: object

# %%
sns.countplot(trmed_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMED_FL', ylabel='count'>

# %%
#住院治療 - Operation for
trmop_fl = cdc.iloc[:,155]
#print(trmop_fl)
print(trmop_fl.value_counts().sort_values(ascending= True), trmop_fl.describe())
# Out:
# Y      4391
# N    130968
# Name: TRMOP_FL, dtype: int64 count     135359
# unique         2
# top            N
# freq      130968
# Name: TRMOP_FL, dtype: object

# %%
sns.countplot(trmop_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMOP_FL', ylabel='count'>

# %%
#住院治療 - Operation for options
trmop_id = cdc.iloc[:,156]
#print(trmop_id)
print(trmop_id.value_counts().sort_values(ascending= True), trmop_id.describe())
# Out:
# 3.0      20
# 5.0     113
# 4.0     892
# 1.0     957
# 2.0    5363
# Name: TRMOP_ID, dtype: int64 count    7345.000000
# mean        2.161470
# std         0.855147
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: TRMOP_ID, dtype: float64

# %%
trmop_id_labels = ["Infracion","ICH","Carotid stenosis (eg:endarterectomy)","Aneurysm","AVM"]
sns.countplot(trmop_id).set_xticklabels(trmop_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Infracion'),
#  Text(1, 0, 'ICH'),
#  Text(2, 0, 'Carotid stenosis (eg:endarterectomy)'),
#  Text(3, 0, 'Aneurysm'),
#  Text(4, 0, 'AVM')]

# %%
#住院治療 - Others
trmot_fl = cdc.iloc[:,157]
#print(trmot_fl)
print(trmot_fl.value_counts().sort_values(ascending= True), trmot_fl.describe())
# Out:
# Y     14000
# N    121204
# Name: TRMOT_FL, dtype: int64 count     135204
# unique         2
# top            N
# freq      121204
# Name: TRMOT_FL, dtype: object

# %%
sns.countplot(trmot_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TRMOT_FL', ylabel='count'>

# %%
#TRMOT_TX

# %%
#出院時藥物 - None
om_fl = cdc.iloc[:,160]
#print(om_fl)
print(om_fl.value_counts().sort_values(ascending= True), om_fl.describe())
# Out:
# Y     12616
# N    122758
# Name: OM_FL, dtype: int64 count     135374
# unique         2
# top            N
# freq      122758
# Name: OM_FL, dtype: object

# %%
sns.countplot(om_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OM_FL', ylabel='count'>

# %%
#出院時藥物 - Aspirin
omas_fl = cdc.iloc[:,161]
#print(omas_fl)
print(omas_fl.value_counts().sort_values(ascending= True), omas_fl.describe())
# Out:
# N    66733
# Y    70245
# Name: OMAS_FL, dtype: int64 count     136978
# unique         2
# top            Y
# freq       70245
# Name: OMAS_FL, dtype: object

# %%
sns.countplot(omas_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMAS_FL', ylabel='count'>

# %%
#出院時藥物 - Aggrenox
omag_fl = cdc.iloc[:,162]
#print(omag_fl)
print(omag_fl.value_counts().sort_values(ascending= True), omag_fl.describe())
# Out:
# Y      2218
# N    132850
# Name: OMAG_FL, dtype: int64 count     135068
# unique         2
# top            N
# freq      132850
# Name: OMAG_FL, dtype: object

# %%
sns.countplot(omag_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMAG_FL', ylabel='count'>

# %%
#出院時藥物 - Ticlopidine
omti_fl = cdc.iloc[:,163]
#print(omti_fl)
print(omti_fl.value_counts().sort_values(ascending= True), omti_fl.describe())
# Out:
# Y      2084
# N    132961
# Name: OMTI_FL, dtype: int64 count     135045
# unique         2
# top            N
# freq      132961
# Name: OMTI_FL, dtype: object

# %%
sns.countplot(omti_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMTI_FL', ylabel='count'>

# %%
#出院時藥物 - Clopidogrel
omcl_fl = cdc.iloc[:,164]
#print(omcl_fl)
print(omcl_fl.value_counts().sort_values(ascending= True), omcl_fl.describe())
# Out:
# Y     19104
# N    116350
# Name: OMCL_FL, dtype: int64 count     135454
# unique         2
# top            N
# freq      116350
# Name: OMCL_FL, dtype: object

# %%
sns.countplot(omcl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMCL_FL', ylabel='count'>

# %%
#出院時藥物 - Pletaal
ompl_fl = cdc.iloc[:,167]
#print(ompl_fl)
print(ompl_fl.value_counts().sort_values(ascending= True), ompl_fl.describe())
# Out:
# Y      1454
# N    133602
# Name: OMPL_FL, dtype: int64 count     135056
# unique         2
# top            N
# freq      133602
# Name: OMPL_FL, dtype: object

# %%
sns.countplot(ompl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMPL_FL', ylabel='count'>

# %%
#出院時藥物 -anti H/T drug
omanh_fl = cdc.iloc[:,168]
#print(omanh_fl)
print(omanh_fl.value_counts().sort_values(ascending= True), omanh_fl.describe())
# Out:
# Y    67224
# N    69680
# Name: OMANH_FL, dtype: int64 count     136904
# unique         2
# top            N
# freq       69680
# Name: OMANH_FL, dtype: object

# %%
sns.countplot(omanh_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMANH_FL', ylabel='count'>

# %%
#出院時藥物 - Warfarin
omwa_fl = cdc.iloc[:,165]
#print(omwa_fl)
print(omwa_fl.value_counts().sort_values(ascending= True), omwa_fl.describe())
# Out:
# Y      9016
# N    126222
# Name: OMWA_FL, dtype: int64 count     135238
# unique         2
# top            N
# freq      126222
# Name: OMWA_FL, dtype: object

# %%
sns.countplot(omwa_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMWA_FL', ylabel='count'>

# %%
#離院時INR
omwa_tx = cdc.iloc[:,166]
#print(omwa_tx)
print(omwa_tx.value_counts().sort_values(ascending= True), omwa_tx.describe())
# Out:
# 1.511      1
# 1.859      1
# 2.109      1
# 1.205      1
# nil        1
#         ...
# 1.5       71
# 1.1       92
# 1.2      104
# 999.9    121
# 1        126
# Name: OMWA_TX, Length: 582, dtype: int64 count     6740
# unique     582
# top          1
# freq       126
# Name: OMWA_TX, dtype: int64

# %%
#omwa_tx.dropna().plot.box(figsize=(5,5))
#plt.show()
#omwa_tx.dropna().plot.hist(figsize=(5,5), bins=100)
#plt.show()
#omwa_tx.dropna().plot.hist(figsize=(5,5), bins=100, range=[100,200])
#plt.show()

# %%
#出院時藥物 - anti DM drug
omand_fl = cdc.iloc[:,169]
#print(omand_fl)
print(omand_fl.value_counts().sort_values(ascending= True), omand_fl.describe())
# Out:
# Y    38275
# N    97806
# Name: OMAND_FL, dtype: int64 count     136081
# unique         2
# top            N
# freq       97806
# Name: OMAND_FL, dtype: object

# %%
sns.countplot(omand_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMAND_FL', ylabel='count'>

# %%
#出院時藥物 - anti DM drug:insulin
omins_fl = cdc.iloc[:,172]
#print(omins_fl)
print(omins_fl.value_counts().sort_values(ascending= True), omins_fl.describe())
# Out:
# Y     3770
# N    71614
# Name: OMINS_FL, dtype: int64 count     75384
# unique        2
# top           N
# freq      71614
# Name: OMINS_FL, dtype: object

# %%
sns.countplot(omins_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMINS_FL', ylabel='count'>

# %%
#出院時藥物 - lipid lowering drug
omli_fl = cdc.iloc[:,173]
#print(omli_fl)
print(omli_fl.value_counts().sort_values(ascending= True), omli_fl.describe())
# Out:
# Y    43951
# N    92076
# Name: OMLI_FL, dtype: int64 count     136027
# unique         2
# top            N
# freq       92076
# Name: OMLI_FL, dtype: object

# %%
sns.countplot(omli_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMLI_FL', ylabel='count'>

# %%
#出院時藥物 - lipid lowering drug: statin
omst_fl = cdc.iloc[:,175]
#print(omst_fl)
print(omst_fl.value_counts().sort_values(ascending= True), omst_fl.describe())
# Out:
# Y    28510
# N    47628
# Name: OMST_FL, dtype: int64 count     76138
# unique        2
# top           N
# freq      47628
# Name: OMST_FL, dtype: object

# %%
sns.countplot(omst_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMST_FL', ylabel='count'>

# %%
#出院時藥物 - lipid lowering drug: non-statin
omns_fl = cdc.iloc[:,176]
#print(omns_fl)
print(omns_fl.value_counts().sort_values(ascending= True), omns_fl.describe())
# Out:
# Y     1550
# N    73736
# Name: OMNS_FL, dtype: int64 count     75286
# unique        2
# top           N
# freq      73736
# Name: OMNS_FL, dtype: object

# %%
sns.countplot(omns_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMNS_FL', ylabel='count'>

# %%
#出院時藥物 - Others
omliot_fl = cdc.iloc[:,177]
#print(omliot_fl)
print(omliot_fl.value_counts().sort_values(ascending= True), omliot_fl.describe())
# Out:
# Y     16277
# N    119017
# Name: OMLIOT_FL, dtype: int64 count     135294
# unique         2
# top            N
# freq      119017
# Name: OMLIOT_FL, dtype: object

# %%
sns.countplot(omliot_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMLIOT_FL', ylabel='count'>

# %%
#OMLIOT_TX

# %%
#出院時藥物 - Others2
omliot2_fl = cdc.iloc[:,179]
#print(omliot2_fl)
print(omliot2_fl.value_counts().sort_values(ascending= True), omliot2_fl.describe())
# Out:
# Y      2268
# N    132871
# Name: OMLIOT2_FL, dtype: int64 count     135139
# unique         2
# top            N
# freq      132871
# Name: OMLIOT2_FL, dtype: object

# %%
sns.countplot(omliot2_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMLIOT2_FL', ylabel='count'>

# %%
#OMLIOT2_TX

# %%
#有相關原因未使用抗血栓藥物
omad_fl = cdc.iloc[:,273]
#print(omad_fl)
print(omad_fl.value_counts().sort_values(ascending= True), omad_fl.describe())
# Out:
# Y     3084
# N    71810
# Name: OMAD_FL, dtype: int64 count     74894
# unique        2
# top           N
# freq      71810
# Name: OMAD_FL, dtype: object

# %%
sns.countplot(omad_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OMAD_FL', ylabel='count'>

# %%
#有相關原因未使用抗血栓藥物 options
omad_id = cdc.iloc[:,274]
#print(omad_id)
print(omad_id.value_counts().sort_values(ascending= True), omad_id.describe())
# Out:
# 5.0     161
# 4.0     166
# 1.0     403
# 3.0     498
# 2.0     584
# 6.0    1251
# Name: OMAD_ID, dtype: int64 count    3063.000000
# mean        3.930787
# std         1.947325
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max         6.000000
# Name: OMAD_ID, dtype: float64

# %%
omad_id_labels = ["UGI bleeding","Hemorrhage infarct",".Others bleeding","Large infarct","Patient or family refuse","Critical AAD or Expired"]
sns.countplot(omad_id).set_xticklabels(omad_id_labels, rotation = 5)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'UGI bleeding'),
#  Text(1, 0, 'Hemorrhage infarct'),
#  Text(2, 0, '.Others bleeding'),
#  Text(3, 0, 'Large infarct'),
#  Text(4, 0, 'Patient or family refuse'),
#  Text(5, 0, 'Critical AAD or Expired')]

# %%
#入院前藥物 - None
am_fl = cdc.iloc[:,181]
#print(am_fl)
print(am_fl.value_counts().sort_values(ascending= True), am_fl.describe())
# Out:
# Y    39739
# N    96322
# Name: AM_FL, dtype: int64 count     136061
# unique         2
# top            N
# freq       96322
# Name: AM_FL, dtype: object

# %%
sns.countplot(am_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AM_FL', ylabel='count'>

# %%
#入院前藥物 - Aspirin
amas_fl = cdc.iloc[:,182]
#print(amas_fl)
print(amas_fl.value_counts().sort_values(ascending= True), amas_fl.describe())
# Out:
# Y     21813
# N    113781
# Name: AMAS_FL, dtype: int64 count     135594
# unique         2
# top            N
# freq      113781
# Name: AMAS_FL, dtype: object

# %%
sns.countplot(amas_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMAS_FL', ylabel='count'>

# %%
#入院前藥物 - Aggrenox
amag_fl = cdc.iloc[:,183]
#print(amag_fl)
print(amag_fl.value_counts().sort_values(ascending= True), amag_fl.describe())
# Out:
# Y       568
# N    134458
# Name: AMAG_FL, dtype: int64 count     135026
# unique         2
# top            N
# freq      134458
# Name: AMAG_FL, dtype: object

# %%
sns.countplot(amag_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMAG_FL', ylabel='count'>

# %%
#入院前藥物 - Ticlopidine
amti_fl = cdc.iloc[:,184]
#print(amti_fl)
print(amti_fl.value_counts().sort_values(ascending= True), amti_fl.describe())
# Out:
# Y      1002
# N    134028
# Name: AMTI_FL, dtype: int64 count     135030
# unique         2
# top            N
# freq      134028
# Name: AMTI_FL, dtype: object

# %%
sns.countplot(amti_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMTI_FL', ylabel='count'>

# %%
#入院前藥物 - Clopidogrel
amcl_fl = cdc.iloc[:,185]
#print(amcl_fl)
print(amcl_fl.value_counts().sort_values(ascending= True), amcl_fl.describe())
# Out:
# Y      5389
# N    129747
# Name: AMCL_FL, dtype: int64 count     135136
# unique         2
# top            N
# freq      129747
# Name: AMCL_FL, dtype: object

# %%
sns.countplot(amcl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMCL_FL', ylabel='count'>

# %%
#入院前藥物 - Pletaal
ampl_fl = cdc.iloc[:,187]
#print(ampl_fl)
print(ampl_fl.value_counts().sort_values(ascending= True), ampl_fl.describe())
# Out:
# Y       658
# N    134391
# Name: AMPL_FL, dtype: int64 count     135049
# unique         2
# top            N
# freq      134391
# Name: AMPL_FL, dtype: object

# %%
sns.countplot(ampl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMPL_FL', ylabel='count'>

# %%
#入院前藥物 - anti H/T drug
amanh_fl = cdc.iloc[:,188]
#print(amanh_fl)
print(amanh_fl.value_counts().sort_values(ascending= True), amanh_fl.describe())
# Out:
# Y    63621
# N    73278
# Name: AMANH_FL, dtype: int64 count     136899
# unique         2
# top            N
# freq       73278
# Name: AMANH_FL, dtype: object

# %%
sns.countplot(amanh_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMANH_FL', ylabel='count'>

# %%
#入院前藥物 - Wafirin
amwa_fl = cdc.iloc[:,186]
#print(amwa_fl)
print(amwa_fl.value_counts().sort_values(ascending= True), amwa_fl.describe())
# Out:
# Y      3758
# N    131364
# Name: AMWA_FL, dtype: int64 count     135122
# unique         2
# top            N
# freq      131364
# Name: AMWA_FL, dtype: object

# %%
sns.countplot(amwa_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMWA_FL', ylabel='count'>

# %%
#入院前藥物 - anti DM drug
amand_fl = cdc.iloc[:,189]
#print(amand_fl)
print(amand_fl.value_counts().sort_values(ascending= True), amand_fl.describe())
# Out:
# Y     33273
# N    102738
# Name: AMAND_FL, dtype: int64 count     136011
# unique         2
# top            N
# freq      102738
# Name: AMAND_FL, dtype: object

# %%
sns.countplot(amand_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMAND_FL', ylabel='count'>

# %%
#入院前藥物 - lipid lowering drug
amli_fl = cdc.iloc[:,190]
#print(amli_fl)
print(amli_fl.value_counts().sort_values(ascending= True), amli_fl.describe())
# Out:
# Y     12379
# N    123021
# Name: AMLI_FL, dtype: int64 count     135400
# unique         2
# top            N
# freq      123021
# Name: AMLI_FL, dtype: object

# %%
sns.countplot(amli_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMLI_FL', ylabel='count'>

# %%
#入院前藥物 - others
amliot_fl = cdc.iloc[:,191]
#print(amliot_fl)
print(amliot_fl.value_counts().sort_values(ascending= True), amliot_fl.describe())
# Out:
# Y     11194
# N    124044
# Name: AMLIOT_FL, dtype: int64 count     135238
# unique         2
# top            N
# freq      124044
# Name: AMLIOT_FL, dtype: object

# %%
sns.countplot(amliot_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMLIOT_FL', ylabel='count'>

# %%
#AMLIOT_TX

# %%
#入院前藥物 - others2
amliot2_fl = cdc.iloc[:,193]
#print(amliot2_fl)
print(amliot2_fl.value_counts().sort_values(ascending= True), amliot2_fl.describe())
# Out:
# Y       692
# N    134357
# Name: AMLIOT2_FL, dtype: int64 count     135049
# unique         2
# top            N
# freq      134357
# Name: AMLIOT2_FL, dtype: object

# %%
sns.countplot(amliot2_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AMLIOT2_FL', ylabel='count'>

# %%
#AMLIOT2_TX

# %%
#併發症 - none
com_id = cdc.iloc[:,195]
#print(com_id)
print(com_id.value_counts(), len(com_id) - com_id.value_counts())
#82929 ppl had no comorbidities
# Out:
# 0.0    57555
# Name: COM_ID, dtype: int64 0.0    82929
# Name: COM_ID, dtype: int64

# %%
#併發症 - Pneumonia
compn_fl = cdc.iloc[:,196]
#print(compn_fl)
print(compn_fl.value_counts().sort_values(ascending= True), compn_fl.describe())
# Out:
# Y      8938
# N    129289
# Name: COMPN_FL, dtype: int64 count     138227
# unique         2
# top            N
# freq      129289
# Name: COMPN_FL, dtype: object

# %%
sns.countplot(compn_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMPN_FL', ylabel='count'>

# %%
#併發症 - Urinary tract infection
comut_fl = cdc.iloc[:,197]
#print(comut_fl)
print(comut_fl.value_counts().sort_values(ascending= True), comut_fl.describe())
# Out:
# Y      7292
# N    130811
# Name: COMUT_FL, dtype: int64 count     138103
# unique         2
# top            N
# freq      130811
# Name: COMUT_FL, dtype: object

# %%
sns.countplot(comut_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMUT_FL', ylabel='count'>

# %%
#併發症 - UGI bleeding
comug_fl = cdc.iloc[:,198]
#print(comug_fl)
print(comug_fl.value_counts().sort_values(ascending= True), comug_fl.describe())
# Out:
# Y      3280
# N    134671
# Name: COMUG_FL, dtype: int64 count     137951
# unique         2
# top            N
# freq      134671
# Name: COMUG_FL, dtype: object

# %%
sns.countplot(comug_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMUG_FL', ylabel='count'>

# %%
#併發症 - Pressure sore
compr_fl = cdc.iloc[:,199]
#print(compr_fl)
print(compr_fl.value_counts().sort_values(ascending= True), compr_fl.describe())
# Out:
# Y      1233
# N    136599
# Name: COMPR_FL, dtype: int64 count     137832
# unique         2
# top            N
# freq      136599
# Name: COMPR_FL, dtype: object

# %%
sns.countplot(compr_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMPR_FL', ylabel='count'>

# %%
#併發症 - Pulmonary edema
compu_fl = cdc.iloc[:,200]
#print(compu_fl)
print(compu_fl.value_counts().sort_values(ascending= True), compu_fl.describe())
# Out:
# Y       359
# N    137454
# Name: COMPU_FL, dtype: int64 count     137813
# unique         2
# top            N
# freq      137454
# Name: COMPU_FL, dtype: object

# %%
sns.countplot(compu_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMPU_FL', ylabel='count'>

# %%
#併發症 - Acute coronary syndrome
comac_fl = cdc.iloc[:,201]
#print(comac_fl)
print(comac_fl.value_counts().sort_values(ascending= True), comac_fl.describe())
# Out:
# Y       289
# N    137524
# Name: COMAC_FL, dtype: int64 count     137813
# unique         2
# top            N
# freq      137524
# Name: COMAC_FL, dtype: object

# %%
sns.countplot(comac_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMAC_FL', ylabel='count'>

# %%
#併發症 - Seizure
comse_fl = cdc.iloc[:,202]
#print(comse_fl)
print(comse_fl.value_counts().sort_values(ascending= True), comse_fl.describe())
# Out:
# Y      1131
# N    136709
# Name: COMSE_FL, dtype: int64 count     137840
# unique         2
# top            N
# freq      136709
# Name: COMSE_FL, dtype: object

# %%
sns.countplot(comse_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMSE_FL', ylabel='count'>

# %%
#併發症 - Deep vein thrombosis
comde_fl = cdc.iloc[:,203]
#print(comde_fl)
print(comde_fl.value_counts().sort_values(ascending= True), comde_fl.describe())
# Out:
# Y        87
# N    137716
# Name: COMDE_FL, dtype: int64 count     137803
# unique         2
# top            N
# freq      137716
# Name: COMDE_FL, dtype: object

# %%
sns.countplot(comde_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMDE_FL', ylabel='count'>

# %%
#併發症 - Others
commo_fl = cdc.iloc[:,204]
#print(commo_fl)
print(commo_fl.value_counts().sort_values(ascending= True), commo_fl.describe())
# Out:
# Y      5769
# N    132144
# Name: COMO_FL, dtype: int64 count     137913
# unique         2
# top            N
# freq      132144
# Name: COMO_FL, dtype: object

# %%
sns.countplot(commo_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='COMO_FL', ylabel='count'>

# %%
#COMO_TX

# %%
#Deterioration - None
det_id = cdc.iloc[:,206]
#print(det_id)
print(det_id.value_counts(), len(det_id) - det_id.value_counts())
#22412 ppl had no become worsen
# Out:
# 0.0    118072
# Name: DET_ID, dtype: int64 0.0    22412
# Name: DET_ID, dtype: int64

# %%
#Deterioration - Stroke-in-evolution (NIHSS≧2)
detst_fl = cdc.iloc[:,207]
#print(detst_fl)
print(detst_fl.value_counts().sort_values(ascending= True), detst_fl.describe())
# Out:
# Y      8566
# N    129695
# Name: DETST_FL, dtype: int64 count     138261
# unique         2
# top            N
# freq      129695
# Name: DETST_FL, dtype: object

# %%
sns.countplot(detst_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETST_FL', ylabel='count'>

# %%
#Deterioration - Herniation
dethe_fl = cdc.iloc[:,208]
#print(dethe_fl)
print(dethe_fl.value_counts().sort_values(ascending= True), dethe_fl.describe())
# Out:
# Y      1557
# N    136580
# Name: DETHE_FL, dtype: int64 count     138137
# unique         2
# top            N
# freq      136580
# Name: DETHE_FL, dtype: object

# %%
sns.countplot(dethe_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETHE_FL', ylabel='count'>

# %%
#Deterioration - Hemorrhagic infarct
detho_fl = cdc.iloc[:,209]
#print(detho_fl)
print(detho_fl.value_counts().sort_values(ascending= True), detho_fl.describe())
# Out:
# Y      1754
# N    136391
# Name: DETHO_FL, dtype: int64 count     138145
# unique         2
# top            N
# freq      136391
# Name: DETHO_FL, dtype: object

# %%
sns.countplot(detho_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETHO_FL', ylabel='count'>

# %%
#Deterioration - Hemorrhagic infarct 36hrs
dethoh_fl = cdc.iloc[:,275]
#print(dethoh_fl)
print(dethoh_fl.value_counts().sort_values(ascending= True), dethoh_fl.describe())
# Out:
# Y      341
# N    77391
# Name: DETHOH_FL, dtype: int64 count     77732
# unique        2
# top           N
# freq      77391
# Name: DETHOH_FL, dtype: object

# %%
sns.countplot(dethoh_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETHOH_FL', ylabel='count'>

# %%
#Deterioration - Hematoma enlargement(ICH)
detha_fl = cdc.iloc[:,210]
#print(detha_fl)
print(detha_fl.value_counts().sort_values(ascending= True), detha_fl.describe())
# Out:
# Y       885
# N    137234
# Name: DETHA_FL, dtype: int64 count     138119
# unique         2
# top            N
# freq      137234
# Name: DETHA_FL, dtype: object

# %%
sns.countplot(detha_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETHA_FL', ylabel='count'>

# %%
#Deterioration - Vasospasm(SAH)
detva_fl = cdc.iloc[:,211]
#print(detva_fl)
print(detva_fl.value_counts().sort_values(ascending= True), detva_fl.describe())
# Out:
# Y       190
# N    137921
# Name: DETVA_FL, dtype: int64 count     138111
# unique         2
# top            N
# freq      137921
# Name: DETVA_FL, dtype: object

# %%
sns.countplot(detva_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETVA_FL', ylabel='count'>

# %%
#Deterioration - Re-bleeding(SAH)
detre_fl = cdc.iloc[:,212]
#print(detre_fl)
print(detre_fl.value_counts().sort_values(ascending= True), detre_fl.describe())
# Out:
# Y       128
# N    137978
# Name: DETRE_FL, dtype: int64 count     138106
# unique         2
# top            N
# freq      137978
# Name: DETRE_FL, dtype: object

# %%
sns.countplot(detre_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETRE_FL', ylabel='count'>

# %%
#Deterioration - Medical problems
detme_fl = cdc.iloc[:,213]
#print(detme_fl)
print(detme_fl.value_counts().sort_values(ascending= True), detme_fl.describe())
# Out:
# Y      2498
# N    135648
# Name: DETME_FL, dtype: int64 count     138146
# unique         2
# top            N
# freq      135648
# Name: DETME_FL, dtype: object

# %%
sns.countplot(detme_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETME_FL', ylabel='count'>

# %%
#Deterioration - Others
deto_fl = cdc.iloc[:,214]
#print(deto_fl)
print(deto_fl.value_counts().sort_values(ascending= True), deto_fl.describe())
# Out:
# Y      1291
# N    136854
# Name: DETO_FL, dtype: int64 count     138145
# unique         2
# top            N
# freq      136854
# Name: DETO_FL, dtype: object

# %%
sns.countplot(deto_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DETO_FL', ylabel='count'>

# %%
#DETO_TX

# %%
#CT日期
ct_dt = cdc.iloc[:,233]
#print(ct_dt)
print(ct_dt.value_counts().sort_values(ascending= True), ct_dt.describe())
# Out:
# 1045-03-08              1
# 2201-02-04 00:00:00     1
# 0107-02-26              1
# 2005-02-05 00:00:00     1
# 0020-04-16              1
#                        ..
# 2007-07-31 00:00:00    68
# 2008-06-16 00:00:00    70
# 2008-02-18 00:00:00    75
# 2007-04-23 00:00:00    80
# 2008-02-11 00:00:00    87
# Name: CT_DT, Length: 4718, dtype: int64 count                  118871
# unique                   4718
# top       2008-02-11 00:00:00
# freq                       87
# Name: CT_DT, dtype: object

# %%
#CT時間 - 時
cth_nm = cdc.iloc[:,235]
#print(cth_nm)
print(cth_nm.value_counts().sort_values(ascending= True), cth_nm.describe())
# Out:
# 38.0       1
# 44.0       1
# 30.0       1
# 42.0       1
# 56.0       1
#         ...
# 13.0    6881
# 12.0    6987
# 9.0     7103
# 11.0    8448
# 10.0    8782
# Name: CTH_NM, Length: 67, dtype: int64 count    113283.000000
# mean         13.659216
# std           5.901942
# min          -2.000000
# 25%          10.000000
# 50%          14.000000
# 75%          18.000000
# max          99.000000
# Name: CTH_NM, dtype: float64

# %%
#CT時間 - 分
ctm_nm = cdc.iloc[:,236]
#print(ctm_nm)
print(ctm_nm.value_counts().sort_values(ascending= True), ctm_nm.describe())
# Out:
# 81.0       1
# 94.0       1
# 91.0       1
# 64.0       1
# 92.0       1
#         ...
# 50.0    2109
# 20.0    2144
# 40.0    2237
# 30.0    2577
# 0.0     3071
# Name: CTM_NM, Length: 76, dtype: int64 count    113278.000000
# mean         29.293693
# std          17.437600
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          99.000000
# Name: CTM_NM, dtype: float64

# %%
#CT no findings
ct_fl = cdc.iloc[:,237]
#print(ct_fl)
print(ct_fl.value_counts().sort_values(ascending= True), ct_fl.describe())
# Out:
# Y     31419
# N    104053
# Name: CT_FL, dtype: int64 count     135472
# unique         2
# top            N
# freq      104053
# Name: CT_FL, dtype: object

# %%
sns.countplot(ct_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CT_FL', ylabel='count'>

# %%
# CTO_TX

# %%
#MRI日期
mri_dt = cdc.iloc[:,239]
#print(mri_dt)
print(mri_dt.value_counts().sort_values(ascending= True), mri_dt.describe())
# Out:
# 2011-05-15       1
# 2017-08-06       1
# 2017-12-17       1
# 2011-05-01       1
# 2011-02-27       1
#               ...
# 2008-05-26      58
# 2008-02-12      59
# 2008-10-13      61
# 2008-02-05      62
# 1900-01-01    1357
# Name: MRI_DT, Length: 4555, dtype: int64 count                   81851
# unique                   4555
# top       1900-01-01 00:00:00
# freq                     1357
# Name: MRI_DT, dtype: object

# %%
#MRI時間 - 時
mrih_nm = cdc.iloc[:,241]
#print(mrih_nm)
print(mrih_nm.value_counts().sort_values(ascending= True), mrih_nm.describe())
# Out:
#  46.0        1
#  25.0        1
#  31.0        1
#  41.0        1
#  73.0        1
#  30.0        1
#  52.0        1
#  55.0        1
#  40.0        1
#  53.0        1
#  28.0        2
# -2.0         2
#  29.0        2
#  75.0        3
#  24.0        3
#  80.0        4
#  84.0        4
#  81.0        4
#  85.0        6
#  90.0        7
#  94.0        9
#  82.0        9
#  93.0        9
#  95.0        9
#  92.0       13
#  91.0       14
#  83.0       17
#  3.0        30
#  4.0        35
#  5.0        39
#  2.0        44
#  6.0        57
#  1.0        64
#  0.0       119
#  23.0      168
#  7.0       633
#  22.0      711
#  21.0     1620
#  20.0     2427
#  19.0     2790
#  18.0     3259
#  17.0     4360
#  8.0      4952
#  13.0     5753
#  14.0     6329
#  9.0      6674
#  16.0     6838
#  15.0     6870
#  12.0     7201
#  10.0     8397
#  11.0    10155
# Name: MRIH_NM, dtype: int64 count    79652.000000
# mean        13.319942
# std          4.595890
# min         -2.000000
# ...

# %%
#MRI時間 - 分
mrim_nm = cdc.iloc[:,242]
#print(mrim_nm)
print(mrim_nm.value_counts().sort_values(ascending= True), mrim_nm.describe())
# Out:
# 95.0       1
# 61.0       1
# 79.0       1
# 78.0       1
# 93.0       1
#         ...
# 33.0    1381
# 35.0    1417
# 40.0    1447
# 30.0    1900
# 0.0     2794
# Name: MRIM_NM, Length: 74, dtype: int64 count    79647.000000
# mean        29.125140
# std         17.524115
# min          0.000000
# 25%         14.000000
# 50%         30.000000
# 75%         44.000000
# max         95.000000
# Name: MRIM_NM, dtype: float64

# %%
# MRI no findings
mri_fl = cdc.iloc[:,243]
#print(mri_fl)
print(mri_fl.value_counts().sort_values(ascending= True), mri_fl.describe())
# Out:
# Y      3123
# N    131530
# Name: MRI_FL, dtype: int64 count     134653
# unique         2
# top            N
# freq      131530
# Name: MRI_FL, dtype: object

# %%
sns.countplot(mri_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MRI_FL', ylabel='count'>

# %%
#MRIO_TX

# %%
#Ultrasound/MRA Studies Carotid duplex
cd_id = cdc.iloc[:,251]
#print(cd_id)
print(cd_id.value_counts().sort_values(ascending= True), cd_id.describe())
# Out:
# 2.0     4033
# 0.0    35789
# 1.0    48024
# Name: CD_ID, dtype: int64 count    87846.000000
# mean         0.638504
# std          0.568014
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: CD_ID, dtype: float64

# %%
cd_id_labels = ["Undone","Present","Absent"]
sns.countplot(cd_id).set_xticklabels(cd_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Undone'), Text(1, 0, 'Present'), Text(2, 0, 'Absent')]

# %%
#R ICA
cdr_id = cdc.iloc[:,252]
#print(cdr_id)
print(cdr_id.value_counts().sort_values(ascending= True), cdr_id.describe())
# Out:
# 4.0     1005
# 3.0     1739
# 2.0     3421
# 1.0    78023
# Name: CDR_ID, dtype: int64 count    84188.000000
# mean         1.117760
# std          0.465653
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: CDR_ID, dtype: float64

# %%
cdr_id_labels = ["0-49%","50-69%","70-99%","100%"]
sns.countplot(cdr_id).set_xticklabels(cdr_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'),
#  Text(1, 0, '50-69%'),
#  Text(2, 0, '70-99%'),
#  Text(3, 0, '100%')]

# %%
#L ICA
cdl_id = cdc.iloc[:,253]
#print(cdl_id)
print(cdl_id.value_counts().sort_values(ascending= True), cdl_id.describe())
# Out:
# 4.0      858
# 3.0     1564
# 2.0     3322
# 1.0    79077
# Name: CDL_ID, dtype: int64 count    84821.000000
# mean         1.106389
# std          0.438911
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: CDL_ID, dtype: float64

# %%
cdl_id_labels = ["0-49%","50-69%","70-99%","100%"]
sns.countplot(cdl_id).set_xticklabels(cdl_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'),
#  Text(1, 0, '50-69%'),
#  Text(2, 0, '70-99%'),
#  Text(3, 0, '100%')]

# %%
#TCCS
tccs_id = cdc.iloc[:,254]
#print(tccs_id)
print(tccs_id.value_counts().sort_values(ascending= True), tccs_id.describe())
# Out:
# 1.0    32742
# 0.0    51914
# Name: TCCS_ID, dtype: int64 count    84656.000000
# mean         0.386765
# std          0.487012
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: TCCS_ID, dtype: float64

# %%
tccs_id_labels = ["Undone","Poor window"]
sns.countplot(tccs_id).set_xticklabels(tccs_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Undone'), Text(1, 0, 'Poor window')]

# %%
#TCCS R MCA
tccsr_id = cdc.iloc[:,255]
#print(tccsr_id)
print(tccsr_id.value_counts().sort_values(ascending= True), tccsr_id.describe())
# Out:
# 3.0      228
# 2.0     6791
# 1.0    34912
# Name: TCCSR_ID, dtype: int64 count    41931.000000
# mean         1.172832
# std          0.392224
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: TCCSR_ID, dtype: float64

# %%
tccsr_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsr_id).set_xticklabels(tccsr_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#TCCS L MCA
tccsl_id = cdc.iloc[:,256]
#print(tccsl_id)
print(tccsl_id.value_counts().sort_values(ascending= True), tccsl_id.describe())
# Out:
# 3.0      211
# 2.0     6711
# 1.0    34921
# Name: TCCSL_ID, dtype: int64 count    41843.000000
# mean         1.170471
# std          0.389229
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: TCCSL_ID, dtype: float64

# %%
tccsl_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsl_id).set_xticklabels(tccsl_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#TCCS BA
tccsba_id = cdc.iloc[:,257]
#print(tccsba_id)
print(tccsba_id.value_counts().sort_values(ascending= True), tccsba_id.describe())
# Out:
# 3.0      141
# 2.0     4864
# 1.0    56240
# Name: TCCSBA_ID, dtype: int64 count    61245.000000
# mean         1.084023
# std          0.285603
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: TCCSBA_ID, dtype: float64

# %%
tccsba_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsba_id).set_xticklabels(tccsba_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#MRA
mra_fl = cdc.iloc[:,258]
#print(mra_fl)
print(mra_fl.value_counts().sort_values(ascending= True), mra_fl.describe())
# Out:
# Y    65115
# N    65813
# Name: MRA_FL, dtype: int64 count     130928
# unique         2
# top            N
# freq       65813
# Name: MRA_FL, dtype: object

# %%
sns.countplot(mra_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MRA_FL', ylabel='count'>

# %%
#CTA
cta_fl = cdc.iloc[:,259]
#print(cta_fl)
print(cta_fl.value_counts().sort_values(ascending= True), cta_fl.describe())
# Out:
# Y      9767
# N    119858
# Name: CTA_FL, dtype: int64 count     129625
# unique         2
# top            N
# freq      119858
# Name: CTA_FL, dtype: object

# %%
sns.countplot(cta_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CTA_FL', ylabel='count'>

# %%
#DSA
dsa_fl = cdc.iloc[:,260]
#print(dsa_fl)
print(dsa_fl.value_counts().sort_values(ascending= True), dsa_fl.describe())
# Out:
# Y      1354
# N    128039
# Name: DSA_FL, dtype: int64 count     129393
# unique         2
# top            N
# freq      128039
# Name: DSA_FL, dtype: object

# %%
sns.countplot(dsa_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DSA_FL', ylabel='count'>

# %%
#Undone MRI, CTA and DSA
mcd_id = cdc.iloc[:,261]
#print(mcd_id)
print(mcd_id.value_counts(), len(mcd_id) - mcd_id.value_counts())
#95664 ppl had not done those tests
# Out:
# 0.0    44820
# Name: MCD_ID, dtype: int64 0.0    95664
# Name: MCD_ID, dtype: int64

# %%
#R MCA
mcdr_id = cdc.iloc[:,262]
#print(mcdr_id)
print(mcdr_id.value_counts().sort_values(ascending= True), mcdr_id.describe())
# Out:
# 3.0     1715
# 2.0     8168
# 1.0    42643
# Name: MCDR_ID, dtype: int64 count    52526.000000
# mean         1.220805
# std          0.487192
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: MCDR_ID, dtype: float64

# %%
mcdr_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdr_id).set_xticklabels(mcdr_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#L MCA
mcdl_id = cdc.iloc[:,263]
#print(mcdl_id)
print(mcdl_id.value_counts().sort_values(ascending= True), mcdl_id.describe())
# Out:
# 3.0     1499
# 2.0     7873
# 1.0    42997
# Name: MCDL_ID, dtype: int64 count    52369.000000
# mean         1.207585
# std          0.470898
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: MCDL_ID, dtype: float64

# %%
mcdl_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdl_id).set_xticklabels(mcdl_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#VA or BA
mcdba_id = cdc.iloc[:,264]
#print(mcdba_id)
print(mcdba_id.value_counts().sort_values(ascending= True), mcdba_id.describe())
# Out:
# 3.0      946
# 2.0     7654
# 1.0    43531
# Name: MCDBA_ID, dtype: int64 count    52131.000000
# mean         1.183116
# std          0.431139
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: MCDBA_ID, dtype: float64

# %%
mcdba_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdba_id).set_xticklabels(mcdba_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#R ICA
mcdri_id = cdc.iloc[:,265]
#print(mcdri_id)
print(mcdri_id.value_counts().sort_values(ascending= True), mcdri_id.describe())
# Out:
# 3.0      674
# 2.0     2157
# 1.0    27965
# Name: MCDRI_ID, dtype: int64 count    30796.000000
# mean         1.113813
# std          0.380311
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: MCDRI_ID, dtype: float64

# %%
mcdri_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdri_id).set_xticklabels(mcdri_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#L ICA
mcdli_id = cdc.iloc[:,266]
#print(mcdli_id)
print(mcdli_id.value_counts().sort_values(ascending= True), mcdli_id.describe())
# Out:
# 3.0      599
# 2.0     1944
# 1.0    28112
# Name: MCDLI_ID, dtype: int64 count    30655.000000
# mean         1.102496
# std          0.362042
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: MCDLI_ID, dtype: float64

# %%
mcdli_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdli_id).set_xticklabels(mcdli_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0-49%'), Text(1, 0, '50-99%'), Text(2, 0, '100%')]

# %%
#NIHSS 最初進院日期
nihsin_dt = cdc.iloc[:,224]
#print(nihsin_dt)
print(nihsin_dt.value_counts().sort_values(ascending= True), nihsin_dt.describe())
# Out:
# 0102-07-15              1
# 0107-03-19              1
# 0106-05-29              1
# 2006-01-05 00:00:00     1
# 0014-05-11              1
#                        ..
# 2008-02-23 00:00:00    65
# 2007-02-21 00:00:00    65
# 2012-01-09 00:00:00    67
# 2008-02-18 00:00:00    75
# 2008-02-11 00:00:00    81
# Name: NIHSIN_DT, Length: 4716, dtype: int64 count                  126042
# unique                   4716
# top       2008-02-11 00:00:00
# freq                       81
# Name: NIHSIN_DT, dtype: object

# %%
#NIHSS 最初進院時間-時
nihsinh_nm = cdc.iloc[:,226]
#print(nihsinh_nm)
print(nihsinh_nm.value_counts().sort_values(ascending= True), nihsinh_nm.describe())
# Out:
# 46.0        1
# 43.0        1
# 33.0        1
# 32.0        1
# 25.0        1
#         ...
# 15.0     8652
# 14.0     8975
# 11.0     9263
# 10.0     9697
# 0.0     15981
# Name: NIHSINH_NM, Length: 62, dtype: int64 count    133083.000000
# mean         12.437607
# std           6.844345
# min          -2.000000
# 25%           9.000000
# 50%          13.000000
# 75%          17.000000
# max          99.000000
# Name: NIHSINH_NM, dtype: float64

# %%
#NIHSS 最初進院時間-分
nihsinm_nm = cdc.iloc[:,227]
#print(nihsinm_nm)
print(nihsinm_nm.value_counts().sort_values(ascending= True), nihsinm_nm.describe())
# Out:
# 90.0        1
# 63.0        1
# 83.0        1
# 70.0        1
# 64.0        1
#         ...
# 40.0     5542
# 20.0     5593
# 50.0     5854
# 30.0    14016
# 0.0     39037
# Name: NIHSINM_NM, Length: 70, dtype: int64 count    133080.000000
# mean         21.228622
# std          18.917841
# min           0.000000
# 25%           0.000000
# 50%          20.000000
# 75%          37.000000
# max          99.000000
# Name: NIHSINM_NM, dtype: float64

# %%
#NIHSS 離院日期
nihsot_dt = cdc.iloc[:,228]
#print(nihsot_dt)
print(nihsot_dt.value_counts().sort_values(ascending= True), nihsot_dt.describe())
# Out:
# 2070-11-20 00:00:00      1
# 2017-06-04 00:00:00      1
# 2501-05-10 00:00:00      1
# 2006-07-09 00:00:00      1
# 2006-05-03 00:00:00      1
#                       ...
# 2007-02-14 00:00:00    101
# 2009-01-23 00:00:00    115
# 2008-02-05 00:00:00    117
# 2007-02-15 00:00:00    118
# 2007-02-16 00:00:00    153
# Name: NIHSOT_DT, Length: 4770, dtype: int64 count                  126165
# unique                   4770
# top       2007-02-16 00:00:00
# freq                      153
# Name: NIHSOT_DT, dtype: object

# %%
#NIHSS 離院時間- 時
nihsoth_nm = cdc.iloc[:,230]
#print(nihsoth_nm)
print(nihsoth_nm.value_counts().sort_values(ascending= True), nihsoth_nm.describe())
# Out:
#  74.0        1
#  70.0        1
#  40.0        1
#  61.0        1
# -2.0         1
#  33.0        1
#  54.0        1
#  99.0        1
#  82.0        2
#  24.0        3
#  80.0        5
#  81.0        5
#  84.0        7
#  85.0        9
#  83.0       11
#  92.0       11
#  94.0       16
#  91.0       18
#  95.0       20
#  93.0       32
#  4.0        95
#  90.0      102
#  3.0       111
#  5.0       119
#  6.0       133
#  2.0       140
#  22.0      227
#  23.0      229
#  21.0      258
#  1.0       277
#  20.0      282
#  19.0      354
#  18.0      467
#  7.0       502
#  17.0     1339
#  16.0     2280
#  15.0     2463
#  13.0     2520
#  14.0     3214
#  12.0     3511
#  8.0      5759
#  0.0     12284
#  11.0    15320
#  9.0     32028
#  10.0    42985
# Name: NIHSOTH_NM, dtype: int64 count    127146.000000
# mean          9.542919
# std           5.141859
# min          -2.000000
# 25%           9.000000
# 50%          10.000000
# 75%          11.000000
# max          99.000000
# ...

# %%
#NIHSS 離院時間- 分
nihsotm_nm = cdc.iloc[:,231]
#print(nihsotm_nm)
print(nihsotm_nm.value_counts().sort_values(ascending= True), nihsotm_nm.describe())
# Out:
# 96.0        1
# 80.0        1
# 70.0        1
# 60.0        1
# 95.0        1
#         ...
# 20.0     1774
# 50.0     1804
# 10.0     1905
# 30.0    10966
# 0.0     92181
# Name: NIHSOTM_NM, Length: 68, dtype: int64 count    127144.000000
# mean          8.187111
# std          15.166333
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          10.000000
# max          99.000000
# Name: NIHSOTM_NM, dtype: float64

# %%
#ECG
ecg_id = cdc.iloc[:,245]
#print(ecg_id)
print(ecg_id.value_counts().sort_values(ascending= True), ecg_id.describe())
# Out:
# 0.0     3520
# 1.0    69560
# Name: ECG_ID, dtype: int64 count    73080.000000
# mean         0.951834
# std          0.214119
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: ECG_ID, dtype: float64

# %%
ecg_id_labels = ["Undone","Normal"]
sns.countplot(ecg_id).set_xticklabels(ecg_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'Undone'), Text(1, 0, 'Normal')]

# %%
#LVH
ecgl_fl = cdc.iloc[:,246]
#print(ecgl_fl)
print(ecgl_fl.value_counts().sort_values(ascending= True), ecgl_fl.describe())
# Out:
# 0        18
# 1       986
# Y     14513
# N    119856
# Name: ECGL_FL, dtype: int64 count     135373
# unique         4
# top            N
# freq      119856
# Name: ECGL_FL, dtype: object

# %%
sns.countplot(ecgl_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECGL_FL', ylabel='count'>

# %%
#Af
ecga_fl = cdc.iloc[:,247]
#print(ecga_fl)
print(ecga_fl.value_counts().sort_values(ascending= True), ecga_fl.describe())
# Out:
# Y     16756
# N    119503
# Name: ECGA_FL, dtype: int64 count     136259
# unique         2
# top            N
# freq      119503
# Name: ECGA_FL, dtype: object

# %%
sns.countplot(ecga_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECGA_FL', ylabel='count'>

# %%
#Q wave
ecgq_fl = cdc.iloc[:,248]
#print(ecgq_fl)
print(ecgq_fl.value_counts().sort_values(ascending= True), ecgq_fl.describe())
# Out:
# Y      1410
# N    134389
# Name: ECGQ_FL, dtype: int64 count     135799
# unique         2
# top            N
# freq      134389
# Name: ECGQ_FL, dtype: object

# %%
sns.countplot(ecgq_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECGQ_FL', ylabel='count'>

# %%
#ECG others
ecgo_fl = cdc.iloc[:,249]
#print(ecgo_fl)
print(ecgo_fl.value_counts().sort_values(ascending= True), ecgo_fl.describe())
# Out:
# Y     29629
# N    107137
# Name: ECGO_FL, dtype: int64 count     136766
# unique         2
# top            N
# freq      107137
# Name: ECGO_FL, dtype: object

# %%
sns.countplot(ecgo_fl)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECGO_FL', ylabel='count'>

# %%
#ECGO_TX

# %%
#抽血結果 - HB
hb_nm = cdc.iloc[:,110]
#print(hb_nm)
print(hb_nm.value_counts().sort_values(ascending= True), hb_nm.describe())
# Out:
# 5.14         1
# 10.83        1
# 5.35         1
# 158.80       1
# 13.26        1
#           ...
# 14.00     2634
# 14.30     2694
# 13.80     2733
# 14.10     2746
# 13.90     2841
# Name: HB_NM, Length: 338, dtype: int64 count    133023.000000
# mean         28.155709
# std         119.050244
# min           0.600000
# 25%          12.300000
# 50%          13.800000
# 75%          15.100000
# max         999.900000
# Name: HB_NM, dtype: float64

# %%
hb_nm.plot.box(figsize=(5,5))
plt.show()
hb_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
hb_nm.plot. hist(figsize=(5,5), bins=100, range=[5,20])
plt.show()

# %%
#抽血結果 - HCT
hct_nm = cdc.iloc[:,111]
#print(hct_nm)
print(hct_nm.value_counts().sort_values(ascending= True), hct_nm.describe())
# Out:
# 38.14        1
# 60.10        1
# 62.90        1
# 47.87        1
# 41.89        1
#           ...
# 40.00     1073
# 41.00     1079
# 43.00     1097
# 42.00     1121
# 999.90    9488
# Name: HCT_NM, Length: 677, dtype: int64 count    130168.000000
# mean        110.522017
# std         250.386292
# min           0.000000
# 25%          37.100000
# 50%          41.100000
# 75%          44.900000
# max         999.900000
# Name: HCT_NM, dtype: float64

# %%
hct_nm.plot.box(figsize=(5,5))
plt.show()
hct_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
hct_nm.plot. hist(figsize=(5,5), bins=100, range=[15,60])
plt.show()

# %%
#抽血結果 - PLATELET
platelet_nm = cdc.iloc[:,112]
#print(platelet_nm)
print(platelet_nm.value_counts().sort_values(ascending= True), platelet_nm.describe())
# Out:
# 6.4         1
# 647.0       1
# 139.1       1
# 757.0       1
# 704.0       1
#          ...
# 200.0     870
# 191.0     877
# 187.0     893
# 196.0     896
# 999.9    2703
# Name: PLATELET_NM, Length: 1140, dtype: int64 count    132784.000000
# mean        227.023970
# std         136.060191
# min           0.800000
# 25%         167.000000
# 50%         208.000000
# 75%         255.000000
# max         999.900000
# Name: PLATELET_NM, dtype: float64

# %%
platelet_nm.plot.box(figsize=(5,5))
plt.show()
platelet_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
platelet_nm.plot. hist(figsize=(5,5), bins=100, range=[0,500])
plt.show()

# %%
#抽血結果 - WBC
wbc_nm = cdc.iloc[:,113]
#print(wbc_nm)
print(wbc_nm.value_counts().sort_values(ascending= True), wbc_nm.describe())
# Out:
# 24.46        1
# 17.49        1
# 659.00       1
# 20.06        1
# 34.20        1
#           ...
# 6.30      1090
# 6.80      1090
# 6.90      1131
# 6.70      1150
# 999.90    2162
# Name: WBC_NM, Length: 2508, dtype: int64 count    132830.000000
# mean         24.947664
# std         125.977946
# min           0.000000
# 25%           6.370000
# 50%           7.930000
# 75%          10.100000
# max         999.900000
# Name: WBC_NM, dtype: float64

# %%
wbc_nm.plot.box(figsize=(5,5))
plt.show()
wbc_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
wbc_nm.plot. hist(figsize=(5,5), bins=100, range=[0,30])
plt.show()

# %%
#抽血結果 - PTT1
ptt1_nm = cdc.iloc[:,114]
#print(ptt1_nm)
print(ptt1_nm.value_counts().sort_values(ascending= True), ptt1_nm.describe())
# Out:
# 90.30         1
# 23.28         1
# 12.96         1
# 14.65         1
# 21.15         1
#           ...
# 28.50      2008
# 28.00      2154
# 29.70      2208
# 31.00      2448
# 999.90    31185
# Name: PTT1_NM, Length: 1146, dtype: int64 count    130272.000000
# mean        261.435582
# std         414.743184
# min           0.000000
# 25%          27.300000
# 50%          29.600000
# 75%          40.800000
# max         999.900000
# Name: PTT1_NM, dtype: float64

# %%
ptt1_nm.plot.box(figsize=(5,5))
plt.show()
ptt1_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ptt1_nm.plot. hist(figsize=(5,5), bins=100, range=[0,50])
plt.show()

# %%
#抽血結果 - PTT2
ptt2_nm = cdc.iloc[:,115]
#print(ptt2_nm)
print(ptt2_nm.value_counts().sort_values(ascending= True), ptt2_nm.describe())
# Out:
# 129.90        1
# 39.29         1
# 54.10         1
# 2.67          1
# 10.58         1
#           ...
# 31.00      2685
# 29.70      2725
# 28.00      2979
# 28.50      3582
# 999.90    32723
# Name: PTT2_NM, Length: 1270, dtype: int64 count    129638.000000
# mean        276.278758
# std         423.849089
# min           0.000000
# 25%          27.300000
# 50%          29.700000
# 75%         999.900000
# max         999.900000
# Name: PTT2_NM, dtype: float64

# %%
ptt2_nm.plot.box(figsize=(5,5))
plt.show()
ptt2_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ptt2_nm.plot. hist(figsize=(5,5), bins=100, range=[0,50])
plt.show()

# %%
#PT(INR)
ptinr_nm = cdc.iloc[:,116]
#print(ptinr_nm)
print(ptinr_nm.value_counts().sort_values(ascending= True), ptinr_nm.describe())
# Out:
# 8.94          1
# 397.00        1
# 398.00        1
# 62.00         1
# 4.87          1
#           ...
# 0.99       5138
# 0.97       5190
# 0.98       5341
# 1.00      10085
# 999.90    23659
# Name: PTINR_NM, Length: 746, dtype: int64 count    131066.000000
# mean        181.844024
# std         384.382089
# min           0.000000
# 25%           0.970000
# 50%           1.020000
# 75%           1.190000
# max         999.900000
# Name: PTINR_NM, dtype: float64

# %%
ptinr_nm.plot.box(figsize=(5,5))
plt.show()
ptinr_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ptinr_nm.plot. hist(figsize=(5,5), bins=100, range=[0,2])
plt.show()

# %%
#GLUCOSE (ER)
er_nm = cdc.iloc[:,117]
#print(er_nm)
print(er_nm.value_counts().sort_values(ascending= True), er_nm.describe())
# Out:
# 983.0        1
# 829.0        1
# 832.0        1
# 19.5         1
# 671.0        1
#          ...
# 113.0     1277
# 103.0     1291
# 104.0     1318
# 105.0     1327
# 999.9    26254
# Name: ER_NM, Length: 905, dtype: int64 count    133057.000000
# mean        328.147257
# std         342.198308
# min           0.000000
# 25%         116.000000
# 50%         154.000000
# 75%         307.000000
# max         999.900000
# Name: ER_NM, dtype: float64

# %%
er_nm.plot.box(figsize=(5,5))
plt.show()
er_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
er_nm.plot. hist(figsize=(5,5), bins=100, range=[0,400])
plt.show()

# %%
#BUN
bun_nm = cdc.iloc[:,118]
#print(bun_nm)
print(bun_nm.value_counts().sort_values(ascending= True), bun_nm.describe())
# Out:
# 46.1         1
# 64.3         1
# 84.5         1
# 96.3         1
# 53.1         1
#          ...
# 13.0      6251
# 16.0      6353
# 15.0      6440
# 14.0      6621
# 999.9    20272
# Name: BUN_NM, Length: 936, dtype: int64 count    129320.000000
# mean        174.684599
# std         357.015978
# min           0.000000
# 25%          14.000000
# 50%          18.900000
# 75%          31.000000
# max         999.900000
# Name: BUN_NM, dtype: float64

# %%
bun_nm.plot.box(figsize=(5,5))
plt.show()
bun_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
bun_nm.plot. hist(figsize=(5,5), bins=100, range=[0,100])
plt.show()

# %%
#Creatinine
cre_nm = cdc.iloc[:,119]
#print(cre_nm)
print(cre_nm.value_counts().sort_values(ascending= True), cre_nm.describe())
# Out:
# 6.35         1
# 12.41        1
# 12.05        1
# 12.04        1
# 8.78         1
#          ...
# 1.20      6566
# 0.80      8335
# 1.10      8538
# 1.00      9773
# 0.90     10089
# Name: CRE_NM, Length: 1245, dtype: int64 count    132722.000000
# mean         38.607233
# std         189.283201
# min           0.000000
# 25%           0.800000
# 50%           1.000000
# 75%           1.340000
# max         999.900000
# Name: CRE_NM, dtype: float64

# %%
cre_nm.plot.box(figsize=(5,5))
plt.show()
cre_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
cre_nm.plot. hist(figsize=(5,5), bins=100, range=[0,4])
plt.show()

# %%
#Albumin
alb_nm = cdc.iloc[:,120]
#print(alb_nm)
print(alb_nm.value_counts().sort_values(ascending= True), alb_nm.describe())
# Out:
# 4.83          1
# 4.99          1
# 314.00        1
# 318.00        1
# 4.84          1
#           ...
# 3.90       3248
# 3.60       3260
# 3.80       3493
# 3.70       3515
# 999.90    75127
# Name: ALB_NM, Length: 369, dtype: int64 count    122115.000000
# mean        620.004030
# std         483.897872
# min          -5.000000
# 25%           3.800000
# 50%         999.900000
# 75%         999.900000
# max         999.900000
# Name: ALB_NM, dtype: float64

# %%
alb_nm.plot.box(figsize=(5,5))
plt.show()
alb_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
alb_nm.plot. hist(figsize=(5,5), bins=100, range=[0,5])
plt.show()

# %%
#CRP
crp_nm = cdc.iloc[:,121]
#print(crp_nm)
print(crp_nm.value_counts().sort_values(ascending= True), crp_nm.describe())
# Out:
# 1.606          1
# 1.236          1
# 7.222          1
# 39.290         1
# 39.460         1
#            ...
# 0.300        465
# 30.000       497
# 0.200        551
# 0.100        808
# 999.900    77846
# Name: CRP_NM, Length: 5673, dtype: int64 count    121606.000000
# mean        645.776371
# std         475.235694
# min           0.000000
# 25%           4.320000
# 50%         999.900000
# 75%         999.900000
# max         999.999000
# Name: CRP_NM, dtype: float64

# %%
crp_nm.plot.box(figsize=(5,5))
plt.show()
crp_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
crp_nm.plot. hist(figsize=(5,5), bins=100, range=[0,20])
plt.show()

# %%
#HbA1c
hbac_nm = cdc.iloc[:,122]
#print(hbac_nm)
print(hbac_nm.value_counts().sort_values(ascending= True), hbac_nm.describe())
# Out:
# 1.19          1
# 0.69          1
# 10.44         1
# 1.08          1
# 7.31          1
#           ...
# 5.60       2869
# 5.90       2937
# 5.80       3028
# 5.70       3115
# 999.90    65943
# Name: HBAC_NM, Length: 301, dtype: int64 count    126674.000000
# mean        525.568746
# std         495.809739
# min           0.000000
# 25%           6.400000
# 50%         999.900000
# 75%         999.900000
# max         999.900000
# Name: HBAC_NM, dtype: float64

# %%
hbac_nm.plot.box(figsize=(5,5))
plt.show()
hbac_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
hbac_nm.plot. hist(figsize=(5,5), bins=100, range=[0,20])
plt.show()

# %%
#Glu (AC)
ac_nm = cdc.iloc[:,123]
#print(ac_nm)
print(ac_nm.value_counts().sort_values(ascending= True), ac_nm.describe())
# Out:
# 95.5         1
# 622.0        1
# 9.5          1
# 475.0        1
# 708.0        1
#          ...
# 94.0      1088
# 97.0      1093
# 93.0      1094
# 98.0      1122
# 999.9    57819
# Name: AC_NM, Length: 667, dtype: int64 count    125625.000000
# mean        534.500042
# std         434.330726
# min           0.000000
# 25%         111.000000
# 50%         230.000000
# 75%         999.900000
# max         999.900000
# Name: AC_NM, dtype: float64

# %%
ac_nm.plot.box(figsize=(5,5))
plt.show()
ac_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ac_nm.plot. hist(figsize=(5,5), bins=100, range=[0,300])
plt.show()

# %%
#UA
ua_nm = cdc.iloc[:,124]
#print(ua_nm)
print(ua_nm.value_counts().sort_values(ascending= True), ua_nm.describe())
# Out:
# 2.74          1
# 999.70        1
# 9.05          1
# 9.99          1
# 3.16          1
#           ...
# 4.80       1700
# 4.90       1724
# 5.20       1734
# 5.10       1743
# 999.90    50794
# Name: UA_NM, Length: 1008, dtype: int64 count    126829.000000
# mean        405.603563
# std         487.329745
# min           0.000000
# 25%           5.200000
# 50%           7.500000
# 75%         999.900000
# max         999.900000
# Name: UA_NM, dtype: float64

# %%
ua_nm.plot.box(figsize=(5,5))
plt.show()
ua_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ua_nm.plot. hist(figsize=(5,5), bins=100, range=[0,15])
plt.show()

# %%
#T-CHO
tcho_nm = cdc.iloc[:,125]
#print(tcho_nm)
print(tcho_nm.value_counts().sort_values(ascending= True), tcho_nm.describe())
# Out:
# 647.0        1
# 943.0        1
# 514.0        1
# 628.0        1
# 2.9          1
#          ...
# 167.0      785
# 163.0      789
# 154.0      790
# 166.0      829
# 999.9    24528
# Name: TCHO_NM, Length: 876, dtype: int64 count    131835.000000
# mean        318.475292
# std         332.987243
# min           0.000000
# 25%         128.000000
# 50%         175.000000
# 75%         246.000000
# max         999.900000
# Name: TCHO_NM, dtype: float64

# %%
tcho_nm.plot.box(figsize=(5,5))
plt.show()
tcho_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
tcho_nm.plot. hist(figsize=(5,5), bins=100, range=[0,400])
plt.show()

# %%
#TG
tg_nm = cdc.iloc[:,126]
#print(tg_nm)
print(tg_nm.value_counts().sort_values(ascending= True), tg_nm.describe())
# Out:
# 1407.0        1
# 680.0         1
# 1452.0        1
# 19.5          1
# 7.3           1
#           ...
# 151.0       661
# 165.0       663
# 162.0       685
# 178.0       686
# 999.9     24559
# Name: TG_NM, Length: 1002, dtype: int64 count    131775.000000
# mean        315.628283
# std         353.068761
# min           0.000000
# 25%         113.000000
# 50%         170.000000
# 75%         249.000000
# max        9999.000000
# Name: TG_NM, dtype: float64

# %%
tg_nm.plot.box(figsize=(5,5))
plt.show()
tg_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
tg_nm.plot. hist(figsize=(5,5), bins=100, range=[0,400])
plt.show()

# %%
#HDL
hdl_nm = cdc.iloc[:,127]
#print(hdl_nm)
print(hdl_nm.value_counts().sort_values(ascending= True), hdl_nm.describe())
# Out:
# 232.4        1
# 7.8          1
# 314.7        1
# 325.0        1
# 13.3         1
#          ...
# 39.0      1813
# 34.0      1844
# 38.0      1899
# 37.0      1942
# 999.9    43270
# Name: HDL_NM, Length: 2107, dtype: int64 count    129806.000000
# mean        383.225964
# std         438.910048
# min           0.000000
# 25%          44.000000
# 50%         105.000000
# 75%         999.900000
# max         999.900000
# Name: HDL_NM, dtype: float64

# %%
hdl_nm.plot.box(figsize=(5,5))
plt.show()
hdl_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
hdl_nm.plot. hist(figsize=(5,5), bins=100, range=[0,200])
plt.show()

# %%
#LDL
ldl_nm = cdc.iloc[:,128]
#print(ldl_nm)
print(ldl_nm.value_counts().sort_values(ascending= True), ldl_nm.describe())
# Out:
# 127.2        1
# 102.4        1
# 71.3         1
# 114.3        1
# 5.6          1
#          ...
# 36.0      1177
# 34.0      1228
# 35.0      1243
# 37.0      1248
# 999.9    34180
# Name: LDL_NM, Length: 1635, dtype: int64 count    130679.000000
# mean        323.226089
# std         405.498533
# min           0.000000
# 25%          49.100000
# 50%         104.400000
# 75%         999.900000
# max         999.900000
# Name: LDL_NM, dtype: float64

# %%
ldl_nm.plot.box(figsize=(5,5))
plt.show()
ldl_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
ldl_nm.plot. hist(figsize=(5,5), bins=100, range=[0,200])
plt.show()

# %%
#GOT
got_nm = cdc.iloc[:,129]
#print(got_nm)
print(got_nm.value_counts().sort_values(ascending= True), got_nm.describe())
# Out:
# 26.7         1
# 918.0        1
# 718.0        1
# 371.0        1
# 26.4         1
#          ...
# 23.0      3859
# 20.0      4020
# 22.0      4109
# 21.0      4171
# 999.9    41949
# Name: GOT_NM, Length: 512, dtype: int64 count    125777.000000
# mean        356.801471
# std         457.559863
# min           0.000000
# 25%          22.000000
# 50%          34.000000
# 75%         999.900000
# max         999.900000
# Name: GOT_NM, dtype: float64

# %%
got_nm.plot.box(figsize=(5,5))
plt.show()
got_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
got_nm.plot. hist(figsize=(5,5), bins=100, range=[0,100])
plt.show()

# %%
#GPT
gpt_nm = cdc.iloc[:,130]
#print(gpt_nm)
print(gpt_nm.value_counts().sort_values(ascending= True), gpt_nm.describe())
# Out:
# 680.0        1
# 20.4         1
# 436.0        1
# 15.6         1
# 19.7         1
#          ...
# 17.0      4059
# 14.0      4079
# 16.0      4161
# 15.0      4275
# 999.9    38850
# Name: GPT_NM, Length: 475, dtype: int64 count    129983.000000
# mean        319.290949
# std         446.308041
# min           0.000000
# 25%          17.000000
# 50%          28.000000
# 75%         999.900000
# max         999.900000
# Name: GPT_NM, dtype: float64

# %%
gpt_nm.plot.box(figsize=(5,5))
plt.show()
gpt_nm.plot.hist(figsize=(5,5), bins=100)
plt.show()
gpt_nm.plot. hist(figsize=(5,5), bins=100, range=[0,100])
plt.show()

# %%
#離院情形
off_id = cdc.iloc[:,216]
#print(off_id)
print(off_id.value_counts().sort_values(ascending= True), off_id.describe())
# Out:
# 1.0      2320
# 0.0      2860
# 2.0      6359
# 3.0    122840
# Name: OFF_ID, dtype: int64 count    134379.000000
# mean          2.854300
# std           0.535445
# min           0.000000
# 25%           3.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000
# Name: OFF_ID, dtype: float64

# %%
off_id_labels = ["0","病危自動離院","死亡","離院"]
sns.countplot(off_id).set_xticklabels(off_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0'), Text(1, 0, '病危自動離院'), Text(2, 0, '死亡'), Text(3, 0, '離院')]

# %%
#死亡日期
offd_dt = cdc.iloc[:,217]
#print(offd_dt)
print(offd_dt.value_counts().sort_values(ascending= True), offd_dt.describe())
# Out:
# 2011-07-05    1
# 2016-09-26    1
# 2016-05-22    1
# 2016-03-02    1
# 2009-05-19    1
#              ..
# 2010-01-15    7
# 2008-07-19    7
# 2014-02-04    7
# 2009-03-06    8
# 2013-01-17    8
# Name: OFFD_DT, Length: 3184, dtype: int64 count                    6226
# unique                   3184
# top       2013-01-17 00:00:00
# freq                        8
# Name: OFFD_DT, dtype: object

# %%
#死因
offd_id = cdc.iloc[:,218]
#print(offd_id)
print(offd_id.value_counts().sort_values(ascending= True), offd_id.describe())
# Out:
# 2.0       738
# 1.0      2025
# 99.0    60358
# Name: OFFD_ID, dtype: int64 count    63121.000000
# mean        94.721931
# std         19.995528
# min          1.000000
# 25%         99.000000
# 50%         99.000000
# 75%         99.000000
# max         99.000000
# Name: OFFD_ID, dtype: float64

# %%
offd_id_labels = ["中風直接致死","併發症致死","其他"]
sns.countplot(offd_id).set_xticklabels(offd_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '中風直接致死'), Text(1, 0, '併發症致死'), Text(2, 0, '其他')]

# %%
#OFFD_TX

# %%
#離院，目的地
offdt_id = cdc.iloc[:,220]
#print(offdt_id)
print(offdt_id.value_counts().sort_values(ascending= True), offdt_id.describe())
# Out:
# 4.0     1069
# 5.0     4362
# 0.0     6917
# 2.0     8172
# 3.0     8486
# 1.0    99835
# Name: OFFDT_ID, dtype: int64 count    128841.000000
# mean          1.301783
# std           0.951771
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           5.000000
# Name: OFFDT_ID, dtype: float64

# %%
offdt_id_labels = ["0","回家","護理之家","轉院","呼吸病房(RCW)","轉復健"]
sns.countplot(offdt_id).set_xticklabels(offdt_id_labels)
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, '0'),
#  Text(1, 0, '回家'),
#  Text(2, 0, '護理之家'),
#  Text(3, 0, '轉院'),
#  Text(4, 0, '呼吸病房(RCW)'),
#  Text(5, 0, '轉復健')]

# %%
#離院，轉院醫院
offdtorg_id = cdc.iloc[:,221]
#print(offdtorg_id)
print(offdtorg_id.value_counts().sort_values(ascending= True), offdtorg_id.describe())
# Out:
# 63         1
# 52         1
# 58         1
# 40         1
# 17         2
#        ...
# 25       130
# O        176
# 22       355
# 99      3455
# 999    69142
# Name: OFFDTORG_ID, Length: 65, dtype: int64 count     74982
# unique       65
# top         999
# freq      69142
# Name: OFFDTORG_ID, dtype: int64

# %%
#OFFDTORG_TX

# %%
#轉復健日期
offre_dt = cdc.iloc[:,223]
#print(offre_dt)
print(offre_dt.value_counts().sort_values(ascending= True), offre_dt.describe())
# Out:
# 2016-05-19       1
# 2015-04-18       1
# 2011-03-30       1
# 2017-08-25       1
# 2017-03-13       1
#               ...
# 2013-04-29       8
# 2013-04-18       8
# 2012-10-11       8
# 2012-07-24       9
# 1900-01-01    1788
# Name: OFFRE_DT, Length: 1816, dtype: int64 count                    6145
# unique                   1816
# top       1900-01-01 00:00:00
# freq                     1788
# Name: OFFRE_DT, dtype: object
