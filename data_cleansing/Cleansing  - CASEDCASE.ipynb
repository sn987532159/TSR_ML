# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.font_manager import FontProperties
import numpy as np

# %%
font_path = os.path.join("..", "kaiu.ttf")
myfont=FontProperties(fname= font_path, size=14)
sns.set(font=myfont.get_name())

plt.rcParams['figure.figsize'] = (10,5)

# %%
csv_path = os.path.join("..", "data","TSR_2018_raw", "CASEDCASE.xlsx")
cdc = pd.read_excel(csv_path)
cdc.head()
# Out:
#    IPROTOCOL_ID  ICASE_ID       IDCASE_ID  CSTATUS_ID  ORG_ID DCTYPE24_ID  \
# 0           NaN         1  007-00000001-1           0    22.0           1
# 1           NaN         1  022-00000001-1           0    22.0         NaN
# 2           NaN         2  007-00000002-1           1    22.0           1
# 3           NaN         2  022-00000002-1           0    22.0           1
# 4           NaN         3  007-00000003-1           1     7.0          72
#
#   PATIENT_ID  INPUT_NM  AGE_NM  HEIGHT_NM  ...  MCDLI_ID  CREATE_DT  \
# 0    1176949       1.0     NaN      160.0  ...       NaN 2011-06-20
# 1        NaN       NaN     NaN        NaN  ...       NaN 2012-09-20
# 2    1377394       1.0     NaN      170.0  ...       NaN 2011-06-21
# 3    1377394       NaN     NaN      170.0  ...       NaN 2012-09-20
# 4    4086713       1.0     NaN      165.0  ...       NaN 2011-06-21
#
#    CREATESTAFF_ID  SYSUPD_DT  SYSUPDSTAFF_ID MODIFY_NM  \
# 0          STROKE 2013-01-18             李雯婷       5.0
# 1            Eric 2012-09-20            Eric       NaN
# 2          STROKE 2011-10-13          STROKE       1.0
# 3            Eric 2012-09-20            Eric       NaN
# 4          STROKE 2011-10-13          STROKE       1.0
#
#                            IGUID_FT OMAD_FL OMAD_ID DETHOH_FL
# 0  80A3E674EC154BD09878F8315D7D65D9       N     NaN         N
# 1                               NaN       N     NaN         N
# 2  9463CE2D986A479D94F870D4B1EF9CF0       N     NaN         N
# 3                               NaN       N     NaN         N
# 4  25805609163F44B696B9E1005F93B066       N     NaN         N
#
# [5 rows x 276 columns]

# %%
cdc.describe()
# Out:
#        IPROTOCOL_ID       ICASE_ID     CSTATUS_ID         ORG_ID     INPUT_NM  \
# count           0.0  140484.000000  140484.000000  139216.000000  9348.000000
# mean            NaN   62524.518401       0.418681      23.513799     1.043646
# std             NaN   37065.229757       0.493345      14.554859     0.225238
# min             NaN       1.000000       0.000000       1.000000     1.000000
# 25%             NaN   30329.750000       0.000000      11.000000     1.000000
# 50%             NaN   61958.500000       0.000000      24.000000     1.000000
# 75%             NaN   94497.250000       1.000000      35.000000     1.000000
# max             NaN  127958.000000       1.000000      64.000000     4.000000
#
#        AGE_NM      HEIGHT_NM      WEIGHT_NM         EDU_ID         PRO_ID  \
# count     0.0  137458.000000  137585.000000  137118.000000  137580.000000
# mean      NaN     267.208864     145.918184       4.149076       6.422721
# std       NaN     279.026415     264.770446      12.441390      17.242067
# min       NaN      -1.000000       0.000000       1.000000       1.000000
# 25%       NaN     156.000000      56.000000       1.000000       1.000000
# 50%       NaN     163.000000      65.000000       2.000000       1.000000
# 75%       NaN     170.000000      75.000000       4.000000       6.000000
# max       NaN     999.990000     999.990000      98.000000      99.000000
#
#        ...      TCCSL_ID     TCCSBA_ID   MCD_ID       MCDR_ID       MCDL_ID  \
# count  ...  41843.000000  61245.000000  44820.0  52526.000000  52369.000000
# mean   ...      1.170471      1.084023      0.0      1.220805      1.207585
# std    ...      0.389229      0.285603      0.0      0.487192      0.470898
# min    ...      1.000000      1.000000      0.0      1.000000      1.000000
# 25%    ...      1.000000      1.000000      0.0      1.000000      1.000000
# 50%    ...      1.000000      1.000000      0.0      1.000000      1.000000
# 75%    ...      1.000000      1.000000      0.0      1.000000      1.000000
# max    ...      3.000000      3.000000      0.0      3.000000      3.000000
#
#            MCDBA_ID      MCDRI_ID      MCDLI_ID    MODIFY_NM      OMAD_ID
# count  52131.000000  30796.000000  30655.000000  9348.000000  3063.000000
# mean       1.183116      1.113813      1.102496     1.511446     3.930787
# std        0.431139      0.380311      0.362042     1.746346     1.947325
# min        1.000000      1.000000      1.000000     0.000000     1.000000
# 25%        1.000000      1.000000      1.000000     0.000000     2.000000
# 50%        1.000000      1.000000      1.000000     1.000000     4.000000
# 75%        1.000000      1.000000      1.000000     2.000000     6.000000
# max        3.000000      3.000000      3.000000    59.000000     6.000000
#
# [8 rows x 105 columns]

# %%
#IPROTOCOL_ID to AGE_NM are meaningless

# %% [markdown]
# # 身高

# %%
ht = cdc.loc[:, "HEIGHT_NM"]
ht[ht <= 0] = np.nan
#ht.isna().sum()
#print(ht)
#print(ht.value_counts() / len(ht))
print(ht.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ht.plot.box(ax = ax1)
ax1.set_title("Height - Boxplot")
ax1.set_xlabel('Height')
ax1.set_ylabel('cm', rotation=0)
ax1.set_xticks([])

#ht.plot.hist(ax = ax2, bins=100)
#plt.show()
ht.plot.hist(ax = ax2, bins=100, range=[100,200])
ax2.set_title("Height - Histogram")
ax2.set_xlabel('Height(cm)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-6-95fae47529c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ht[ht <= 0] = np.nan
# count    137445.000000
# mean        267.234144
# std         279.027501
# min           1.000000
# 25%         156.000000
# 50%         163.000000
# 75%         170.000000
# max         999.990000
# Name: HEIGHT_NM, dtype: float64

# %% [markdown]
# # 體重

# %%
wt = cdc.loc[:,"WEIGHT_NM"]
wt[wt <= 0] = np.nan
#print(wt)
#print(wt.value_counts()len(wt))
print(wt.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

wt.plot.box(ax = ax1)
ax1.set_title("Weight - Boxplot")
ax1.set_xlabel('Weight')
ax1.set_ylabel('kg', rotation=0)
ax1.set_xticks([])

#wt.plot.hist(ax = ax2, bins=100)
#plt.show()
wt.plot.hist(ax = ax2, bins=100, range=[20,120])
ax2.set_title("Weight - Histogram")
ax2.set_xlabel('Weight(kg)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-7-cef915eaedd4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt[wt <= 0] = np.nan
# count    137577.000000
# mean        145.926669
# std         264.775806
# min           1.000000
# 25%          56.000000
# 50%          65.000000
# 75%          75.000000
# max         999.990000
# Name: WEIGHT_NM, dtype: float64

# %% [markdown]
# # 教育程度

# %%
edu = cdc.loc[:,"EDU_ID"]
edu[edu == 98] = np.nan
#print(edu)
print(edu.value_counts() / len(edu))
#print(edu.describe())

edu_labels = ["無","國小","國中","高中職","大學","研究所","不詳"]
sns.countplot(edu).set_xticklabels(edu_labels)
plt.title("Education Level - Barplot")
plt.xlabel('Education Level')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 2.0    0.318406
# 1.0    0.268102
# 4.0    0.143938
# 3.0    0.120782
# 5.0    0.086928
# 7.0    0.013603
# 6.0    0.007638
# Name: EDU_ID, dtype: float64
# <ipython-input-8-3a633672c028>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu[edu == 98] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 職業

# %%
pro = cdc.loc[:,"PRO_ID"]
pro[(pro == 98) | (pro == 99)] = np.nan
#print(pro)
print(pro.value_counts() / len(pro))
#print(pro.describe())

pro_labels = ["無","軍","公","教","工","農","商","服務業","學生","退休","不詳","其他"]
sns.countplot(pro).set_xticklabels(pro_labels)
plt.title("Occupation - Barplot")
plt.xlabel('Occupation')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-9-d2e9df54471d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pro[(pro == 98) | (pro == 99)] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0     0.611109
# 10.0    0.086900
# 5.0     0.071894
# 8.0     0.051024
# 7.0     0.044062
# 6.0     0.041257
# 12.0    0.014464
# 3.0     0.009275
# 11.0    0.009140
# 4.0     0.004769
# 9.0     0.002036
# 2.0     0.001516
# Name: PRO_ID, dtype: float64

# %%
#ITOWN_ID to FTITLE_TX are meaningless

# %% [markdown]
# # 入院方式

# %%
opc_id = cdc.loc[:,"OPC_ID"]
#print(opc_id)
print(opc_id.value_counts() / len(opc_id))
#print(opc_id.describe())

opc_id_labels = ["Inpatient","Outpatient","Emergency Room"]
sns.countplot(opc_id).set_xticklabels(opc_id_labels)
plt.title("Types of Hospital Admission - Barplot")
plt.xlabel('Types of Hospital Admission')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 3.0    0.859180
# 2.0    0.080984
# 1.0    0.046575
# Name: OPC_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 是否住院

# %%
ih_fl = cdc.loc[:,"IH_FL"]
ih_fl[ih_fl == 1] = "Y"
ih_fl[ih_fl == 0] = "N"
#print(ih_fl)
print(ih_fl.value_counts() / len(ih_fl))
#print(ih_fl.describe())

sns.countplot(ih_fl)
plt.title("Whether Being Hospitalised or Not - Barplot")
plt.xlabel('Whether Being Hospitalised or Not')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.915784
# Y    0.024280
# Name: IH_FL, dtype: float64
# <ipython-input-12-75986b56b8af>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ih_fl[ih_fl == 1] = "Y"
# <ipython-input-12-75986b56b8af>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ih_fl[ih_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 住院日期

# %%
ih_dt = cdc.loc[:,"IH_DT"]
ih_dt = pd.to_datetime(ih_dt, errors='coerce')
ih_dt[(ih_dt.dt.year < 2005) | (ih_dt.dt.year > 2018)] = np.nan
#print(ih_dt)
print(ih_dt.value_counts() / len(ih_dt))
print(ih_dt.describe())

ih_dt.value_counts().plot()
plt.title("Date of Hospital Admission - Lineplot")
plt.xlabel('Date of Hospital Admission')
plt.ylabel('Number', rotation=0)
plt.xticks()

plt.show()
# Out:
# 2008-02-18    0.000612
# 2008-02-11    0.000591
# 2008-01-21    0.000541
# 2007-02-12    0.000505
# 2008-08-18    0.000505
#                 ...
# 2006-02-18    0.000007
# 2006-01-04    0.000007
# 2006-02-01    0.000007
# 2006-02-15    0.000007
# 2006-02-23    0.000007
# Name: IH_DT, Length: 4574, dtype: float64
# count                  134517
# unique                   4574
# top       2008-02-18 00:00:00
# freq                       86
# first     2005-09-02 00:00:00
# last      2018-12-30 00:00:00
# Name: IH_DT, dtype: object
# <ipython-input-13-297d2289a959>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(ih_dt.describe())

# %% [markdown]
# # 離院日期

# %%
oh_dt = cdc.loc[:,"OH_DT"]
oh_dt = pd.to_datetime(oh_dt, errors='coerce')
oh_dt[(oh_dt.dt.year < 2006) | (oh_dt.dt.year > 2018) | (oh_dt < ih_dt)] = np.nan
#print(oh_dt)
#print(oh_dt.value_counts() / len(oh_dt))
#print(oh_dt.describe())

hospitalised_time = oh_dt - ih_dt
hospitalised_time = hospitalised_time.dt.days
#print(hospitalised_time.value_counts().sort_values(ascending= True))
print(hospitalised_time.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hospitalised_time.plot.box(ax = ax1)
ax1.set_title("Days at Hospitals - Boxplot")
ax1.set_xlabel('Days at Hospitals')
ax1.set_ylabel('Days', rotation=0)
ax1.set_xticks([])

#hospitalised_time.plot.hist(ax = ax2, bins=100)
#plt.show()
hospitalised_time.plot.hist(ax = ax2, bins=100, range=[0,80])
ax2.set_title("Days at Hospitals - Histogram")
ax2.set_xlabel('Days at Hospitals')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    132120.000000
# mean         15.480745
# std          35.101733
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          17.000000
# max        3696.000000
# dtype: float64

# %% [markdown]
# # 發病日期

# %%
onset_time = cdc.loc[:,["ONSET_DT", "ONSETH_NM", "ONSETM_NM"]]
onset_time.ONSET_DT = pd.to_datetime(onset_time.ONSET_DT, errors = "coerce", format = "%Y-%m-%d")
onset_time[(onset_time.ONSET_DT.dt.year < 2005) | (onset_time.ONSET_DT.dt.year > 2018)] = np.nan
print(onset_time.ONSET_DT.describe())

onset_time['ONSETH_NM'] = onset_time['ONSETH_NM'].fillna(0)
onset_time['ONSETM_NM'] = onset_time['ONSETM_NM'].fillna(0)

onset = onset_time['ONSET_DT'].astype(str)+' '+onset_time['ONSETH_NM'].astype(int).map(str)+':'+onset_time['ONSETM_NM'].astype(int).map(str)

onset_day = pd.to_datetime(onset, format='%Y/%m/%d %H:%M', errors='coerce')
print(onset_day.value_counts() / len(onset_day))

onset_day.value_counts().plot()
plt.title("Onset Date - Lineplot")
plt.xlabel('Onset Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-15-17f3261441c2>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(onset_time.ONSET_DT.describe())
# count                  140289
# unique                   4551
# top       2008-02-11 00:00:00
# freq                       76
# first     2006-01-08 00:00:00
# last      2018-12-18 00:00:00
# Name: ONSET_DT, dtype: object
# 2008-08-25 00:00:00    0.000299
# 2008-01-25 00:00:00    0.000278
# 2011-07-08 00:00:00    0.000270
# 2011-12-05 00:00:00    0.000263
# 2008-01-19 00:00:00    0.000249
#                          ...
# 2015-04-29 17:40:00    0.000007
# 2009-07-01 18:20:00    0.000007
# 2009-02-23 09:10:00    0.000007
# 2008-05-13 22:00:00    0.000007
# 2010-07-31 10:00:00    0.000007
# Length: 63602, dtype: float64

# %% [raw]
# onset_time = cdc.loc[:,["ONSET_DT", "ONSETH_NM", "ONSETM_NM"]]
# onset_time.fillna(0)
# onset_time.ONSET_DT = pd.to_datetime(onset_time.ONSET_DT, errors = "coerce", format = "%Y-%m-%d %H:%M:%S")
#
#
# onset_time['ONSETH_NM'] = onset_time['ONSETH_NM'].fillna(0)
# onset_time['ONSETM_NM'] = onset_time['ONSETM_NM'].fillna(0)
#
# onset_time['year'] = onset_time['ONSET_DT'].dt.year.astype(str)
# onset_time['month'] = onset_time['ONSET_DT'].dt.month.astype(str)
# onset_time['day'] = onset_time['ONSET_DT'].dt.day.astype(str)
# onset_time['ONSETH_NM'] = onset_time['ONSETH_NM'].astype(str)
# onset_time['ONSETM_NM'] = onset_time['ONSETM_NM'].astype(str)
#
# onset_time['TIME'] = onset_time['year']+onset_time['month']+onset_time['day']+onset_time['ONSETH_NM']+onset_time['ONSETM_NM']
# onset_time['TIME']

# %% [raw]
# onset_dt = cdc.loc[:,"ONSET_DT"]
# #print(onset_dt)
# print(onset_dt.value_counts() / len(onset_dt))
# #print(onset_dt.describe())

# %% [markdown]
# # 發病時間-時

# %%
onseth_nm = cdc.loc[:,"ONSETH_NM"]
onseth_nm[onseth_nm > 24] = np.nan
onseth_nm[onseth_nm == 24] = 0
#print(onseth_nm)
#print(onseth_nm.value_counts() / len(onseth_nm))
print(onseth_nm.describe())
# Out:
# count    75230.000000
# mean        12.399721
# std          6.061045
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         18.000000
# max         23.000000
# Name: ONSETH_NM, dtype: float64
# <ipython-input-16-1c53fdfee14b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onseth_nm[onseth_nm > 24] = np.nan
# <ipython-input-16-1c53fdfee14b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onseth_nm[onseth_nm == 24] = 0

# %% [markdown]
# # 發病時間-分

# %%
onsetm_nm = cdc.loc[:,"ONSETM_NM"]
onsetm_nm[onsetm_nm > 60] = np.nan
onsetm_nm[onsetm_nm == 60] = 0
#print(onsetm_nm)
#print(onsetm_nm.value_counts()len(onsetm_nm))
print(onsetm_nm.describe())
# Out:
# count    75075.000000
# mean         8.476856
# std         14.404438
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         20.000000
# max         59.000000
# Name: ONSETM_NM, dtype: float64
# <ipython-input-17-bf7ea34f05a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onsetm_nm[onsetm_nm > 60] = np.nan
# <ipython-input-17-bf7ea34f05a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onsetm_nm[onsetm_nm == 60] = 0

# %% [markdown]
# # 不確定發病時間

# %%
onset_fl = cdc.loc[:,"ONSET_FL"]
#print(onset_fl)
print(onset_fl.value_counts() / len(onset_fl))
#print(onset_fl.describe())

sns.countplot(onset_fl)
plt.title("Onset Date Unknown - Barplot")
plt.xlabel('Onset Date Unknown')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.544254
# Y    0.431159
# Name: ONSET_FL, dtype: float64

# %% [markdown]
# # 門診/急診日期

# %%
ot_time = cdc.loc[:,["OT_DT", "OTTIH_NM", "OTTIM_NM"]]
ot_time.OT_DT = pd.to_datetime(ot_time.OT_DT, errors = "coerce", format = "%Y-%m-%d")
ot_time[(ot_time.OT_DT.dt.year < 2005) | (ot_time.OT_DT.dt.year > 2018)] = np.nan
print(ot_time.OT_DT.describe())

ot_time['OTTIH_NM'] = ot_time['OTTIH_NM'].fillna(0)
ot_time['OTTIM_NM'] = ot_time['OTTIM_NM'].fillna(0)

otset = ot_time['OT_DT'].astype(str)+' '+ot_time['OTTIH_NM'].astype(int).map(str)+':'+ot_time['OTTIM_NM'].astype(int).map(str)

otset_day = pd.to_datetime(otset, format='%Y/%m/%d %H:%M', errors='coerce')
print(otset_day.value_counts() / len(otset_day))

otset_day.value_counts().plot()
plt.title("Outpatient/ER Date - Lineplot")
plt.xlabel('Outpatient/ER Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-19-5671103d321e>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(ot_time.OT_DT.describe())
# count                  126290
# unique                   4550
# top       2008-02-11 00:00:00
# freq                       77
# first     2005-03-07 00:00:00
# last      2018-10-11 00:00:00
# Name: OT_DT, dtype: object
# 2014-09-11 00:00:00    0.000057
# 2013-10-08 00:00:00    0.000050
# 2016-05-09 00:00:00    0.000043
# 2012-07-16 00:00:00    0.000043
# 2015-10-19 00:00:00    0.000043
#                          ...
# 2008-03-24 18:38:00    0.000007
# 2007-08-30 16:51:00    0.000007
# 2015-10-31 01:03:00    0.000007
# 2013-12-07 23:06:00    0.000007
# 2017-11-15 17:50:00    0.000007
# Length: 122876, dtype: float64

# %% [raw]
# ot_dt = cdc.loc[:,"OT_DT"]
# #print(ot_dt)
# print(ot_dt.value_counts() / len(ot_dt))
# #print(ot_dt.describe())

# %% [markdown]
# # 門診/急診時間-時

# %%
ottih_nm = cdc.loc[:,"OTTIH_NM"]
ottih_nm[ottih_nm > 24] = np.nan
ottih_nm[ottih_nm == 24] = 0
#print(ottih_nm)
#print(ottih_nm.value_counts() / len(ottih_nm))
print(ottih_nm.describe())
# Out:
# count    123343.000000
# mean         13.324550
# std           5.428062
# min           0.000000
# 25%           9.000000
# 50%          13.000000
# 75%          18.000000
# max          23.000000
# Name: OTTIH_NM, dtype: float64
# <ipython-input-20-769385712e00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ottih_nm[ottih_nm > 24] = np.nan
# <ipython-input-20-769385712e00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ottih_nm[ottih_nm == 24] = 0

# %% [markdown]
# # 門診/急診時間-分

# %%
ottim_nm = cdc.loc[:,"OTTIM_NM"]
ottim_nm[ottim_nm > 60] = np.nan
ottim_nm[ottim_nm == 60] = 0
#print(ottim_nm)
#print(ottim_nm.value_counts() / len(ottim_nm))
print(ottim_nm.describe())
# Out:
# count    123336.000000
# mean         29.173307
# std          17.376852
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          59.000000
# Name: OTTIM_NM, dtype: float64
# <ipython-input-21-08d8fd551d36>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ottim_nm[ottim_nm > 60] = np.nan
# <ipython-input-21-08d8fd551d36>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ottim_nm[ottim_nm == 60] = 0

# %% [markdown]
# # 不確定門/急診時間

# %%
ot_fl = cdc.loc[:,"OT_FL"]
#print(ot_fl)
print(ot_fl.value_counts() / len(ot_fl))
#print(ot_fl.describe())

sns.countplot(ot_fl)
plt.title("Outpatient/ER Date Unknown - Barplot")
plt.xlabel('Outpatient/ER Date Unknown')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.942563
# Y    0.020116
# Name: OT_FL, dtype: float64

# %% [markdown]
# # 第一次醫師檢視日期

# %%
flook_time = cdc.loc[:,["FLOOK_DT", "FLOOKH_NM", "FLOOKM_NM"]]
flook_time.FLOOK_DT = pd.to_datetime(flook_time.FLOOK_DT, errors = "coerce", format = "%Y-%m-%d")
flook_time[(flook_time.FLOOK_DT.dt.year < 2005) | (flook_time.FLOOK_DT.dt.year > 2018)] = np.nan
print(flook_time.FLOOK_DT.describe())

flook_time['FLOOKH_NM'] = flook_time['FLOOKH_NM'].fillna(0)
flook_time['FLOOKM_NM'] = flook_time['FLOOKM_NM'].fillna(0)

flookset = flook_time['FLOOK_DT'].astype(str)+' '+flook_time['FLOOKH_NM'].astype(int).map(str)+':'+flook_time['FLOOKM_NM'].astype(int).map(str)

flookset_day = pd.to_datetime(flookset, format='%Y/%m/%d %H:%M', errors='coerce')
print(flookset_day.value_counts() / len(flookset_day))

flookset_day.value_counts().plot()
plt.title("Doctors First Check Date - Lineplot")
plt.xlabel('Doctors First Check Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-23-26332079adac>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(flook_time.FLOOK_DT.describe())
# count                  129087
# unique                   4561
# top       2008-02-11 00:00:00
# freq                       76
# first     2005-05-15 00:00:00
# last      2018-12-29 00:00:00
# Name: FLOOK_DT, dtype: object
# 2014-09-11 00:00:00    0.000057
# 2011-05-02 00:00:00    0.000050
# 2016-03-09 00:00:00    0.000050
# 2017-05-01 00:00:00    0.000050
# 2016-05-09 00:00:00    0.000043
#                          ...
# 2013-12-29 18:14:00    0.000007
# 2011-07-20 21:04:00    0.000007
# 2013-04-04 03:19:00    0.000007
# 2017-11-26 10:56:00    0.000007
# 2007-12-23 13:02:00    0.000007
# Length: 124872, dtype: float64

# %% [raw]
# flook_dt = cdc.loc[:,"FLOOK_DT"]
# #print(flook_dt)
# print(flook_dt.value_counts() / len(flook_dt))
# #print(flook_dt.describe())

# %% [markdown]
# # 第一次醫師檢視時間-時

# %%
flookh_nm = cdc.loc[:,"FLOOKH_NM"]
flookh_nm[flookh_nm > 24] = np.nan
flookh_nm[flookh_nm == 24] = 0
#print(flookh_nm)
#print(flookh_nm.value_counts() / len(flookh_nm))
print(flookh_nm.describe())
# Out:
# count    126030.000000
# mean         13.449091
# std           5.451031
# min           0.000000
# 25%          10.000000
# 50%          13.000000
# 75%          18.000000
# max          23.000000
# Name: FLOOKH_NM, dtype: float64
# <ipython-input-24-32f543158887>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flookh_nm[flookh_nm > 24] = np.nan
# <ipython-input-24-32f543158887>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flookh_nm[flookh_nm == 24] = 0

# %% [markdown]
# # 第一次醫師檢視時間-分

# %%
flookm_nm = cdc.loc[:,"FLOOKM_NM"]
flookm_nm[flookm_nm > 60] = np.nan
flookm_nm[flookm_nm == 60] = 0
#print(flookm_nm)
#print(flookm_nm.value_counts() / len(flookm_nm))
print(flookm_nm.describe())
# Out:
# count    126026.000000
# mean         28.519559
# std          17.451589
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          59.000000
# Name: FLOOKM_NM, dtype: float64
# <ipython-input-25-617009275d1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flookm_nm[flookm_nm > 60] = np.nan
# <ipython-input-25-617009275d1f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flookm_nm[flookm_nm == 60] = 0

# %% [markdown]
# # 不確定第一次醫師檢視時間

# %%
flook_fl = cdc.loc[:,"FLOOK_FL"]
#print(flook_fl)
print(flook_fl.value_counts() / len(flook_fl))
print(flook_fl.describe())

sns.countplot(flook_fl)
plt.title("Doctors First Check Date Unknown - Barplot")
plt.xlabel('Doctors First Check Date Unknown')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.942285
# Y    0.019774
# Name: FLOOK_FL, dtype: float64
# count     135154
# unique         2
# top            N
# freq      132376
# Name: FLOOK_FL, dtype: object

# %% [markdown]
# # 1st CT 日期

# %%
fct_time = cdc.loc[:,["FCT_DT", "FCTH_NM", "FCTM_NM"]]
fct_time.FCT_DT = pd.to_datetime(fct_time.FCT_DT, errors = "coerce", format = "%Y-%m-%d")
fct_time[(fct_time.FCT_DT.dt.year < 2005) | (fct_time.FCT_DT.dt.year > 2018)] = np.nan
print(fct_time.FCT_DT.describe())

fct_time['FCTH_NM'] = fct_time['FCTH_NM'].fillna(0)
fct_time['FCTM_NM'] = fct_time['FCTM_NM'].fillna(0)

fctset = fct_time['FCT_DT'].astype(str)+' '+fct_time['FCTH_NM'].astype(int).map(str)+':'+fct_time['FCTM_NM'].astype(int).map(str)

fctset_day = pd.to_datetime(fctset, format='%Y/%m/%d %H:%M', errors='coerce')
print(fctset_day.value_counts() / len(fctset_day))

fctset_day.value_counts().plot()
plt.title("First CT Date - Lineplot")
plt.xlabel('First CT Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-27-1489a5fc920c>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(fct_time.FCT_DT.describe())
# count                  130517
# unique                   4563
# top       2008-02-11 00:00:00
# freq                       87
# first     2005-02-05 00:00:00
# last      2018-12-29 00:00:00
# Name: FCT_DT, dtype: object
# 2006-12-24 00:00:00    0.000085
# 2007-04-23 00:00:00    0.000085
# 2012-08-02 00:00:00    0.000085
# 2007-02-06 00:00:00    0.000078
# 2007-02-27 00:00:00    0.000078
#                          ...
# 2007-10-13 15:23:00    0.000007
# 2008-02-14 20:17:00    0.000007
# 2018-07-20 21:06:00    0.000007
# 2007-07-22 18:30:00    0.000007
# 2008-12-06 12:52:00    0.000007
# Length: 125155, dtype: float64

# %% [raw]
# fct_dt = cdc.loc[:,"FCT_DT"]
# #print(fct_dt)
# print(fct_dt.value_counts() / len(fct_dt))
# #print(fct_dt.describe())

# %% [markdown]
# # 1st CT 時間-時

# %%
fcth_nm = cdc.loc[:,"FCTH_NM"]
fcth_nm[fcth_nm > 24] = np.nan
fcth_nm[fcth_nm == 24] = 0
#print(fcth_nm)
#print(fcth_nm.value_counts() / len(fcth_nm))
print(fcth_nm.describe())
# Out:
# count    125083.000000
# mean         13.613361
# std           5.448601
# min           0.000000
# 25%          10.000000
# 50%          14.000000
# 75%          18.000000
# max          23.000000
# Name: FCTH_NM, dtype: float64
# <ipython-input-28-ad03d7974b4f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fcth_nm[fcth_nm > 24] = np.nan
# <ipython-input-28-ad03d7974b4f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fcth_nm[fcth_nm == 24] = 0

# %% [markdown]
# # 1st CT 時間-分

# %%
fctm_nm = cdc.loc[:,"FCTM_NM"]
fctm_nm[fctm_nm > 60] = np.nan
fctm_nm[fctm_nm == 60] = 0
#print(fctm_nm)
#print(fctm_nm.value_counts() / len(fctm_nm))
print(fctm_nm.describe())
# Out:
# count    125078.000000
# mean         29.339084
# std          17.367697
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          59.000000
# Name: FCTM_NM, dtype: float64
# <ipython-input-29-aa6711eb963f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fctm_nm[fctm_nm > 60] = np.nan
# <ipython-input-29-aa6711eb963f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fctm_nm[fctm_nm == 60] = 0

# %% [markdown]
# # 1st CT 外片

# %%
fctoh_fl = cdc.loc[:,"FCTOH_FL"]
#print(fctoh_fl)
print(fctoh_fl.value_counts() / len(fctoh_fl))
#print(fctoh_fl.describe())

sns.countplot(fctoh_fl)
plt.title("First CT From Another Hospital - Barplot")
plt.xlabel('First CT From Another Hospital')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.495950
# Y    0.042446
# Name: FCTOH_FL, dtype: float64

# %% [markdown]
# # IV-tPA

# %%
ivtpath_id = cdc.loc[:,"IVTPATH_ID"]
#print(ivtpath_id)
print(ivtpath_id.value_counts() / len(ivtpath_id))
#print(ivtpath_id.describe())

ivtpath_id_labels = ["This hospital","Another hospital"]
sns.countplot(ivtpath_id).set_xticklabels(ivtpath_id_labels)
plt.title("IV-tPA - Barplot")
plt.xlabel('IV-tPA')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.039015
# 2.0    0.001459
# Name: IVTPATH_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # IV-tPA 日期

# %%
ivtpa_time = cdc.loc[:,["IVTPA_DT", "IVTPAH_NM", "IVTPAM_NM"]]
ivtpa_time.IVTPA_DT = pd.to_datetime(ivtpa_time.IVTPA_DT, errors = "coerce", format = "%Y-%m-%d")
ivtpa_time[(ivtpa_time.IVTPA_DT.dt.year < 2005) | (ivtpa_time.IVTPA_DT.dt.year > 2018)] = np.nan
print(ivtpa_time.IVTPA_DT.describe())

ivtpa_time['IVTPAH_NM'] = ivtpa_time['IVTPAH_NM'].fillna(0)
ivtpa_time['IVTPAM_NM'] = ivtpa_time['IVTPAM_NM'].fillna(0)

ivtpaset = ivtpa_time['IVTPA_DT'].astype(str)+' '+ivtpa_time['IVTPAH_NM'].astype(int).map(str)+':'+ivtpa_time['IVTPAM_NM'].astype(int).map(str)

ivtpaset_day = pd.to_datetime(ivtpaset, format='%Y/%m/%d %H:%M', errors='coerce')
print(ivtpaset_day.value_counts() / len(ivtpaset_day))

ivtpaset_day.value_counts().plot()
plt.title("IV-tPA Date - Lineplot")
plt.xlabel('IV-tPA Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# count                    5642
# unique                   2925
# top       2014-02-12 00:00:00
# freq                        9
# first     2006-05-02 00:00:00
# last      2018-09-23 00:00:00
# Name: IVTPA_DT, dtype: object
# <ipython-input-32-158e0adf6eed>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(ivtpa_time.IVTPA_DT.describe())
# 2017-07-23 20:02:00    0.000014
# 2016-11-26 16:10:00    0.000014
# 2013-12-09 03:45:00    0.000014
# 2013-05-18 00:00:00    0.000014
# 2014-09-17 10:24:00    0.000014
#                          ...
# 2014-12-22 22:43:00    0.000007
# 2015-08-29 18:52:00    0.000007
# 2013-11-02 14:03:00    0.000007
# 2009-03-04 13:12:00    0.000007
# 2009-01-31 12:45:00    0.000007
# Length: 5595, dtype: float64

# %% [raw]
# ivtpa_dt = cdc.loc[:,"IVTPA_DT"]
# #print(ivtpa_dt)
# print(ivtpa_dt.value_counts() / len(ivtpa_dt))
# #print(ivtpa_dt.describe())

# %% [markdown]
# # IV-tPA 時間-時

# %%
ivtpah_nm = cdc.loc[:,"IVTPAH_NM"]
ivtpah_nm[ivtpah_nm > 24] = np.nan
ivtpah_nm[ivtpah_nm == 24] = 0
#print(ivtpah_nm)
#print(ivtpah_nm.value_counts() / len(ivtpah_nm))
print(ivtpah_nm.describe())
# Out:
# count    5591.000000
# mean       13.844929
# std         5.883280
# min         0.000000
# 25%        10.000000
# 50%        14.000000
# 75%        19.000000
# max        23.000000
# Name: IVTPAH_NM, dtype: float64
# <ipython-input-33-2713d1c9aacf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ivtpah_nm[ivtpah_nm > 24] = np.nan
# <ipython-input-33-2713d1c9aacf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ivtpah_nm[ivtpah_nm == 24] = 0

# %% [markdown]
# # IV-tPA 時間-分

# %%
ivtpam_nm = cdc.loc[:,"IVTPAM_NM"]
ivtpam_nm[ivtpam_nm > 60] = np.nan
ivtpam_nm[ivtpam_nm == 60] = 0
#print(ivtpam_nm)
#print(ivtpam_nm.value_counts() / len(ivtpam_nm))
print(ivtpam_nm.describe())
# Out:
# count    5590.000000
# mean       28.233095
# std        17.434946
# min         0.000000
# 25%        14.000000
# 50%        29.000000
# 75%        43.000000
# max        59.000000
# Name: IVTPAM_NM, dtype: float64
# <ipython-input-34-18f53075e4df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ivtpam_nm[ivtpam_nm > 60] = np.nan
# <ipython-input-34-18f53075e4df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ivtpam_nm[ivtpam_nm == 60] = 0

# %% [markdown]
# # Start IV-tPA mg

# %%
ivtpamg_nm = cdc.loc[:,"IVTPAMG_NM"]
#print(ivtpamg_nm)
#print(ivtpamg_nm.value_counts() / len(ivtpamg_nm))
print(ivtpamg_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ivtpamg_nm.plot.box(ax = ax1)
ax1.set_title("Start IV-tPA - Boxplot")
ax1.set_xlabel('Start IV-tPA')
ax1.set_ylabel('mg', rotation=0)
ax1.set_xticks([])

#ivtpamg_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ivtpamg_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("Start IV-tPA - Histogram")
ax2.set_xlabel('Start IV-tPA(mg)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    4534.000000
# mean       48.940940
# std        21.941571
# min         0.000000
# 25%        40.000000
# 50%        50.000000
# 75%        58.000000
# max      1000.000000
# Name: IVTPAMG_NM, dtype: float64

# %% [markdown]
# # 未打IV-tPA 原因

# %%
nivtpa_id = cdc.loc[:,"NIVTPA_ID"]
#print(nivtpa_id)
print(nivtpa_id.value_counts() / len(nivtpa_id))
#print(nivtpa_id.describe())

nivtpa_id[nivtpa_id == 1] = "輸注本藥前，急性缺血性中風發作的時間已超過 3 小時或症狀發作時間不明"
nivtpa_id[nivtpa_id == 2] = "缺血性中風發作至到院2 小時內，但不符合下列施打條件"
nivtpa_id[nivtpa_id == 3] = "缺血性中風發作至到院2-3 小時內，但不符合下列施打條件"

sns.countplot(nivtpa_id, hue = nivtpa_id)
plt.title("IV-tPA not Injected Reasons - Barplot")
plt.xlabel('IV-tPA not Injected Reasons')
plt.ylabel('Number', rotation=0)
plt.xticks([])
plt.legend(loc = 6, title="IV-tPA not Injected Reasons")
plt.show()
# Out:
# 1.0    0.312954
# 2.0    0.034659
# 3.0    0.021084
# Name: NIVTPA_ID, dtype: float64
# <ipython-input-36-ab0ee387799e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa_id[nivtpa_id == 1] = "輸注本藥前，急性缺血性中風發作的時間已超過 3 小時或症狀發作時間不明"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 輸注本藥前，急性缺血性腦中風的症狀已迅速改善或症狀輕微。（如NIHSS<6分）

# %%
nivtpa1_fl = cdc.loc[:,"NIVTPA1_FL"]
nivtpa1_fl[nivtpa1_fl == 1] = "Y"
nivtpa1_fl[nivtpa1_fl == 0] = "N"
#print(nivtpa1_fl)
print(nivtpa1_fl.value_counts() / len(nivtpa1_fl))
#print(nivtpa1_fl.describe())

sns.countplot(nivtpa1_fl)
plt.title("輸注本藥前，急性缺血性腦中風的症狀已迅速改善或症狀輕微。（如NIHSS<6分）- Barplot")
plt.xlabel('輸注本藥前，急性缺血性腦中風的症狀已迅速改善或症狀輕微。（如NIHSS<6分）')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.530039
# Y    0.032196
# Name: NIVTPA1_FL, dtype: float64
# <ipython-input-37-f903f0b6b201>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa1_fl[nivtpa1_fl == 1] = "Y"
# <ipython-input-37-f903f0b6b201>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa1_fl[nivtpa1_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 臨床或影像判定為嚴重之中風（如NIHSS>25）

# %%
nivtpa2_fl = cdc.loc[:,"NIVTPA2_FL"]
nivtpa2_fl[nivtpa2_fl == 1] = "Y"
nivtpa2_fl[nivtpa2_fl == 0] = "N"
#print(nivtpa2_fl)
print(nivtpa2_fl.value_counts() / len(nivtpa2_fl))
#print(nivtpa2_fl.describe())

sns.countplot(nivtpa2_fl)
plt.title("臨床或影像判定為嚴重之中風（如NIHSS>25）- Barplot")
plt.xlabel('臨床或影像判定為嚴重之中風（如NIHSS>25）')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.556768
# Y    0.005467
# Name: NIVTPA2_FL, dtype: float64
# <ipython-input-38-9364219a3088>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa2_fl[nivtpa2_fl == 1] = "Y"
# <ipython-input-38-9364219a3088>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa2_fl[nivtpa2_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 年齡在18歲以下，或80歲以上

# %%
nivtpa3_fl = cdc.loc[:,"NIVTPA3_FL"]
nivtpa3_fl[nivtpa3_fl == 1] = "Y"
nivtpa3_fl[nivtpa3_fl == 0] = "N"
#print(nivtpa3_fl)
print(nivtpa3_fl.value_counts() / len(nivtpa3_fl))
#print(nivtpa3_fl.describe())

sns.countplot(nivtpa3_fl)
plt.title("年齡在18歲以下，或80歲以上 - Barplot")
plt.xlabel('年齡在18歲以下，或80歲以上')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.549208
# Y    0.013026
# Name: NIVTPA3_FL, dtype: float64
# <ipython-input-39-15c841910f4b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa3_fl[nivtpa3_fl == 1] = "Y"
# <ipython-input-39-15c841910f4b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa3_fl[nivtpa3_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 過去曾中風且合併糖尿病

# %%
nivtpa4_fl = cdc.loc[:,"NIVTPA4_FL"]
nivtpa4_fl[nivtpa4_fl == 1] = "Y"
nivtpa4_fl[nivtpa4_fl == 0] = "N"
#print(nivtpa4_fl)
print(nivtpa4_fl.value_counts() / len(nivtpa4_fl))
#print(nivtpa4_fl.describe())

sns.countplot(nivtpa4_fl)
plt.title("過去曾中風且合併糖尿病 - Barplot")
plt.xlabel('過去曾中風且合併糖尿病')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-40-6672ec89fb63>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa4_fl[nivtpa4_fl == 1] = "Y"
# <ipython-input-40-6672ec89fb63>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa4_fl[nivtpa4_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.557978
# Y    0.003595
# Name: NIVTPA4_FL, dtype: float64

# %% [markdown]
# # 最近3個月內有中風病史或有嚴重性頭部創傷

# %%
nivtpa5_fl = cdc.loc[:,"NIVTPA5_FL"]
nivtpa5_fl[nivtpa5_fl == 1] = "Y"
nivtpa5_fl[nivtpa5_fl == 0] = "N"
#print(nivtpa5_fl)
print(nivtpa5_fl.value_counts() / len(nivtpa5_fl))
#print(nivtpa5_fl.describe())

sns.countplot(nivtpa5_fl)
plt.title("最近3個月內有中風病史或有嚴重性頭部創傷 - Barplot")
plt.xlabel('最近3個月內有中風病史或有嚴重性頭部創傷')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.559886
# Y    0.001687
# Name: NIVTPA5_FL, dtype: float64
# <ipython-input-41-80b761063780>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa5_fl[nivtpa5_fl == 1] = "Y"
# <ipython-input-41-80b761063780>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa5_fl[nivtpa5_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 中風發作時併發癲癇

# %%
nivtpa6_fl = cdc.loc[:,"NIVTPA6_FL"]
nivtpa6_fl[nivtpa6_fl == 1] = "Y"
nivtpa6_fl[nivtpa6_fl == 0] = "N"
#print(nivtpa6_fl)
print(nivtpa6_fl.value_counts() / len(nivtpa6_fl))
#print(nivtpa6_fl.describe())

sns.countplot(nivtpa6_fl)
plt.title("中風發作時併發癲癇 - Barplot")
plt.xlabel('中風發作時併發癲癇')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-42-a5f493203e3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa6_fl[nivtpa6_fl == 1] = "Y"
# <ipython-input-42-a5f493203e3e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa6_fl[nivtpa6_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.560470
# Y    0.001103
# Name: NIVTPA6_FL, dtype: float64

# %% [markdown]
# # 病人正接受口服抗凝血劑，如warfarin sodium（INR>1.3）

# %%
nivtpa7_fl = cdc.loc[:,"NIVTPA7_FL"]
nivtpa7_fl[nivtpa7_fl == 1] = "Y"
nivtpa7_fl[nivtpa7_fl == 0] = "N"
#print(nivtpa7_fl)
print(nivtpa7_fl.value_counts() / len(nivtpa7_fl))
#print(nivtpa7_fl.describe())

sns.countplot(nivtpa7_fl)
plt.title("病人正接受口服抗凝血劑，如warfarin sodium（INR>1.3）- Barplot")
plt.xlabel('病人正接受口服抗凝血劑，如warfarin sodium（INR>1.3）')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.559950
# Y    0.001623
# Name: NIVTPA7_FL, dtype: float64
# <ipython-input-43-cba4392a5de9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa7_fl[nivtpa7_fl == 1] = "Y"
# <ipython-input-43-cba4392a5de9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa7_fl[nivtpa7_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 最近3個月內曾患胃腸道潰瘍

# %%
nivtpa8_fl = cdc.loc[:,"NIVTPA8_FL"]
nivtpa8_fl[nivtpa8_fl == 1] = "Y"
nivtpa8_fl[nivtpa8_fl == 0] = "N"
#print(nivtpa8_fl)
print(nivtpa8_fl.value_counts() / len(nivtpa8_fl))
#print(nivtpa8_fl.describe())

sns.countplot(nivtpa8_fl)
plt.title("最近3個月內曾患胃腸道潰瘍- Barplot")
plt.xlabel('最近3個月內曾患胃腸道潰瘍')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-44-7b406dca0a7a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa8_fl[nivtpa8_fl == 1] = "Y"
# <ipython-input-44-7b406dca0a7a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa8_fl[nivtpa8_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.560811
# Y    0.000762
# Name: NIVTPA8_FL, dtype: float64

# %% [markdown]
# # 家屬拒絕

# %%
nivtpa9_fl = cdc.loc[:,"NIVTPA9_FL"]
nivtpa9_fl[nivtpa9_fl == 1] = "Y"
nivtpa9_fl[nivtpa9_fl == 0] = "N"
#print(nivtpa9_fl)
print(nivtpa9_fl.value_counts() / len(nivtpa9_fl))
#print(nivtpa9_fl.describe())

sns.countplot(nivtpa9_fl)
plt.title("家屬拒絕 - Barplot")
plt.xlabel('家屬拒絕')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.560099
# Y    0.001473
# Name: NIVTPA9_FL, dtype: float64
# <ipython-input-45-a91cf764367a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa9_fl[nivtpa9_fl == 1] = "Y"
# <ipython-input-45-a91cf764367a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa9_fl[nivtpa9_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 輸注本藥前，缺血性腦中風發作的時間已超過3小時

# %%
nivtpa10_fl = cdc.loc[:,"NIVTPA10_FL"]
nivtpa10_fl[nivtpa10_fl == 1] = "Y"
nivtpa10_fl[nivtpa10_fl == 0] = "N"
#print(nivtpa10_fl)
print(nivtpa10_fl.value_counts() / len(nivtpa10_fl))
#print(nivtpa10_fl.describe())

sns.countplot(nivtpa10_fl)
plt.title("輸注本藥前，缺血性腦中風發作的時間已超過3小時 - Barplot")
plt.xlabel('輸注本藥前，缺血性腦中風發作的時間已超過3小時')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-46-5d422809492a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa10_fl[nivtpa10_fl == 1] = "Y"
# <ipython-input-46-5d422809492a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa10_fl[nivtpa10_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.546874
# Y    0.014699
# Name: NIVTPA10_FL, dtype: float64

# %% [markdown]
# # 收縮壓>185mmhg或舒張壓>110mmhg

# %%
nivtpa11_fl = cdc.loc[:,"NIVTPA11_FL"]
nivtpa11_fl[nivtpa11_fl == 1] = "Y"
nivtpa11_fl[nivtpa11_fl == 0] = "N"
#print(nivtpa11_fl)
print(nivtpa11_fl.value_counts() / len(nivtpa11_fl))
#print(nivtpa11_fl.describe())

sns.countplot(nivtpa11_fl)
plt.title("收縮壓>185mmhg或舒張壓>110mmhg - Barplot")
plt.xlabel('收縮壓>185mmhg或舒張壓>110mmhg')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-47-b6d28f1fa01b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa11_fl[nivtpa11_fl == 1] = "Y"
# <ipython-input-47-b6d28f1fa01b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa11_fl[nivtpa11_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.557935
# Y    0.003637
# Name: NIVTPA11_FL, dtype: float64

# %% [markdown]
# # 不符合施打條件其他(未打IV-tPA 原因)

# %%
nivtpa99_fl = cdc.loc[:,"NIVTPA99_FL"]
nivtpa99_fl[nivtpa99_fl == 1] = "Y"
nivtpa99_fl[nivtpa99_fl == 0] = "N"
#print(nivtpa99_fl)
print(nivtpa99_fl.value_counts() / len(nivtpa99_fl))
#print(nivtpa99_fl.describe())

sns.countplot(nivtpa99_fl)
plt.title("不符合施打條件其他(未打IV-tPA 原因) - Barplot")
plt.xlabel('不符合施打條件其他(未打IV-tPA 原因)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.551436
# Y    0.010136
# Name: NIVTPA99_FL, dtype: float64
# <ipython-input-48-99bb9491c4f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa99_fl[nivtpa99_fl == 1] = "Y"
# <ipython-input-48-99bb9491c4f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nivtpa99_fl[nivtpa99_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#nivtpa99_tx

# %% [markdown]
# # GCS-E (eye opening)

# %%
gscenm = cdc.loc[:,"GCSE_NM"]
gscenm[(gscenm != 1) & (gscenm != 2) & (gscenm != 3) & (gscenm != 4)]  = np.nan
#print(gscenm)
print(gscenm.value_counts() / len(gscenm))
#print(gscenm.describe())

sns.countplot(gscenm)
plt.title("GCS-E - Barplot")
plt.xlabel('GCS-E')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-50-cd95a93c801a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gscenm[(gscenm != 1) & (gscenm != 2) & (gscenm != 3) & (gscenm != 4)]  = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 4.0    0.828799
# 3.0    0.058918
# 1.0    0.055558
# 2.0    0.031299
# Name: GCSE_NM, dtype: float64

# %% [markdown]
# # GCS-V (verbal response)

# %%
gscvnm = cdc.loc[:,"GCSV_NM"]
gscvnm[(gscvnm != 1) & (gscvnm != 2) & (gscvnm != 3) & (gscvnm != 4) & (gscvnm != 5)]  = np.nan
#print(gscvnm)
print(gscvnm.value_counts() / len(gscvnm))
#print(gscvnm.describe())

sns.countplot(gscvnm)
plt.title("GCS-V - Barplot")
plt.xlabel('GCS-V')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-51-4b614efd6105>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gscvnm[(gscvnm != 1) & (gscvnm != 2) & (gscvnm != 3) & (gscvnm != 4) & (gscvnm != 5)]  = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 5    0.708237
# 1    0.097499
# 2    0.054618
# 4    0.049365
# 3    0.023497
# Name: GCSV_NM, dtype: float64

# %% [markdown]
# # GCS-M (motor response)

# %%
gscmnm = cdc.loc[:,"GCSM_NM"]
gscmnm[(gscmnm != 1) & (gscmnm != 2) & (gscmnm != 3) & (gscmnm != 4) & (gscmnm != 5)& (gscmnm != 6)]  = np.nan
#print(gscmnm)
print(gscmnm.value_counts() / len(gscmnm))
#print(gscmnm.describe())

sns.countplot(gscmnm)
plt.title("GCS-M - Barplot")
plt.xlabel('GCS-M')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 6.0    0.772259
# 5.0    0.091662
# 4.0    0.055679
# 1.0    0.026708
# 3.0    0.016742
# 2.0    0.011581
# Name: GCSM_NM, dtype: float64
# <ipython-input-52-6a05e3344fcc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gscmnm[(gscmnm != 1) & (gscmnm != 2) & (gscmnm != 3) & (gscmnm != 4) & (gscmnm != 5)& (gscmnm != 6)]  = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # SBP

# %%
sbp_nm = cdc.loc[:,"SBP_NM"]
#print(sbp_nm)
#print(sbp_nm.value_counts() / len(sbp_nm))
print(sbp_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

sbp_nm.plot.box(ax = ax1)
ax1.set_title("SBP - Boxplot")
ax1.set_xlabel('SBP')
ax1.set_ylabel('mmHg', rotation=0)
ax1.set_xticks([])

#sbp_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
sbp_nm.plot.hist(ax = ax2, bins=100, range=[50,300])
ax2.set_title("SBP - Histogram")
ax2.set_xlabel('SBP(mmHg)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    136910.000000
# mean        161.874082
# std          38.356997
# min           0.000000
# 25%         139.000000
# 50%         159.000000
# 75%         182.000000
# max         999.900000
# Name: SBP_NM, dtype: float64

# %% [markdown]
# # DBP

# %%
dbp_nm = cdc.loc[:,"DBP_NM"]
#print(dbp_nm)
#print(dbp_nm.value_counts() / len(dbp_nm))
print(dbp_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

dbp_nm.plot.box(ax = ax1)
ax1.set_title("DBP - Boxplot")
ax1.set_xlabel('DBP')
ax1.set_ylabel('mmHg', rotation=0)
ax1.set_xticks([])

#dbp_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
dbp_nm.plot.hist(ax = ax2, bins=100, range=[0,200])
ax2.set_title("DBP - Histogram")
ax2.set_xlabel('DBP(mmHg)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    136909.000000
# mean         90.442104
# std          30.883359
# min           0.000000
# 25%          76.000000
# 50%          88.000000
# 75%         102.000000
# max         999.900000
# Name: DBP_NM, dtype: float64

# %% [markdown]
# # BT bleeding time?

# %%
dt_nm = cdc.loc[:,"BT_NM"]
#print(dt_nm)
#print(dt_nm.value_counts() / len(dt_nm))
print(dt_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

dt_nm.plot.box(ax = ax1)
ax1.set_title("BT - Boxplot")
ax1.set_xlabel('BT')
ax1.set_ylabel('min', rotation=0)
ax1.set_xticks([])

#dt_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
dt_nm.plot.hist(ax = ax2, bins=100, range=[34,40])
ax2.set_title("BT - Histogram")
ax2.set_xlabel('BT(min)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    136870.000000
# mean         37.721094
# std          33.523866
# min           0.000000
# 25%          36.000000
# 50%          36.500000
# 75%          36.800000
# max         999.900000
# Name: BT_NM, dtype: float64

# %% [markdown]
# # Heart Rate

# %%
hr_nm = cdc.loc[:,"HR_NM"]
#print(hr_nm)
#print(hr_nm.value_counts() / len(hr_nm))
print(hr_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hr_nm.plot.box(ax = ax1)
ax1.set_title("Heart Rate - Boxplot")
ax1.set_xlabel('Heart Rate')
ax1.set_ylabel('frequency', rotation=0)
ax1.set_xticks([])

#hr_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
hr_nm.plot.hist(ax = ax2, bins=100, range=[0,200])
ax2.set_title("Heart Rate - Histogram")
ax2.set_xlabel('Heart Rate(frequency)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    136904.000000
# mean         82.621670
# std          28.288596
# min           0.000000
# 25%          70.000000
# 50%          80.000000
# 75%          92.000000
# max         999.900000
# Name: HR_NM, dtype: float64

# %% [markdown]
# # Respiratory Rate

# %%
rr_nm = cdc.loc[:,"RR_NM"]
#print(rr_nm)
#print(rr_nm.value_counts() / len(rr_nm))
print(rr_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

rr_nm.plot.box(ax = ax1)
ax1.set_title("Respiratory Rate - Boxplot")
ax1.set_xlabel('Respiratory Rate')
ax1.set_ylabel('Frequency', rotation=0)
ax1.set_xticks([])

#rr_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
rr_nm.plot.hist(ax = ax2, bins=100, range=[10,30])
ax2.set_title("Respiratory Rate - Histogram")
ax2.set_xlabel('Respiratory Rate(Frequency)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    136684.000000
# mean         21.193953
# std          48.110909
# min           0.000000
# 25%          18.000000
# 50%          19.000000
# 75%          20.000000
# max         999.900000
# Name: RR_NM, dtype: float64

# %% [markdown]
# # Final Stroke Diagnosis

# %%
icd_id = cdc.loc[:,"ICD_ID"]
#print(icd_id)
print(icd_id.value_counts() / len(icd_id))
#print(icd_id.describe())

icd_id_labels = ["Infarct","TIA", "ICH", "SAH", "Others"]
sns.countplot(icd_id).set_xticklabels(icd_id_labels)
plt.title("Final Stroke Diagnosis - Barplot")
plt.xlabel('Final Stroke Diagnosis')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0     0.729336
# 3.0     0.136891
# 2.0     0.070755
# 4.0     0.024067
# 99.0    0.002242
# Name: ICD_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#ICD_TX

# %% [markdown]
# # Final Stroke Diagnosis (TIA Subtypes)

# %%
icdtia_id = cdc.loc[:,"ICDTIA_ID"]
#print(icdtia_id)
#print(icdtia_id.value_counts() / len(icdtia_id))
print(icdtia_id.describe())

icdtia_id_labels = ["Carotid","VB"]
sns.countplot(icdtia_id).set_xticklabels(icdtia_id_labels)
plt.title("Final Stroke Diagnosis (TIA Subtypes) - Barplot")
plt.xlabel('Final Stroke Diagnosis (TIA Subtypes)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# count    10381.000000
# mean         1.300260
# std          0.458393
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000
# Name: ICDTIA_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#ICDO_TX

# %% [markdown]
# # Ischemic Subtype(TOAST 分類)

# %%
toast_id = cdc.loc[:,"TOAST_ID"]
#print(toast_id)
print(toast_id.value_counts() / len(toast_id))
#print(toast_id.describe())

toast_id[toast_id == 1] = "Large artery atherosclerosis"
toast_id[toast_id == 2] = "Small vessel occlusion"
toast_id[toast_id == 3] = "Specific etiology"
toast_id[toast_id == 4] = "Cardioembolism"
toast_id[toast_id == 5] = "Undetermined etiology"

sns.countplot(toast_id, hue = toast_id)
plt.title("Ischemic Subtype(TOAST Groups) - Barplot")
plt.xlabel('Ischemic Subtype(TOAST Groups)')
plt.ylabel('Number', rotation=0)
plt.xticks([])
plt.legend(loc = 1, title="Ischemic Subtype(TOAST Groups)")
plt.show()
# Out:
# 2.0    0.262087
# 1.0    0.189153
# 5.0    0.126093
# 4.0    0.088074
# 3.0    0.011845
# Name: TOAST_ID, dtype: float64
# <ipython-input-62-9ab5e1a919dd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toast_id[toast_id == 1] = "Large artery atherosclerosis"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Large Artery Atherosclerosis (Extra)

# %%
toastle_fl = cdc.loc[:,"TOASTLE_FL"]
toastle_fl[toastle_fl == 1] = "Y"
toastle_fl[toastle_fl == 0] = "N"
#print(toastle_fl)
print(toastle_fl.value_counts() / len(toastle_fl))
#print(toastle_fl.describe())

sns.countplot(toastle_fl)
plt.title("Large Artery Atherosclerosis (Extra) - Barplot")
plt.xlabel('Large Artery Atherosclerosis (Extra)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.943574
# Y    0.041983
# Name: TOASTLE_FL, dtype: float64
# <ipython-input-63-3f0b3306947e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastle_fl[toastle_fl == 1] = "Y"
# <ipython-input-63-3f0b3306947e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastle_fl[toastle_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Large Artery Atherosclerosis (Intra)

# %%
toastli_fl = cdc.loc[:,"TOASTLI_FL"]
toastli_fl[toastli_fl == 1] = "Y"
toastli_fl[toastli_fl == 0] = "N"
#print(toastli_fl)
print(toastli_fl.value_counts() / len(toastli_fl))
#print(toastli_fl.describe())

sns.countplot(toastli_fl)
plt.title("Large Artery Atherosclerosis (Intra) - Barplot")
plt.xlabel('Large Artery Atherosclerosis (Intra)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-64-f1389bb6fedb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastli_fl[toastli_fl == 1] = "Y"
# <ipython-input-64-f1389bb6fedb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastli_fl[toastli_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.830913
# Y    0.154644
# Name: TOASTLI_FL, dtype: float64

# %% [markdown]
# # Specific Etiology (Cerebral Venous Thrombosis)

# %%
toastsce_fl = cdc.loc[:,"TOASTSCE_FL"]
toastsce_fl[toastsce_fl == 1] = "Y"
toastsce_fl[toastsce_fl == 0] = "N"
#print(toastsce_fl)
print(toastsce_fl.value_counts() / len(toastsce_fl))
#print(toastsce_fl.describe())

sns.countplot(toastsce_fl)
plt.title("Specific Etiology (Cerebral Venous Thrombosis) - Barplot")
plt.xlabel('Specific Etiology (Cerebral Venous Thrombosis)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.984162
# Y    0.001395
# Name: TOASTSCE_FL, dtype: float64
# <ipython-input-65-6ee8211c0be5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsce_fl[toastsce_fl == 1] = "Y"
# <ipython-input-65-6ee8211c0be5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsce_fl[toastsce_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Moyamoya Syndrome)

# %%
toastsmo_fl = cdc.loc[:,"TOASTSMO_FL"]
toastsmo_fl[toastsmo_fl == 1] = "Y"
toastsmo_fl[toastsmo_fl == 0] = "N"
#print(toastsmo_fl)
print(toastsmo_fl.value_counts() / len(toastsmo_fl))
#print(toastsmo_fl.describe())

sns.countplot(toastsmo_fl)
plt.title("Specific Etiology (Moyamoya Syndrome) - Barplot")
plt.xlabel('Specific Etiology (Moyamoya Syndrome)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.967612
# Y    0.017945
# Name: TOASTSMO_FL, dtype: float64
# <ipython-input-66-14662b075a33>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsmo_fl[toastsmo_fl == 1] = "Y"
# <ipython-input-66-14662b075a33>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsmo_fl[toastsmo_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Radiation)

# %%
toastsra_fl = cdc.loc[:,"TOASTSRA_FL"]
toastsra_fl[toastsra_fl == 1] = "Y"
toastsra_fl[toastsra_fl == 0] = "N"
#print(toastsra_fl)
print(toastsra_fl.value_counts() / len(toastsra_fl))
#print(toastsra_fl.describe())

sns.countplot(toastsra_fl)
plt.title("Specific Etiology (Radiation) - Barplot")
plt.xlabel('Specific Etiology (Radiation)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-67-0388610f5e7e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsra_fl[toastsra_fl == 1] = "Y"
# <ipython-input-67-0388610f5e7e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsra_fl[toastsra_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.914261
# Y    0.071296
# Name: TOASTSRA_FL, dtype: float64

# %% [markdown]
# # Specific Etiology (Dissection)

# %%
toastsdi_fl = cdc.loc[:,"TOASTSDI_FL"]
toastsdi_fl[toastsdi_fl == 1] = "Y"
toastsdi_fl[toastsdi_fl == 0] = "N"
#print(toastsdi_fl)
print(toastsdi_fl.value_counts() / len(toastsdi_fl))
#print(toastsdi_fl.describe())

sns.countplot(toastsdi_fl)
plt.title("Specific Etiology (Dissection) - Barplot")
plt.xlabel('Specific Etiology (Dissection)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-68-44ee149e1a88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsdi_fl[toastsdi_fl == 1] = "Y"
# <ipython-input-68-44ee149e1a88>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsdi_fl[toastsdi_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.982767
# Y    0.002790
# Name: TOASTSDI_FL, dtype: float64

# %% [markdown]
# # Specific Etiology (Migraine)

# %%
toastsmi_fl = cdc.loc[:,"TOASTSMI_FL"]
toastsmi_fl[toastsmi_fl == 1] = "Y"
toastsmi_fl[toastsmi_fl == 0] = "N"
#print(toastsmi_fl)
print(toastsmi_fl.value_counts() / len(toastsmi_fl))
#print(toastsmi_fl.describe())

sns.countplot(toastsmi_fl)
plt.title("Specific Etiology (Migraine) - Barplot")
plt.xlabel('Specific Etiology (Migraine)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-69-3d80f9e52440>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsmi_fl[toastsmi_fl == 1] = "Y"
# <ipython-input-69-3d80f9e52440>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsmi_fl[toastsmi_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.985514
# Y    0.000043
# Name: TOASTSMI_FL, dtype: float64

# %% [markdown]
# # Specific Etiology (Antiphospholipid Ab Synd)

# %%
toastsantip_fl = cdc.loc[:,"TOASTSANTIP_FL"]
toastsantip_fl[toastsantip_fl == 1] = "Y"
toastsantip_fl[toastsantip_fl == 0] = "N"
#print(toastsantip_fl)
print(toastsantip_fl.value_counts() / len(toastsantip_fl))
#print(toastsantip_fl.describe())

sns.countplot(toastsantip_fl)
plt.title("Specific Etiology (Antiphospholipid Ab Synd) - Barplot")
plt.xlabel('Specific Etiology (Antiphospholipid Ab Synd)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.984952
# Y    0.000605
# Name: TOASTSANTIP_FL, dtype: float64
# <ipython-input-70-c35c4f7628db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsantip_fl[toastsantip_fl == 1] = "Y"
# <ipython-input-70-c35c4f7628db>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsantip_fl[toastsantip_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Autoimmune Disease)

# %%
toastsau_fl = cdc.loc[:,"TOASTSAU_FL"]
toastsau_fl[toastsau_fl == 1] = "Y"
toastsau_fl[toastsau_fl == 0] = "N"
#print(toastsau_fl)
print(toastsau_fl.value_counts() / len(toastsau_fl))
#print(toastsau_fl.describe())

sns.countplot(toastsau_fl)
plt.title("Specific Etiology (Autoimmune Disease) - Barplot")
plt.xlabel('Specific Etiology (Autoimmune Disease)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.985073
# Y    0.000484
# Name: TOASTSAU_FL, dtype: float64
# <ipython-input-71-f24d7d7737fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsau_fl[toastsau_fl == 1] = "Y"
# <ipython-input-71-f24d7d7737fa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsau_fl[toastsau_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Hyperfibrinogenemia)

# %%
toastshy_fl = cdc.loc[:,"TOASTSHY_FL"]
toastshy_fl[toastshy_fl == 1] = "Y"
toastshy_fl[toastshy_fl == 0] = "N"
#print(toastshy_fl)
print(toastshy_fl.value_counts() / len(toastshy_fl))
#print(toastshy_fl.describe())

sns.countplot(toastshy_fl)
plt.title("Specific Etiology (Hyperfibrinogenemia) - Barplot")
plt.xlabel('Specific Etiology (Hyperfibrinogenemia)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-72-4be1fdd50ff3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastshy_fl[toastshy_fl == 1] = "Y"
# <ipython-input-72-4be1fdd50ff3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastshy_fl[toastshy_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.985507
# Y    0.000050
# Name: TOASTSHY_FL, dtype: float64

# %% [markdown]
# # Specific Etiology (Prot C/Prot S Deficiency)

# %%
toastspr_fl = cdc.loc[:,"TOASTSPR_FL"]
toastspr_fl[toastspr_fl == 1] = "Y"
toastspr_fl[toastspr_fl == 0] = "N"
#print(toastspr_fl)
print(toastspr_fl.value_counts() / len(toastspr_fl))
#print(toastspr_fl.describe())

sns.countplot(toastspr_fl)
plt.title("Specific Etiology (Prot C/Prot S Deficiency) - Barplot")
plt.xlabel('Specific Etiology (Prot C/Prot S Deficiency)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.985258
# Y    0.000299
# Name: TOASTSPR_FL, dtype: float64
# <ipython-input-73-2e0c9ad41efb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastspr_fl[toastspr_fl == 1] = "Y"
# <ipython-input-73-2e0c9ad41efb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastspr_fl[toastspr_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Antithrombin III Deficiency)

# %%
toastsantit_fl = cdc.loc[:,"TOASTSANTIT_FL"]
toastsantit_fl[toastsantit_fl == 1] = "Y"
toastsantit_fl[toastsantit_fl == 0] = "N"
#print(toastsantit_fl)
print(toastsantit_fl.value_counts() / len(toastsantit_fl))
#print(toastsantit_fl.describe())

sns.countplot(toastsantit_fl)
plt.title("Specific Etiology (Antithrombin III Deficiency) - Barplot")
plt.xlabel('Specific Etiology (Antithrombin III Deficiency)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.985443
# Y    0.000114
# Name: TOASTSANTIT_FL, dtype: float64
# <ipython-input-74-302e35c5d1c0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsantit_fl[toastsantit_fl == 1] = "Y"
# <ipython-input-74-302e35c5d1c0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsantit_fl[toastsantit_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Homocystinuria)

# %%
toastsho_fl = cdc.loc[:,"TOASTSHO_FL"]
toastsho_fl[toastsho_fl == 1] = "Y"
toastsho_fl[toastsho_fl == 0] = "N"
#print(toastsho_fl)
print(toastsho_fl.value_counts() / len(toastsho_fl))
#print(toastsho_fl.describe())

sns.countplot(toastsho_fl)
plt.title("Specific Etiology (Homocystinuria) - Barplot")
plt.xlabel('Specific Etiology (Homocystinuria)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.985166
# Y    0.000392
# Name: TOASTSHO_FL, dtype: float64
# <ipython-input-75-1d9de0ce8caa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsho_fl[toastsho_fl == 1] = "Y"
# <ipython-input-75-1d9de0ce8caa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsho_fl[toastsho_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Hypercoagulable State)

# %%
toastshys_fl = cdc.loc[:,"TOASTSHYS_FL"]
toastshys_fl[toastshys_fl == 1] = "Y"
toastshys_fl[toastshys_fl == 0] = "N"
#print(toastshys_fl)
print(toastshys_fl.value_counts() / len(toastshys_fl))
#print(toastshys_fl.describe())

sns.countplot(toastshys_fl)
plt.title("Specific Etiology (Hypercoagulable State) - Barplot")
plt.xlabel('Specific Etiology (Hypercoagulable State)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.985037
# Y    0.000520
# Name: TOASTSHYS_FL, dtype: float64
# <ipython-input-76-6689da81ef80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastshys_fl[toastshys_fl == 1] = "Y"
# <ipython-input-76-6689da81ef80>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastshys_fl[toastshys_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Specific Etiology (Cancer)

# %%
toastsca_fl = cdc.loc[:,"TOASTSCA_FL"]
toastsca_fl[toastsca_fl == 1] = "Y"
toastsca_fl[toastsca_fl == 0] = "N"
#print(toastsca_fl)
print(toastsca_fl.value_counts() / len(toastsca_fl))
#print(toastsca_fl.describe())

sns.countplot(toastsca_fl)
plt.title("Specific Etiology (Cancer) - Barplot")
plt.xlabel('Specific Etiology (Cancer)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.982653
# Y    0.002904
# Name: TOASTSCA_FL, dtype: float64
# <ipython-input-77-b547ccdaa422>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsca_fl[toastsca_fl == 1] = "Y"
# <ipython-input-77-b547ccdaa422>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastsca_fl[toastsca_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Cancer text

# %% [markdown]
# # Specific Etiology (Others)

# %%
toastso_fl = cdc.loc[:,"TOASTSO_FL"]
toastso_fl[toastso_fl == 1] = "Y"
toastso_fl[toastso_fl == 0] = "N"
#print(toastso_fl)
print(toastso_fl.value_counts() / len(toastso_fl))
#print(toastso_fl.describe())

sns.countplot(toastso_fl)
plt.title("Specific Etiology (Others) - Barplot")
plt.xlabel('Specific Etiology (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-79-a9ef1183d29b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastso_fl[toastso_fl == 1] = "Y"
# <ipython-input-79-a9ef1183d29b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toastso_fl[toastso_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.982688
# Y    0.002869
# Name: TOASTSO_FL, dtype: float64

# %%
#Others text

# %% [markdown]
# # Undetermined Etiology

# %%
toastu_id = cdc.loc[:,"TOASTU_ID"]
#print(toastu_id)
print(toastu_id.value_counts() / len(toastu_id))
#print(toastu_id.describe())

toastu_id_labels = ["Imcomplete study","Conflict data","Complete study"]
sns.countplot(toastu_id).set_xticklabels(toastu_id_labels)
plt.title("Undetermined Etiology - Barplot")
plt.xlabel('Undetermined Etiology')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.052084
# 3.0    0.045115
# 2.0    0.030836
# Name: TOASTU_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Cause of ICH ???

# %%
cich_id = cdc.loc[:,"CICH_ID"]
#print(cich_id)
print(cich_id.value_counts() / len(cich_id))
#print(cich_id.describe())

#cich_id_labels = ["Hypertension","Non-Hypertension","2"], but documement says that the labels are 1 and 2
#sns.countplot(cich_id).set_xticklabels(cich_id_labels)
sns.countplot(cich_id)
plt.title("Cause of ICH - Barplot")
plt.xlabel('Cause of ICH')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.809843
# 1.0    0.108326
# 2.0    0.022394
# Name: CICH_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Cause of SAH (蜘蛛膜下腔出血(Subarachnoid hemorrhage, SAH))

# %%
csah_id = cdc.loc[:,"CSAH_ID"]
#print(csah_id)
print(csah_id.value_counts() / len(csah_id))
#print(csah_id.describe())

csah_id_labels = ["Aneurysm","AVM","Angio negative","Angio undone","Others"]
sns.countplot(csah_id).set_xticklabels(csah_id_labels)
plt.title("Cause of SAH - Barplot")
plt.xlabel('Cause of SAH')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0     0.017781
# 4.0     0.002299
# 2.0     0.002178
# 99.0    0.001538
# 3.0     0.001196
# Name: CSAH_ID, dtype: float64

# %%
#Cause of SAH - Others

# %% [markdown]
# # Type of Heart Disease (NONE)

# %%
thd_id = cdc.loc[:,"THD_ID"]
#print(thd_id)
print(thd_id.value_counts(), len(thd_id) - thd_id.value_counts())
#88927 ppl have heart disease
#print(thd_id.describe())

#sns.countplot(thd_id)
#plt.title("Type of heart disease (NONE) - Barplot")
#plt.xlabel('Type of heart disease (NONE)')
#plt.ylabel('Number', rotation=0)
#plt.show()
# Out:
# 0.0    51557
# Name: THD_ID, dtype: int64 0.0    88927
# Name: THD_ID, dtype: int64

# %% [markdown]
# # Type of Heart Disease (Atrial Fibrillation)

# %%
thda_fl = cdc.loc[:,"THDA_FL"]
thda_fl[thda_fl == 1] = "Y"
thda_fl[thda_fl == 0] = "N"
#print(thda_fl)
print(thda_fl.value_counts() / len(thda_fl))
#print(thda_fl.describe())

sns.countplot(thda_fl)
plt.title("Type of Heart Disease (Atrial Fibrillation) - Barplot")
plt.xlabel('Type of Heart Disease (Atrial Fibrillation)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.901512
# Y    0.080571
# Name: THDA_FL, dtype: float64
# <ipython-input-86-217ec0c1086c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thda_fl[thda_fl == 1] = "Y"
# <ipython-input-86-217ec0c1086c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thda_fl[thda_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (Heart Failure)

# %%
thdh_fl = cdc.loc[:,"THDH_FL"]
thdh_fl[thdh_fl == 1] = "Y"
thdh_fl[thdh_fl == 0] = "N"
#print(thdh_fl)
print(thdh_fl.value_counts() / len(thdh_fl))
#print(thdh_fl.describe())

sns.countplot(thdh_fl)
plt.title("Type of Heart Disease (Heart Failure) - Barplot")
plt.xlabel('Type of Heart Disease (Heart Failure)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-87-555a34005a62>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdh_fl[thdh_fl == 1] = "Y"
# <ipython-input-87-555a34005a62>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdh_fl[thdh_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.955646
# Y    0.024494
# Name: THDH_FL, dtype: float64

# %% [markdown]
# # Type of Heart Disease (Ischemic Heart - CAD, old MI)

# %%
thdi_fl = cdc.loc[:,"THDI_FL"]
thdi_fl[thdi_fl == 1] = "Y"
thdi_fl[thdi_fl == 0] = "N"
#print(thdi_fl)
print(thdi_fl.value_counts() / len(thdi_fl))
#print(thdi_fl.describe())

sns.countplot(thdi_fl)
plt.title("Type of Heart Disease (Ischemic Heart - CAD, old MI) - Barplot")
plt.xlabel('Type of Heart Disease (Ischemic Heart - CAD, old MI)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-88-f9efaab8450d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdi_fl[thdi_fl == 1] = "Y"
# <ipython-input-88-f9efaab8450d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdi_fl[thdi_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.869273
# Y    0.112753
# Name: THDI_FL, dtype: float64

# %% [markdown]
# # Type of Heart Disease (Heart Disease - AMI<4W)

# %%
thdam_fl = cdc.loc[:,"THDAM_FL"]
thdam_fl[thdam_fl == 1] = "Y"
thdam_fl[thdam_fl == 0] = "N"
#print(thdam_fl)
print(thdam_fl.value_counts() / len(thdam_fl))
#print(thdam_fl.describe())

sns.countplot(thdam_fl)
plt.title("Type of Heart Disease (Heart Disease - AMI<4W) - Barplot")
plt.xlabel('Type of Heart Disease (Heart Disease - AMI<4W)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-89-2b8d48dd33cb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdam_fl[thdam_fl == 1] = "Y"
# <ipython-input-89-2b8d48dd33cb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdam_fl[thdam_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.958579
# Y    0.002862
# Name: THDAM_FL, dtype: float64

# %% [markdown]
# # Type of Heart Disease (Valvular Replacement)

# %%
thdv_fl = cdc.loc[:,"THDV_FL"]
thdv_fl[thdv_fl == 1] = "Y"
thdv_fl[thdv_fl == 0] = "N"
#print(thdv_fl)
print(thdv_fl.value_counts() / len(thdv_fl))
#print(thdv_fl.describe())

sns.countplot(thdv_fl)
plt.title("Type of Heart Disease (Valvular Replacement) - Barplot")
plt.xlabel('Type of Heart Disease (Valvular Replacement)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.974965
# Y    0.004463
# Name: THDV_FL, dtype: float64
# <ipython-input-90-abb43184c178>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdv_fl[thdv_fl == 1] = "Y"
# <ipython-input-90-abb43184c178>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdv_fl[thdv_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (Endocarditis)

# %%
thde_fl = cdc.loc[:,"THDE_FL"]
thde_fl[thde_fl == 1] = "Y"
thde_fl[thde_fl == 0] = "N"
#print(thde_fl)
print(thde_fl.value_counts() / len(thde_fl))
#print(thde_fl.describe())

sns.countplot(thde_fl)
plt.title("Type of Heart Disease (Endocarditis) - Barplot")
plt.xlabel('Type of Heart Disease (Endocarditis)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.978752
# Y    0.000569
# Name: THDE_FL, dtype: float64
# <ipython-input-91-0b0ad093ba1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thde_fl[thde_fl == 1] = "Y"
# <ipython-input-91-0b0ad093ba1c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thde_fl[thde_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (Myxoma)

# %%
thdm_fl = cdc.loc[:,"THDM_FL"]
thdm_fl[thdm_fl == 1] = "Y"
thdm_fl[thdm_fl == 0] = "N"
#print(thdm_fl)
print(thdm_fl.value_counts() / len(thdm_fl))
#print(thdm_fl.describe())

sns.countplot(thdm_fl)
plt.title("Type of Heart Disease (Myxoma) - Barplot")
plt.xlabel('Type of Heart Disease (Myxoma)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.979208
# Y    0.000107
# Name: THDM_FL, dtype: float64
# <ipython-input-92-eb7ad8d14fe3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdm_fl[thdm_fl == 1] = "Y"
# <ipython-input-92-eb7ad8d14fe3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdm_fl[thdm_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (RHD)

# %%
thdr_fl = cdc.loc[:,"THDR_FL"]
thdr_fl[thdr_fl == 1] = "Y"
thdr_fl[thdr_fl == 0] = "N"
#print(thdr_fl)
print(thdr_fl.value_counts() / len(thdr_fl))
#print(thdr_fl.describe())

sns.countplot(thdr_fl)
plt.title("Type of Heart Disease (RHD) - Barplot")
plt.xlabel('Type of Heart Disease (RHD)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.977997
# Y    0.001395
# Name: THDR_FL, dtype: float64
# <ipython-input-93-013339e71f31>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdr_fl[thdr_fl == 1] = "Y"
# <ipython-input-93-013339e71f31>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdr_fl[thdr_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (Patent Foramen Ovale)

# %%
thdp_fl = cdc.loc[:,"THDP_FL"]
thdp_fl[thdp_fl == 1] = "Y"
thdp_fl[thdp_fl == 0] = "N"
#print(thdp_fl)
print(thdp_fl.value_counts() / len(thdp_fl))
#print(thdp_fl.describe())

sns.countplot(thdp_fl)
plt.title("Type of Heart Disease (Patent Foramen Ovale) - Barplot")
plt.xlabel('Type of Heart Disease (Patent Foramen Ovale)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.978944
# Y    0.000399
# Name: THDP_FL, dtype: float64
# <ipython-input-94-ac109da5d098>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdp_fl[thdp_fl == 1] = "Y"
# <ipython-input-94-ac109da5d098>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdp_fl[thdp_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Type of Heart Disease (Others)

# %%
thdoo_fl = cdc.loc[:,"THDOO_FL"]
thdoo_fl[thdoo_fl == 1] = "Y"
thdoo_fl[thdoo_fl == 0] = "N"
#print(thdoo_fl)
print(thdoo_fl.value_counts() / len(thdoo_fl))
#print(thdoo_fl.describe())

sns.countplot(thdoo_fl)
plt.title("Type of Heart Disease (Others) - Barplot")
plt.xlabel('Type of Heart Disease (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.949347
# Y    0.030651
# Name: THDOO_FL, dtype: float64
# <ipython-input-95-3d20d890c80e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdoo_fl[thdoo_fl == 1] = "Y"
# <ipython-input-95-3d20d890c80e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thdoo_fl[thdoo_fl == 0] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#THDOO_TX

# %% [markdown]
# # Hospitalised (None)

# %%
trm_id = cdc.loc[:,"TRM_ID"]
#print(trm_id)
print(trm_id.value_counts(), len(trm_id) - trm_id.value_counts())
#140175 ppl were hospitalised
#print(trm_id.describe())

#sns.countplot(trm_id)
#plt.title("Hospitalised (NONE) - Barplot")
#plt.xlabel('Hospitalised (NONE)')
#plt.ylabel('Number', rotation=0)
#plt.show()
# Out:
# 0.0    309
# Name: TRM_ID, dtype: int64 0.0    140175
# Name: TRM_ID, dtype: int64

# %% [markdown]
# # Hospitalised (Antithrombotic Drugs Dtart Within 48h)

# %%
trman_fl = cdc.loc[:,"TRMAN_FL"]
#print(trman_fl)
print(trman_fl.value_counts() / len(trman_fl))
#print(trman_fl.describe())

sns.countplot(trman_fl)
plt.title("Hospitalised (Antithrombotic Drugs Dtart Within 48h) - Barplot")
plt.xlabel('Hospitalised (Antithrombotic Drugs Dtart Within 48h)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.583127
# Y    0.397134
# Name: TRMAN_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Aspirin)

# %%
trmas_fl = cdc.loc[:,"TRMAS_FL"]
#print(trmas_fl)
print(trmas_fl.value_counts() / len(trmas_fl))
#print(trmas_fl.describe())

sns.countplot(trmas_fl)
plt.title("Hospitalised (Aspirin) - Barplot")
plt.xlabel('Hospitalised (Aspirin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.607913
# Y    0.371508
# Name: TRMAS_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Ticlopidine)

# %%
trmti_fl = cdc.loc[:,"TRMTI_FL"]
#print(trmti_fl)
print(trmti_fl.value_counts() / len(trmti_fl))
#print(trmti_fl.describe())

sns.countplot(trmti_fl)
plt.title("Hospitalised (Ticlopidine) - Barplot")
plt.xlabel('Hospitalised (Ticlopidine)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.899633
# Y    0.062185
# Name: TRMTI_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Heparin)

# %%
trmhe_fl = cdc.loc[:,"TRMHE_FL"]
#print(trmhe_fl)
print(trmhe_fl.value_counts() / len(trmhe_fl))
#print(trmhe_fl.describe())

sns.countplot(trmhe_fl)
plt.title("Hospitalised (Heparin) - Barplot")
plt.xlabel('Hospitalised (Heparin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.940911
# Y    0.020849
# Name: TRMHE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Warfarin)

# %%
trmwa_fl = cdc.loc[:,"TRMWA_FL"]
#print(trmwa_fl)
print(trmwa_fl.value_counts() / len(trmwa_fl))
#print(trmwa_fl.describe())

sns.countplot(trmwa_fl)
plt.title("Hospitalised (Warfarin) - Barplot")
plt.xlabel('Hospitalised (Warfarin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.900145
# Y    0.062819
# Name: TRMWA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (IA Thrombolysis)

# %%
trmia_fl = cdc.loc[:,"TRMIA_FL"]
#print(trmia_fl)
print(trmia_fl.value_counts() / len(trmia_fl))
#print(trmia_fl.describe())

sns.countplot(trmia_fl)
plt.title("Hospitalised (IA Thrombolysis) - Barplot")
plt.xlabel('Hospitalised (IA Thrombolysis)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.947389
# Y    0.014123
# Name: TRMIA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Foley)

# %%
trmfo_fl = cdc.loc[:,"TRMFO_FL"]
#print(trmfo_fl)
print(trmfo_fl.value_counts() / len(trmfo_fl))
#print(trmfo_fl.describe())

sns.countplot(trmfo_fl)
plt.title("Hospitalised (Foley) - Barplot")
plt.xlabel('Hospitalised (Foley)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.721555
# Y    0.246533
# Name: TRMFO_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Transarterial - Embolization)

# %%
trmta_fl = cdc.loc[:,"TRMTA_FL"]
#print(trmta_fl)
print(trmta_fl.value_counts() / len(trmta_fl))
#print(trmta_fl.describe())

sns.countplot(trmta_fl)
plt.title("Hospitalised (Transarterial - Embolization) - Barplot")
plt.xlabel('Hospitalised (Transarterial - Embolization)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.960131
# Y    0.001466
# Name: TRMTA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Sign DNR)

# %%
trmsd_fl = cdc.loc[:,"TRMSD_FL"]
#print(trmsd_fl)
print(trmsd_fl.value_counts() / len(trmsd_fl))
#print(trmsd_fl.describe())

sns.countplot(trmsd_fl)
plt.title("Hospitalised (Sign DNR) - Barplot")
plt.xlabel('Hospitalised (Sign DNR)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.890664
# Y    0.073261
# Name: TRMSD_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Rehab)

# %%
trmre_fl = cdc.loc[:,"TRMRE_FL"]
#print(trmre_fl)
print(trmre_fl.value_counts() / len(trmre_fl))
#print(trmre_fl.describe())

sns.countplot(trmre_fl)
plt.title("Hospitalised (Rehab) - Barplot")
plt.xlabel('Hospitalised (Rehab)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# Y    0.546240
# N    0.430732
# Name: TRMRE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Endovascular Treatment)

# %%
trmen_fl = cdc.loc[:,"TRMEN_FL"]
#print(trmen_fl)
print(trmen_fl.value_counts() / len(trmen_fl))
#print(trmen_fl.describe())

sns.countplot(trmen_fl)
plt.title("Hospitalised (Endovascular Treatment) - Barplot")
plt.xlabel('Hospitalised (Endovascular Treatment)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.959227
# Y    0.002349
# Name: TRMEN_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Endovascular Treatment Options)

# %%
trmen_id = cdc.loc[:,"TRMEN_ID"]
#print(trmen_id)
print(trmen_id.value_counts() / len(trmen_id))
#print(trmen_id.describe())

trmen_id_labels = ["Aneurysm","AVM","Stenting"]
sns.countplot(trmen_id).set_xticklabels(trmen_id_labels)
plt.title("Hospitalised (Endovascular Treatment Options) - Barplot")
plt.xlabel('Hospitalised (Endovascular Treatment Options)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 3.0    0.001374
# 1.0    0.000427
# 2.0    0.000135
# Name: TRMEN_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Aggrenox)

# %%
trmag_fl = cdc.loc[:,"TRMAG_FL"]
#print(trmag_fl)
print(trmag_fl.value_counts() / len(trmag_fl))
#print(trmag_fl.describe())

sns.countplot(trmag_fl)
plt.title("Hospitalised (Aggrenox) - Barplot")
plt.xlabel('Hospitalised (Aggrenox)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.952486
# Y    0.009360
# Name: TRMAG_FL, dtype: float64

# %% [markdown]
# # Hospitalised (Clopidogrel)

# %%
trmcl_fl = cdc.loc[:,"TRMCL_FL"]
#print(trmcl_fl)
print(trmcl_fl.value_counts() / len(trmcl_fl))
#print(trmcl_fl.describe())

sns.countplot(trmcl_fl)
plt.title("Hospitalised (Clopidogrel) - Barplot")
plt.xlabel('Hospitalised (Clopidogrel)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.816726
# Y    0.147974
# Name: TRMCL_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Pletaal)

# %%
trmpl_fl = cdc.loc[:,"TRMPL_FL"]
#print(trmpl_fl)
print(trmpl_fl.value_counts() / len(trmpl_fl))
#print(trmpl_fl.describe())

sns.countplot(trmpl_fl)
plt.title("Hospitalised (Pletaal) - Barplot")
plt.xlabel('Hospitalised (Pletaal)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.951802
# Y    0.009859
# Name: TRMPL_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (LMW Heparin)

# %%
trmlm_fl = cdc.loc[:,"TRMLM_FL"]
#print(trmlm_fl)
print(trmlm_fl.value_counts() / len(trmlm_fl))
#print(trmlm_fl.describe())

sns.countplot(trmlm_fl)
plt.title("Hospitalised (LMW Heparin) - Barplot")
plt.xlabel('Hospitalised (LMW Heparin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.935430
# Y    0.027348
# Name: TRMLM_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (IV t-PA)

# %%
trmiv_fl = cdc.loc[:,"TRMIV_FL"]
#print(trmiv_fl)
print(trmiv_fl.value_counts() / len(trmiv_fl))
#print(trmiv_fl.describe())

sns.countplot(trmiv_fl)
plt.title("Hospitalised (IV t-PA) - Barplot")
plt.xlabel('Hospitalised (IV t-PA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.931409
# Y    0.031349
# Name: TRMIV_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Ventilator)

# %%
trmve_fl = cdc.loc[:,"TRMVE_FL"]
#print(trmve_fl)
print(trmve_fl.value_counts() / len(trmve_fl))
#print(trmve_fl.describe())

sns.countplot(trmve_fl)
plt.title("Hospitalised (Ventilator) - Barplot")
plt.xlabel('Hospitalised (Ventilator)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.853272
# Y    0.112084
# Name: TRMVE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Nasogastric Tube)

# %%
trmng_fl = cdc.loc[:,"TRMNG_FL"]
#print(trmng_fl)
print(trmng_fl.value_counts() / len(trmng_fl))
#print(trmng_fl.describe())

sns.countplot(trmng_fl)
plt.title("Hospitalised (Nasogastric Tube) - Barplot")
plt.xlabel('Hospitalised (Nasogastric Tube)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.681088
# Y    0.288175
# Name: TRMNG_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Dysphagia Screen)

# %%
trmdy_fl = cdc.loc[:,"TRMDY_FL"]
#print(trmdy_fl)
print(trmdy_fl.value_counts() / len(trmdy_fl))
#print(trmdy_fl.describe())

sns.countplot(trmdy_fl)
plt.title("Hospitalised (Dysphagia Screen) - Barplot")
plt.xlabel('Hospitalised (Dysphagia Screen)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.547358
# Y    0.431885
# Name: TRMDY_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Admission to ICU)

# %%
trmicu_fl = cdc.loc[:,"TRMICU_FL"]
#print(trmicu_fl)
print(trmicu_fl.value_counts() / len(trmicu_fl))
#print(trmicu_fl.describe())

sns.countplot(trmicu_fl)
plt.title("Hospitalised (Admission to ICU) - Barplot")
plt.xlabel('Hospitalised (Admission to ICU)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.811801
# Y    0.157619
# Name: TRMICU_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Smoking Cessation Counseling)

# %%
trmsm_fl = cdc.loc[:,"TRMSM_FL"]
#print(trmsm_fl)
print(trmsm_fl.value_counts() / len(trmsm_fl))
#print(trmsm_fl.describe())

sns.countplot(trmsm_fl)
plt.title("Hospitalised (Smoking Cessation Counseling) - Barplot")
plt.xlabel('Hospitalised (Smoking Cessation Counseling)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.666617
# Y    0.313075
# Name: TRMSM_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Education About Stroke)

# %%
trmed_fl = cdc.loc[:,"TRMED_FL"]
#print(trmed_fl)
print(trmed_fl.value_counts() / len(trmed_fl))
#print(trmed_fl.describe())

sns.countplot(trmed_fl)
plt.title("Hospitalised (Education About Stroke) - Barplot")
plt.xlabel('Hospitalised (Education About Stroke)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.517596
# Y    0.466324
# Name: TRMED_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Operation for)

# %%
trmop_fl = cdc.loc[:,"TRMOP_FL"]
#print(trmop_fl)
print(trmop_fl.value_counts() / len(trmop_fl))
#print(trmop_fl.describe())

sns.countplot(trmop_fl)
plt.title("Hospitalised (Operation for) - Barplot")
plt.xlabel('Hospitalised (Operation for)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.932263
# Y    0.031256
# Name: TRMOP_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Operation for Options)

# %%
trmop_id = cdc.loc[:,"TRMOP_ID"]
#print(trmop_id)
print(trmop_id.value_counts() / len(trmop_id))
#print(trmop_id.describe())

trmop_id_labels = ["Infracion","ICH","Carotid Stenosis \n (eg:Endarterectomy)","Aneurysm","AVM"]
sns.countplot(trmop_id).set_xticklabels(trmop_id_labels)
plt.title("Hospitalised (Operation for Options) - Barplot")
plt.xlabel('Hospitalised (Operation for Options)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 2.0    0.038175
# 1.0    0.006812
# 4.0    0.006349
# 5.0    0.000804
# 3.0    0.000142
# Name: TRMOP_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hospitalised (Others)

# %%
trmot_fl = cdc.loc[:,"TRMOT_FL"]
#print(trmot_fl)
print(trmot_fl.value_counts() / len(trmot_fl))
#print(trmot_fl.describe())

sns.countplot(trmot_fl)
plt.title("Hospitalised (Others) - Barplot")
plt.xlabel('Hospitalised (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.862760
# Y    0.099655
# Name: TRMOT_FL, dtype: float64

# %%
#TRMOT_TX

# %% [markdown]
# # Discharged (None)

# %%
om_fl = cdc.loc[:,"OM_FL"]
#print(om_fl)
print(om_fl.value_counts() / len(om_fl))
#print(om_fl.describe())

sns.countplot(om_fl)
plt.title("Discharged (Others) - Barplot")
plt.xlabel('Discharged (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.873822
# Y    0.089804
# Name: OM_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Aspirin)

# %%
omas_fl = cdc.loc[:,"OMAS_FL"]
#print(omas_fl)
print(omas_fl.value_counts() / len(omas_fl))
#print(omas_fl.describe())

sns.countplot(omas_fl)
plt.title("Discharged (Aspirin) - Barplot")
plt.xlabel('Discharged (Aspirin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# Y    0.500021
# N    0.475022
# Name: OMAS_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Aggrenox)

# %%
omag_fl = cdc.loc[:,"OMAG_FL"]
#print(omag_fl)
print(omag_fl.value_counts() / len(omag_fl))
#print(omag_fl.describe())

sns.countplot(omag_fl)
plt.title("Discharged (Aggrenox) - Barplot")
plt.xlabel('Discharged (Aggrenox)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.945659
# Y    0.015788
# Name: OMAG_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Ticlopidine)

# %%
omti_fl = cdc.loc[:,"OMTI_FL"]
#print(omti_fl)
print(omti_fl.value_counts() / len(omti_fl))
#print(omti_fl.describe())

sns.countplot(omti_fl)
plt.title("Discharged (Ticlopidine) - Barplot")
plt.xlabel('Discharged (Ticlopidine)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.946449
# Y    0.014834
# Name: OMTI_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Clopidogrel)

# %%
omcl_fl = cdc.loc[:,"OMCL_FL"]
#print(omcl_fl)
print(omcl_fl.value_counts() / len(omcl_fl))
#print(omcl_fl.describe())

sns.countplot(omcl_fl)
plt.title("Discharged (Clopidogrel) - Barplot")
plt.xlabel('Discharged (Clopidogrel)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.828208
# Y    0.135987
# Name: OMCL_FL, dtype: float64

# %% [markdown]
# # Discharged (Pletaal)

# %%
ompl_fl = cdc.loc[:,"OMPL_FL"]
#print(ompl_fl)
print(ompl_fl.value_counts() / len(ompl_fl))
#print(ompl_fl.describe())

sns.countplot(ompl_fl)
plt.title("Discharged (Pletaal) - Barplot")
plt.xlabel('Discharged (Pletaal)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.951012
# Y    0.010350
# Name: OMPL_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Anti H/T Drug)

# %%
omanh_fl = cdc.loc[:,"OMANH_FL"]
#print(omanh_fl)
print(omanh_fl.value_counts() / len(omanh_fl))
#print(omanh_fl.describe())

sns.countplot(omanh_fl)
plt.title("Discharged (Anti H/T Drug) - Barplot")
plt.xlabel('Discharged (Anti H/T Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.496000
# Y    0.478517
# Name: OMANH_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Warfarin)

# %%
omwa_fl = cdc.loc[:,"OMWA_FL"]
#print(omwa_fl)
print(omwa_fl.value_counts() / len(omwa_fl))
#print(omwa_fl.describe())

sns.countplot(omwa_fl)
plt.title("Discharged (Warfarin) - Barplot")
plt.xlabel('Discharged (Warfarin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.898480
# Y    0.064178
# Name: OMWA_FL, dtype: float64

# %%
#OMWA_TX(離院時INR)

# %% [markdown]
# # Discharged (Anti DM Drug)

# %%
omand_fl = cdc.loc[:,"OMAND_FL"]
#print(omand_fl)
print(omand_fl.value_counts() / len(omand_fl))
#print(omand_fl.describe())

sns.countplot(omand_fl)
plt.title("Discharged (Anti DM Drug) - Barplot")
plt.xlabel('Discharged (Anti DM Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.696207
# Y    0.272451
# Name: OMAND_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Anti DM Drug - Insulin)

# %%
omins_fl = cdc.loc[:,"OMINS_FL"]
#print(omins_fl)
print(omins_fl.value_counts() / len(omins_fl))
#print(omins_fl.describe())

sns.countplot(omins_fl)
plt.title("Discharged (Anti DM Drug - Insulin) - Barplot")
plt.xlabel('Discharged (Anti DM Drug - Insulin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.509766
# Y    0.026836
# Name: OMINS_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Lipid Lower Drug)

# %%
omli_fl = cdc.loc[:,"OMLI_FL"]
#print(omli_fl)
print(omli_fl.value_counts() / len(omli_fl))
#print(omli_fl.describe())

sns.countplot(omli_fl)
plt.title("Discharged (Lipid Lower Drug) - Barplot")
plt.xlabel('Discharged (Lipid Lower Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.655420
# Y    0.312854
# Name: OMLI_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Lipid Lower Drug - Statin)

# %%
omst_fl = cdc.loc[:,"OMST_FL"]
#print(omst_fl)
print(omst_fl.value_counts() / len(omst_fl))
#print(omst_fl.describe())

sns.countplot(omst_fl)
plt.title("Discharged (Lipid Lower Drug - Statin) - Barplot")
plt.xlabel('Discharged (Lipid Lower Drug - Statin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.339028
# Y    0.202941
# Name: OMST_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Lipid Lower Drug - Non-Statin)

# %%
omns_fl = cdc.loc[:,"OMNS_FL"]
#print(omns_fl)
print(omns_fl.value_counts() / len(omns_fl))
#print(omns_fl.describe())

sns.countplot(omns_fl)
plt.title("Discharged (Lipid Lower Drug - Non-Statin) - Barplot")
plt.xlabel('Discharged (Lipid Lower Drug - Non-Statin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.524871
# Y    0.011033
# Name: OMNS_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (Others)

# %%
omliot_fl = cdc.loc[:,"OMLIOT_FL"]
#print(omliot_fl)
print(omliot_fl.value_counts() / len(omliot_fl))
#print(omliot_fl.describe())

sns.countplot(omliot_fl)
plt.title("Discharged (Others) - Barplot")
plt.xlabel('Discharged (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.847193
# Y    0.115864
# Name: OMLIOT_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#OMLIOT_TX

# %% [markdown]
# # Discharged (Others2)

# %%
omliot2_fl = cdc.loc[:,"OMLIOT2_FL"]
#print(omliot2_fl)
print(omliot2_fl.value_counts() / len(omliot2_fl))
#print(omliot2_fl.describe())

sns.countplot(omliot2_fl)
plt.title("Discharged (Others2) - Barplot")
plt.xlabel('Discharged (Others2)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.945809
# Y    0.016144
# Name: OMLIOT2_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#OMLIOT2_TX

# %% [markdown]
# # Discharged (有相關原因未使用抗血栓藥物)

# %%
omad_fl = cdc.loc[:,"OMAD_FL"]
#print(omad_fl)
print(omad_fl.value_counts() / len(omad_fl))
#print(omad_fl.describe())

sns.countplot(omad_fl)
plt.title("Discharged (有相關原因未使用抗血栓藥物) - Barplot")
plt.xlabel('Discharged (有相關原因未使用抗血栓藥物)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.511161
# Y    0.021953
# Name: OMAD_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Discharged (有相關原因未使用抗血栓藥物 Options)

# %%
omad_id = cdc.loc[:,"OMAD_ID"]
#print(omad_id)
print(omad_id.value_counts() / len(omad_id))
#print(omad_id.describe())

omad_id[omad_id == 1] = "UGI bleeding"
omad_id[omad_id == 2] = "Hemorrhage infarct"
omad_id[omad_id == 3] = "Others bleeding"
omad_id[omad_id == 4] = "Large infarct"
omad_id[omad_id == 5] = "Patient or family refuse"
omad_id[omad_id == 6] = "Critical AAD or Expired"

sns.countplot(omad_id, hue = omad_id)
plt.title("Discharged (有相關原因未使用抗血栓藥物 Options) - Barplot")
plt.xlabel('Discharged (有相關原因未使用抗血栓藥物 Options)')
plt.ylabel('Number', rotation=0)
plt.xticks([])
plt.legend(loc = 1, title="相關原因未使用抗血栓藥物")
plt.show()
# Out:
# 6.0    0.008905
# 2.0    0.004157
# 3.0    0.003545
# 1.0    0.002869
# 4.0    0.001182
# 5.0    0.001146
# Name: OMAD_ID, dtype: float64
# <ipython-input-144-021896b6179a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   omad_id[omad_id == 1] = "UGI bleeding"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (None)

# %%
am_fl = cdc.loc[:,"AM_FL"]
#print(am_fl)
print(am_fl.value_counts() / len(am_fl))
#print(am_fl.describe())

sns.countplot(am_fl)
plt.title("Before Admitted (None) - Barplot")
plt.xlabel('Before Admitted (None)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.685644
# Y    0.282872
# Name: AM_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Aspirin)

# %%
amas_fl = cdc.loc[:,"AMAS_FL"]
#print(amas_fl)
print(amas_fl.value_counts() / len(amas_fl))
#print(amas_fl.describe())

sns.countplot(amas_fl)
plt.title("Before Admitted (Aspirin) - Barplot")
plt.xlabel('Before Admitted (Aspirin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.809921
# Y    0.155270
# Name: AMAS_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Aggrenox)

# %%
amag_fl = cdc.loc[:,"AMAG_FL"]
#print(amag_fl)
print(amag_fl.value_counts() / len(amag_fl))
#print(amag_fl.describe())

sns.countplot(amag_fl)
plt.title("Before Admitted (Aggrenox) - Barplot")
plt.xlabel('Before Admitted (Aggrenox)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.957105
# Y    0.004043
# Name: AMAG_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Ticlopidine)

# %%
amti_fl = cdc.loc[:,"AMTI_FL"]
#print(amti_fl)
print(amti_fl.value_counts() / len(amti_fl))
#print(amti_fl.describe())

sns.countplot(amti_fl)
plt.title("Before Admitted (Ticlopidine) - Barplot")
plt.xlabel('Before Admitted (Ticlopidine)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.954045
# Y    0.007132
# Name: AMTI_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Clopidogrel)

# %%
amcl_fl = cdc.loc[:,"AMCL_FL"]
#print(amcl_fl)
print(amcl_fl.value_counts() / len(amcl_fl))
#print(amcl_fl.describe())

sns.countplot(amcl_fl)
plt.title("Before Admitted (Clopidogrel) - Barplot")
plt.xlabel('Before Admitted (Clopidogrel)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.923571
# Y    0.038360
# Name: AMCL_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Pletaal)

# %%
ampl_fl = cdc.loc[:,"AMPL_FL"]
#print(ampl_fl)
print(ampl_fl.value_counts() / len(ampl_fl))
#print(ampl_fl.describe())

sns.countplot(ampl_fl)
plt.title("Before Admitted (Pletaal) - Barplot")
plt.xlabel('Before Admitted (Pletaal)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.956629
# Y    0.004684
# Name: AMPL_FL, dtype: float64

# %% [markdown]
# # Before Admitted (Anti H/T Drug)

# %%
amanh_fl = cdc.loc[:,"AMANH_FL"]
#print(amanh_fl)
print(amanh_fl.value_counts() / len(amanh_fl))
#print(amanh_fl.describe())

sns.countplot(amanh_fl)
plt.title("Before Admitted (Anti H/T Drug) - Barplot")
plt.xlabel('Before Admitted (Anti H/T Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.521611
# Y    0.452870
# Name: AMANH_FL, dtype: float64

# %% [markdown]
# # Before Admitted (Wafirin)

# %%
amwa_fl = cdc.loc[:,"AMWA_FL"]
#print(amwa_fl)
print(amwa_fl.value_counts() / len(amwa_fl))
#print(amwa_fl.describe())

sns.countplot(amwa_fl)
plt.title("Before Admitted (Wafirin) - Barplot")
plt.xlabel('Before Admitted (Wafirin)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.935082
# Y    0.026750
# Name: AMWA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Anti DM Drug)

# %%
amand_fl = cdc.loc[:,"AMAND_FL"]
#print(amand_fl)
print(amand_fl.value_counts() / len(amand_fl))
#print(amand_fl.describe())

sns.countplot(amand_fl)
plt.title("Before Admitted (Anti DM Drug) - Barplot")
plt.xlabel('Before Admitted (Anti DM Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.731315
# Y    0.236845
# Name: AMAND_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Lipid Lowering Drug)

# %%
amli_fl = cdc.loc[:,"AMLI_FL"]
#print(amli_fl)
print(amli_fl.value_counts() / len(amli_fl))
#print(amli_fl.describe())

sns.countplot(amli_fl)
plt.title("Before Admitted (Lipid Lowering Drug) - Barplot")
plt.xlabel('Before Admitted (Lipid Lowering Drug)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.875694
# Y    0.088117
# Name: AMLI_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Before Admitted (Others)

# %%
amliot_fl = cdc.loc[:,"AMLIOT_FL"]
#print(amliot_fl)
print(amliot_fl.value_counts() / len(amliot_fl))
#print(amliot_fl.describe())

sns.countplot(amliot_fl)
plt.title("Before Admitted (Others) - Barplot")
plt.xlabel('Before Admitted (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.882976
# Y    0.079682
# Name: AMLIOT_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#AMLIOT_TX

# %% [markdown]
# # Before Admitted (Others2)

# %%
amliot2_fl = cdc.loc[:,"AMLIOT2_FL"]
#print(amliot2_fl)
print(amliot2_fl.value_counts() / len(amliot2_fl))
#print(amliot2_fl.describe())

sns.countplot(amliot2_fl)
plt.title("Before Admitted (Others2) - Barplot")
plt.xlabel('Before Admitted (Others2)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.956386
# Y    0.004926
# Name: AMLIOT2_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#AMLIOT2_TX

# %% [markdown]
# # Complication (None)

# %%
com_id = cdc.loc[:,"COM_ID"]
#print(com_id)
print(com_id.value_counts(), len(com_id) - com_id.value_counts())
#82929 ppl have no complications
#print(com_id.describe())

#sns.countplot(com_id)
#plt.title("Complication (None) - Barplot")
#plt.xlabel('Complication (None)')
#plt.ylabel('Number', rotation=0)
#plt.show()
# Out:
# 0.0    57555
# Name: COM_ID, dtype: int64 0.0    82929
# Name: COM_ID, dtype: int64

# %% [markdown]
# # Complication (Pneumonia)

# %%
compn_fl = cdc.loc[:,"COMPN_FL"]
#print(compn_fl)
print(compn_fl.value_counts() / len(compn_fl))
#print(compn_fl.describe())

sns.countplot(compn_fl)
plt.title("Complication (Pneumonia) - Barplot")
plt.xlabel('Complication (Pneumonia)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.920311
# Y    0.063623
# Name: COMPN_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (Urinary Tract Infection)

# %%
comut_fl = cdc.loc[:,"COMUT_FL"]
#print(comut_fl)
print(comut_fl.value_counts() / len(comut_fl))
#print(comut_fl.describe())

sns.countplot(comut_fl)
plt.title("Complication (Urinary Tract Infection) - Barplot")
plt.xlabel('Complication (Urinary Tract Infection)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.931145
# Y    0.051906
# Name: COMUT_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (UGI Bleeding)

# %%
comug_fl = cdc.loc[:,"COMUG_FL"]
#print(comug_fl)
print(comug_fl.value_counts() / len(comug_fl))
#print(comug_fl.describe())

sns.countplot(comug_fl)
plt.title("Complication (UGI Bleeding) - Barplot")
plt.xlabel('Complication (UGI Bleeding)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.958622
# Y    0.023348
# Name: COMUG_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (Pressure Sore)

# %%
compr_fl = cdc.loc[:,"COMPR_FL"]
#print(compr_fl)
print(compr_fl.value_counts() / len(compr_fl))
#print(compr_fl.describe())

sns.countplot(compr_fl)
plt.title("Complication (Pressure Sore) - Barplot")
plt.xlabel('Complication (Pressure Sore)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.972346
# Y    0.008777
# Name: COMPR_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (Pulmonary Edema)

# %%
compu_fl = cdc.loc[:,"COMPU_FL"]
#print(compu_fl)
print(compu_fl.value_counts() / len(compu_fl))
#print(compu_fl.describe())

sns.countplot(compu_fl)
plt.title("Complication (Pulmonary Edema) - Barplot")
plt.xlabel('Complication (Pulmonary Edema)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.978432
# Y    0.002555
# Name: COMPU_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (Acute Coronary Syndrome)

# %%
comac_fl = cdc.loc[:,"COMAC_FL"]
#print(comac_fl)
print(comac_fl.value_counts() / len(comac_fl))
#print(comac_fl.describe())

sns.countplot(comac_fl)
plt.title("Complication (Acute Coronary Syndrome) - Barplot")
plt.xlabel('Complication (Acute Coronary Syndrome)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.978930
# Y    0.002057
# Name: COMAC_FL, dtype: float64

# %% [markdown]
# # Complication (Seizure)

# %%
comse_fl = cdc.loc[:,"COMSE_FL"]
#print(comse_fl)
print(comse_fl.value_counts() / len(comse_fl))
#print(comse_fl.describe())

sns.countplot(comse_fl)
plt.title("Complication (Seizure) - Barplot")
plt.xlabel('Complication (Seizure)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.973129
# Y    0.008051
# Name: COMSE_FL, dtype: float64

# %% [markdown]
# # Complication (Deep Vein Thrombosis)

# %%
comde_fl = cdc.loc[:,"COMDE_FL"]
#print(comde_fl)
print(comde_fl.value_counts() / len(comde_fl))
#print(comde_fl.describe())

sns.countplot(comde_fl)
plt.title("Complication (Deep Vein Thrombosis) - Barplot")
plt.xlabel('Complication (Deep Vein Thrombosis)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.980297
# Y    0.000619
# Name: COMDE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Complication (Others)

# %%
commo_fl = cdc.loc[:,"COMO_FL"]
#print(commo_fl)
print(commo_fl.value_counts() / len(commo_fl))
#print(commo_fl.describe())

sns.countplot(commo_fl)
plt.title("Complication (Others) - Barplot")
plt.xlabel('Complication (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.940634
# Y    0.041065
# Name: COMO_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#COMO_TX

# %% [markdown]
# # Deterioration (None)

# %%
det_id = cdc.loc[:,"DET_ID"]
#print(det_id)
print(det_id.value_counts(), len(det_id) - det_id.value_counts())
#22412 ppl have no deterioration
#print(det_id.describe())

#sns.countplot(det_id)
#plt.title("Deterioration (None) - Barplot")
#plt.xlabel('Deterioration (None)')
#plt.ylabel('Number', rotation=0)
#plt.show()
# Out:
# 0.0    118072
# Name: DET_ID, dtype: int64 0.0    22412
# Name: DET_ID, dtype: int64

# %% [markdown]
# # Deterioration (Stroke-in-evolution - NIHSS≧2)

# %%
detst_fl = cdc.loc[:,"DETST_FL"]
#print(detst_fl)
print(detst_fl.value_counts() / len(detst_fl))
#print(detst_fl.describe())

sns.countplot(detst_fl)
plt.title("Deterioration (Stroke-in-evolution - NIHSS≧2) - Barplot")
plt.xlabel('Deterioration (Stroke-in-evolution - NIHSS≧2)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.923201
# Y    0.060975
# Name: DETST_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Deterioration (Herniation)

# %%
dethe_fl = cdc.loc[:,"DETHE_FL"]
#print(dethe_fl)
print(dethe_fl.value_counts() / len(dethe_fl))
#print(dethe_fl.describe())

sns.countplot(dethe_fl)
plt.title("Deterioration (Herniation) - Barplot")
plt.xlabel('Deterioration (Herniation)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.972210
# Y    0.011083
# Name: DETHE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Deterioration (Hemorrhagic Infarct)

# %%
detho_fl = cdc.loc[:,"DETHO_FL"]
#print(detho_fl)
print(detho_fl.value_counts() / len(detho_fl))
#print(detho_fl.describe())

sns.countplot(detho_fl)
plt.title("Deterioration (Hemorrhagic Infarct) - Barplot")
plt.xlabel('Deterioration (Hemorrhagic Infarct)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.970865
# Y    0.012485
# Name: DETHO_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Deterioration (Hemorrhagic Infarct 36hrs)

# %%
dethoh_fl = cdc.loc[:,"DETHOH_FL"]
#print(dethoh_fl)
print(dethoh_fl.value_counts() / len(dethoh_fl))
#print(dethoh_fl.describe())

sns.countplot(dethoh_fl)
plt.title("Deterioration (Hemorrhagic Infarct 36hrs) - Barplot")
plt.xlabel('Deterioration (Hemorrhagic Infarct 36hrs)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.550888
# Y    0.002427
# Name: DETHOH_FL, dtype: float64

# %% [markdown]
# # Deterioration (Hematoma Enlargement - ICH)

# %%
detha_fl = cdc.loc[:,"DETHA_FL"]
#print(detha_fl)
print(detha_fl.value_counts() / len(detha_fl))
#print(detha_fl.describe())

sns.countplot(detha_fl)
plt.title("Deterioration (Hematoma Enlargement - ICH) - Barplot")
plt.xlabel('Deterioration (Hematoma Enlargement - ICH)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.976866
# Y    0.006300
# Name: DETHA_FL, dtype: float64

# %% [markdown]
# # Deterioration (Vasospasm - SAH)

# %%
detva_fl = cdc.loc[:,"DETVA_FL"]
#print(detva_fl)
print(detva_fl.value_counts() / len(detva_fl))
#print(detva_fl.describe())

sns.countplot(detva_fl)
plt.title("Deterioration (Vasospasm - SAH) - Barplot")
plt.xlabel('Deterioration (Vasospasm - SAH)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.981756
# Y    0.001352
# Name: DETVA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Deterioration (Re-bleeding - SAH)

# %%
detre_fl = cdc.loc[:,"DETRE_FL"]
#print(detre_fl)
print(detre_fl.value_counts() / len(detre_fl))
#print(detre_fl.describe())

sns.countplot(detre_fl)
plt.title("Deterioration (Re-bleeding - SAH) - Barplot")
plt.xlabel('Deterioration (Re-bleeding - SAH)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.982162
# Y    0.000911
# Name: DETRE_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Deterioration (Medical Problems)

# %%
detme_fl = cdc.loc[:,"DETME_FL"]
#print(detme_fl)
print(detme_fl.value_counts() / len(detme_fl))
#print(detme_fl.describe())

sns.countplot(detme_fl)
plt.title("Deterioration (Medical Problems) - Barplot")
plt.xlabel('Deterioration (Medical Problems)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.965576
# Y    0.017781
# Name: DETME_FL, dtype: float64

# %% [markdown]
# # Deterioration (Others)

# %%
deto_fl = cdc.loc[:,"DETO_FL"]
#print(deto_fl)
print(deto_fl.value_counts() / len(deto_fl))
#print(deto_fl.describe())

sns.countplot(deto_fl)
plt.title("Deterioration (Others) - Barplot")
plt.xlabel('Deterioration (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.974161
# Y    0.009190
# Name: DETO_FL, dtype: float64

# %%
#DETO_TX

# %% [markdown]
# # CT日期

# %%
ct_time = cdc.loc[:,["CT_DT", "CTH_NM", "CTM_NM"]]
ct_time.CT_DT = pd.to_datetime(ct_time.CT_DT, errors = "coerce", format = "%Y-%m-%d")
ct_time[(ct_time.CT_DT.dt.year < 2005) | (ct_time.CT_DT.dt.year > 2018)] = np.nan
print(ct_time.CT_DT.describe())

ct_time['CTH_NM'] = ct_time['CTH_NM'].fillna(0)
ct_time['CTM_NM'] = ct_time['CTM_NM'].fillna(0)

ct = ct_time['CT_DT'].astype(str)+' '+ct_time['CTH_NM'].astype(int).map(str)+':'+ct_time['CTM_NM'].astype(int).map(str)

ct_dt = pd.to_datetime(ct, format='%Y/%m/%d %H:%M', errors='coerce')
print(ct_dt.value_counts() / len(ct_dt))

ct_dt.value_counts().plot()
plt.title("CT Date - Lineplot")
plt.xlabel('CT Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-181-7f4a19f440d1>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(ct_time.CT_DT.describe())
# count                  118679
# unique                   4563
# top       2008-02-11 00:00:00
# freq                       87
# first     2005-02-05 00:00:00
# last      2018-10-11 00:00:00
# Name: CT_DT, dtype: object
# 2006-12-24 00:00:00    0.000085
# 2007-04-23 00:00:00    0.000085
# 2007-02-27 00:00:00    0.000078
# 2007-02-06 00:00:00    0.000078
# 2007-02-08 00:00:00    0.000071
#                          ...
# 2009-02-23 06:38:00    0.000007
# 2014-01-22 17:17:00    0.000007
# 2007-02-20 01:08:00    0.000007
# 2013-02-25 10:36:00    0.000007
# 2008-12-06 12:52:00    0.000007
# Length: 113676, dtype: float64

# %% [raw]
# ct_dt = cdc.loc[:,"CT_DT"]
# #print(ct_dt)
# print(ct_dt.value_counts() / len(ct_dt))
# #print(ct_dt.describe())

# %% [markdown]
# # CT時間 - 時

# %%
cth_nm = cdc.loc[:,"CTH_NM"]
cth_nm[(cth_nm < 0) | (cth_nm > 24)] = np.nan
cth_nm[cth_nm == 24] = 0
#print(cth_nm)
#print(cth_nm.value_counts() / len(cth_nm))
print(cth_nm.describe())
# Out:
# count    113146.000000
# mean         13.589442
# std           5.481469
# min           0.000000
# 25%          10.000000
# 50%          14.000000
# 75%          18.000000
# max          23.000000
# Name: CTH_NM, dtype: float64
# <ipython-input-182-2fad8d0c0dbb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cth_nm[(cth_nm < 0) | (cth_nm > 24)] = np.nan
# <ipython-input-182-2fad8d0c0dbb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cth_nm[cth_nm == 24] = 0

# %% [markdown]
# # CT時間 - 分

# %%
ctm_nm = cdc.loc[:,"CTM_NM"]
ctm_nm[(cth_nm < 0) | (ctm_nm > 60)] = np.nan
ctm_nm[ctm_nm == 60] = 0
#print(ctm_nm)
#print(ctm_nm.value_counts() / len(ctm_nm))
print(ctm_nm.describe())
# Out:
# count    113246.000000
# mean         29.276946
# std          17.411803
# min           0.000000
# 25%          14.000000
# 50%          29.000000
# 75%          44.000000
# max          59.000000
# Name: CTM_NM, dtype: float64
# <ipython-input-183-7ab88a7a3f07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctm_nm[(cth_nm < 0) | (ctm_nm > 60)] = np.nan
# <ipython-input-183-7ab88a7a3f07>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctm_nm[ctm_nm == 60] = 0

# %% [markdown]
# # CT no Findings

# %%
ct_fl = cdc.loc[:,"CT_FL"]
#print(ct_fl)
print(ct_fl.value_counts() / len(ct_fl))
#print(ct_fl.describe())

sns.countplot(ct_fl)
plt.title("CT no Findings - Barplot")
plt.xlabel('CT no Findings')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.740675
# Y    0.223648
# Name: CT_FL, dtype: float64

# %%
# CTO_TX

# %% [markdown]
# # MRI日期

# %%
mri_time = cdc.loc[:,["MRI_DT", "MRIH_NM", "MRIM_NM"]]
mri_time.MRI_DT = pd.to_datetime(mri_time.MRI_DT, errors = "coerce", format = "%Y-%m-%d")
mri_time[(mri_time.MRI_DT.dt.year < 2005) | (mri_time.MRI_DT.dt.year > 2018)] = np.nan
print(mri_time.MRI_DT.describe())

mri_time['MRIH_NM'] = mri_time['MRIH_NM'].fillna(0)
mri_time['MRIM_NM'] = mri_time['MRIM_NM'].fillna(0)

mri = mri_time['MRI_DT'].astype(str)+' '+mri_time['MRIH_NM'].astype(int).map(str)+':'+mri_time['MRIM_NM'].astype(int).map(str)

mri_dt = pd.to_datetime(mri, format='%Y/%m/%d %H:%M', errors='coerce')
print(mri_dt.value_counts() / len(mri_dt))

mri_dt.value_counts().plot()
plt.title("MRI Date - Lineplot")
plt.xlabel('MRI Date')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-186-6f39a22d2466>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(mri_time.MRI_DT.describe())
# count                   80388
# unique                   4454
# top       2008-02-05 00:00:00
# freq                       62
# first     2005-03-04 00:00:00
# last      2018-12-29 00:00:00
# Name: MRI_DT, dtype: object
# 2007-04-09 00:00:00    0.000071
# 2007-04-23 00:00:00    0.000071
# 2007-03-28 00:00:00    0.000064
# 2008-01-30 00:00:00    0.000057
# 2007-03-01 00:00:00    0.000050
#                          ...
# 2014-09-22 15:05:00    0.000007
# 2016-03-29 17:29:00    0.000007
# 2016-07-15 20:20:00    0.000007
# 2017-05-09 10:16:00    0.000007
# 2013-04-15 13:42:00    0.000007
# Length: 77643, dtype: float64

# %% [raw]
# mri_dt = cdc.loc[:,"MRI_DT"]
# #print(mri_dt)
# print(mri_dt.value_counts() / len(mri_dt))
# #print(mri_dt.describe())

# %% [markdown]
# # MRI時間 - 時

# %%
mrih_nm = cdc.loc[:,"MRIH_NM"]
mrih_nm[(mrih_nm < 0) | (mrih_nm > 24)] = np.nan
mrih_nm[mrih_nm == 24] = 0
#print(mrih_nm)
#print(mrih_nm.value_counts() / len(mrih_nm))
print(mrih_nm.describe())
# Out:
# count    79528.000000
# mean        13.213334
# std          3.656798
# min          0.000000
# 25%         10.000000
# 50%         13.000000
# 75%         16.000000
# max         23.000000
# Name: MRIH_NM, dtype: float64
# <ipython-input-187-7db603007c2d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrih_nm[(mrih_nm < 0) | (mrih_nm > 24)] = np.nan
# <ipython-input-187-7db603007c2d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrih_nm[mrih_nm == 24] = 0

# %% [markdown]
# # MRI時間 - 分

# %%
mrim_nm = cdc.loc[:,"MRIM_NM"]
mrim_nm[(mrim_nm < 0) | (mrim_nm > 60)] = np.nan
mrim_nm[mrim_nm == 60] = 0
#print(mrim_nm)
#print(mrim_nm.value_counts() / len(mrim_nm))
print(mrim_nm.describe())
# Out:
# count    79626.000000
# mean        29.110529
# std         17.508709
# min          0.000000
# 25%         14.000000
# 50%         30.000000
# 75%         44.000000
# max         59.000000
# Name: MRIM_NM, dtype: float64
# <ipython-input-188-3403c57d1125>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrim_nm[(mrim_nm < 0) | (mrim_nm > 60)] = np.nan
# <ipython-input-188-3403c57d1125>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrim_nm[mrim_nm == 60] = 0

# %% [markdown]
# # MRI no Findings

# %%
mri_fl = cdc.loc[:,"MRI_FL"]
#print(mri_fl)
print(mri_fl.value_counts() / len(mri_fl))
#print(mri_fl.describe())

sns.countplot(mri_fl)
plt.title("CT no Findings - Barplot")
plt.xlabel('CT no Findings')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.936263
# Y    0.022230
# Name: MRI_FL, dtype: float64

# %%
#MRIO_TX

# %% [markdown]
# # Ultrasound/MRA Studies

# %% [markdown]
# # Carotid Duplex

# %%
cd_id = cdc.loc[:,"CD_ID"]
#print(cd_id)
print(cd_id.value_counts() / len(cd_id))
#print(cd_id.describe())

cd_id_labels = ["Undone","Present","Absent"]
sns.countplot(cd_id).set_xticklabels(cd_id_labels)
plt.title("Carotid Duplex - Barplot")
plt.xlabel('Carotid Duplex')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.341847
# 0.0    0.254755
# 2.0    0.028708
# Name: CD_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Carotid Atherosclerosis (R ICA)

# %%
cdr_id = cdc.loc[:,"CDR_ID"]
#print(cdr_id)
print(cdr_id.value_counts() / len(cdr_id))
#print(cdr_id.describe())

cdr_id_labels = ["0-49%","50-69%","70-99%","100%"]
sns.countplot(cdr_id).set_xticklabels(cdr_id_labels)
plt.title("Carotid Atherosclerosis (R ICA) - Barplot")
plt.xlabel('Carotid Atherosclerosis (R ICA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.555387
# 2.0    0.024352
# 3.0    0.012379
# 4.0    0.007154
# Name: CDR_ID, dtype: float64

# %% [markdown]
# # Carotid Atherosclerosis (L ICA)

# %%
cdl_id = cdc.loc[:,"CDL_ID"]
#print(cdl_id)
print(cdl_id.value_counts() / len(cdl_id))
#print(cdl_id.describe())

cdl_id_labels = ["0-49%","50-69%","70-99%","100%"]
sns.countplot(cdl_id).set_xticklabels(cdl_id_labels)
plt.title("Carotid Atherosclerosis (L ICA) - Barplot")
plt.xlabel('Carotid Atherosclerosis (L ICA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.562890
# 2.0    0.023647
# 3.0    0.011133
# 4.0    0.006107
# Name: CDL_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # TCCS

# %%
tccs_id = cdc.loc[:,"TCCS_ID"]
#print(tccs_id)
print(tccs_id.value_counts() / len(tccs_id))
#print(tccs_id.describe())

tccs_id_labels = ["Undone","Poor window"]
sns.countplot(tccs_id).set_xticklabels(tccs_id_labels)
plt.title("TCCS - Barplot")
plt.xlabel('TCCS')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.369537
# 1.0    0.233066
# Name: TCCS_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # TCCS (R MCA)

# %%
tccsr_id = cdc.loc[:,"TCCSR_ID"]
#print(tccsr_id)
print(tccsr_id.value_counts() / len(tccsr_id))
#print(tccsr_id.describe())

tccsr_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsr_id).set_xticklabels(tccsr_id_labels)
plt.title("TCCS (R MCA) - Barplot")
plt.xlabel('TCCS (R MCA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.248512
# 2.0    0.048340
# 3.0    0.001623
# Name: TCCSR_ID, dtype: float64

# %% [markdown]
# # TCCS (L MCA)

# %%
tccsl_id = cdc.loc[:,"TCCSL_ID"]
#print(tccsl_id)
print(tccsl_id.value_counts() / len(tccsl_id))
#print(tccsl_id.describe())

tccsl_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsl_id).set_xticklabels(tccsl_id_labels)
plt.title("TCCS (L MCA) - Barplot")
plt.xlabel('TCCS (L MCA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.248576
# 2.0    0.047771
# 3.0    0.001502
# Name: TCCSL_ID, dtype: float64

# %% [markdown]
# # TCCS (BA)

# %%
tccsba_id = cdc.loc[:,"TCCSBA_ID"]
#print(tccsba_id)
print(tccsba_id.value_counts() / len(tccsba_id))
#print(tccsba_id.describe())

tccsba_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(tccsba_id).set_xticklabels(tccsba_id_labels)
plt.title("TCCS (BA) - Barplot")
plt.xlabel('TCCS (BA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.400330
# 2.0    0.034623
# 3.0    0.001004
# Name: TCCSBA_ID, dtype: float64

# %% [markdown]
# # MRA

# %%
mra_fl = cdc.loc[:,"MRA_FL"]
#print(mra_fl)
print(mra_fl.value_counts() / len(mra_fl))
#print(mra_fl.describe())

sns.countplot(mra_fl)
plt.title("MRA - Barplot")
plt.xlabel('MRA')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.468473
# Y    0.463505
# Name: MRA_FL, dtype: float64

# %% [markdown]
# # CTA

# %%
cta_fl = cdc.loc[:,"CTA_FL"]
#print(cta_fl)
print(cta_fl.value_counts() / len(cta_fl))
#print(cta_fl.describe())

sns.countplot(cta_fl)
plt.title("CTA - Barplot")
plt.xlabel('CTA')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.853179
# Y    0.069524
# Name: CTA_FL, dtype: float64

# %% [markdown]
# # DSA

# %%
dsa_fl = cdc.loc[:,"DSA_FL"]
#print(dsa_fl)
print(dsa_fl.value_counts() / len(dsa_fl))
#print(dsa_fl.describe())

sns.countplot(dsa_fl)
plt.title("DSA - Barplot")
plt.xlabel('DSA')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# N    0.911413
# Y    0.009638
# Name: DSA_FL, dtype: float64

# %% [markdown]
# # Undone MRI, CTA and DSA

# %%
mcd_id = cdc.loc[:,"MCD_ID"]
#print(mcd_id)
print(mcd_id.value_counts(), len(mcd_id) - mcd_id.value_counts())
#95664 ppl had not done those tests
#print(mcd_id.describe())

#sns.countplot(mcd_id)
#plt.title("Undone MRI, CTA and DSA - Barplot")
#plt.xlabel('Undone MRI, CTA and DSA')
#plt.ylabel('Number', rotation=0)
#plt.show()
# Out:
# 0.0    44820
# Name: MCD_ID, dtype: int64 0.0    95664
# Name: MCD_ID, dtype: int64

# %% [markdown]
# # MRI, CTA and DSA (R MCA)

# %%
mcdr_id = cdc.loc[:,"MCDR_ID"]
#print(mcdr_id)
print(mcdr_id.value_counts() / len(mcdr_id))
#print(mcdr_id.describe())

mcdr_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdr_id).set_xticklabels(mcdr_id_labels)
plt.title("MRI, CTA and DSA (R MCA) - Barplot")
plt.xlabel('MRI, CTA and DSA (R MCA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.303543
# 2.0    0.058142
# 3.0    0.012208
# Name: MCDR_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # MRI, CTA and DSA (L MCA)

# %%
mcdl_id = cdc.loc[:,"MCDL_ID"]
#print(mcdl_id)
print(mcdl_id.value_counts() / len(mcdl_id))
#print(mcdl_id.describe())

mcdl_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdl_id).set_xticklabels(mcdl_id_labels)
plt.title("MRI, CTA and DSA (L MCA) - Barplot")
plt.xlabel('MRI, CTA and DSA (L MCA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.306063
# 2.0    0.056042
# 3.0    0.010670
# Name: MCDL_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # MRI, CTA and DSA (VA or BA)

# %%
mcdba_id = cdc.loc[:,"MCDBA_ID"]
#print(mcdba_id)
print(mcdba_id.value_counts() / len(mcdba_id))
#print(mcdba_id.describe())

mcdba_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdba_id).set_xticklabels(mcdba_id_labels)
plt.title("MRI, CTA and DSA (VA or BA) - Barplot")
plt.xlabel('MRI, CTA and DSA (VA or BA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.309864
# 2.0    0.054483
# 3.0    0.006734
# Name: MCDBA_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # MRI, CTA and DSA (R ICA)

# %%
mcdri_id = cdc.loc[:,"MCDRI_ID"]
#print(mcdri_id)
print(mcdri_id.value_counts() / len(mcdri_id))
#print(mcdri_id.describe())

mcdri_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdri_id).set_xticklabels(mcdri_id_labels)
plt.title("MRI, CTA and DSA (R ICA) - Barplot")
plt.xlabel('MRI, CTA and DSA (R ICA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.199062
# 2.0    0.015354
# 3.0    0.004798
# Name: MCDRI_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # MRI, CTA and DSA (L ICA)

# %%
mcdli_id = cdc.loc[:,"MCDLI_ID"]
#print(mcdli_id)
print(mcdli_id.value_counts() / len(mcdli_id))
#print(mcdli_id.describe())

mcdli_id_labels = ["0-49%","50-99%","100%"]
sns.countplot(mcdli_id).set_xticklabels(mcdli_id_labels)
plt.title("MRI, CTA and DSA (L ICA) - Barplot")
plt.xlabel('MRI, CTA and DSA (L ICA)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.200108
# 2.0    0.013838
# 3.0    0.004264
# Name: MCDLI_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # NIHSS 最初進院日期

# %%
nihsin_time = cdc.loc[:,["NIHSIN_DT", "NIHSINH_NM", "NIHSINM_NM"]]
nihsin_time.NIHSIN_DT = pd.to_datetime(nihsin_time.NIHSIN_DT, errors = "coerce", format = "%Y-%m-%d")
nihsin_time[(nihsin_time.NIHSIN_DT.dt.year < 2005) | (nihsin_time.NIHSIN_DT.dt.year > 2018)] = np.nan
print(nihsin_time.NIHSIN_DT.describe())

nihsin_time['NIHSINH_NM'] = nihsin_time['NIHSINH_NM'].fillna(0)
nihsin_time['NIHSINM_NM'] = nihsin_time['NIHSINM_NM'].fillna(0)

nihsin = nihsin_time['NIHSIN_DT'].astype(str)+' '+nihsin_time['NIHSINH_NM'].astype(int).map(str)+':'+nihsin_time['NIHSINM_NM'].astype(int).map(str)

nihsin_dt = pd.to_datetime(nihsin, format='%Y/%m/%d %H:%M', errors='coerce')
print(nihsin_dt.value_counts() / len(nihsin_dt))

nihsin_dt.value_counts().plot()
plt.title("NIHSS 最初進院日期 - Lineplot")
plt.xlabel('NIHSS 最初進院日期')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# <ipython-input-207-199f784837e4>:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(nihsin_time.NIHSIN_DT.describe())
# count                  125887
# unique                   4566
# top       2008-02-11 00:00:00
# freq                       81
# first     2005-01-01 00:00:00
# last      2018-12-31 00:00:00
# Name: NIHSIN_DT, dtype: object
# 2008-02-23 00:00:00    0.000093
# 2008-04-30 00:00:00    0.000093
# 2008-05-26 00:00:00    0.000085
# 2010-08-09 00:00:00    0.000085
# 2008-10-03 00:00:00    0.000085
#                          ...
# 2009-09-09 10:00:00    0.000007
# 2013-12-10 00:00:00    0.000007
# 2009-01-10 22:22:00    0.000007
# 2011-12-13 11:00:00    0.000007
# 2015-06-21 13:14:00    0.000007
# Length: 112473, dtype: float64

# %% [raw]
# nihsin_dt = cdc.loc[:,"NIHSIN_DT"]
# nihsin_dt = pd.to_datetime(nihsin_dt, errors='coerce')
# #print(nihsin_dt)
# print(nihsin_dt.value_counts() / len(nihsin_dt))
# #print(nihsin_dt.describe())
#
# nihsin_dt.value_counts().plot()
# plt.title("NIHSS 最初進院日期 - Lineplot")
# plt.xlabel('NIHSS 最初進院日期')
# plt.ylabel('Number', rotation=0)
# plt.xticks()
# plt.show()

# %% [markdown]
# # NIHSS 最初進院時間 - 時

# %%
nihsinh_nm = cdc.loc[:,"NIHSINH_NM"]
nihsinh_nm[(nihsinh_nm < 0) | (nihsinh_nm > 24)] = np.nan
nihsinh_nm[nihsinh_nm == 24] = 0
#print(nihsinh_nm)
#print(nihsinh_nm.value_counts() / len(nihsinh_nm))
print(nihsinh_nm.describe())
# Out:
# count    132955.000000
# mean         12.372818
# std           6.516582
# min           0.000000
# 25%           9.000000
# 50%          13.000000
# 75%          17.000000
# max          23.000000
# Name: NIHSINH_NM, dtype: float64
# <ipython-input-208-c15c72eba883>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsinh_nm[(nihsinh_nm < 0) | (nihsinh_nm > 24)] = np.nan
# <ipython-input-208-c15c72eba883>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsinh_nm[nihsinh_nm == 24] = 0

# %% [markdown]
# # NIHSS 最初進院時間 - 分

# %%
nihsinm_nm = cdc.loc[:,"NIHSINM_NM"]
nihsinm_nm[(nihsinm_nm < 0) | (nihsinm_nm > 60)] = np.nan
nihsinm_nm[nihsinm_nm == 60] = 0
#print(nihsinm_nm)
#print(nihsinm_nm.value_counts() / len(nihsinm_nm))
print(nihsinm_nm.describe())
# Out:
# count    133068.000000
# mean         21.222052
# std          18.910731
# min           0.000000
# 25%           0.000000
# 50%          20.000000
# 75%          37.000000
# max          59.000000
# Name: NIHSINM_NM, dtype: float64
# <ipython-input-209-7e2df93aa11b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsinm_nm[(nihsinm_nm < 0) | (nihsinm_nm > 60)] = np.nan
# <ipython-input-209-7e2df93aa11b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsinm_nm[nihsinm_nm == 60] = 0

# %% [markdown]
# # NIHSS 離院日期

# %%
nihsot_dt = cdc.loc[:,"NIHSOT_DT"]
nihsot_dt = pd.to_datetime(nihsot_dt, errors='coerce')
nihsot_dt[(nihsot_dt.dt.year < 2005) | (nihsot_dt.dt.year > 2018) | (nihsot_dt < nihsin_time.NIHSIN_DT)] = np.nan
#print(nihsot_dt)
#print(nihsot_dt.value_counts() / len(nihsot_dt))
print(nihsot_dt.describe())

nihss_hospitalised_time = nihsot_dt - nihsin_dt
nihss_hospitalised_time = nihss_hospitalised_time.dt.days
#print(nihss_hospitalised_time.value_counts().sort_values(ascending= True))
print(nihss_hospitalised_time.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

nihss_hospitalised_time.plot.box(ax = ax1)
ax1.set_title("NIHSS 住院天數 - Boxplot")
ax1.set_xlabel('NIHSS 住院天數')
ax1.set_ylabel('Days', rotation=0)
ax1.set_xticks([])

#nihss_hospitalised_time.plot.hist(ax = ax2, bins=100)
#plt.show()
nihss_hospitalised_time.plot.hist(ax = ax2, bins=100, range=[0,80])
ax2.set_title("NIHSS 住院天數 - Histogram")
ax2.set_xlabel('NIHSS 住院天數')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-210-320ecb2b6f63>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(nihsot_dt.describe())
# count                  125006
# unique                   4522
# top       2007-02-16 00:00:00
# freq                      150
# first     2006-01-05 00:00:00
# last      2018-10-28 00:00:00
# Name: NIHSOT_DT, dtype: object
# count    116917.000000
# mean         13.667414
# std          30.734117
# min          -1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          15.000000
# max        3679.000000
# dtype: float64

# %% [markdown]
# # NIHSS 離院時間 - 時

# %%
nihsoth_nm = cdc.loc[:,"NIHSOTH_NM"]
nihsoth_nm[(nihsoth_nm < 0) | (nihsoth_nm > 24)] = np.nan
nihsoth_nm[nihsoth_nm == 24] = 0
#print(nihsoth_nm)
#print(nihsoth_nm.value_counts() / len(nihsoth_nm))
print(nihsoth_nm.describe())
# Out:
# count    126900.000000
# mean          9.388479
# std           3.753961
# min           0.000000
# 25%           9.000000
# 50%          10.000000
# 75%          11.000000
# max          23.000000
# Name: NIHSOTH_NM, dtype: float64
# <ipython-input-211-22f94d9860e8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsoth_nm[(nihsoth_nm < 0) | (nihsoth_nm > 24)] = np.nan
# <ipython-input-211-22f94d9860e8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsoth_nm[nihsoth_nm == 24] = 0

# %% [markdown]
# # NIHSS 離院時間 - 分

# %%
nihsotm_nm = cdc.loc[:,"NIHSOTM_NM"]
nihsotm_nm[(nihsotm_nm < 0) | (nihsotm_nm > 60)] = np.nan
nihsotm_nm[nihsotm_nm == 60] = 0
#print(nihsotm_nm)
#print(nihsotm_nm.value_counts() / len(nihsotm_nm))
print(nihsotm_nm.describe())
# Out:
# count    127133.000000
# mean          8.179764
# std          15.147958
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          10.000000
# max          59.000000
# Name: NIHSOTM_NM, dtype: float64
# <ipython-input-212-ee4fae75729e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsotm_nm[(nihsotm_nm < 0) | (nihsotm_nm > 60)] = np.nan
# <ipython-input-212-ee4fae75729e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nihsotm_nm[nihsotm_nm == 60] = 0

# %% [markdown]
# # ECG

# %%
ecg_id = cdc.loc[:,"ECG_ID"]
#print(ecg_id)
print(ecg_id.value_counts() / len(ecg_id))
#print(ecg_id.describe())

ecg_id_labels = ["Undone","Normal"]
sns.countplot(ecg_id).set_xticklabels(ecg_id_labels)
plt.title("ECG - Barplot")
plt.xlabel('ECG')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    0.495145
# 0.0    0.025056
# Name: ECG_ID, dtype: float64

# %% [markdown]
# # ECG (LVH)

# %%
ecgl_fl = cdc.loc[:,"ECGL_FL"]
ecgl_fl[ecgl_fl == 1] = "Y"
ecgl_fl[ecgl_fl == 0] = "N"
#print(ecgl_fl)
print(ecgl_fl.value_counts() / len(ecgl_fl))
#print(ecgl_fl.describe())

sns.countplot(ecgl_fl)
plt.title("ECG (LVH) - Barplot")
plt.xlabel('ECG (LVH)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-214-2a5c55a9b9b5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecgl_fl[ecgl_fl == 1] = "Y"
# <ipython-input-214-2a5c55a9b9b5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecgl_fl[ecgl_fl == 0] = "N"
# N    0.853293
# Y    0.110326
# Name: ECGL_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # ECG (AF)

# %%
ecga_fl = cdc.loc[:,"ECGA_FL"]
#print(ecga_fl)
print(ecga_fl.value_counts() / len(ecga_fl))
#print(ecga_fl.describe())

sns.countplot(ecga_fl)
plt.title("ECG (AF) - Barplot")
plt.xlabel('ECG (AF)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.850652
# Y    0.119273
# Name: ECGA_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # ECG (Q wave)

# %%
ecgq_fl = cdc.loc[:,"ECGQ_FL"]
#print(ecgq_fl)
print(ecgq_fl.value_counts() / len(ecgq_fl))
#print(ecgq_fl.describe())

sns.countplot(ecgq_fl)
plt.title("ECG (Q wave) - Barplot")
plt.xlabel('ECG (Q wave)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.956614
# Y    0.010037
# Name: ECGQ_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # ECG (Others)

# %%
ecgo_fl = cdc.loc[:,"ECGO_FL"]
#print(ecgo_fl)
print(ecgo_fl.value_counts() / len(ecgo_fl))
#print(ecgo_fl.describe())

sns.countplot(ecgo_fl)
plt.title("ECG (Others) - Barplot")
plt.xlabel('ECG (Others)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.762628
# Y    0.210907
# Name: ECGO_FL, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#ECGO_TX

# %% [markdown]
# # 抽血結果 - 急診抽血或第一次抽血

# %% [markdown]
# # HB

# %%
hb_nm = cdc.loc[:,"HB_NM"]
#print(hb_nm)
#print(hb_nm.value_counts() / len(hb_nm))
print(hb_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hb_nm.plot.box(ax = ax1)
ax1.set_title("HB - Boxplot")
ax1.set_xlabel('HB')
ax1.set_ylabel('g/dL', rotation=0)
ax1.set_xticks([])

#hb_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
hb_nm.plot.hist(ax = ax2, bins=100, range=[5,20])
ax2.set_title("HB - Histogram")
ax2.set_xlabel('HB(g/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    133023.000000
# mean         28.155709
# std         119.050244
# min           0.600000
# 25%          12.300000
# 50%          13.800000
# 75%          15.100000
# max         999.900000
# Name: HB_NM, dtype: float64

# %% [markdown]
# # HCT

# %%
hct_nm = cdc.loc[:,"HCT_NM"]
#print(hct_nm)
#print(hct_nm.value_counts() / len(hct_nm))
print(hct_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hct_nm.plot.box(ax = ax1)
ax1.set_title("HCT - Boxplot")
ax1.set_xlabel('HCT')
ax1.set_ylabel('%', rotation=0)
ax1.set_xticks([])

#hct_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
hct_nm.plot.hist(ax = ax2, bins=100, range=[15,60])
ax2.set_title("HCT - Histogram")
ax2.set_xlabel('HCT(%)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    130168.000000
# mean        110.522017
# std         250.386292
# min           0.000000
# 25%          37.100000
# 50%          41.100000
# 75%          44.900000
# max         999.900000
# Name: HCT_NM, dtype: float64

# %% [markdown]
# # PLATELET

# %%
platelet_nm = cdc.loc[:,"PLATELET_NM"]
#print(platelet_nm)
#print(platelet_nm.value_counts() / len(platelet_nm))
print(platelet_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

platelet_nm.plot.box(ax = ax1)
ax1.set_title("PLATELET - Boxplot")
ax1.set_xlabel('PLATELET')
ax1.set_ylabel('1000 cells/μL', rotation=0)
ax1.set_xticks([])

#platelet_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
platelet_nm.plot.hist(ax = ax2, bins=100, range=[0,500])
ax2.set_title("PLATELET - Histogram")
ax2.set_xlabel('PLATELET(1000 cells/μL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    132784.000000
# mean        227.023970
# std         136.060191
# min           0.800000
# 25%         167.000000
# 50%         208.000000
# 75%         255.000000
# max         999.900000
# Name: PLATELET_NM, dtype: float64

# %% [markdown]
# # WBC

# %%
wbc_nm = cdc.loc[:,"WBC_NM"]
#print(wbc_nm)
#print(wbc_nm.value_counts() / len(wbc_nm))
print(wbc_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

wbc_nm.plot.box(ax = ax1)
ax1.set_title("WBC - Boxplot")
ax1.set_xlabel('WBC')
ax1.set_ylabel('1000 cells/μL', rotation=0)
ax1.set_xticks([])

#wbc_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
wbc_nm.plot.hist(ax = ax2, bins=100, range=[0,30])
ax2.set_title("WBC - Histogram")
ax2.set_xlabel('WBC(1000 cells/μL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    132830.000000
# mean         24.947664
# std         125.977946
# min           0.000000
# 25%           6.370000
# 50%           7.930000
# 75%          10.100000
# max         999.900000
# Name: WBC_NM, dtype: float64

# %% [markdown]
# # PTT1 ???

# %%
ptt1_nm = cdc.loc[:,"PTT1_NM"]
#print(ptt1_nm)
#print(ptt1_nm.value_counts() / len(ptt1_nm))
print(ptt1_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ptt1_nm.plot.box(ax = ax1)
ax1.set_title("PTT1 - Boxplot")
ax1.set_xlabel('PTT1')
ax1.set_ylabel('Second', rotation=0)
ax1.set_xticks([])

#ptt1_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ptt1_nm.plot.hist(ax = ax2, bins=100, range=[0,50])
ax2.set_title("PTT1 - Histogram")
ax2.set_xlabel('PTT1(Second)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    130272.000000
# mean        261.435582
# std         414.743184
# min           0.000000
# 25%          27.300000
# 50%          29.600000
# 75%          40.800000
# max         999.900000
# Name: PTT1_NM, dtype: float64

# %% [markdown]
# # PTT2 ???

# %%
ptt2_nm = cdc.loc[:,"PTT2_NM"]
#print(ptt2_nm)
#print(ptt2_nm.value_counts() / len(ptt2_nm))
print(ptt2_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ptt2_nm.plot.box(ax = ax1)
ax1.set_title("PTT2 - Boxplot")
ax1.set_xlabel('PTT2')
ax1.set_ylabel('Second', rotation=0)
ax1.set_xticks([])

#ptt2_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ptt2_nm.plot.hist(ax = ax2, bins=100, range=[0,50])
ax2.set_title("PTT2 - Histogram")
ax2.set_xlabel('PTT2(Second)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    129638.000000
# mean        276.278758
# std         423.849089
# min           0.000000
# 25%          27.300000
# 50%          29.700000
# 75%         999.900000
# max         999.900000
# Name: PTT2_NM, dtype: float64

# %% [markdown]
# # PT (INR)

# %%
ptinr_nm = cdc.loc[:,"PTINR_NM"]
#print(ptinr_nm)
#print(ptinr_nmptinr_nm.value_counts() / len(ptinr_nm))
print(ptinr_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ptinr_nm.plot.box(ax = ax1)
ax1.set_title("PT(INR) - Boxplot")
ax1.set_xlabel('PT(INR)')
ax1.set_ylabel('Second', rotation=0)
ax1.set_xticks([])

#ptinr_nmptinr_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ptinr_nm.plot.hist(ax = ax2, bins=100, range=[0,2])
ax2.set_title("PT(INR) - Histogram")
ax2.set_xlabel('PT(INR)(Second)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    131066.000000
# mean        181.844024
# std         384.382089
# min           0.000000
# 25%           0.970000
# 50%           1.020000
# 75%           1.190000
# max         999.900000
# Name: PTINR_NM, dtype: float64

# %% [markdown]
# # GLUCOSE (ER)

# %%
er_nm = cdc.loc[:,"ER_NM"]
#print(er_nm)
#print(er_nm.value_counts() / len(er_nm))
print(er_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

er_nm.plot.box(ax = ax1)
ax1.set_title("GLUCOSE (ER) - Boxplot")
ax1.set_xlabel('GLUCOSE (ER)')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#er_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
er_nm.plot.hist(ax = ax2, bins=100, range=[0,400])
ax2.set_title("GLUCOSE (ER) - Histogram")
ax2.set_xlabel('GLUCOSE (ER)(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    133057.000000
# mean        328.147257
# std         342.198308
# min           0.000000
# 25%         116.000000
# 50%         154.000000
# 75%         307.000000
# max         999.900000
# Name: ER_NM, dtype: float64

# %% [markdown]
# # BUN

# %%
bun_nm = cdc.loc[:,"BUN_NM"]
#print(bun_nm)
#print(bun_nm.value_counts() / len(bun_nm))
print(bun_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

bun_nm.plot.box(ax = ax1)
ax1.set_title("BUN - Boxplot")
ax1.set_xlabel('BUN')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#bun_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
bun_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("BUN - Histogram")
ax2.set_xlabel('BUN(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    129320.000000
# mean        174.684599
# std         357.015978
# min           0.000000
# 25%          14.000000
# 50%          18.900000
# 75%          31.000000
# max         999.900000
# Name: BUN_NM, dtype: float64

# %% [markdown]
# # Creatinine

# %%
cre_nm = cdc.loc[:,"CRE_NM"]
#print(cre_nm)
#print(cre_nm.value_counts() / len(cre_nm))
print(cre_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

cre_nm.plot.box(ax = ax1)
ax1.set_title("Creatinine - Boxplot")
ax1.set_xlabel('Creatinine')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#cre_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
cre_nm.plot.hist(ax = ax2, bins=100, range=[0,4])
ax2.set_title("Creatinine - Histogram")
ax2.set_xlabel('Creatinine(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    132722.000000
# mean         38.607233
# std         189.283201
# min           0.000000
# 25%           0.800000
# 50%           1.000000
# 75%           1.340000
# max         999.900000
# Name: CRE_NM, dtype: float64

# %% [markdown]
# # Albumin

# %%
alb_nm = cdc.loc[:,"ALB_NM"]
alb_nm[alb_nm < 0] = np.nan
#print(alb_nm)
#print(alb_nm.value_counts() / len(alb_nm))
print(alb_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

alb_nm.plot.box(ax = ax1)
ax1.set_title("Albumin - Boxplot")
ax1.set_xlabel('Albumin')
ax1.set_ylabel('g/dL', rotation=0)
ax1.set_xticks([])

#alb_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
alb_nm.plot.hist(ax = ax2, bins=100, range=[0,5])
ax2.set_title("Albumin - Histogram")
ax2.set_xlabel('Albumin(g/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-229-f97567f1d6b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alb_nm[alb_nm < 0] = np.nan
# count    122114.000000
# mean        620.009149
# std         483.896548
# min           0.000000
# 25%           3.800000
# 50%         999.900000
# 75%         999.900000
# max         999.900000
# Name: ALB_NM, dtype: float64

# %% [markdown]
# # CRP

# %%
crp_nm = cdc.loc[:,"CRP_NM"]
#print(crp_nm)
#print(crp_nm.value_counts() / len(crp_nm))
print(crp_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

crp_nm.plot.box(ax = ax1)
ax1.set_title("CRP - Boxplot")
ax1.set_xlabel('CRP')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#crp_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
crp_nm.plot.hist(ax = ax2, bins=100, range=[0,20])
ax2.set_title("CRP - Histogram")
ax2.set_xlabel('CRP(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    121606.000000
# mean        645.776371
# std         475.235694
# min           0.000000
# 25%           4.320000
# 50%         999.900000
# 75%         999.900000
# max         999.999000
# Name: CRP_NM, dtype: float64

# %% [markdown]
# # HbA1c

# %%
hbac_nm = cdc.loc[:,"HBAC_NM"]
#print(hbac_nm)
#print(hbac_nm.value_counts() / len(hbac_nm))
print(hbac_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hbac_nm.plot.box(ax = ax1)
ax1.set_title("HbA1c - Boxplot")
ax1.set_xlabel('HbA1c')
ax1.set_ylabel('%', rotation=0)
ax1.set_xticks([])

#hbac_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
hbac_nm.plot.hist(ax = ax2, bins=100, range=[0,20])
ax2.set_title("HbA1c - Histogram")
ax2.set_xlabel('HbA1c(%)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    126674.000000
# mean        525.568746
# std         495.809739
# min           0.000000
# 25%           6.400000
# 50%         999.900000
# 75%         999.900000
# max         999.900000
# Name: HBAC_NM, dtype: float64

# %% [markdown]
# # 抽血結果 - 第一次空腹抽血

# %% [markdown]
# # Glu (AC)

# %%
ac_nm = cdc.loc[:,"AC_NM"]
#print(ac_nm)
#print(ac_nm.value_counts() / len(ac_nm))
print(ac_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ac_nm.plot.box(ax = ax1)
ax1.set_title("Glu (AC) - Boxplot")
ax1.set_xlabel('Glu (AC)')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#ac_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ac_nm.plot.hist(ax = ax2, bins=100, range=[0,300])
ax2.set_title("Glu (AC) - Histogram")
ax2.set_xlabel('Glu (AC)(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    125625.000000
# mean        534.500042
# std         434.330726
# min           0.000000
# 25%         111.000000
# 50%         230.000000
# 75%         999.900000
# max         999.900000
# Name: AC_NM, dtype: float64

# %% [markdown]
# # UA

# %%
ua_nm = cdc.loc[:,"UA_NM"]
#print(ua_nm)
#print(ua_nm.value_counts() / len(ua_nm))
print(ua_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ua_nm.plot.box(ax = ax1)
ax1.set_title("UA - Boxplot")
ax1.set_xlabel('UA')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#ua_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ua_nm.plot.hist(ax = ax2, bins=100, range=[0,15])
ax2.set_title("UA - Histogram")
ax2.set_xlabel('UA(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    126829.000000
# mean        405.603563
# std         487.329745
# min           0.000000
# 25%           5.200000
# 50%           7.500000
# 75%         999.900000
# max         999.900000
# Name: UA_NM, dtype: float64

# %% [markdown]
# # T-CHO

# %%
tcho_nm = cdc.loc[:,"TCHO_NM"]
#print(tcho_nm)
#print(tcho_nm.value_counts() / len(tcho_nm))
print(tcho_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

tcho_nm.plot.box(ax = ax1)
ax1.set_title("T-CHO - Boxplot")
ax1.set_xlabel('T-CHO')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#tcho_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
tcho_nm.plot.hist(ax = ax2, bins=100, range=[0,400])
ax2.set_title("T-CHO - Histogram")
ax2.set_xlabel('T-CHO(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    131835.000000
# mean        318.475292
# std         332.987243
# min           0.000000
# 25%         128.000000
# 50%         175.000000
# 75%         246.000000
# max         999.900000
# Name: TCHO_NM, dtype: float64

# %% [markdown]
# # TG

# %%
tg_nm = cdc.loc[:,"TG_NM"]
#print(tg_nm)
#print(tg_nm.value_counts() / len(tg_nm))
print(tg_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

tg_nm.plot.box(ax = ax1)
ax1.set_title("TG - Boxplot")
ax1.set_xlabel('TG')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#tg_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
tg_nm.plot.hist(ax = ax2, bins=100, range=[0,400])
ax2.set_title("TG - Histogram")
ax2.set_xlabel('TG(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    131775.000000
# mean        315.628283
# std         353.068761
# min           0.000000
# 25%         113.000000
# 50%         170.000000
# 75%         249.000000
# max        9999.000000
# Name: TG_NM, dtype: float64

# %% [markdown]
# # HDL

# %%
hdl_nm = cdc.loc[:,"HDL_NM"]
#print(hdl_nm)
#print(hdl_nm.value_counts() / len(hdl_nm))
print(hdl_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

hdl_nm.plot.box(ax = ax1)
ax1.set_title("HDL - Boxplot")
ax1.set_xlabel('HDL')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#hdl_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
hdl_nm.plot.hist(ax = ax2, bins=100, range=[0,200])
ax2.set_title("HDL - Histogram")
ax2.set_xlabel('HDL(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    129806.000000
# mean        383.225964
# std         438.910048
# min           0.000000
# 25%          44.000000
# 50%         105.000000
# 75%         999.900000
# max         999.900000
# Name: HDL_NM, dtype: float64

# %% [markdown]
# # LDL

# %%
ldl_nm = cdc.loc[:,"LDL_NM"]
#print(ldl_nm)
#print(ldl_nm.value_counts() / len(ldl_nm))
print(ldl_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

ldl_nm.plot.box(ax = ax1)
ax1.set_title("LDL - Boxplot")
ax1.set_xlabel('LDL')
ax1.set_ylabel('mg/dL', rotation=0)
ax1.set_xticks([])

#ldl_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
ldl_nm.plot.hist(ax = ax2, bins=100, range=[0,200])
ax2.set_title("LDL - Histogram")
ax2.set_xlabel('LDL(mg/dL)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    130679.000000
# mean        323.226089
# std         405.498533
# min           0.000000
# 25%          49.100000
# 50%         104.400000
# 75%         999.900000
# max         999.900000
# Name: LDL_NM, dtype: float64

# %% [markdown]
# # GOT

# %%
got_nm = cdc.loc[:,"GOT_NM"]
#print(got_nm)
#print(got_nm.value_counts() / len(got_nm))
print(got_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

got_nm.plot.box(ax = ax1)
ax1.set_title("GOT - Boxplot")
ax1.set_xlabel('GOT')
ax1.set_ylabel('U/L', rotation=0)
ax1.set_xticks([])

#got_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
got_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("GOT - Histogram")
ax2.set_xlabel('GOT(U/L)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    125777.000000
# mean        356.801471
# std         457.559863
# min           0.000000
# 25%          22.000000
# 50%          34.000000
# 75%         999.900000
# max         999.900000
# Name: GOT_NM, dtype: float64

# %% [markdown]
# # GPT

# %%
gpt_nm = cdc.loc[:,"GPT_NM"]
#print(gpt_nm)
#print(gpt_nm.value_counts() / len(gpt_nm))
print(gpt_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

gpt_nm.plot.box(ax = ax1)
ax1.set_title("GPT - Boxplot")
ax1.set_xlabel('GPT')
ax1.set_ylabel('U/L', rotation=0)
ax1.set_xticks([])

#gpt_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
gpt_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("GPT - Histogram")
ax2.set_xlabel('GPT(U/L)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    129983.000000
# mean        319.290949
# std         446.308041
# min           0.000000
# 25%          17.000000
# 50%          28.000000
# 75%         999.900000
# max         999.900000
# Name: GPT_NM, dtype: float64

# %% [markdown]
# # 離院情形

# %%
off_id = cdc.loc[:,"OFF_ID"]
off_id[off_id == 0] = np.nan
#print(off_id)
print(off_id.value_counts() / len(off_id))
#print(off_id.describe())

off_id_labels = ["病危自動離院","死亡","離院"]
sns.countplot(off_id).set_xticklabels(off_id_labels)
plt.title("離院情形 - Barplot")
plt.xlabel('離院情形')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 3.0    0.874406
# 2.0    0.045265
# 1.0    0.016514
# Name: OFF_ID, dtype: float64
# <ipython-input-240-ff3d9ed86bfb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   off_id[off_id == 0] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 死亡日期

# %%
offd_dt = cdc.loc[:,"OFFD_DT"]
offd_dt = pd.to_datetime(offd_dt, errors='coerce')
offd_dt[(offd_dt.dt.year < 2006) | (offd_dt.dt.year > 2018)] = np.nan
#print(offd_dt)
print(offd_dt.value_counts() / len(offd_dt))
print(offd_dt.describe())

offd_dt.value_counts().plot()
plt.title("死亡日期 - Lineplot")
plt.xlabel('死亡日期')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# 2013-01-17    0.000057
# 2009-03-06    0.000057
# 2012-09-21    0.000050
# 2010-01-15    0.000050
# 2012-08-08    0.000050
#                 ...
# 2012-06-15    0.000007
# 2016-08-22    0.000007
# 2015-11-05    0.000007
# 2008-05-28    0.000007
# 2011-02-07    0.000007
# Name: OFFD_DT, Length: 3170, dtype: float64
# count                    6211
# unique                   3170
# top       2013-01-17 00:00:00
# freq                        8
# first     2006-01-31 00:00:00
# last      2018-10-01 00:00:00
# Name: OFFD_DT, dtype: object
# <ipython-input-241-42a45ea5d549>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(offd_dt.describe())

# %% [markdown]
# # 死因

# %%
offd_id = cdc.loc[:,"OFFD_ID"]
#print(offd_id)
print(offd_id.value_counts() / len(offd_id))
#print(offd_id.describe())

offd_id_labels = ["中風直接致死","併發症致死","其他"]
sns.countplot(offd_id).set_xticklabels(offd_id_labels)
plt.title("死因 - Barplot")
plt.xlabel('死因')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 99.0    0.429643
# 1.0     0.014414
# 2.0     0.005253
# Name: OFFD_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#OFFD_TX

# %% [markdown]
# # 離院，目的地

# %%
offdt_id = cdc.loc[:,"OFFDT_ID"]
offdt_id[offdt_id == 0] = np.nan
#print(offdt_id)
print(offdt_id.value_counts() / len(offdt_id))
#print(offdt_id.describe())

offdt_id_labels = ["回家","護理之家","轉院","呼吸病房(RCW)","轉復健"]
sns.countplot(offdt_id).set_xticklabels(offdt_id_labels)
plt.title("離院，目的地 - Barplot")
plt.xlabel('離院，目的地')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.710650
# 3.0    0.060405
# 2.0    0.058170
# 5.0    0.031050
# 4.0    0.007609
# Name: OFFDT_ID, dtype: float64
# <ipython-input-244-8cf04674f76d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offdt_id[offdt_id == 0] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 離院，轉院醫院

# %%
offdtorg_id = cdc.loc[:,"OFFDTORG_ID"]
#print(offdtorg_id)
print(offdtorg_id.value_counts() / len(offdtorg_id))
#print(offdtorg_id.describe())
# Out:
# 999    0.492170
# 99     0.024594
# 22     0.002527
# O      0.001253
# 25     0.000925
#          ...
# 17     0.000014
# 52     0.000007
# 40     0.000007
# 58     0.000007
# 63     0.000007
# Name: OFFDTORG_ID, Length: 65, dtype: float64

# %%
#OFFDTORG_TX

# %% [markdown]
# # 轉復健日期

# %%
offre_dt = cdc.loc[:,"OFFRE_DT"]
offre_dt = pd.to_datetime(offre_dt, errors='coerce')
offre_dt[(offre_dt.dt.year < 2006) | (offre_dt.dt.year > 2018)] = np.nan
#print(offre_dt)
print(offre_dt.value_counts() / len(offre_dt))
print(offre_dt.describe())

offre_dt.value_counts().plot()
plt.title("轉復健日期 - Lineplot")
plt.xlabel('轉復健日期')
plt.ylabel('Number', rotation=0)
plt.xticks()
plt.show()
# Out:
# 2012-07-24    0.000064
# 2013-04-01    0.000057
# 2013-04-18    0.000057
# 2012-04-30    0.000057
# 2013-02-19    0.000057
#                 ...
# 2017-05-31    0.000007
# 2016-05-08    0.000007
# 2011-10-14    0.000007
# 2012-04-04    0.000007
# 2013-05-21    0.000007
# Name: OFFRE_DT, Length: 1799, dtype: float64
# count                    4340
# unique                   1799
# top       2012-07-24 00:00:00
# freq                        9
# first     2009-10-05 00:00:00
# last      2018-10-09 00:00:00
# Name: OFFRE_DT, dtype: object
# <ipython-input-247-ec069cbc7335>:6: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(offre_dt.describe())
