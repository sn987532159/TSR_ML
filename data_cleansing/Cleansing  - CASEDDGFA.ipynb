# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib.font_manager import FontProperties
import numpy as np

# %%
font_path = os.path.join("..", "kaiu.ttf")
myfont=FontProperties(fname= font_path, size=14)
sns.set(font=myfont.get_name())

plt.rcParams['figure.figsize'] = (10,5)

# %%
csv_path = os.path.join("..", "data","TSR_2018_raw", "CASEDDGFA.csv")
cdd = pd.read_csv(csv_path)
cdd.head()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (21,34,37,40,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    IPROTOCOL_ID  ICASE_ID       IDCASE_ID  HD_ID  HDMT_ID  PCVA_ID  PCVAMT_ID  \
# 0           NaN      9066  010-00009066-1    0.0      NaN      0.0        NaN
# 1           NaN      9066  022-00009066-1    0.0      NaN      0.0        NaN
# 2           NaN      4830  005-00004830-2    1.0      NaN      1.0        NaN
# 3           NaN      9067  005-00009067-1    1.0      NaN      0.0        NaN
# 4           NaN      9068  005-00009068-1    0.0      NaN      0.0        NaN
#
#    PCVACI_ID  PCVACH_ID  PO_ID  ...  PADMT_ID  AL_ID  CA_ID  CA_TX  OT_ID  \
# 0        0.0        0.0    0.0  ...       NaN      0    0.0    NaN      0
# 1        0.0        0.0    0.0  ...       NaN      0    0.0    NaN      0
# 2        1.0        0.0    0.0  ...       NaN      0    0.0    NaN      0
# 3        0.0        0.0    0.0  ...       NaN      0    0.0    NaN      1
# 4        0.0        0.0    0.0  ...       NaN      0    0.0    NaN      0
#
#               OT_TX  THISHC_ID  THISHY_ID  THISDI_ID  IGUID_FT
# 0               NaN        NaN        NaN        NaN       NaN
# 1               NaN        NaN        NaN        NaN       NaN
# 2               NaN        NaN        NaN        NaN       NaN
# 3  artery stenosis         NaN        NaN        NaN       NaN
# 4               NaN        NaN        NaN        NaN       NaN
#
# [5 rows x 43 columns]

# %%
cdd.describe()
# Out:
#        IPROTOCOL_ID       ICASE_ID          HD_ID  HDMT_ID        PCVA_ID  \
# count           0.0  140871.000000  123606.000000      0.0  123960.000000
# mean            NaN   62420.901449       0.337726      NaN       0.310358
# std             NaN   37117.663830       0.485597      NaN       0.474113
# min             NaN       1.000000       0.000000      NaN       0.000000
# 25%             NaN   30135.500000       0.000000      NaN       0.000000
# 50%             NaN   61827.000000       0.000000      NaN       0.000000
# 75%             NaN   94456.000000       1.000000      NaN       1.000000
# max             NaN  127958.000000       4.000000      NaN       2.000000
#
#        PCVAMT_ID      PCVACI_ID      PCVACH_ID          PO_ID  POMT_ID  ...  \
# count        0.0  119203.000000  116330.000000  118741.000000      0.0  ...
# mean         NaN       0.289707       0.056047       0.033493      NaN  ...
# std          NaN       0.471653       0.263917       0.248658      NaN  ...
# min          NaN       0.000000       0.000000       0.000000      NaN  ...
# 25%          NaN       0.000000       0.000000       0.000000      NaN  ...
# 50%          NaN       0.000000       0.000000       0.000000      NaN  ...
# 75%          NaN       1.000000       0.000000       0.000000      NaN  ...
# max          NaN       9.000000       2.000000       9.000000      NaN  ...
#
#                HT_ID  HTY_NM  HTMT_ID          DM_ID  DMY_NM  DMMT_ID  \
# count  130228.000000     0.0      0.0  125459.000000     0.0      0.0
# mean        0.807461     NaN      NaN       0.416758     NaN      NaN
# std         0.404049     NaN      NaN       0.506438     NaN      NaN
# min         0.000000     NaN      NaN       0.000000     NaN      NaN
# 25%         1.000000     NaN      NaN       0.000000     NaN      NaN
# 50%         1.000000     NaN      NaN       0.000000     NaN      NaN
# 75%         1.000000     NaN      NaN       1.000000     NaN      NaN
# max         4.000000     NaN      NaN       2.000000     NaN      NaN
#
#               PAD_ID  PADMT_ID          CA_ID  THISHC_ID
# count  120890.000000       0.0  121118.000000        0.0
# mean        0.106940       NaN       0.047450        NaN
# std         0.429144       NaN       0.224647        NaN
# min         0.000000       NaN       0.000000        NaN
# 25%         0.000000       NaN       0.000000        NaN
# 50%         0.000000       NaN       0.000000        NaN
# 75%         0.000000       NaN       0.000000        NaN
# max         2.000000       NaN       9.000000        NaN
#
# [8 rows x 34 columns]

# %% [markdown]
# # Risk Factors

# %% [markdown]
# # Heart Disease

# %%
hd_id = cdd.loc[:,"HD_ID"]
hd_id[hd_id == 4] = np.nan
#print(hd_id)
print(hd_id.value_counts() / len(hd_id))
#print(hd_id.describe())

hd_id_labels = ["No","Yes","Unknown"]
sns.countplot(hd_id).set_xticklabels(hd_id_labels)
plt.title("Heart Disease - Barplot")
plt.xlabel('Heart Disease')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.586409
# 1.0    0.285744
# 2.0    0.005281
# Name: HD_ID, dtype: float64
# <ipython-input-5-46657e08d802>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hd_id[hd_id == 4] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Previous CVA

# %%
pcva_id = cdd.loc[:,"PCVA_ID"]
#print(pcva_id)
print(pcva_id.value_counts() / len(pcva_id))
#print(pcva_id.describe())

pcva_id_labels = ["No","Yes","Unknown"]
sns.countplot(pcva_id).set_xticklabels(pcva_id_labels)
plt.title("Previous CVA - Barplot")
plt.xlabel('Previous CVA')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.611581
# 1.0    0.263645
# 2.0    0.004728
# Name: PCVA_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Previous CVA (Cerebral Infraction)

# %%
pcvaci_id = cdd.loc[:,"PCVACI_ID"]
pcvaci_id[(pcvaci_id == 3) | (pcvaci_id == 9)] = np.nan
#print(pcvaci_id)
print(pcvaci_id.value_counts() / len(pcvaci_id))
#print(pcvaci_id.describe())

pcvaci_id_labels = ["No","Yes","Unknown"]
sns.countplot(pcvaci_id).set_xticklabels(pcvaci_id_labels)
plt.title("Previous CVA (Cerebral Infraction) - Barplot")
plt.xlabel('Previous CVA (Cerebral Infraction)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.607889
# 1.0    0.231503
# 2.0    0.006779
# Name: PCVACI_ID, dtype: float64
# <ipython-input-7-36efc43e09dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pcvaci_id[(pcvaci_id == 3) | (pcvaci_id == 9)] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Previous CVA (Cerebral Hemorrhage)

# %%
pcvach_id = cdd.loc[:,"PCVACH_ID"]
#print(pcvach_id)
print(pcvach_id.value_counts() / len(pcvach_id))
#print(pcvach_id.describe())

pcvach_id_labels = ["No","Yes","Unknown"]
sns.countplot(pcvach_id).set_xticklabels(pcvach_id_labels)
plt.title("Previous CVA (Cerebral Hemorrhage) - Barplot")
plt.xlabel('Previous CVA (Cerebral Hemorrhage)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0    0.786422
# 1.0    0.032455
# 2.0    0.006914
# Name: PCVACH_ID, dtype: float64

# %% [markdown]
# # Polycythemia

# %%
po_id = cdd.loc[:,"PO_ID"]
po_id[po_id == 9] = np.nan
#print(po_id)
print(po_id.value_counts() / len(po_id))
#print(po_id.describe())

po_id_labels = ["No","Yes","Unknown"]
sns.countplot(po_id).set_xticklabels(po_id_labels)
plt.title("Polycythemia - Barplot")
plt.xlabel('Polycythemia')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-9-2619e292853b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_id[po_id == 9] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0    0.826693
# 2.0    0.011905
# 1.0    0.004295
# Name: PO_ID, dtype: float64

# %% [markdown]
# # Uremia

# %%
ur_id = cdd.loc[:,"UR_ID"]
#print(ur_id)
print(ur_id.value_counts() / len(ur_id))
#print(ur_id.describe())

ur_id_labels = ["No","Yes","Unknown"]
sns.countplot(ur_id).set_xticklabels(ur_id_labels)
plt.title("Uremia - Barplot")
plt.xlabel('Uremia')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.812552
# 1.0    0.029452
# 2.0    0.004841
# Name: UR_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Smoking

# %%
sm_id = cdd.loc[:,"SM_ID"]
sm_id[sm_id == 4] = np.nan
#print(sm_id)
print(sm_id.value_counts() / len(sm_id))
#print(sm_id.describe())

sm_id_labels = ["No","Yes","Unknown"]
sns.countplot(sm_id).set_xticklabels(sm_id_labels)
plt.title("Smoking - Barplot")
plt.xlabel('Smoking')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.570075
# 1.0    0.316240
# 2.0    0.009086
# Name: SM_ID, dtype: float64
# <ipython-input-11-379491a0a5a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm_id[sm_id == 4] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Smoking (支/天)

# %%
smc_nm = cdd.loc[:, "SMC_NM"]
#print(smc_nm)
#print(smc_nm.value_counts() / len(smc_nm))
print(smc_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

smc_nm.plot.box(ax = ax1)
ax1.set_title("Smoking (cigarette/ per day) - Boxplot")
ax1.set_xlabel('Smoking')
ax1.set_ylabel('cigarette/ per day', rotation=0)
ax1.set_xticks([])

#smc_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
smc_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("Smoking (cigarette/ per day) - Histogram")
ax2.set_xlabel('Smoking(cigarette/ per day)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    64080.000000
# mean        16.568847
# std         49.726399
# min          0.000000
# 25%          0.000000
# 50%         10.000000
# 75%         20.000000
# max        999.900000
# Name: SMC_NM, dtype: float64

# %% [markdown]
# # Smoking (年)

# %%
smy_nm = cdd.loc[:, "SMY_NM"]
#print(smy_nm)
#print(smy_nm.value_counts() / len(smy_nm))
print(smy_nm.describe())

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

smy_nm.plot.box(ax = ax1)
ax1.set_title("Smoking (year) - Boxplot")
ax1.set_xlabel('Smoking')
ax1.set_ylabel('year', rotation=0)
ax1.set_xticks([])

#smy_nm.plot.hist(ax = ax2, bins=100)
#plt.show()
smy_nm.plot.hist(ax = ax2, bins=100, range=[0,100])
ax2.set_title("Smoking (year) - Histogram")
ax2.set_xlabel('Smoking(year)')
ax2.set_ylabel('Number', rotation=0)
plt.show()
# Out:
# count    62500.000000
# mean        24.013627
# std         58.173079
# min          0.000000
# 25%          0.000000
# 50%         20.000000
# 75%         40.000000
# max        999.900000
# Name: SMY_NM, dtype: float64

# %% [markdown]
# # Smoking Status

# %%
smcp_id = cdd.loc[:,"SMCP_ID"]
#print(smcp_id)
print(smcp_id.value_counts() / len(smcp_id))
#print(smcp_id.describe())

smcp_id_labels = ["Current","Past (more than 2 years)"]
sns.countplot(smcp_id).set_xticklabels(smcp_id_labels)
plt.title("Smoking Status - Barplot")
plt.xlabel('Smoking Status')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.197855
# 2.0    0.087562
# Name: SMCP_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Previous TIA

# %%
ptia_id = cdd.loc[:,"PTIA_ID"]
#print(ptia_id)
print(ptia_id.value_counts() / len(ptia_id))
#print(ptia_id.describe())

ptia_id_labels = ["No","Yes","Unknown"]
sns.countplot(ptia_id).set_xticklabels(ptia_id_labels)
plt.title("Smoking Status - Barplot")
plt.xlabel('Smoking Status')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.820389
# 1.0    0.014701
# 2.0    0.011677
# Name: PTIA_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Dyslipidemia

# %%
hc_id = cdd.loc[:,"HC_ID"]
#print(hc_id)
#print(hc_id.value_counts() / len(hc_id))
#print(hc_id.describe())

hc_id[hc_id == str(0)] = int(0)
hc_id[hc_id == str(1)] = int(1)
hc_id[hc_id == str(2)] = int(2)
hc_id[hc_id == ","] = np.nan
print(hc_id.value_counts() / len(hc_id))
#print(hc_id.describe())

hc_id_labels = ["No","Yes","Unknown"]
sns.countplot(hc_id).set_xticklabels(hc_id_labels)
plt.title("Dyslipidemia - Barplot")
plt.xlabel('Dyslipidemia')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-16-acb04af5f893>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hc_id[hc_id == str(0)] = int(0)
# <ipython-input-16-acb04af5f893>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hc_id[hc_id == str(1)] = int(1)
# <ipython-input-16-acb04af5f893>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hc_id[hc_id == str(2)] = int(2)
# <ipython-input-16-acb04af5f893>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hc_id[hc_id == ","] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0    0.419469
# 1.0    0.403035
# 2.0    0.071810
# Name: HC_ID, dtype: float64

# %% [markdown]
# # Dyslipidemia (Hypertriglyceridemia)

# %%
hcht_id = cdd.loc[:,"HCHT_ID"]
#print(hcht_id)
print(hcht_id.value_counts() / len(hcht_id))
#print(hcht_id.describe())

hcht_id_labels = ["No","Yes","Unknown"]
sns.countplot(hcht_id).set_xticklabels(hcht_id_labels)
plt.title("Dyslipidemia (Hypertriglyceridemia) - Barplot")
plt.xlabel('Dyslipidemia (Hypertriglyceridemia)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.600407
# 1.0    0.183842
# 2.0    0.078462
# Name: HCHT_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Dyslipidemia (Hypercholesterolemia)

# %%
hchc_id = cdd.loc[:,"HCHC_ID"]
hchc_id[hchc_id == 9] = np.nan
#print(hchc_id)
print(hchc_id.value_counts() / len(hchc_id))
#print(hchc_id.describe())

hchc_id_labels = ["No","Yes","Unknown"]
sns.countplot(hchc_id).set_xticklabels(hchc_id_labels)
plt.title("Dyslipidemia (Hypercholesterolemia) - Barplot")
plt.xlabel('Dyslipidemia (Hypercholesterolemia)')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.487481
# 1.0    0.300814
# 2.0    0.077461
# Name: HCHC_ID, dtype: float64
# <ipython-input-18-29a12472ea2e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hchc_id[hchc_id == 9] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Hypertension

# %%
ht_id = cdd.loc[:,"HT_ID"]
ht_id[ht_id == 4] = np.nan
#print(ht_id)
print(ht_id.value_counts() / len(ht_id))
#print(ht_id.describe())

ht_id_labels = ["No","Yes","Unknown"]
sns.countplot(ht_id).set_xticklabels(ht_id_labels)
plt.title("Hypertension - Barplot")
plt.xlabel('Hypertension')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 1.0    0.739315
# 0.0    0.181570
# 2.0    0.003556
# Name: HT_ID, dtype: float64
# <ipython-input-19-3267c033e547>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ht_id[ht_id == 4] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # DM

# %%
dm_id = cdd.loc[:,"DM_ID"]
#print(dm_id)
print(dm_id.value_counts() / len(dm_id))
#print(dm_id.describe())

dm_id_labels = ["No","Yes","Unknown"]
sns.countplot(dm_id).set_xticklabels(dm_id_labels)
plt.title("DM - Barplot")
plt.xlabel('DM')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.525403
# 1.0    0.359222
# 2.0    0.005970
# Name: DM_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # PAD

# %%
pad_id = cdd.loc[:,"PAD_ID"]
#print(pad_id)
print(pad_id.value_counts() / len(pad_id))
#print(pad_id.describe())

pad_id_labels = ["No","Yes","Unknown"]
sns.countplot(pad_id).set_xticklabels(pad_id_labels)
plt.title("PAD - Barplot")
plt.xlabel('PAD')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# 0.0    0.804431
# 2.0    0.038042
# 1.0    0.015688
# Name: PAD_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Alcohol

# %%
al_id = cdd.loc[:,"AL_ID"]
#print(al_id)
print(al_id.value_counts() / len(al_id))
#print(al_id.describe())

al_id[al_id == str(0)] = int(0)
al_id[al_id == str(1)] = int(1)
al_id[al_id == str(2)] = int(2)
print(al_id.value_counts() / len(al_id))
#print(al_id.describe())

pad_id_labels = ["No","Yes","Unknown"]
sns.countplot(pad_id).set_xticklabels(pad_id_labels)
plt.title("Alcohol - Barplot")
plt.xlabel('Alcohol')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-22-2d55a4f90e65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   al_id[al_id == str(0)] = int(0)
# 0.0    0.671096
# 1.0    0.104109
# 0      0.088215
# 1      0.015163
# 2.0    0.007305
# 2      0.001129
#        0.000007
# Name: AL_ID, dtype: float64
# 0.0    0.759312
# 1.0    0.119272
# 2.0    0.008433
#        0.000007
# Name: AL_ID, dtype: float64
# <ipython-input-22-2d55a4f90e65>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   al_id[al_id == str(1)] = int(1)
# <ipython-input-22-2d55a4f90e65>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   al_id[al_id == str(2)] = int(2)
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Cancer

# %%
ca_id = cdd.loc[:,"CA_ID"]
ca_id[ca_id == 9] = np.nan
#print(ca_id)
print(ca_id.value_counts() / len(ca_id))
#print(ca_id.describe())

ca_id_labels = ["No","Yes","Unknown"]
sns.countplot(ca_id).set_xticklabels(ca_id_labels)
plt.title("Cancer - Barplot")
plt.xlabel('Cancer')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-23-dc29df4d4354>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_id[ca_id == 9] = np.nan
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0    0.821049
# 1.0    0.036714
# 2.0    0.002009
# Name: CA_ID, dtype: float64

# %%
#CA_TX

# %% [markdown]
# # Others

# %%
ot_id = cdd.loc[:,"OT_ID"]
#print(ot_id)
#print(ot_id.value_counts() / len(ot_id))
#print(ot_id.describe())

ot_id[ot_id == str(0)] = int(0)
ot_id[ot_id == str(1)] = int(1)
ot_id[ot_id == str(2)] = int(2)
ot_id[ot_id == "M"] = np.nan
print(ot_id.value_counts() / len(ot_id))
#print(ot_id.describe())

ot_id_labels = ["No","Yes","Unknown"]
sns.countplot(ot_id).set_xticklabels(ot_id_labels)
plt.title("Others - Barplot")
plt.xlabel('Others')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-25-8230a962e36a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ot_id[ot_id == str(0)] = int(0)
# <ipython-input-25-8230a962e36a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ot_id[ot_id == str(1)] = int(1)
# <ipython-input-25-8230a962e36a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ot_id[ot_id == str(2)] = int(2)
# <ipython-input-25-8230a962e36a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ot_id[ot_id == "M"] = np.nan
# 0.0    0.685826
# 1.0    0.134698
# 2.0    0.005963
# Name: OT_ID, dtype: float64
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#OT_TX

# %% [markdown]
# # Hypertension Was Diagnosed at This Visit

# %%
thishy_id = cdd.loc[:,"THISHY_ID"]
#print(thishy_id)
#print(thishy_id.value_counts() / len(thishy_id))
#print(thishy_id.describe())

thishy_id[thishy_id == str(1)] = int(1)
thishy_id[thishy_id == 0] = "Y"
thishy_id[thishy_id == 1] = "N"
print(thishy_id.value_counts() / len(thishy_id))
#print(thishy_id.describe())

sns.countplot(thishy_id)
plt.title("Hypertension Was Diagnosed at This Visit - Barplot")
plt.xlabel('Hypertension Was Diagnosed at This Visit')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# N    0.052729
# Y    0.003677
# Name: THISHY_ID, dtype: float64
# <ipython-input-27-fa7c367c0da2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thishy_id[thishy_id == str(1)] = int(1)
# <ipython-input-27-fa7c367c0da2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thishy_id[thishy_id == 0] = "Y"
# <ipython-input-27-fa7c367c0da2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thishy_id[thishy_id == 1] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # DM Was Diagnosed at This Visit

# %%
thisdi_id = cdd.loc[:,"THISDI_ID"]
#print(thisdi_id)
#print(thisdi_id.value_counts() / len(thisdi_id))
#print(thisdi_id.describe())

thisdi_id[thisdi_id == str(1)] = int(1)
thisdi_id[thisdi_id == 0] = "Y"
thisdi_id[thisdi_id == 1] = "N"
print(thisdi_id.value_counts() / len(thisdi_id))
#print(thisdi_id.describe())

sns.countplot(thisdi_id)
plt.title("DM Was Diagnosed at This Visit - Barplot")
plt.xlabel('DM Was Diagnosed at This Visit')
plt.ylabel('Number', rotation=0)
plt.show()
# Out:
# <ipython-input-28-d6d608eba850>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thisdi_id[thisdi_id == str(1)] = int(1)
# <ipython-input-28-d6d608eba850>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thisdi_id[thisdi_id == 0] = "Y"
# N    0.046922
# Y    0.002960
# Name: THISDI_ID, dtype: float64
# <ipython-input-28-d6d608eba850>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thisdi_id[thisdi_id == 1] = "N"
# C:\Users\Jacky C\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
