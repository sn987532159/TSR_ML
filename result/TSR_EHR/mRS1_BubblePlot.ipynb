# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = os.path.join("..", "..", "data","LINKED_DATA", "TSR_EHR", "TSR_1_CLEANED.csv")
tsr_1 = pd.read_csv(csv_path)
tsr_1.head()
# Out:
#    height_nm  weight_nm  edu_id  pro_id  opc_id  ih_fl  ivtpamg_nm  \
# 0      150.0       49.0       2       1       3      0         0.0
# 1      153.0       62.0       3       1       3      0         0.0
# 2      152.0       62.0       3       1       2      0         0.0
# 3      148.0       56.0       2       1       2      0         0.0
# 4      152.0       56.0       4       1       2      0         0.0
#
#    hospitalised_time  nivtpa_id  nivtpa1_fl  ...  nihs_6br_out  nihs_7_out  \
# 0               16.0          1           0  ...             0           0
# 1                8.0          0         999  ...             0           1
# 2                4.0          0         999  ...             0           0
# 3                5.0          0         999  ...             0           0
# 4                3.0          1           0  ...             0           0
#
#    nihs_8_out  nihs_9_out  nihs_10_out  nihs_11_out  total_out  SexName   Age  \
# 0           0           0            0            0          8        0  66.0
# 1           1           0            1            0          4        0  67.0
# 2           1           0            0            0          1        0  69.0
# 3           1           0            0            0          2        0  71.0
# 4           0           0            0            0          0        0  71.0
#
#    mrs_tx_1
# 0         4
# 1         1
# 2         1
# 3         0
# 4         0
#
# [5 rows x 307 columns]

# %%
mrs_tx_1 = tsr_1.mrs_tx_1
total = tsr_1.total
total_in = tsr_1.total_in
total_out = tsr_1.total_out
crp_nm = tsr_1.crp_nm
gcsv_nm = tsr_1.gcsv_nm
ldl_nm = tsr_1.ldl_nm
hospitalised_time = tsr_1.hospitalised_time

# %% [markdown]
# # mRS VERSUS suspected features

# %% [markdown]
# ## 6 Outcomes

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, hospitalised_time, s = 100,  alpha=0.1)
sns.kdeplot(hospitalised_time,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total, s = 100,  alpha=0.1)
sns.kdeplot(total,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total_in, s = 100,  alpha=0.1)
sns.kdeplot(total_in,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total_out, s = 100,  alpha=0.1)
sns.kdeplot(total_out,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, crp_nm, s = 100,  alpha=0.1)
sns.kdeplot(crp_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.xlim(0, 30)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, gcsv_nm, s = 100,  alpha=0.1)
sns.kdeplot(gcsv_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, ldl_nm, s = 100,  alpha=0.1)
sns.kdeplot(ldl_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %% [markdown]
# ## 2 classes

# %%
mrs_tx_1[(mrs_tx_1 == 0)|(mrs_tx_1 == 1)|(mrs_tx_1 == 2)] = 0
mrs_tx_1[(mrs_tx_1 == 3)|(mrs_tx_1 == 4)|(mrs_tx_1 == 5)] = 1
# Out:
# <ipython-input-22-34e998b99dcc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs_tx_1[(mrs_tx_1 == 0)|(mrs_tx_1 == 1)|(mrs_tx_1 == 2)] = 0
# <ipython-input-22-34e998b99dcc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs_tx_1[(mrs_tx_1 == 3)|(mrs_tx_1 == 4)|(mrs_tx_1 == 5)] = 1

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, hospitalised_time, s = 100,  alpha=0.1)
sns.kdeplot(hospitalised_time,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total, s = 100,  alpha=0.1)
sns.kdeplot(total,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total_in, s = 100,  alpha=0.1)
sns.kdeplot(total_in,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, total_out, s = 100,  alpha=0.1)
sns.kdeplot(total_out,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, crp_nm, s = 100,  alpha=0.1)
sns.kdeplot(crp_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.xlim(0, 30)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, gcsv_nm, s = 100,  alpha=0.1)
sns.kdeplot(gcsv_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_1, ldl_nm, s = 100,  alpha=0.1)
sns.kdeplot(ldl_nm,hue = mrs_tx_1,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()
