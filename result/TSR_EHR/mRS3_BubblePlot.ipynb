# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = os.path.join("..", "..", "data","LINKED_DATA", "TSR_EHR", "TSR_3_CLEANED.csv")
tsr_3 = pd.read_csv(csv_path)
tsr_3.head()
# Out:
#    height_nm  weight_nm  edu_id  pro_id  opc_id  ih_fl  ivtpamg_nm  \
# 0      153.0       62.0       3       1       3      0         0.0
# 1      152.0       62.0       3       1       2      0         0.0
# 2      148.0       56.0       2     999       2      0         0.0
# 3      152.0       56.0       4       1       2      0         0.0
# 4      160.0       60.0       2       1       3      0         0.0
#
#    hospitalised_time  nivtpa_id  nivtpa1_fl  ...  nihs_7_out  nihs_8_out  \
# 0                8.0          0         999  ...           1           1
# 1                4.0          0         999  ...           0           1
# 2                5.0          0         999  ...           0           1
# 3                3.0          1           0  ...           0           0
# 4                4.0          0         999  ...           0           0
#
#    nihs_9_out  nihs_10_out  nihs_11_out  total_out  SexName   Age  mrs_tx_1  \
# ...

# %%
mrs_tx_1 = tsr_3.mrs_tx_1
mrs_tx_3 = tsr_3.mrs_tx_3
total = tsr_3.total
total_in = tsr_3.total_in
total_out = tsr_3.total_out
crp_nm = tsr_3.crp_nm
gcsv_nm = tsr_3.gcsv_nm
ldl_nm = tsr_3.ldl_nm
hospitalised_time = tsr_3.hospitalised_time

# %% [markdown]
# # mRS VERSUS suspected features

# %% [markdown]
# ## 6 Outcomes

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, hospitalised_time, s = 100,  alpha=0.1)
sns.kdeplot(hospitalised_time,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total, s = 100,  alpha=0.1)
sns.kdeplot(total,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total_in, s = 100,  alpha=0.1)
sns.kdeplot(total_in,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total_out, s = 100,  alpha=0.1)
sns.kdeplot(total_out,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, crp_nm, s = 100,  alpha=0.1)
sns.kdeplot(crp_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.xlim(0, 30)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, gcsv_nm, s = 100,  alpha=0.1)
sns.kdeplot(gcsv_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, ldl_nm, s = 100,  alpha=0.1)
sns.kdeplot(ldl_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, mrs_tx_1, s = 100,  alpha=0.1)
sns.kdeplot(mrs_tx_1,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %% [markdown]
# ## 2 classes

# %%
mrs_tx_3[(mrs_tx_3 == 0)|(mrs_tx_3 == 1)|(mrs_tx_3 == 2)] = 0
mrs_tx_3[(mrs_tx_3 == 3)|(mrs_tx_3 == 4)|(mrs_tx_3 == 5)] = 1
# Out:
# <ipython-input-12-c4b42fe29116>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs_tx_3[(mrs_tx_3 == 0)|(mrs_tx_3 == 1)|(mrs_tx_3 == 2)] = 0
# <ipython-input-12-c4b42fe29116>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs_tx_3[(mrs_tx_3 == 3)|(mrs_tx_3 == 4)|(mrs_tx_3 == 5)] = 1

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, hospitalised_time, s = 100,  alpha=0.1)
sns.kdeplot(hospitalised_time,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total, s = 100,  alpha=0.1)
sns.kdeplot(total,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total_in, s = 100,  alpha=0.1)
sns.kdeplot(total_in,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, total_out, s = 100,  alpha=0.1)
sns.kdeplot(total_out,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, crp_nm, s = 100,  alpha=0.1)
sns.kdeplot(crp_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.xlim(0, 30)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, gcsv_nm, s = 100,  alpha=0.1)
sns.kdeplot(gcsv_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, ldl_nm, s = 100,  alpha=0.1)
sns.kdeplot(ldl_nm,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
ax1.scatter(mrs_tx_3, mrs_tx_1, s = 100,  alpha=0.1)
sns.kdeplot(mrs_tx_1,hue = mrs_tx_3,vertical=False, fill=True, alpha = 0.3, palette="crest", linewidth=1)
plt.show()
