# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ET_G_AUC_plot = [["1 month","ALL", 0.743],
                 ["1 month", "TOP10", 0.71],
                 ["1 month", "TOP20", 0.718],
                 ["1 month", "TOP30", 0.71],
                 ["1 month", "Intersection", 0.681],
                 ["3 month", "ALL", 0.726],
                 ["3 month", "TOP10", 0.716],
                 ["3 month", "TOP20", 0.73],
                 ["3 month", "TOP30", 0.719],
                 ["3 month", "Intersection", 0.732],
                 ["3+1 month", "ALL", 0.845],
                 ["3+1 month", "TOP10", 0.833],
                 ["3+1 month", "TOP20", 0.839],
                 ["3+1 month", "TOP30", 0.837],
                 ["3+1 month", "Intersection", 0.844]]

ET_G_AUC_plot = pd.DataFrame(ET_G_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=ET_G_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of ET_GOOD')

#plt.savefig('INFO/Comparison_AUC_of_ET_G.png')
plt.show()

# %%
XGBC_G_AUC_plot = [["1 month","ALL", 0.751],
                 ["1 month", "TOP10", 0.688],
                 ["1 month", "TOP20", 0.704],
                 ["1 month", "TOP30", 0.707],
                 ["1 month", "Intersection", 0.697],
                 ["3 month", "ALL", 0.74],
                 ["3 month", "TOP10", 0.72],
                 ["3 month", "TOP20", 0.733],
                 ["3 month", "TOP30", 0.735],
                 ["3 month", "Intersection", 0.735],
                 ["3+1 month", "ALL", 0.845],
                 ["3+1 month", "TOP10", 0.807],
                 ["3+1 month", "TOP20", 0.841],
                 ["3+1 month", "TOP30", 0.848],
                 ["3+1 month", "Intersection", 0.844]]

XGBC_G_AUC_plot = pd.DataFrame(XGBC_G_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=XGBC_G_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of XGBC_GOOD')
#plt.savefig('INFO/Comparison_AUC_of_XGBC_G.png')
plt.show()

# %%
ET_B_AUC_plot = [["1 month","ALL", 0.857],
                 ["1 month", "TOP10", 0.834],
                 ["1 month", "TOP20", 0.851],
                 ["1 month", "TOP30", 0.855],
                 ["1 month", "Intersection", 0.855],
                 ["3 month", "ALL", 0.862],
                 ["3 month", "TOP10", 0.842],
                 ["3 month", "TOP20", 0.86],
                 ["3 month", "TOP30", 0.86],
                 ["3 month", "Intersection", 0.859],
                 ["3+1 month", "ALL", 0.926],
                 ["3+1 month", "TOP10", 0.921],
                 ["3+1 month", "TOP20", 0.924],
                 ["3+1 month", "TOP30", 0.924],
                 ["3+1 month", "Intersection", 0.922]]

ET_B_AUC_plot = pd.DataFrame(ET_B_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=ET_B_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of ET_BAD')
#plt.savefig('INFO/Comparison_AUC_of_ET_B.png')
plt.show()

# %%
XGBC_B_AUC_plot = [["1 month","ALL", 0.859],
                 ["1 month", "TOP10", 0.844],
                 ["1 month", "TOP20", 0.855],
                 ["1 month", "TOP30", 0.855],
                 ["1 month", "Intersection", 0.854],
                 ["3 month", "ALL", 0.868],
                 ["3 month", "TOP10", 0.849],
                 ["3 month", "TOP20", 0.86],
                 ["3 month", "TOP30", 0.864],
                 ["3 month", "Intersection", 0.862],
                 ["3+1 month", "ALL", 0.927],
                 ["3+1 month", "TOP10", 0.918],
                 ["3+1 month", "TOP20", 0.923],
                 ["3+1 month", "TOP30", 0.923],
                 ["3+1 month", "Intersection", 0.922]]

XGBC_B_AUC_plot = pd.DataFrame(XGBC_B_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=XGBC_B_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of XGBC_BAD')
#plt.savefig('INFO/Comparison_AUC_of_XGBC_B.png')
plt.show()
