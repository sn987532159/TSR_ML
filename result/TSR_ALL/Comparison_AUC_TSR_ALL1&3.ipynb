# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ET_G_AUC_plot = [["1 month","ALL", 0.740],
                 ["1 month", "TOP10", 0.705],
                 ["1 month", "TOP20", 0.725],
                 ["1 month", "TOP30", 0.727],
                 ["1 month", "Intersection", 0.692],
                 ["3 month", "ALL", 0.736],
                 ["3 month", "TOP10", 0.721],
                 ["3 month", "TOP20", 0.738],
                 ["3 month", "TOP30", 0.730],
                 ["3 month", "Intersection", 0.719],
                 ["3+1 month", "ALL", 0.840],
                 ["3+1 month", "TOP10", 0.838],
                 ["3+1 month", "TOP20", 0.846],
                 ["3+1 month", "TOP30", 0.848],
                 ["3+1 month", "Intersection", 0.840]]

ET_G_AUC_plot = pd.DataFrame(ET_G_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=ET_G_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of ET_GOOD')
#plt.savefig('PLOT/Comparison_AUC_of_ET_G.png')
plt.show()

# %%
XGBC_G_AUC_plot = [["1 month","ALL", 0.744],
                 ["1 month", "TOP10", 0.720],
                 ["1 month", "TOP20", 0.720],
                 ["1 month", "TOP30", 0.718],
                 ["1 month", "Intersection", 0.709],
                 ["3 month", "ALL", 0.746],
                 ["3 month", "TOP10", 0.717],
                 ["3 month", "TOP20", 0.722],
                 ["3 month", "TOP30", 0.729],
                 ["3 month", "Intersection", 0.719],
                 ["3+1 month", "ALL", 0.849],
                 ["3+1 month", "TOP10", 0.843],
                 ["3+1 month", "TOP20", 0.840],
                 ["3+1 month", "TOP30", 0.847],
                 ["3+1 month", "Intersection", 0.840]]

XGBC_G_AUC_plot = pd.DataFrame(XGBC_G_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=XGBC_G_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of XGBC_GOOD')
#plt.savefig('PLOT/Comparison_AUC_of_XGBC_G.png')
plt.show()

# %%
ET_B_AUC_plot = [["1 month","ALL", 0.857],
                 ["1 month", "TOP10", 0.830],
                 ["1 month", "TOP20", 0.854],
                 ["1 month", "TOP30", 0.857],
                 ["1 month", "Intersection", 0.855],
                 ["3 month", "ALL", 0.863],
                 ["3 month", "TOP10", 0.845],
                 ["3 month", "TOP20", 0.861],
                 ["3 month", "TOP30", 0.864],
                 ["3 month", "Intersection", 0.862],
                 ["3+1 month", "ALL", 0.926],
                 ["3+1 month", "TOP10", 0.917],
                 ["3+1 month", "TOP20", 0.924],
                 ["3+1 month", "TOP30", 0.924],
                 ["3+1 month", "Intersection", 0.921]]

ET_B_AUC_plot = pd.DataFrame(ET_B_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=ET_B_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of ET_BAD')
#plt.savefig('PLOT/Comparison_AUC_of_ET_B.png')
plt.show()

# %%
XGBC_B_AUC_plot = [["1 month","ALL", 0.858],
                 ["1 month", "TOP10", 0.835],
                 ["1 month", "TOP20", 0.851],
                 ["1 month", "TOP30", 0.855],
                 ["1 month", "Intersection", 0.853],
                 ["3 month", "ALL", 0.868],
                 ["3 month", "TOP10", 0.846],
                 ["3 month", "TOP20", 0.856],
                 ["3 month", "TOP30", 0.866],
                 ["3 month", "Intersection", 0.864],
                 ["3+1 month", "ALL", 0.928],
                 ["3+1 month", "TOP10", 0.920],
                 ["3+1 month", "TOP20", 0.922],
                 ["3+1 month", "TOP30", 0.922],
                 ["3+1 month", "Intersection", 0.920]]

XGBC_B_AUC_plot = pd.DataFrame(XGBC_B_AUC_plot, columns=["month", "n_feature", "AUC"])

sns.barplot(x='month', y='AUC', hue='n_feature', data=XGBC_B_AUC_plot)
plt.legend(title = "Number of Feature", bbox_to_anchor=(1, 1))
plt.ylim(0.65)
plt.title('Comparison AUC of XGBC_BAD')
#plt.savefig('PLOT/Comparison_AUC_of_XGBC_B.png')
plt.show()
