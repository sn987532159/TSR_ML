# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = os.path.join("INFO","TSR_ALL_sigma.csv")

# %%
etG1_sigma = pd.read_csv(csv_path)[["etG1_index","etG1_value"]]
etG1_sigma = etG1_sigma.set_index("etG1_index")
etG1_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etG1_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL1_ET_G Feature Importance')
#plt.savefig('INFO/TSR_ALL1/etG1_sigma.png')
plt.show()

# %%
xgbcG1_sigma = pd.read_csv(csv_path)[["xgbcG1_index","xgbcG1_value"]]
xgbcG1_sigma = xgbcG1_sigma.set_index("xgbcG1_index")
xgbcG1_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(xgbcG1_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL1_XGBC_G Feature Importance')
#plt.savefig('INFO/TSR_ALL1/xgbcG1_sigma.png')
plt.show()

# %%
etB1_sigma = pd.read_csv(csv_path)[["etB1_index","etB1_value"]]
etB1_sigma = etB1_sigma.set_index("etB1_index")
etB1_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etB1_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL1_ET_B Feature Importance')
#plt.savefig('INFO/TSR_ALL1/etB1_sigma.png')
plt.show()

# %%
xgbcB1_sigma = pd.read_csv(csv_path)[["xgbcB1_index","xgbcB1_value"]]
xgbcB1_sigma = xgbcB1_sigma.set_index("xgbcB1_index")
xgbcB1_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(xgbcB1_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL1_XGBC_B Feature Importance')
#plt.savefig('INFO/TSR_ALL1/xgbcB1_sigma.png')
plt.show()

# %%
etG3_sigma = pd.read_csv(csv_path)[["etG3_index","etG3_value"]]
etG3_sigma = etG3_sigma.set_index("etG3_index")
etG3_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etG3_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3_ET_G Feature Importance')
#plt.savefig('INFO/TSR_ALL3/etG3_sigma.png')
plt.show()

# %%
xgbcG3_sigma = pd.read_csv(csv_path)[["xgbcG3_index","xgbcG3_value"]]
xgbcG3_sigma = xgbcG3_sigma.set_index("xgbcG3_index")
xgbcG3_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(xgbcG3_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3_XGBC_G Feature Importance')
#plt.savefig('INFO/TSR_ALL3/xgbcG3_sigma.png')
plt.show()

# %%
etB3_sigma = pd.read_csv(csv_path)[["etB3_index","etB3_value"]]
etB3_sigma = etB3_sigma.set_index("etB3_index")
etB3_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etB3_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3_ET_B Feature Importance')
#plt.savefig('INFO/TSR_ALL3/etB3_sigma.png')
plt.show()

# %%
xgbcB3_sigma = pd.read_csv(csv_path)[["xgbcB3_index","xgbcB3_value"]]
xgbcB3_sigma = xgbcB3_sigma.set_index("xgbcB3_index")
xgbcB3_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(xgbcB3_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3_XGBC_B Feature Importance')
#plt.savefig('INFO/TSR_ALL3/xgbcB3_sigma.png')
plt.show()

# %%
etG31_sigma = pd.read_csv(csv_path)[["etG31_index","etG31_value"]]
etG31_sigma = etG31_sigma.set_index("etG31_index")
etG31_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etG31_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3+1_ET_G Feature Importance')
#plt.savefig('INFO/TSR_ALL3/etG31_sigma.png')
plt.show()

# %%
xgbcG31_sigma = pd.read_csv(csv_path)[["xgbcG31_index","xgbcG31_value"]]
xgbcG31_sigma = xgbcG31_sigma.set_index("xgbcG31_index")
xgbcG31_sigma.index.name = ""
xgbcG31_sigma.index[12] == "Stroke-in-evolution(▵NIHSS≥2)"

plt.figure(figsize=(5, 10))
sns.heatmap(xgbcG31_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3+1_XGBC_G Feature Importance')
#plt.savefig('INFO/TSR_ALL3/xgbcG31_sigma.png')
plt.show()

# %%
etB31_sigma = pd.read_csv(csv_path)[["etB31_index","etB31_value"]]
etB31_sigma = etB31_sigma.set_index("etB31_index")
etB31_sigma.index.name = ""

plt.figure(figsize=(5, 10))
sns.heatmap(etB31_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3+1_ET_B Feature Importance')
#plt.savefig('INFO/TSR_ALL3/etB31_sigma.png')
plt.show()

# %%
xgbcB31_sigma = pd.read_csv(csv_path)[["xgbcB31_index","xgbcB31_value"]]
xgbcB31_sigma = xgbcB31_sigma.set_index("xgbcB31_index")
xgbcB31_sigma.index.name = ""


plt.figure(figsize=(5, 10))
sns.heatmap(xgbcB31_sigma, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Threshold of TSR_ALL3+1_XGBC_B Feature Importance')
#plt.savefig('INFO/TSR_ALL3/xgbcB31_sigma.png')
plt.show()

# %%
G1 = set(etG1_sigma.index) & set(xgbcG1_sigma.index)
B1 = set(etB1_sigma.index) & set(xgbcB1_sigma.index)
G3 = set(etG3_sigma.index) & set(xgbcG3_sigma.index)
B3 = set(etB3_sigma.index) & set(xgbcB3_sigma.index)
G31 = set(etG31_sigma.index) & set(xgbcG31_sigma.index)
B31 = set(etB31_sigma.index) & set(xgbcB31_sigma.index)

# %%
threshold_and = pd.DataFrame([G1, B1, G3, B3, G31, B31]).T
threshold_and.index = threshold_and.index+1
threshold_and[threshold_and.isnull()] = ""
threshold_and.columns = ["G1", "B1", "G3", "B3", "G31", "B31"]

csv_save = os.path.join("INFO", "Threshold_Intersection.csv")
threshold_and.to_csv(csv_save, index=True)
